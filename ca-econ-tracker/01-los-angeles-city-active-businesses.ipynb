# %% [markdown]
# # Los Angeles active businesses

# %% [markdown]
# ### Load python tools

# %%
import pandas as pd
from urllib.request import urlopen 
import os
import glob
import requests
import matplotlib
import numpy as np
from altair import datum
import altair as alt
import altair_latimes as lat
from sodapy import Socrata
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
pd.options.display.max_columns = 50
pd.options.display.max_rows = 34000

# %% [markdown]
# ### Read L.A. city database of active businesses

# %%
#https://dev.socrata.com/foundry/data.lacity.org/r4uk-afju

# %%
token = '2bOhwWJ7cVA7veVVCeHbFyWif'
username="matt.stiles@latimes.com"
password="datadesk!1"

client = Socrata('data.lacity.org', token, username, password)
results = client.get("6rrh-rzua", limit=2000000)
biz = pd.DataFrame.from_records(results)

# %%
biz.columns = biz.columns.str.strip().str.lower().str.replace(' ', '_')\
    .str.replace('(', '').str.replace(')', '').str.replace('-','_').str.replace('_&_','_')

# %%
biz.head()
# Out:
#     location_account                                  business_name  \
# 0  0000000108-0001-3                 PALACE OF VENICE GUEST HOME /C
# 1  0000000115-0001-3                               VINCENZO LABELLA
# 2  0000000121-0001-9       WILCARE ECONOMIC DEVELOPMENT CORPORATION
# 3  0000000132-0001-7                                   CARLOS ANGEL
# 4  0000000133-0001-1  A A OFICINA CENTRAL HISPANA DE LOS ANGELES /C
#
#                    street_address               city    zip_code  \
# 0              1727 CRENSHAW BLVD        LOS ANGELES  90019-6037
# 1           521 SWARTHMORE AVENUE  PACIFIC PALISADES  90272-4350
# 2                9911 AVALON BLVD        LOS ANGELES  90003-4805
# 3  1221 W 7TH STREET SUITE #N-407        LOS ANGELES  90017-2689
# 4                 4917 S BROADWAY        LOS ANGELES  90037-3211
#
#         location_description   naics  \
# 0   1727 CRENSHAW 90019-6037  721310
# 1  521 SWARTHMORE 90272-4350  561500
# 2     9911 AVALON 90003-4805  721310
# ...

# %%
biz['location_end_date'] = pd.to_datetime(biz['location_end_date'], errors='coerce')
biz['location_start_date'] = pd.to_datetime(biz['location_start_date'], errors='coerce')

# %%
biz['end_month'] = biz['location_end_date'].dt.month.astype(str)
biz['end_year'] = biz['location_end_date'].dt.year.astype(str)

# %%
biz.sort_values(by='location_end_date', ascending=False).head(10)

# %%
biz.groupby(['location_end_date']).agg('size').reset_index(name='closures')
# Out:
#       location_end_date  closures
# 0            1943-02-01         1
# 1            1958-01-01         1
# 2            1969-12-31         1
# 3            1970-09-15         1
# 4            1970-12-31         1
# 5            1972-12-22         1
# 6            1972-12-30         1
# 7            1973-12-31         1
# 8            1974-02-13         1
# 9            1975-01-01         1
# 10           1975-01-23         1
# 11           1975-09-30         1
# 12           1975-12-30         1
# 13           1976-01-09         1
# 14           1976-01-23         1
# 15           1976-02-06         1
# 16           1976-03-08         1
# 17           1976-04-15         1
# 18           1976-06-21         1
# 19           1976-07-12         1
# 20           1976-07-18         1
# 21           1976-12-31         2
# 22           1977-03-30         1
# 23           1977-04-01         1
# 24           1977-05-08         1
# 25           1977-05-31         1
# ...
