# %% [markdown]
# # NFL scoring plays
# > This notebook fetches all scroring plays from the ESPN API from 1999 to the most-recent season. Other API endpoints detailed in [this gist](https://gist.github.com/nntrn/ee26cb2a0716de0947a0a4e9a157bc1c).

# %% [markdown]
# ---

# %% [markdown]
# #### Import Python tools and Jupyter config

# %%
import json
import time
import requests
import datetime
import pandas as pd
import jupyter_black
from tqdm.notebook import tqdm

# %%
jupyter_black.load()
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = None

# %%
FIRST_SEASON = 2004
MOST_RECENT_SEASON = 2024

# %% [markdown]
# ---

# %%
df_scoring = pd.read_json("data/processed/nfl_scoring_2004-2024.json")

# %%
df_scoring.head()
# Out:
#      game_id             home_team           away_team          scoring_team  \
# 0  240909017  New England Patriots  Indianapolis Colts  New England Patriots
# 1  240909017  New England Patriots  Indianapolis Colts  New England Patriots
# 2  240909017  New England Patriots  Indianapolis Colts  New England Patriots
# 3  240909017  New England Patriots  Indianapolis Colts  New England Patriots
# 4  240909017  New England Patriots  Indianapolis Colts  New England Patriots
#
#   home_away  quarter  clock               type  \
# 0      home        1  14:51    Pass Completion
# 1      home        1  14:21    Pass Completion
# 2      home        1  13:36  Pass Incompletion
# 3      home        1  13:23    Pass Completion
# 4      home        1  12:54    Pass Completion
#
#                                                                            description  \
# 0  Tom Brady (NWE) pass across the middle complete to David Givens (NWE) for 19 yards.
# 1  Tom Brady (NWE) pass across the middle complete to Deion Branch (NWE) for 14 yards.
# 2                                    Tom Brady (NWE) pass incomplete to the left side.
# 3            Tom Brady (NWE) pass right side complete to Ben Watson (NWE) for 2 yards.
# 4           Tom Brady (NWE) pass right side complete to Ben Watson (NWE) for 14 yards.
#
#    score_home  score_away yard_line          game_date  season  week
# 0           0           0     NE 37  2004-09-10T01:00Z    2004     1
# 1           0           0    IND 44  2004-09-10T01:00Z    2004     1
# 2           0           0    IND 30  2004-09-10T01:00Z    2004     1
# 3           0           0    IND 30  2004-09-10T01:00Z    2004     1
# 4           0           0    IND 28  2004-09-10T01:00Z    2004     1

# %%
# 1) make sure your date is datetime
df_scoring["game_date"] = pd.to_datetime(df_scoring["game_date"])

# %%
# 2) Q4 share by season: what fraction of scoring plays happen in Q4?
q4_share = (
    df_scoring["quarter"].eq(4).groupby(df_scoring["season"]).mean().rename("q4_share")
)

# %%
# 3) Field‑goal share by season: fraction of scoring plays that are FGs
fg_share = (
    df_scoring["type"]
    .str.contains("Field Goal", case=False)
    .groupby(df_scoring["season"])
    .mean()
    .rename("fg_share")
)

# %%
# 4) Build a game‑level table with final scores, pt diff, and home‑win flag
game_final = (
    df_scoring.groupby(["game_id", "season"])
    .agg(home_score=("score_home", "max"), away_score=("score_away", "max"))
    .assign(
        pt_diff=lambda d: (d.home_score - d.away_score).abs(),
        home_win=lambda d: d.home_score > d.away_score,
    )
    .reset_index()
)

# %%
# 5) Average point‑diff and home‑win pct by season
avg_diff = game_final.groupby("season")["pt_diff"].mean().rename("avg_pt_diff")
home_win_pct = game_final.groupby("season")["home_win"].mean().rename("home_win_pct")

# %%
# 6) Combine into one summary DataFrame
summary = pd.concat([q4_share, fg_share, avg_diff, home_win_pct], axis=1).reset_index()
summary
# Out:
#     season  q4_share  fg_share  avg_pt_diff  home_win_pct
# 0     2004  0.276992  0.000308    11.128906      0.558594
# 1     2005  0.274392  0.021932    11.666667      0.592157
# 2     2006  0.273746  0.021632    11.429688      0.535156
# 3     2007  0.278693  0.021937    12.371094      0.574219
# 4     2008  0.270713  0.023082    12.222656      0.570312
# 5     2009  0.271113  0.021113    12.957031      0.570312
# 6     2010  0.276600  0.022254    11.746094      0.558594
# 7     2011  0.276803  0.023145    12.023438      0.566406
# 8     2012  0.273967  0.022579    12.152344      0.570312
# 9     2013  0.274008  0.021958    11.292969      0.597656
# 10    2014  0.273037  0.022534    12.650980      0.564706
# 11    2015  0.277886  0.022431    11.058594      0.535156
# 12    2016  0.278899  0.023156    10.171875      0.574219
# 13    2017  0.275201  0.023794    11.789062      0.570312
# 14    2018  0.274845  0.022113    11.019531      0.597656
# 15    2019  0.276824  0.022682    11.566406      0.511719
# 16    2020  0.277583  0.022172    11.066406      0.496094
# 17    2021  0.278722  0.022776    12.176471      0.514706
# 18    2022  0.279994  0.023698     9.715867      0.557196
# 19    2023  0.272799  0.021904    11.264706      0.558824
# 20    2024  0.273865  0.022817    11.198529      0.533088
