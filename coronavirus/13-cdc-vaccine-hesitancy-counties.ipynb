# %% [markdown]
# # Vaccine Hesitancy for COVID-19: County and local estimates

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd
import altair as alt
import altair_latimes as lat
import glob
import os

# %%
alt.themes.register("latimes", lat.theme)
alt.themes.enable("latimes")
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ### Get the data from the CDC portal

# %%
# https://data.cdc.gov/Vaccinations/Vaccine-Hesitancy-for-COVID-19-County-and-local-es/q9mh-h2tw

# %%
url = "https://data.cdc.gov/api/views/q9mh-h2tw/rows.csv?accessType=DOWNLOAD"

# %%
df = pd.read_csv(url)

# %% [markdown]
# ### Clean up the headers

# %%
df.columns = (
    df.columns.str.strip()
    .str.lower()
    .str.replace(" ", "_", regex=False)
    .str.replace(":", "", regex=False)
    .str.replace("/", "_", regex=False)
    .str.replace(",", "_", regex=False)
)

# %%
df.drop(
    ["county_boundary", "state_boundary", "geographical_point"], axis=1, inplace=True
)

# %%
df["fips_code"] = df["fips_code"].astype(str).str.zfill(5)

# %%
df.head()
# Out:
#   fips_code                 county_name    state  estimated_hesitant  \
# 0     01123  Tallapoosa County, Alabama  ALABAMA                0.23
# 1     01121   Talladega County, Alabama  ALABAMA                0.23
# 2     01131      Wilcox County, Alabama  ALABAMA                0.23
# 3     01129  Washington County, Alabama  ALABAMA                0.23
# 4     01133     Winston County, Alabama  ALABAMA                0.22
#
#    estimated_strongly_hesitant  social_vulnerability_index_(svi)  \
# 0                         0.12                              0.89
# 1                         0.11                              0.87
# 2                         0.11                              0.93
# 3                         0.11                              0.73
# 4                         0.11                              0.70
#
#               svi_category  ability_to_handle_a_covid-19_outbreak_(cvac)  \
# 0  Very High Vulnerability                                          0.64
# 1  Very High Vulnerability                                          0.84
# 2  Very High Vulnerability                                          0.94
# 3       High Vulnerability                                          0.82
# 4       High Vulnerability                                          0.80
#
#              cvac_category  percent_adults_fully_vaccinated_against_covid-19  \
# 0       High Vulnerability                                             0.161
# 1  Very High Vulnerability                                             0.133
# 2  Very High Vulnerability                                             0.228
# 3  Very High Vulnerability                                             0.192
# 4       High Vulnerability                                             0.085
#
#    percent_hispanic  percent_non-hispanic_american_indian_alaska_native  \
# 0            0.0242                                             0.0022
# 1            0.0229                                             0.0043
# 2            0.0053                                             0.0009
# 3            0.0146                                             0.0731
# 4            0.0315                                             0.0034
#
#    percent_non-hispanic_asian  percent_non-hispanic_black  \
# 0                      0.0036                      0.2697
# 1                      0.0061                      0.3237
# 2                      0.0003                      0.6938
# 3                      0.0025                      0.2354
# 4                      0.0016                      0.0073
#
#    percent_non-hispanic_native_hawaiian_pacific_islander  \
# 0                                             0.0000
# 1                                             0.0003
# 2                                             0.0000
# 3                                             0.0000
# 4                                             0.0005
#
#    percent_non-hispanic_white state_code
# 0                      0.6887         AL
# 1                      0.6263         AL
# 2                      0.2684         AL
# 3                      0.6495         AL
# 4                      0.9370         AL

# %% [markdown]
# ### Merge with election results

# %%
df_election = pd.read_json(
    "../elections/data/election_results_2020.json", dtype={"county_fips": str}
)

# %%
df_election.head()
# Out:
#   state_name county_fips     county_name  votes_gop  votes_dem  total_votes  \
# 0    Alabama       01001  Autauga County      19838       7503        27770
# 1    Alabama       01003  Baldwin County      83544      24578       109679
# 2    Alabama       01005  Barbour County       5622       4816        10518
# 3    Alabama       01007     Bibb County       7525       1986         9595
# 4    Alabama       01009   Blount County      24711       2640        27588
#
#     diff   per_gop   per_dem  per_point_diff winner
# 0  12335  0.714368  0.270184        0.444184  Trump
# 1  58966  0.761714  0.224090        0.537623  Trump
# 2    806  0.534512  0.457882        0.076631  Trump
# 3   5539  0.784263  0.206983        0.577280  Trump
# 4  22071  0.895716  0.095694        0.800022  Trump

# %%
merge = pd.merge(
    df,
    df_election,
    left_on="fips_code",
    right_on="county_fips",
    how="left",
).drop(["county_name_y"], axis=1)

# %%
merge.dtypes
# Out:
# fips_code                                                 object
# county_name_x                                             object
# state                                                     object
# estimated_hesitant                                       float64
# estimated_strongly_hesitant                              float64
# social_vulnerability_index_(svi)                         float64
# svi_category                                              object
# ability_to_handle_a_covid-19_outbreak_(cvac)             float64
# cvac_category                                             object
# percent_adults_fully_vaccinated_against_covid-19         float64
# percent_hispanic                                         float64
# percent_non-hispanic_american_indian_alaska_native       float64
# percent_non-hispanic_asian                               float64
# percent_non-hispanic_black                               float64
# percent_non-hispanic_native_hawaiian_pacific_islander    float64
# percent_non-hispanic_white                               float64
# state_code                                                object
# state_name                                                object
# county_fips                                               object
# votes_gop                                                float64
# votes_dem                                                float64
# total_votes                                              float64
# diff                                                     float64
# per_gop                                                  float64
# per_dem                                                  float64
# per_point_diff                                           float64
# winner                                                    object
# dtype: object

# %%
merge.rename(columns={"county_name_x": "county_name"}, inplace=True)

# %%
merge_corr = merge[
    ["fips_code", "county_name", "estimated_hesitant", "per_gop", "winner"]
]

# %%
merge_corr[merge_corr.winner == "Trump"].corr(method="pearson")
# Out:
#                     estimated_hesitant   per_gop
# estimated_hesitant            1.000000  0.252561
# per_gop                       0.252561  1.000000

# %%
alt.Chart(merge).mark_circle(size=40).encode(
    x=alt.X("per_gop", title="% Trump", axis=alt.Axis(tickCount=4, format=("%"))),
    y=alt.Y(
        "estimated_hesitant",
        title="% hesitant",
        axis=alt.Axis(tickCount=4, format=("%")),
    ),
    color=alt.Color(
        "winner", scale=alt.Scale(domain=["Trump", "Biden"], range=["red", "blue"])
    ),
).properties(
    width=800, height=500, title="Relationship between Trump vote and vaccine hesitancy"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Just California

# %%
ca_merge = merge[merge["state"] == "CALIFORNIA"].sort_values(
    "estimated_strongly_hesitant", ascending=False
)

# %%
alt.Chart(ca_merge).mark_circle(size=50).encode(
    x=alt.X("per_gop", title="% Trump", axis=alt.Axis(tickCount=6, format=("%"))),
    y=alt.Y(
        "estimated_hesitant",
        title="% hesitant",
        axis=alt.Axis(tickCount=4, format=("%")),
    ),
    color=alt.Color(
        "winner", scale=alt.Scale(domain=["Trump", "Biden"], range=["red", "blue"])
    ),
    size=alt.Size("total_votes"),
).properties(
    width=800, height=500, title="Relationship between Trump vote and vaccine hesitancy"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Least hesitant in CA

# %%
ca_merge.sort_values("estimated_hesitant", ascending=True).head()
# Out:
#     fips_code                       county_name       state  \
# 422     06075  San Francisco County, California  CALIFORNIA
# 410     06041          Marin County, California  CALIFORNIA
# 442     06081      San Mateo County, California  CALIFORNIA
# 524     06085    Santa Clara County, California  CALIFORNIA
# 500     06013   Contra Costa County, California  CALIFORNIA
#
#      estimated_hesitant  estimated_strongly_hesitant  \
# 422                0.07                         0.03
# 410                0.08                         0.03
# 442                0.08                         0.03
# 524                0.08                         0.03
# 500                0.09                         0.04
#
#      social_vulnerability_index_(svi)            svi_category  \
# 422                              0.39       Low Vulnerability
# 410                              0.27       Low Vulnerability
# 442                              0.26       Low Vulnerability
# 524                              0.36       Low Vulnerability
# 500                              0.41  Moderate Vulnerability
#
#      ability_to_handle_a_covid-19_outbreak_(cvac)           cvac_category  \
# 422                                          0.52  Moderate Vulnerability
# 410                                          0.31       Low Vulnerability
# 442                                          0.40  Moderate Vulnerability
# 524                                          0.42  Moderate Vulnerability
# 500                                          0.47  Moderate Vulnerability
#
#      percent_adults_fully_vaccinated_against_covid-19  percent_hispanic  \
# 422                                             0.237            0.1524
# 410                                             0.333            0.1598
# 442                                             0.264            0.2440
# 524                                             0.216            0.2547
# 500                                             0.261            0.2559
#
#      percent_non-hispanic_american_indian_alaska_native  \
# 422                                             0.0019
# 410                                             0.0017
# 442                                             0.0015
# 524                                             0.0017
# 500                                             0.0020
#
#      percent_non-hispanic_asian  percent_non-hispanic_black  \
# 422                      0.3407                      0.0500
# 410                      0.0581                      0.0213
# 442                      0.2831                      0.0218
# 524                      0.3628                      0.0235
# 500                      0.1648                      0.0840
#
#      percent_non-hispanic_native_hawaiian_pacific_islander  \
# 422                                             0.0034
# 410                                             0.0010
# 442                                             0.0132
# 524                                             0.0032
# 500                                             0.0046
#
#      percent_non-hispanic_white state_code  state_name county_fips  votes_gop  \
# 422                      0.4051         CA  California       06075    56417.0
# 410                      0.7115         CA  California       06041    24612.0
# 442                      0.3924         CA  California       06081    75563.0
# 524                      0.3154         CA  California       06085   214612.0
# 500                      0.4383         CA  California       06013   152877.0
#
#      votes_dem  total_votes      diff   per_gop   per_dem  per_point_diff  \
# 422   378156.0     443458.0 -321739.0  0.127221  0.852744        0.725523
# 410   128288.0     155801.0 -103676.0  0.157971  0.823409        0.665439
# 442   291410.0     374138.0 -215847.0  0.201966  0.778884        0.576918
# 524   617967.0     850522.0 -403355.0  0.252330  0.726574        0.474244
# 500   416386.0     581230.0 -263509.0  0.263023  0.716388        0.453364
#
#     winner
# 422  Biden
# 410  Biden
# 442  Biden
# 524  Biden
# 500  Biden

# %% [markdown]
# ### Most hesitant in CA?

# %%
ca_merge.sort_values("estimated_hesitant", ascending=True).tail()
# Out:
#     fips_code                  county_name       state  estimated_hesitant  \
# 529     06063    Plumas County, California  CALIFORNIA                0.15
# 416     06049     Modoc County, California  CALIFORNIA                0.15
# 534     06093  Siskiyou County, California  CALIFORNIA                0.15
# 465     06035    Lassen County, California  CALIFORNIA                0.15
# 403     06031     Kings County, California  CALIFORNIA                0.16
#
#      estimated_strongly_hesitant  social_vulnerability_index_(svi)  \
# 529                         0.06                              0.27
# 416                         0.06                              0.75
# 534                         0.06                              0.72
# 465                         0.06                              0.60
# 403                         0.06                              0.97
#
#                 svi_category  ability_to_handle_a_covid-19_outbreak_(cvac)  \
# 529        Low Vulnerability                                          0.54
# 416       High Vulnerability                                          0.78
# 534       High Vulnerability                                          0.68
# 465   Moderate Vulnerability                                          0.70
# 403  Very High Vulnerability                                          0.75
#
#               cvac_category  percent_adults_fully_vaccinated_against_covid-19  \
# 529  Moderate Vulnerability                                               NaN
# 416      High Vulnerability                                               NaN
# 534      High Vulnerability                                             0.215
# 465      High Vulnerability                                             0.131
# 403      High Vulnerability                                             0.108
#
#      percent_hispanic  percent_non-hispanic_american_indian_alaska_native  \
# 529            0.0895                                             0.0144
# 416            0.1449                                             0.0418
# 534            0.1258                                             0.0320
# 465            0.1896                                             0.0274
# 403            0.5449                                             0.0085
#
#      percent_non-hispanic_asian  percent_non-hispanic_black  \
# 529                      0.0114                      0.0076
# 416                      0.0111                      0.0153
# 534                      0.0160                      0.0157
# 465                      0.0139                      0.0848
# 403                      0.0369                      0.0583
#
#      percent_non-hispanic_native_hawaiian_pacific_islander  \
# 529                                             0.0046
# 416                                             0.0010
# 534                                             0.0029
# 465                                             0.0080
# 403                                             0.0016
#
#      percent_non-hispanic_white state_code  state_name county_fips  votes_gop  \
# 529                      0.8314         CA  California       06063     6445.0
# 416                      0.7769         CA  California       06049     3109.0
# 534                      0.7610         CA  California       06093    13290.0
# 465                      0.6543         CA  California       06035     8970.0
# 403                      0.3221         CA  California       06031    24072.0
#
#      votes_dem  total_votes    diff   per_gop   per_dem  per_point_diff winner
# 529     4561.0      11256.0  1884.0  0.572584  0.405206        0.167377  Trump
# 416     1150.0       4338.0  1959.0  0.716690  0.265099        0.451591  Trump
# 534     9593.0      23450.0  3697.0  0.566738  0.409083        0.157655  Trump
# 465     2799.0      11985.0  6171.0  0.748436  0.233542        0.514894  Trump
# 403    18699.0      43858.0  5373.0  0.548862  0.426353        0.122509  Trump

# %% [markdown]
# ---

# %%
counties = gpd.read_file("input/counties/usa_counties_clean_simplified.json")

# %%
counties.columns = (
    counties.columns.str.strip()
    .str.lower()
    .str.replace(" ", "_", regex=False)
    .str.replace(":", "", regex=False)
    .str.replace("/", "_", regex=False)
    .str.replace(",", "_", regex=False)
)

# %%
counties.head()
# Out:
#   statefp countyfp  countyns  geoid       name  shape_area  \
# 0      15      003  00365281  15003   Honolulu    0.138087
# 1      41      003  01155126  41003     Benton    0.198723
# 2      41      011  01135848  41011       Coos    0.471548
# 3      06      045  00277287  06045  Mendocino    0.935848
# 4      41      041  01135856  41041    Lincoln    0.294925
#
#                                             geometry
# 0  POLYGON ((-157.91418 21.63521, -157.98643 21.6...
# 1  POLYGON ((-123.14903 44.72022, -123.17499 44.7...
# 2  POLYGON ((-123.81155 42.78884, -123.81150 42.7...
# 3  POLYGON ((-123.54446 40.00192, -123.59440 40.0...
# 4  POLYGON ((-123.72466 45.04443, -123.74415 45.0...

# %%
merge_geo = counties.merge(merge, right_on="fips_code", left_on="geoid")

# %%
len(merge_geo)
# Out:
# 3142

# %%
merge_geo.plot()

# %%
merge_geo.to_file("output/vaccine_hesitancy_geo.geojson", driver="GeoJSON")

# %% [markdown]
# ---

# %% [markdown]
# ## Exports

# %%
ca_merge.sort_values("estimated_hesitant", ascending=True).head().to_csv(
    "output/hesitancy/seven_hesitant_hesitant.csv", index=False
)

# %%
ca_merge.sort_values("estimated_hesitant", ascending=True).tail(7).to_csv(
    "output/hesitancy/seven_most_hesitant.csv", index=False
)
