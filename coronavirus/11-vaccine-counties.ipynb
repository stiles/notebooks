# %% [markdown]
# # Coronavirus vaccine administration by county

# %% [markdown]
# ### Load Python tools

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd
import altair as alt

# %%
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ### Get the county-level data from CDC

# %%
# Pulled from here: https://covid.cdc.gov/covid-data-tracker/#county-view

# %%
url = "https://covid.cdc.gov/covid-data-tracker/COVIDData/getAjaxData?id=vaccination_county_condensed_data"

# %%
df_nested = pd.read_json(url)

# %% [markdown]
# ### Extract the nested data

# %%
df = pd.json_normalize(df_nested["vaccination_county_condensed_data"])

# %%
df.head()
# Out:
#          Date   FIPS StateName StateAbbr          County  \
# 0  2021-12-06  01001   Alabama       AL   Autauga County
# 1  2021-12-06  01003   Alabama       AL   Baldwin County
# 2  2021-12-06  01005   Alabama       AL   Barbour County
# 3  2021-12-06  01007   Alabama       AL      Bibb County
# 4  2021-12-06  01009   Alabama       AL    Blount County
#
#    Series_Complete_18Plus  Series_Complete_18PlusPop_Pct  \
# 0                 19595.0                           45.7
# 1                 98911.0                           56.3
# 2                  9670.0                           49.3
# 3                  6841.0                           38.4
# 4                 16061.0                           36.0
#
#    Series_Complete_65Plus  Series_Complete_65PlusPop_Pct  Series_Complete_Yes  \
# 0                  5872.0                           65.8              20864.0
# 1                 37266.0                           79.6             103802.0
# 2                  3375.0                           69.4              10129.0
# 3                  2226.0                           59.6               7183.0
# 4                  5637.0                           52.1              16777.0
#
#    Series_Complete_Pop_Pct  Completeness_pct  Census2019_12PlusPop  \
# 0                     37.3              92.7               47574.0
# 1                     46.5              92.7              192649.0
# 2                     41.0              92.7               21404.0
# 3                     32.1              92.7               19480.0
# 4                     29.0              92.7               49234.0
#
#    Series_Complete_12Plus  Series_Complete_12PlusPop_Pct  \
# 0                 20838.0                           43.8
# 1                103701.0                           53.8
# 2                 10124.0                           47.3
# 3                  7178.0                           36.8
# 4                 16775.0                           34.1
#
#    Administered_Dose1_Recip  Administered_Dose1_Recip_12Plus  \
# 0                   26087.0                          25843.0
# 1                  131573.0                         130741.0
# 2                   12438.0                          12392.0
# 3                    8796.0                           8771.0
# 4                   20273.0                          20198.0
#
#    Administered_Dose1_Recip_18Plus  Administered_Dose1_Recip_65Plus  \
# 0                          24261.0                           7034.0
# 1                         124402.0                          46064.0
# 2                          11808.0                           3902.0
# 3                           8364.0                           2500.0
# 4                          19292.0                           6489.0
#
#    Administered_Dose1_Pop_Pct  Administered_Dose1_Recip_12PlusPop_Pct  \
# 0                        46.7                                    54.3
# 1                        58.9                                    67.9
# 2                        50.4                                    57.9
# 3                        39.3                                    45.0
# 4                        35.1                                    41.0
#
#    Administered_Dose1_Recip_18PlusPop_Pct  \
# 0                                    56.5
# 1                                    70.8
# 2                                    60.2
# 3                                    46.9
# 4                                    43.3
#
#    Administered_Dose1_Recip_65PlusPop_Pct Series_Complete_Pop_Pct_SVI  \
# 0                                    78.8                           6
# 1                                    98.4                           3
# 2                                    80.3                          15
# 3                                    67.0                          10
# 4                                    60.0                           5
#
#   Series_Complete_12PlusPop_Pct_SVI Series_Complete_18PlusPop_Pct_SVI  \
# 0                                 7                                 7
# 1                                 4                                 4
# 2                                15                                15
# 3                                10                                10
# 4                                 6                                 6
#
#   Series_Complete_65PlusPop_Pct_SVI SVI_CTGY  \
# 0                                 7        B
# 1                                 4        A
# 2                                15        D
# 3                                11        C
# 4                                 7        B
#
#    series_complete_pop_pct_UR_Equity  series_complete_12PlusPop_pct_UR_Equity  \
# 0                                2.0                                      3.0
# 1                                3.0                                      4.0
# 2                                7.0                                      7.0
# 3                                2.0                                      2.0
# 4                                1.0                                      2.0
#
#    series_complete_18PlusPop_pct_UR_Equity  \
# 0                                      3.0
# 1                                      4.0
# 2                                      7.0
# 3                                      2.0
# 4                                      2.0
#
#    series_complete_65PlusPop_pct_UR_Equity metro_status
# 0                                      3.0        Metro
# 1                                      4.0        Metro
# 2                                      7.0    Non-metro
# 3                                      3.0        Metro
# 4                                      3.0        Metro

# %% [markdown]
# ### Clean up headers, dates and extra spaces around strings

# %%
df.columns = df.columns.str.lower()

# %%
df_obj = df.select_dtypes(["object"])
df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

# %%
df["date"] = pd.to_datetime(df["date"])
df["month"] = df["date"].dt.month
df["month"] = df["month"].astype(str)

# %%
df.dtypes
# Out:
# date                                       datetime64[ns]
# fips                                               object
# statename                                          object
# stateabbr                                          object
# county                                             object
# series_complete_18plus                            float64
# series_complete_18pluspop_pct                     float64
# series_complete_65plus                            float64
# series_complete_65pluspop_pct                     float64
# series_complete_yes                               float64
# series_complete_pop_pct                           float64
# completeness_pct                                  float64
# census2019_12pluspop                              float64
# series_complete_12plus                            float64
# series_complete_12pluspop_pct                     float64
# administered_dose1_recip                          float64
# administered_dose1_recip_12plus                   float64
# administered_dose1_recip_18plus                   float64
# administered_dose1_recip_65plus                   float64
# administered_dose1_pop_pct                        float64
# administered_dose1_recip_12pluspop_pct            float64
# administered_dose1_recip_18pluspop_pct            float64
# administered_dose1_recip_65pluspop_pct            float64
# series_complete_pop_pct_svi                        object
# series_complete_12pluspop_pct_svi                  object
# series_complete_18pluspop_pct_svi                  object
# series_complete_65pluspop_pct_svi                  object
# svi_ctgy                                           object
# series_complete_pop_pct_ur_equity                 float64
# series_complete_12pluspop_pct_ur_equity           float64
# series_complete_18pluspop_pct_ur_equity           float64
# series_complete_65pluspop_pct_ur_equity           float64
# metro_status                                       object
# month                                              object
# dtype: object

# %% [markdown]
# ### Filter the data frame to just a specific state

# %%
ca = df[df["stateabbr"] == "CA"]

# %%
ca[["date", "fips", "county", "statename", "series_complete_pop_pct"]].sort_values(
    "series_complete_pop_pct", ascending=False
).head(10)
# Out:
#           date   fips                county   statename  \
# 207 2021-12-06  06041          Marin County  California
# 229 2021-12-06  06085    Santa Clara County  California
# 224 2021-12-06  06075  San Francisco County  California
# 227 2021-12-06  06081      San Mateo County  California
# 193 2021-12-06  06013   Contra Costa County  California
# 187 2021-12-06  06001        Alameda County  California
# 199 2021-12-06  06025       Imperial County  California
# 230 2021-12-06  06087     Santa Cruz County  California
# 235 2021-12-06  06097         Sonoma County  California
# 214 2021-12-06  06055           Napa County  California
#
#      series_complete_pop_pct
# 207                     80.9
# 229                     78.8
# 224                     77.8
# 227                     76.1
# 193                     74.4
# 187                     74.0
# 199                     73.6
# 230                     71.8
# 235                     71.2
# 214                     70.6

# %% [markdown]
# ### Which counties in the U.S. have the highest vaccination rates?

# %%
df[["date", "fips", "county", "statename", "series_complete_pop_pct"]].sort_values(
    "series_complete_pop_pct", ascending=False
).head(10)
# Out:
#            date   fips                county    statename  \
# 2318 2021-12-06  72013          Arecibo Muno  Puerto Rico
# 413  2021-12-06  13053  Chattahoochee County      Georgia
# 71   2021-12-06  02060   Bristol Bay Borough       Alaska
# 109  2021-12-06  04023     Santa Cruz County      Arizona
# 2336 2021-12-06  72049          Culebra Muno  Puerto Rico
# 301  2021-12-06  08111       San Juan County     Colorado
# 2995 2021-12-06  51740       Portsmouth City     Virginia
# 2353 2021-12-06  72081            Lares Muno  Puerto Rico
# 3217 2021-12-06  56039          Teton County      Wyoming
# 97   2021-12-06  04001         Apache County      Arizona
#
#       series_complete_pop_pct
# 2318                     99.9
# 413                      99.9
# 71                       95.8
# 109                      95.3
# 2336                     94.3
# 301                      88.9
# 2995                     86.0
# 2353                     84.8
# 3217                     84.5
# 97                       84.1

# %% [markdown]
# ---

# %% [markdown]
# ### Export to csv

# %%
df.to_csv("output/vaccinations_by_county.csv", index=False)
