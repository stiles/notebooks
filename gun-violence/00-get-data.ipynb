# %% [markdown]
# # FBI background checks

# %% [markdown]
# ### Import Python tools and Jupyter configuration

# %%
# %load_ext lab_black

# %%
import tabula

# %%
import pandas as pd
import geopandas as gpd
import altair as alt
import datetime as dt
import numpy as np

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = None

# %%
month_year_updated = dt.date.today().strftime("%m_%Y")

# %% [markdown]
# ---

# %%
url = "https://www.fbi.gov/file-repository/nics_firearm_checks_-_month_year.pdf"

# %% [markdown]
# ### Download the latest version of the FBI PDF

# %%
# !wget -O data/raw/latest_{month_year_updated}.pdf {url} --quiet

# %% [markdown]
# ### Read PDF file and use stream argument to keep rows/columns in place

# %%
table = tabula.read_pdf(
    f"data/raw/latest_{month_year_updated}.pdf", stream=True, pages=1
)

# %% [markdown]
# ### Make a dataframe from the first (and, in this case, only) table in the list

# %%
src = table[0].drop([0, 24])

# %% [markdown]
# ### Clean up

# %%
src.fillna(0, inplace=True)

# %%
src.columns = src.columns.str.lower()

# %%
src["year"] = src["year"].astype(str)
src["year"] = src["year"].astype(str)

# %%
src.replace(",", "", regex=True, inplace=True)

# %%
src[
    [
        "jan",
        "feb",
        "mar",
        "apr",
        "may",
        "jun",
        "jul",
        "aug",
        "sep",
        "oct",
        "nov",
        "dec",
        "totals",
    ]
] = src[
    [
        "jan",
        "feb",
        "mar",
        "apr",
        "may",
        "jun",
        "jul",
        "aug",
        "sep",
        "oct",
        "nov",
        "dec",
        "totals",
    ]
].astype(
    int
)

# %% [markdown]
# ### Copy the dataframe

# %%
df = src.copy()

# %% [markdown]
# ---

# %% [markdown]
# ### How many per year?

# %%
annual = df[["year", "totals"]].sort_values("year", ascending=False)

# %%
annual.head()
# Out:
#     year    totals
# 23  2021  35778134
# 22  2020  39695315
# 21  2019  28369750
# 20  2018  26181936
# 19  2017  25235215

# %%
months = df[
    ["jan", "feb", "mar", "apr", "may", "jun", "jul", "aug", "sep", "oct", "nov", "dec"]
]

# %%
for m in months:
    df[f"{m}_share"] = ((df[f"{m}"] / df["totals"]) * 100).round(2)

# %%
df_share = df[
    [
        "year",
        "jan_share",
        "feb_share",
        "mar_share",
        "apr_share",
        "may_share",
        "jun_share",
        "jul_share",
        "aug_share",
        "sep_share",
        "oct_share",
        "nov_share",
        "dec_share",
    ]
]

# %%
df_share.round(0).style.background_gradient(cmap="Oranges").set_precision(0)
# Out:
# <style  type="text/css" >
# #T_c2da0_row0_col1,#T_c2da0_row0_col3,#T_c2da0_row0_col4,#T_c2da0_row0_col5,#T_c2da0_row0_col6,#T_c2da0_row0_col7,#T_c2da0_row1_col4,#T_c2da0_row1_col5,#T_c2da0_row1_col6,#T_c2da0_row1_col7,#T_c2da0_row2_col3,#T_c2da0_row2_col4,#T_c2da0_row2_col5,#T_c2da0_row2_col6,#T_c2da0_row2_col7,#T_c2da0_row3_col3,#T_c2da0_row3_col4,#T_c2da0_row3_col6,#T_c2da0_row3_col7,#T_c2da0_row4_col4,#T_c2da0_row4_col6,#T_c2da0_row4_col7,#T_c2da0_row5_col3,#T_c2da0_row5_col4,#T_c2da0_row5_col5,#T_c2da0_row5_col6,#T_c2da0_row5_col7,#T_c2da0_row6_col4,#T_c2da0_row6_col5,#T_c2da0_row6_col6,#T_c2da0_row6_col7,#T_c2da0_row7_col3,#T_c2da0_row7_col4,#T_c2da0_row7_col5,#T_c2da0_row7_col6,#T_c2da0_row7_col7,#T_c2da0_row9_col3,#T_c2da0_row9_col4,#T_c2da0_row9_col6,#T_c2da0_row13_col4,#T_c2da0_row13_col9,#T_c2da0_row14_col6,#T_c2da0_row14_col7,#T_c2da0_row14_col8,#T_c2da0_row14_col9,#T_c2da0_row15_col8,#T_c2da0_row15_col9,#T_c2da0_row16_col4,#T_c2da0_row17_col8,#T_c2da0_row17_col9,#T_c2da0_row19_col9,#T_c2da0_row20_col2,#T_c2da0_row21_col2,#T_c2da0_row21_col4,#T_c2da0_row21_col9,#T_c2da0_row22_col9,#T_c2da0_row22_col10,#T_c2da0_row22_col11,#T_c2da0_row22_col12{
#             background-color:  #fff5eb;
#             color:  #000000;
#         }#T_c2da0_row0_col2,#T_c2da0_row1_col2,#T_c2da0_row2_col2,#T_c2da0_row3_col2,#T_c2da0_row4_col2,#T_c2da0_row5_col2,#T_c2da0_row6_col2,#T_c2da0_row7_col2,#T_c2da0_row8_col2,#T_c2da0_row8_col6,#T_c2da0_row9_col2,#T_c2da0_row10_col6,#T_c2da0_row10_col11,#T_c2da0_row11_col6,#T_c2da0_row11_col11,#T_c2da0_row12_col6,#T_c2da0_row12_col11,#T_c2da0_row13_col6,#T_c2da0_row14_col11,#T_c2da0_row15_col6,#T_c2da0_row15_col11,#T_c2da0_row16_col2,#T_c2da0_row16_col6,#T_c2da0_row17_col11,#T_c2da0_row18_col11,#T_c2da0_row19_col6,#T_c2da0_row19_col11,#T_c2da0_row20_col11,#T_c2da0_row21_col11{
#             background-color:  #fdd0a2;
#             color:  #000000;
#         }#T_c2da0_row0_col8,#T_c2da0_row0_col12,#T_c2da0_row1_col8,#T_c2da0_row2_col8,#T_c2da0_row2_col9,#T_c2da0_row2_col10,#T_c2da0_row3_col8,#T_c2da0_row4_col8,#T_c2da0_row5_col8,#T_c2da0_row6_col8,#T_c2da0_row7_col8,#T_c2da0_row8_col8,#T_c2da0_row9_col8,#T_c2da0_row9_col11,#T_c2da0_row10_col8,#T_c2da0_row11_col8,#T_c2da0_row12_col8,#T_c2da0_row13_col8,#T_c2da0_row13_col12,#T_c2da0_row14_col1,#T_c2da0_row14_col2,#T_c2da0_row16_col8,#T_c2da0_row16_col12,#T_c2da0_row18_col8,#T_c2da0_row19_col8,#T_c2da0_row20_col8,#T_c2da0_row21_col6,#T_c2da0_row21_col7,#T_c2da0_row21_col8,#T_c2da0_row22_col1,#T_c2da0_row22_col3,#T_c2da0_row22_col4,#T_c2da0_row22_col5,#T_c2da0_row22_col8{
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }#T_c2da0_row0_col9,#T_c2da0_row1_col9,#T_c2da0_row3_col9,#T_c2da0_row4_col9,#T_c2da0_row5_col9,#T_c2da0_row6_col9,#T_c2da0_row7_col9,#T_c2da0_row10_col4,#T_c2da0_row11_col4,#T_c2da0_row17_col7,#T_c2da0_row18_col5,#T_c2da0_row19_col5,#T_c2da0_row20_col5,#T_c2da0_row21_col5,#T_c2da0_row22_col7{
#             background-color:  #e95e0d;
#             color:  #000000;
#         }#T_c2da0_row0_col10,#T_c2da0_row1_col10,#T_c2da0_row3_col10,#T_c2da0_row4_col10,#T_c2da0_row5_col10,#T_c2da0_row6_col10,#T_c2da0_row7_col10,#T_c2da0_row19_col3{
#             background-color:  #f3701b;
#             color:  #000000;
#         }#T_c2da0_row0_col11,#T_c2da0_row1_col11,#T_c2da0_row2_col11,#T_c2da0_row15_col2,#T_c2da0_row22_col2,#T_c2da0_row22_col6{
#             background-color:  #d84801;
#             color:  #f1f1f1;
#         }#T_c2da0_row1_col1,#T_c2da0_row2_col1,#T_c2da0_row9_col1,#T_c2da0_row13_col1,#T_c2da0_row21_col1{
#             background-color:  #fedfc0;
#             color:  #000000;
#         }#T_c2da0_row1_col3,#T_c2da0_row4_col3,#T_c2da0_row6_col3,#T_c2da0_row8_col3,#T_c2da0_row11_col3,#T_c2da0_row12_col3,#T_c2da0_row12_col10,#T_c2da0_row13_col3,#T_c2da0_row13_col10,#T_c2da0_row14_col10,#T_c2da0_row15_col10,#T_c2da0_row16_col3,#T_c2da0_row17_col3,#T_c2da0_row17_col10,#T_c2da0_row18_col10,#T_c2da0_row19_col10,#T_c2da0_row20_col3,#T_c2da0_row20_col10,#T_c2da0_row21_col3,#T_c2da0_row21_col10{
#             background-color:  #fdd9b4;
#             color:  #000000;
#         }#T_c2da0_row1_col12,#T_c2da0_row2_col12,#T_c2da0_row3_col12,#T_c2da0_row4_col12,#T_c2da0_row5_col12,#T_c2da0_row7_col12,#T_c2da0_row9_col12{
#             background-color:  #ad3803;
#             color:  #f1f1f1;
#         }#T_c2da0_row3_col1,#T_c2da0_row3_col5,#T_c2da0_row4_col1,#T_c2da0_row4_col5,#T_c2da0_row5_col1,#T_c2da0_row6_col1,#T_c2da0_row7_col1,#T_c2da0_row8_col1,#T_c2da0_row8_col4,#T_c2da0_row8_col5,#T_c2da0_row8_col7,#T_c2da0_row8_col9,#T_c2da0_row9_col5,#T_c2da0_row9_col7,#T_c2da0_row9_col9,#T_c2da0_row10_col5,#T_c2da0_row10_col7,#T_c2da0_row10_col9,#T_c2da0_row11_col1,#T_c2da0_row11_col5,#T_c2da0_row11_col7,#T_c2da0_row11_col9,#T_c2da0_row12_col1,#T_c2da0_row12_col4,#T_c2da0_row12_col5,#T_c2da0_row12_col7,#T_c2da0_row12_col9,#T_c2da0_row13_col5,#T_c2da0_row13_col7,#T_c2da0_row14_col4,#T_c2da0_row14_col5,#T_c2da0_row15_col1,#T_c2da0_row15_col4,#T_c2da0_row15_col5,#T_c2da0_row15_col7,#T_c2da0_row16_col1,#T_c2da0_row16_col5,#T_c2da0_row16_col7,#T_c2da0_row16_col9,#T_c2da0_row17_col4,#T_c2da0_row17_col5,#T_c2da0_row18_col1,#T_c2da0_row18_col4,#T_c2da0_row18_col7,#T_c2da0_row18_col9,#T_c2da0_row19_col1,#T_c2da0_row19_col4,#T_c2da0_row19_col7,#T_c2da0_row20_col1,#T_c2da0_row20_col4,#T_c2da0_row20_col7,#T_c2da0_row20_col9{
#             background-color:  #fdb97d;
#             color:  #000000;
#         }#T_c2da0_row3_col11,#T_c2da0_row4_col11,#T_c2da0_row5_col11,#T_c2da0_row6_col11,#T_c2da0_row7_col11,#T_c2da0_row8_col11,#T_c2da0_row10_col1,#T_c2da0_row10_col2,#T_c2da0_row11_col2,#T_c2da0_row12_col2,#T_c2da0_row13_col2,#T_c2da0_row13_col11,#T_c2da0_row16_col11,#T_c2da0_row17_col1,#T_c2da0_row17_col2,#T_c2da0_row17_col6,#T_c2da0_row18_col2,#T_c2da0_row18_col6,#T_c2da0_row19_col2,#T_c2da0_row20_col6{
#             background-color:  #fd8c3b;
#             color:  #000000;
#         }#T_c2da0_row6_col12{
#             background-color:  #952f03;
#             color:  #f1f1f1;
#         }#T_c2da0_row8_col10,#T_c2da0_row9_col10,#T_c2da0_row10_col3,#T_c2da0_row10_col10,#T_c2da0_row11_col10,#T_c2da0_row14_col3,#T_c2da0_row16_col10,#T_c2da0_row18_col3{
#             background-color:  #fda762;
#             color:  #000000;
#         }#T_c2da0_row8_col12,#T_c2da0_row11_col12,#T_c2da0_row12_col12,#T_c2da0_row15_col12{
#             background-color:  #c94202;
#             color:  #f1f1f1;
#         }#T_c2da0_row10_col12,#T_c2da0_row14_col12,#T_c2da0_row17_col12,#T_c2da0_row18_col12,#T_c2da0_row19_col12,#T_c2da0_row20_col12,#T_c2da0_row21_col12{
#             background-color:  #e05206;
#             color:  #000000;
#         }#T_c2da0_row15_col3{
#             background-color:  #c54102;
#             color:  #f1f1f1;
#         }</style><table id="T_c2da0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >year</th>        <th class="col_heading level0 col1" >jan_share</th>        <th class="col_heading level0 col2" >feb_share</th>        <th class="col_heading level0 col3" >mar_share</th>        <th class="col_heading level0 col4" >apr_share</th>        <th class="col_heading level0 col5" >may_share</th>        <th class="col_heading level0 col6" >jun_share</th>        <th class="col_heading level0 col7" >jul_share</th>        <th class="col_heading level0 col8" >aug_share</th>        <th class="col_heading level0 col9" >sep_share</th>        <th class="col_heading level0 col10" >oct_share</th>        <th class="col_heading level0 col11" >nov_share</th>        <th class="col_heading level0 col12" >dec_share</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c2da0_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_c2da0_row0_col0" class="data row0 col0" >1999</td>
#                         <td id="T_c2da0_row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_c2da0_row0_col2" class="data row0 col2" >8</td>

# %%
df_share.style.background_gradient(cmap="Oranges", axis=None).format("{:.4}")
# Out:
# <style  type="text/css" >
# #T_84c0b_row0_col1,#T_84c0b_row0_col7,#T_84c0b_row1_col6,#T_84c0b_row5_col7,#T_84c0b_row9_col6{
#             background-color:  #fd9a4e;
#             color:  #000000;
#         }#T_84c0b_row0_col2,#T_84c0b_row6_col1,#T_84c0b_row9_col9,#T_84c0b_row10_col8,#T_84c0b_row12_col9,#T_84c0b_row15_col10,#T_84c0b_row16_col1,#T_84c0b_row18_col8,#T_84c0b_row19_col5,#T_84c0b_row20_col1{
#             background-color:  #fa8331;
#             color:  #000000;
#         }#T_84c0b_row0_col3,#T_84c0b_row13_col10,#T_84c0b_row20_col4{
#             background-color:  #f67723;
#             color:  #000000;
#         }#T_84c0b_row0_col4,#T_84c0b_row8_col6,#T_84c0b_row11_col5,#T_84c0b_row12_col6,#T_84c0b_row15_col5,#T_84c0b_row21_col2{
#             background-color:  #fd8f3e;
#             color:  #000000;
#         }#T_84c0b_row0_col5,#T_84c0b_row1_col5,#T_84c0b_row4_col7,#T_84c0b_row5_col6,#T_84c0b_row6_col7,#T_84c0b_row7_col7{
#             background-color:  #fd9d53;
#             color:  #000000;
#         }#T_84c0b_row0_col6,#T_84c0b_row4_col6,#T_84c0b_row5_col5,#T_84c0b_row6_col5,#T_84c0b_row6_col6,#T_84c0b_row7_col5{
#             background-color:  #fd9e54;
#             color:  #000000;
#         }#T_84c0b_row0_col8,#T_84c0b_row4_col1,#T_84c0b_row5_col8,#T_84c0b_row6_col8,#T_84c0b_row18_col5{
#             background-color:  #f98230;
#             color:  #000000;
#         }#T_84c0b_row0_col9,#T_84c0b_row6_col9,#T_84c0b_row18_col2{
#             background-color:  #f26b15;
#             color:  #000000;
#         }#T_84c0b_row0_col10,#T_84c0b_row6_col11,#T_84c0b_row20_col12{
#             background-color:  #de4e05;
#             color:  #f1f1f1;
#         }#T_84c0b_row0_col11,#T_84c0b_row8_col12,#T_84c0b_row15_col12{
#             background-color:  #d14501;
#             color:  #f1f1f1;
#         }#T_84c0b_row0_col12{
#             background-color:  #8b2c04;
#             color:  #f1f1f1;
#         }#T_84c0b_row1_col1,#T_84c0b_row12_col5,#T_84c0b_row13_col9,#T_84c0b_row19_col9{
#             background-color:  #fb8735;
#             color:  #000000;
#         }#T_84c0b_row1_col2,#T_84c0b_row5_col2,#T_84c0b_row6_col2,#T_84c0b_row7_col8,#T_84c0b_row15_col4,#T_84c0b_row20_col5,#T_84c0b_row21_col10{
#             background-color:  #f57622;
#             color:  #000000;
#         }#T_84c0b_row1_col3,#T_84c0b_row10_col1,#T_84c0b_row11_col2{
#             background-color:  #f36f1a;
#             color:  #000000;
#         }#T_84c0b_row1_col4,#T_84c0b_row17_col9,#T_84c0b_row20_col2,#T_84c0b_row22_col10{
#             background-color:  #fc8b3a;
#             color:  #000000;
#         }#T_84c0b_row1_col7,#T_84c0b_row3_col7{
#             background-color:  #fd9c51;
#             color:  #000000;
#         }#T_84c0b_row1_col8,#T_84c0b_row11_col9,#T_84c0b_row12_col8,#T_84c0b_row17_col7,#T_84c0b_row19_col10{
#             background-color:  #f87d29;
#             color:  #000000;
#         }#T_84c0b_row1_col9,#T_84c0b_row7_col9,#T_84c0b_row8_col10,#T_84c0b_row17_col3,#T_84c0b_row19_col11,#T_84c0b_row21_col7,#T_84c0b_row21_col11{
#             background-color:  #ee6511;
#             color:  #000000;
#         }#T_84c0b_row1_col10,#T_84c0b_row21_col6{
#             background-color:  #e4580a;
#             color:  #000000;
#         }#T_84c0b_row1_col11,#T_84c0b_row11_col12,#T_84c0b_row19_col3{
#             background-color:  #db4b03;
#             color:  #f1f1f1;
#         }#T_84c0b_row1_col12{
#             background-color:  #bd3e02;
#             color:  #f1f1f1;
#         }#T_84c0b_row2_col1,#T_84c0b_row8_col5,#T_84c0b_row20_col7{
#             background-color:  #fd8c3b;
#             color:  #000000;
#         }#T_84c0b_row2_col2,#T_84c0b_row11_col8,#T_84c0b_row22_col8,#T_84c0b_row22_col11{
#             background-color:  #fa8532;
#             color:  #000000;
#         }#T_84c0b_row2_col3,#T_84c0b_row3_col2,#T_84c0b_row3_col8,#T_84c0b_row7_col2,#T_84c0b_row8_col2,#T_84c0b_row8_col8,#T_84c0b_row9_col3,#T_84c0b_row12_col4{
#             background-color:  #f67824;
#             color:  #000000;
#         }#T_84c0b_row2_col4,#T_84c0b_row4_col5,#T_84c0b_row15_col7{
#             background-color:  #fd9649;
#             color:  #000000;
#         }#T_84c0b_row2_col5,#T_84c0b_row3_col6,#T_84c0b_row7_col6{
#             background-color:  #fda057;
#             color:  #000000;
#         }#T_84c0b_row2_col6,#T_84c0b_row2_col7,#T_84c0b_row14_col6,#T_84c0b_row14_col7{
#             background-color:  #fda159;
#             color:  #000000;
#         }#T_84c0b_row2_col8,#T_84c0b_row15_col1,#T_84c0b_row19_col8{
#             background-color:  #f87e2b;
#             color:  #000000;
#         }#T_84c0b_row2_col9,#T_84c0b_row14_col12,#T_84c0b_row16_col11,#T_84c0b_row19_col12{
#             background-color:  #e75b0b;
#             color:  #000000;
#         }#T_84c0b_row2_col10{
#             background-color:  #c14002;
#             color:  #f1f1f1;
#         }#T_84c0b_row2_col11{
#             background-color:  #d04501;
#             color:  #f1f1f1;
#         }#T_84c0b_row2_col12{
#             background-color:  #b63c02;
#             color:  #f1f1f1;
#         }#T_84c0b_row3_col1,#T_84c0b_row21_col8{
#             background-color:  #f87f2c;
#             color:  #000000;
#         }#T_84c0b_row3_col3,#T_84c0b_row5_col3,#T_84c0b_row8_col9,#T_84c0b_row17_col10,#T_84c0b_row19_col4{
#             background-color:  #f4721e;
#             color:  #000000;
#         }#T_84c0b_row3_col4,#T_84c0b_row5_col4,#T_84c0b_row9_col1,#T_84c0b_row9_col4,#T_84c0b_row11_col7,#T_84c0b_row16_col4,#T_84c0b_row19_col6{
#             background-color:  #fb8836;
#             color:  #000000;
#         }#T_84c0b_row3_col5,#T_84c0b_row13_col5,#T_84c0b_row14_col8,#T_84c0b_row17_col8{
#             background-color:  #fd9547;
#             color:  #000000;
#         }#T_84c0b_row3_col9,#T_84c0b_row6_col3,#T_84c0b_row11_col4,#T_84c0b_row14_col11,#T_84c0b_row15_col11{
#             background-color:  #f3701b;
#             color:  #000000;
#         }#T_84c0b_row3_col10,#T_84c0b_row10_col12,#T_84c0b_row17_col12{
#             background-color:  #e25508;
#             color:  #000000;
#         }#T_84c0b_row3_col11,#T_84c0b_row14_col3{
#             background-color:  #dc4c03;
#             color:  #f1f1f1;
#         }#T_84c0b_row3_col12{
#             background-color:  #c34002;
#             color:  #f1f1f1;
#         }#T_84c0b_row4_col2,#T_84c0b_row20_col8{
#             background-color:  #f57520;
#             color:  #000000;
#         }#T_84c0b_row4_col3,#T_84c0b_row4_col9,#T_84c0b_row10_col11,#T_84c0b_row16_col3{
#             background-color:  #f36e19;
#             color:  #000000;
#         }#T_84c0b_row4_col4,#T_84c0b_row6_col4,#T_84c0b_row15_col8,#T_84c0b_row21_col4,#T_84c0b_row22_col9{
#             background-color:  #fc8937;
#             color:  #000000;
#         }#T_84c0b_row4_col8,#T_84c0b_row18_col1,#T_84c0b_row18_col4,#T_84c0b_row22_col7{
#             background-color:  #f77a27;
#             color:  #000000;
#         }#T_84c0b_row4_col10{
#             background-color:  #e15407;
#             color:  #000000;
#         }#T_84c0b_row4_col11,#T_84c0b_row15_col2,#T_84c0b_row21_col12{
#             background-color:  #e45709;
#             color:  #000000;
#         }#T_84c0b_row4_col12,#T_84c0b_row15_col3{
#             background-color:  #b83c02;
#             color:  #f1f1f1;
#         }#T_84c0b_row5_col1,#T_84c0b_row8_col1,#T_84c0b_row9_col2,#T_84c0b_row12_col1,#T_84c0b_row14_col10,#T_84c0b_row16_col2,#T_84c0b_row18_col10{
#             background-color:  #f77b28;
#             color:  #000000;
#         }#T_84c0b_row5_col9,#T_84c0b_row16_col10,#T_84c0b_row22_col6{
#             background-color:  #f4711c;
#             color:  #000000;
#         }#T_84c0b_row5_col10{
#             background-color:  #e35608;
#             color:  #000000;
#         }#T_84c0b_row5_col11,#T_84c0b_row13_col11,#T_84c0b_row18_col12{
#             background-color:  #df5106;
#             color:  #f1f1f1;
#         }#T_84c0b_row5_col12{
#             background-color:  #ab3803;
#             color:  #f1f1f1;
#         }#T_84c0b_row6_col10{
#             background-color:  #e95e0d;
#             color:  #000000;
#         }#T_84c0b_row6_col12{
#             backgroun

# %%
df_share.to_csv("data/processed/df_share.csv", index=False)

# %% [markdown]
# ---

# %% [markdown]
# ### Normalize

# %%
pop = pd.read_csv("data/raw/population.csv", dtype={"year": str})

# %%
pop.replace(",", "", regex=True, inplace=True)

# %%
pop["population"] = pop["population"].astype(int)

# %%
norm_df = pd.merge(annual, pop, on="year")

# %%
norm_df["per_thousand"] = ((norm_df["totals"] / norm_df["population"]) * 1000).round()

# %%
norm_df.head()
# Out:
#    year    totals  population  per_thousand
# 0  2021  35778134   332992659         107.0
# 1  2020  39695315   329484123         120.0
# 2  2019  28369750   328329953          86.0
# 3  2018  26181936   326838199          80.0
# 4  2017  25235215   325122128          78.0

# %%
alt.Chart(norm_df).mark_bar().encode(
    x=alt.X("year", axis=alt.Axis(tickCount=9), title="Year"),
    y=alt.Y("per_thousand", axis=alt.Axis(tickCount=5, title="Rate")),
).properties(width=650, title="FBI firearm background checks per 1,000 Americans")
# Out:
# alt.Chart(...)

# %% [markdown]
# ---

# %% [markdown]
# ### Export

# %%
norm_df.to_csv("data/processed/fbi_annual_background_checks.csv", index=False)
