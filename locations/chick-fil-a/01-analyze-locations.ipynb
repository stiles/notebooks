# %% [markdown]
# # Chick-fil-A locations

# %%
import pandas as pd
import geopandas as gpd
import altair as alt
import altair_grid as altgrid
from vega_datasets import data
import numpy as np
import circlify
import squarify
import matplotlib.pyplot as plt
# Out:
# /Users/stiles/.local/share/virtualenvs/notebooks-sxqKeO4C/lib/python3.8/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
alt.themes.register("grid", altgrid.theme)
alt.themes.enable("grid")
# Out:
# ThemeRegistry.enable('grid')

# %%
# %load_ext lab_black

# %% [markdown]
# ---

# %% [markdown]
# ## ZIP Codes

# %%
zips = pd.read_csv(
    "https://grid-news-static-files.s3.us-east-2.amazonaws.com/data/usa-zips-wealth.csv"
)

# %%
zips_pop = zips.sort_values("totpop_cy", ascending=False).head(1500)

# %% [markdown]
# ---

# %% [markdown]
# ## Locations

# %%
src = pd.read_csv("data/processed/locations.csv", dtype={"open_year": str})

# %%
df = src[src["status"] == "OPEN"].copy()

# %%
gdf = gpd.read_file("data/processed/locations_geo.geojson")

# %% [markdown]
# #### Decades

# %%
df["decade"] = df["open_year"].str[:3] + "0s"

# %% [markdown]
# ---

# %% [markdown]
# ## Aggregate

# %% [markdown]
# #### Operators

# %%
operators = (
    df.groupby(["operator"])
    .agg({"locationname": "count"})
    .reset_index()
    .rename(columns={"locationname": "count"})
    .sort_values("count", ascending=False)
)

# %% [markdown]
# #### Share of operators who own more than one?

# %%
round((len(operators[operators["count"] > 1]) / len(operators)) * 100, 2)
# Out:
# 16.67

# %% [markdown]
# #### Locations by year

# %%
df["open_year"] = df["open_year"].astype(str).str.replace(".0", "", regex=False)

# %%
years = (
    df.groupby(["open_year"])["url"]
    .count()
    .reset_index()
    .rename(columns={"url": "count", "open_year": "year"})
)

# %%
years.head()
# Out:
#    year  count
# 0  1946      1
# 1  1969      1
# 2  1970      2
# 3  1972      3
# 4  1973      2

# %%
years.tail()
# Out:
#     year  count
# 49  2018     97
# 50  2019     94
# 51  2020     89
# 52  2021    125
# 53  2022     52

# %% [markdown]
# #### States

# %%
states = (
    (
        df.groupby(["region"])["url"]
        .count()
        .reset_index()
        .rename(columns={"url": "count", "region": "state"})
    )
    .sort_values("count", ascending=False)
    .reset_index(drop=True)
)

# %%
states.head(8)
# Out:
#   state  count
# 0    TX    306
# 1    GA    161
# 2    FL    156
# 3    CA    137
# 4    NC    109
# 5    VA     86
# 6    OH     61
# 7    PA     57

# %% [markdown]
# #### Types over time

# %%
df.head()
# Out:
#    locationname   marketname     city countrycode                address  \
# 0  Morton Ranch  Houston, TX     Katy          US    2826 W Grand Pkwy N
# 1    Mason Road  Houston, TX     Katy          US         369 S Mason Rd
# 2    Katy Green  Houston, TX  Houston          US         19303 Katy Fwy
# 3    Katy Mills  Houston, TX     Katy          US       25601 Nelson Way
# 4   Cinco Ranch  Houston, TX     Katy          US  23860 Westheimer Pkwy
#
#      zip region        lat        lon       operator status         timezone  \
# 0  77449     TX  29.814042 -95.772170    Amanda Baca   OPEN  America/Chicago
# 1  77450     TX  29.780570 -95.751140    Rusty Wylie   OPEN  America/Chicago
# 2  77094     TX  29.784326 -95.706519    Rusty Wylie   OPEN  America/Chicago
# 3  77494     TX  29.774121 -95.819225  Cynthia Cavin   OPEN  America/Chicago
# 4  77494     TX  29.735510 -95.778000    Rusty Wylie   OPEN  America/Chicago
#
#                                        url  open_day  open_month open_year  \
# 0  https://www.chick-fil-a.com/mortonranch      30.0        11.0      2017
# 1    https://www.chick-fil-a.com/masonroad      14.0         9.0      1995
# 2    https://www.chick-fil-a.com/katygreen      11.0         6.0      2015
# 3    https://www.chick-fil-a.com/katymills      26.0         4.0      2012
# 4   https://www.chick-fil-a.com/cincoranch       2.0         6.0      2005
#
#    other_date playground  drivethru       format in_mall  \
# 0  2017-11-30   interior       True  Stand Alone   False
# 1  2014-10-02   interior       True  Stand Alone   False
# 2  2015-06-11   interior       True  Stand Alone   False
# 3  2011-12-08   interior       True  Stand Alone   False
# 4  2005-06-02   interior       True  Stand Alone   False
#
#                          geometry decade
# 0  POINT (-95.7721704 29.8140416)  2010s
# 1      POINT (-95.75114 29.78057)  1990s
# 2  POINT (-95.7065195 29.7843262)  2010s
# 3    POINT (-95.819225 29.774121)  2010s
# 4        POINT (-95.778 29.73551)  2000s

# %%
types_time = (
    df.groupby(["format", "open_year"])["url"]
    .count()
    .reset_index()
    .rename(columns={"url": "count", "open_year": "year"})
)

# %%
types_time.head()
# Out:
#        format  year  count
# 0  Food Court  1969      1
# 1  Food Court  1970      2
# 2  Food Court  1972      3
# 3  Food Court  1973      2
# 4  Food Court  1974      4

# %%
types_time["cumsum_type"] = types_time.groupby("format")["count"].cumsum()

# %%
types_time.head()
# Out:
#        format  year  count  cumsum_type
# 0  Food Court  1969      1            1
# 1  Food Court  1970      2            3
# 2  Food Court  1972      3            6
# 3  Food Court  1973      2            8
# 4  Food Court  1974      4           12

# %%
alt.Chart(types_time).mark_line().encode(
    x=alt.X("year:T", title="", axis=alt.Axis(tickCount=6)),
    y=alt.Y("cumsum_type", title="", axis=alt.Axis(tickCount=4)),
    color=alt.Color(
        "format",
        title="",
        scale=alt.Scale(
            domain=["Food Court", "In-Line", "Stand Alone"],
            range=["#4daf4a", "#377eb8", "#e41a1c"],
        ),
    ),
).configure_legend(
    orient="top", symbolType="stroke", offset=-30, padding=-35
).properties(
    width=650,
    height=300,
    title="Cumulative Chick-fil-A restaurant openings, by type",
)
# Out:
# alt.Chart(...)

# %%
df.format.value_counts()
# Out:
# Stand Alone    1536
# Food Court      190
# In-Line          67
# Name: format, dtype: int64

# %% [markdown]
# ---

# %%
df.groupby("format")["url"].count().reset_index()
# Out:
#         format   url
# 0   Food Court   190
# 1      In-Line    67
# 2  Stand Alone  1536

# %%
states = alt.topo_feature(data.us_10m.url, feature="states")

places = (
    alt.Chart()
    .mark_circle()
    .encode(
        longitude="lon:Q",
        latitude="lat:Q",
        size=alt.value(8),
        tooltip=["locationname", "city", "region"],
        color=alt.Color(
            "format",
            title=" ",
            scale=alt.Scale(
                domain=["Food Court", "In-Line", "Stand Alone"],
                range=["#4daf4a", "#377eb8", "#e41a1c"],
            ),
        ),
    )
    .project("albersUsa")
    .properties(width=250, height=150)
)

states = (
    alt.Chart(states).mark_geoshape(fill="#E9E9E9", stroke="white").project("albersUsa")
)

alt.layer(states, places, data=df).facet(
    facet=alt.Facet(
        "decade",
        title=" ",
        header=alt.Header(labelFontSize=14, labelFont="Summit Sans"),
    ),
    columns=4,
).configure_legend(orient="top", symbolType="circle").properties(
    title="Chick-fil-A openings, by location and decade"
)
# Out:
# alt.FacetChart(...)

# %%
df[df["city"] == "Houma"]
# Out:
#      locationname       marketname   city countrycode  \
# 1715        Houma  New Orleans, LA  Houma          US
#
#                               address    zip region       lat       lon  \
# 1715  1741 Martin Luther King Jr Blvd  70360     LA  29.61324 -90.75665
#
#            operator status         timezone  \
# 1715  Shannon Lewis   OPEN  America/Chicago
#
#                                     url  open_day  open_month open_year  \
# 1715  https://www.chick-fil-a.com/houma      16.0         2.0      2006
#
#       other_date playground  drivethru       format in_mall  \
# 1715  2006-02-16   interior       True  Stand Alone   False
#
#                         geometry decade
# 1715  POINT (-90.75665 29.61324)  2000s
