# %%
import pandas as pd
import matplotlib as mpl
import geopandas as gpd
import descartes
import geojson
import json
import altair as alt
alt.renderers.enable('notebook')
import altair_latimes as lat
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
# Out:
# ThemeRegistry.enable('latimes')

# %%
arrests = pd.read_csv('/Users/mhustiles/Desktop/data/LA/Arrest_Data_from_2010_to_Present.csv')
arrests.columns = arrests.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
arrests.columns
# Out:
# Index(['report_id', 'arrest_date', 'time', 'area_id', 'area_name',
#        'reporting_district', 'age', 'sex_code', 'descent_code',
#        'charge_group_code', 'charge_group_description', 'arrest_type_code',
#        'charge', 'charge_description', 'address', 'cross_street', 'location'],
#       dtype='object')

# %%
arrests[['report_id', 'time', 'area_id', 'charge_group_code', 'reporting_district']] = arrests[['report_id', 'time', 'area_id', 'charge_group_code', 'reporting_district']].astype(str)

# %%
arrests['arrest_date'] = pd.to_datetime(arrests['arrest_date'], format='%m/%d/%Y')
arrests['year'] = arrests['arrest_date'].dt.year
arrests['month'] = arrests['arrest_date'].dt.month
arrests['year'] = arrests['arrest_date'].dt.year
arrests['weekday'] = arrests['arrest_date'].dt.weekday_name

# %% [markdown]
# ### Clean up location field so lat/lon separated

# %%
arrests['location'] = arrests.location.str.replace('(', '').str.replace(')', '')

lat = []
lon = []

for row in arrests['location']:
    try:
        lat.append(row.split(',')[0])
        lon.append(row.split(',')[1])
    except:
        lat.append(np.NaN)
        lon.append(np.NaN)

arrests['latitude'] = lat
arrests['longitude'] = lon

# %%
arrests.drop('cross_street', axis=1, inplace=True)

# %%
arrests.head()
# Out:
#    report_id arrest_date    time area_id    area_name reporting_district  age  \
# 0  192115378  2019-09-07  1330.0      21      Topanga               2134   70
# 1  191222114  2019-09-07   558.0      12  77th Street               1249   20
# 2    5740147  2019-09-07  1500.0      14      Pacific               1431   56
# 3    5739903  2019-09-07   340.0       2      Rampart                246   27
# 4    5739905  2019-09-07   240.0       5       Harbor                517   45
#
#   sex_code descent_code charge_group_code  ... arrest_type_code       charge  \
# 0        M            W              16.0  ...                M      11364HS
# 1        F            B              13.0  ...                M     647(B)PC
# 2        F            W               8.0  ...                M  243(E)(1)PC
# 3        M            H               8.0  ...                M     243(A)PC
# 4        F            H              22.0  ...                M   23152(A)VC
#
# ...

# %%
charges = arrests.groupby(['charge', 'charge_description', 'area_name', 'reporting_district']).agg('size').sort_values(ascending=False).reset_index()

# %%
charges
# Out:
#              charge                        charge_description    area_name  \
# 0              LAMC                LOS ANGELES MUNICIPAL CODE      Pacific
# 1              LAMC                LOS ANGELES MUNICIPAL CODE      Pacific
# 2        41.27CLAMC                        DRINKING IN PUBLIC    Hollywood
# 3        41.27CLAMC                        DRINKING IN PUBLIC    Hollywood
# 4        41.18DLAMC          SIT/LIE/SLEEP SIDEWALK OR STREET      Central
# 5        25620(A)BP                          DRINKING ALCOHOL      Pacific
# 6              LAMC                LOS ANGELES MUNICIPAL CODE      Pacific
# 7        25620(A)BP                          DRINKING ALCOHOL      Pacific
# 8        41.27CLAMC                        DRINKING IN PUBLIC      Central
# 9        20002(A)VC                   HIT AND RUN:PROP DAMAGE     Van Nuys
# 10       41.27CLAMC                        DRINKING IN PUBLIC    Hollywood
# ...

# %%
homeless = arrests[arrests.charge == '41.18DLAMC']

# %%
homeless.head()
# Out:
#       report_id arrest_date    time area_id    area_name reporting_district  \
# 172   190618578  2019-09-05  1000.0       6    Hollywood                637
# 419   190122466  2019-09-04  2145.0       1      Central                192
# 572   190122462  2019-09-03  2045.0       1      Central                163
# 1209  191516619  2019-09-01  1010.0      15  N Hollywood               1511
# 1629  190122040  2019-08-30  1900.0       1      Central                164
#
#       age sex_code descent_code charge_group_code  ... arrest_type_code  \
# 172    33        M            W              20.0  ...                M
# 419    42        F            O              20.0  ...                M
# 572    41        M            O              20.0  ...                M
# 1209   51        M            W              20.0  ...                M
# 1629   30        M            H              20.0  ...                M
#
#           charge                charge_description  \
# ...

# %%
charges_homeless = homeless.groupby(['charge', 'charge_description', 'area_name', 'reporting_district', 'year']).agg('size').sort_values(ascending=False).reset_index()

# %%
charges_homeless.columns = ['charge', 'charge_description', 'area_name', 'reporting_district', 'year','count']
charges_homeless.head()
# Out:
#        charge                charge_description area_name reporting_district  \
# 0  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                157
# 1  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                111
# 2  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                158
# 3  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                157
# 4  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                157
#
#    year  count
# 0  2016    572
# 1  2017    427
# 2  2013    425
# 3  2014    423
# 4  2013    388

# %%
charges_homeless_2019 = charges_homeless[charges_homeless['year'] == 2019]

# %%
charges_homeless['reporting_district'] = charges_homeless['reporting_district'].astype(str)

# %%
charges_homeless_2019
# Out:
#           charge                charge_description    area_name  \
# 311   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET      Central
# 342   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET    Hollywood
# 387   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET      Central
# 416   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET      Central
# 418   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET      Central
# 447   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET      West LA
# 471   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET      Central
# 472   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET      West LA
# 473   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET      Central
# 478   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET      Central
# 480   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET    Northeast
# 488   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET    Hollywood
# 498   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET       Newton
# 514   41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET       Harbor
# ...

# %% [markdown]
# ### What's the average age for men and women who get arrested?

# %%
mean_age = charges_homeless['age'].groupby(charges_homeless['sex_code'])

# %%
mean_age.mean()
# Out:
# sex_code
# F   40.02527667714168
# M   42.58162167220325
# Name: age, dtype: float64

# %% [markdown]
# ### Geography: LAPD reporting districts

# %%
divisions = gpd.read_file('/Users/mhustiles/Desktop/github/notebooks/arrests/input/LAPD_Reporting_Districts/LAPD_Reporting_Districts.shp')

# %%
divisions.plot()

# %%
divisions.head()
# Out:
#    OBJECTID  REPDIST  PREC   APREC        BUREAU BASICCAR            AREA  \
# 0      1001      508     5  HARBOR  SOUTH BUREAU     5A11 8,990,764.35014
# 1      1002      509     5  HARBOR  SOUTH BUREAU     5A11 12,066,207.8976
# 2      1003      518     5  HARBOR  SOUTH BUREAU     5A15  10,535,450.473
# 3      1004      515     5  HARBOR  SOUTH BUREAU     5A15 10,252,327.5136
# 4      1005      514     5  HARBOR  SOUTH BUREAU     5A15 15,698,893.0403
#
#        PERIMETER         Shape__Are        Shape__Len  \
# 0  13,489.076845 8,990,764.35058594 13,489.0768449759
# 1 15,408.6119051 12,066,207.8945313 15,408.6119050818
# 2 16,626.3076558   10,535,450.46875 16,626.3076557746
# 3 12,878.1808569 10,252,327.5166016  12,878.180856913
# 4  19,760.285056 15,698,893.0380859  19,760.285055993
#
#                                             geometry
# 0  POLYGON ((-118.30892111155 33.8170462789921, -...
# 1  POLYGON ((-118.308361446386 33.8089939909678, ...
# ...

# %% [markdown]
# ### Geography: LAPD divisions

# %%
districts = gpd.read_file('/Users/mhustiles/Desktop/github/notebooks/arrests/input/LAPD_Divisions/LAPD_Divisions.shp')

# %%
districts.plot()

# %%
districts.head()
# Out:
#    OBJECTID        APREC  PREC             AREA      PERIMETER  \
# 0         1      MISSION    19  699,582,609.226 190,817.495739
# 1         2   DEVONSHIRE    17 1,346,816,369.83 175,591.702871
# 2         3     FOOTHILL    16 1,297,384,550.74 203,717.879169
# 3         4      TOPANGA    21  909,032,643.829 155,505.795458
# 4         5  WEST VALLEY    10  936,405,735.233 136,316.899694
#
#          Shape__Are        Shape__Len  \
# 0  0.00636337016502  0.57617741864457
# 1 0.012248870266222 0.534006674038975
# 2 0.011797447409252  0.62775481937394
# 3 0.008259907673307 0.470165251933301
# 4  0.00850700942907 0.407795145942631
#
#                                             geometry
# 0  POLYGON ((-118.50735928314 34.3346403905959, -...
# 1  POLYGON ((-118.50735928314 34.3346403905959, -...
# 2  POLYGON ((-118.415805070687 34.2938431214396, ...
# 3  POLYGON ((-118.631656365269 34.2385791630306, ...
# 4  POLYGON ((-118.562293263355 34.2203518619892, ...
