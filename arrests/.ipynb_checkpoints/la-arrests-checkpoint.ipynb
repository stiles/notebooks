# %% [markdown]
# # LAPD Arrests

# %%
import pandas as pd
import matplotlib as mpl
import geopandas as gpd
import descartes
import geojson
import json
import io
import numpy as np
import requests
import warnings
import altair as alt
alt.renderers.enable('notebook')
import altair_latimes as lat
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
pd.options.display.max_columns = 50
pd.options.display.max_rows = 500

# %% [markdown]
# ### Get arrest data from city portal

# %%
# url='https://data.lacity.org/api/views/yru6-6re4/rows.csv'
# data=requests.get(url).content
# src=pd.read_csv(io.StringIO(data.decode('utf-8')))
# arrests = src

arrests = pd.read_csv('/Users/mhustiles/Desktop/data/LA/Arrest_Data_from_2010_to_Present.csv')

# %% [markdown]
# ### Clean up arrests DataFrame

# %%
arrests.columns = arrests.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
arrests.dtypes
# Out:
# report_id                            int64
# arrest_date                 datetime64[ns]
# time                               float64
# area_id                              int64
# area_name                           object
# reporting_district                   int64
# age                                  int64
# sex_code                            object
# descent_code                        object
# charge_group_code                  float64
# charge_group_description            object
# arrest_type_code                    object
# charge                              object
# charge_description                  object
# address                             object
# cross_street                        object
# location                            object
# year                                 int64
# day                                  int64
# month                                int64
# weekday                             object
# dtype: object

# %%
arrests['arrest_date'] = pd.to_datetime(arrests['arrest_date'], format='%m/%d/%Y')
arrests['year'] = arrests['arrest_date'].dt.year
arrests['day'] = arrests['arrest_date'].dt.day
arrests['month'] = arrests['arrest_date'].dt.month
arrests[['report_id', 'time', 'area_id', 'charge_group_code', 'reporting_district', 'year', 'month', 'day']] = arrests[['report_id', 'time', 'area_id', 'charge_group_code', 'reporting_district', 'year', 'month','day']].astype(str)
arrests['charge_group_code'] = arrests['charge_group_code'].str.replace('.0', '', regex=False)
arrests['weekday'] = arrests['arrest_date'].dt.weekday_name
arrests['time'] = arrests['time'].str.replace('.0','', regex=False)
arrests['hour'] = arrests['time'].str[:2]
arrests['minute'] = arrests['time'].str[2:]

# %%
len(arrests)
# Out:
# 1297610

# %% [markdown]
# ### Separate location field into lat/lon

# %%
arrests['location'] = arrests.location.str.replace('(', '').str.replace(')', '')

lat = []
lon = []

for row in arrests['location']:
    try:
        lat.append(row.split(',')[0])
        lon.append(row.split(',')[1])
    except:
        lat.append(np.NaN)
        lon.append(np.NaN)

arrests['latitude'] = lat
arrests['longitude'] = lon

arrests['latitude'] = arrests['latitude'].astype(float)
arrests['longitude'] = arrests['longitude'].astype(float)

# %%
arrests.drop('cross_street', axis=1, inplace=True)

# %%
arrests.columns
# Out:
# Index(['report_id', 'arrest_date', 'time', 'area_id', 'area_name',
#        'reporting_district', 'age', 'sex_code', 'descent_code',
#        'charge_group_code', 'charge_group_description', 'arrest_type_code',
#        'charge', 'charge_description', 'address', 'location', 'year', 'day',
#        'month', 'weekday', 'hour', 'minute', 'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# ### Count the arrests by charge type

# %%
charges_grouped = arrests.groupby(['charge', 'charge_description']).agg('size').sort_values(ascending=False).reset_index(name='total')

# %% [markdown]
# ### Top 10 arrest charges 2010-2019

# %%
charges_grouped.head(10)
# Out:
#        charge                        charge_description  total
# 0  23152(A)VC               DRUNK DRIVING ALCOHOL/DRUGS  96833
# 1  41.27CLAMC                        DRINKING IN PUBLIC  93397
# 2  273.5(A)PC  CORPORAL INJURY ON SPOUSE/COHABITANT/ETC  45890
# 3  11377(A)HS           POSSESSION CONTROLLED SUBSTANCE  40611
# 4     853.7PC                 FTA AFTER WRITTEN PROMISE  31416
# 5  11350(A)HS  POSSESSION NARCOTIC CONTROLLED SUBSTANCE  29348
# 6    647(B)PC                              PROSTITUTION  26503
# 7     25620BP   OPEN ALCOHOLIC BEV IN PUBLIC PARK/PLACE  25890
# 8  41.18DLAMC          SIT/LIE/SLEEP SIDEWALK OR STREET  25695
# 9        LAMC                LOS ANGELES MUNICIPAL CODE  24527

# %% [markdown]
# ### Isolate all 'sit-lie' cases and just 41.18D

# %%
sit_lie_all = arrests[arrests.charge.str.contains('41.18')]
sit_lie_d = arrests[arrests['charge'] == '41.18DLAMC']

# %%
# How many 'sit-lie' cases total?
len(sit_lie_all)
# Out:
# 36900

# %%
# How many '41.18D' cases total?
len(sit_lie_d)
# Out:
# 28692

# %% [markdown]
# ### Group all 'sit-lie' cases by charge, location, year — and count arrests

# %%
charges_grouped_sit_lie_all = sit_lie_all.groupby(['charge', 'charge_description', 'area_name', 'reporting_district', 'year']).agg('size').sort_values(ascending=False).reset_index()

# %%
charges_grouped_sit_lie_all.columns = ['charge', 'charge_description', 'area_name', 'reporting_district', 'year','total']
charges_grouped_sit_lie_all['reporting_district'] = charges_grouped_sit_lie_all['reporting_district'].astype(str)

# %%
charges_grouped_sit_lie_all.head()
# Out:
#        charge                charge_description area_name reporting_district  \
# 0  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                157
# 1  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                111
# 2  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                158
# 3  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                157
# 4  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                157
#
#    year  total
# 0  2016    572
# 1  2017    427
# 2  2013    425
# 3  2014    423
# 4  2013    388

# %% [markdown]
# ---

# %% [markdown]
# # Geography

# %% [markdown]
# ### Import LAPD reporting districts

# %%
# convert from shp to geojson
# !mapshaper '/Users/mhustiles/Desktop/github/notebooks/arrests/input/LAPD_Reporting_Districts/*.shp'\
-o format=geojson\
'/Users/mhustiles/Desktop/github/notebooks/arrests/output/lapd_reporting_districts.json'

reporting_districts_src = gpd.read_file('/Users/mhustiles/Desktop/github/notebooks/arrests/output/lapd_reporting_districts.json')
# Out:
# [o] Wrote /Users/mhustiles/Desktop/github/notebooks/arrests/output/lapd_reporting_districts.json

# %%
reporting_districts_src.plot()

# %%
reporting_districts_src.columns = reporting_districts_src.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
districts = reporting_districts_src[['repdist', 'repdist', 'aprec', 'area', 'geometry']]
districts.head()
# Out:
#    repdist  repdist   aprec          area  \
# 0      508      508  HARBOR  8.990764e+06
# 1      509      509  HARBOR  1.206621e+07
# 2      518      518  HARBOR  1.053545e+07
# 3      515      515  HARBOR  1.025233e+07
# 4      514      514  HARBOR  1.569889e+07
#
#                                             geometry
# 0  POLYGON ((-118.30892111155 33.8170462789921, -...
# 1  POLYGON ((-118.308361446386 33.8089939909678, ...
# 2  POLYGON ((-118.256808964071 33.7995306576062, ...
# 3  POLYGON ((-118.275300496187 33.7985858785498, ...
# 4  POLYGON ((-118.275300496187 33.7985858785498, ...

# %% [markdown]
# ---

# %% [markdown]
# ### Import LAPD divisions

# %%
# convert from shp to geojson
# !mapshaper '/Users/mhustiles/Desktop/github/notebooks/arrests/input/LAPD_Divisions/LAPD_Divisions.shp'\
-o format=geojson\
'/Users/mhustiles/Desktop/github/notebooks/arrests/output/lapd_divisions.json'

divisions_src = gpd.read_file('/Users/mhustiles/Desktop/github/notebooks/arrests/output/lapd_divisions.json')
# Out:
# [o] Wrote /Users/mhustiles/Desktop/github/notebooks/arrests/output/lapd_divisions.json

# %%
divisions_src.plot()

# %%
divisions_src.columns = divisions_src.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
divisions = divisions_src[['aprec', 'prec', 'area', 'geometry']]

# %% [markdown]
# ### Import LA Times neighborhoods

# %%
hoodssrc = gpd.read_file('/Users/mhustiles/Desktop/data/GIS/LA/la-county-city-neighborhoods.geojson')

# %%
hoodssrc.columns = hoodssrc.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
hoodssrc.plot()

# %% [markdown]
# ### Trim the dataframe

# %%
hoods = hoodssrc[['slug', 'name', 'sqmi', 'type', 'geometry']]

# %%
hoods.head()
# Out:
#               slug             name            sqmi                 type  \
# 0            acton            Acton   39.3391089485  unincorporated-area
# 1  adams-normandie  Adams-Normandie  0.805350187789    segment-of-a-city
# 2     agoura-hills     Agoura Hills   8.14676029818      standalone-city
# 3       agua-dulce       Agua Dulce   31.4626319451  unincorporated-area
# 4         alhambra         Alhambra   7.62381430605      standalone-city
#
#                                             geometry
# 0  (POLYGON ((-118.2026174792054 34.5389897207692...
# 1  (POLYGON ((-118.3090080000001 34.0374109991240...
# 2  (POLYGON ((-118.761925 34.16820299912263, -118...
# 3  (POLYGON ((-118.2546773959221 34.5583040337505...
# 4  (POLYGON ((-118.1217470000001 34.1050399991233...

# %% [markdown]
# ---

# %% [markdown]
# ## Merge arrests data with geography

# %% [markdown]
# ### Relate all 'sit-lie' arrests to LA Times neighborhoods

# %%
sit_lie_all_gdf = gpd.GeoDataFrame(sit_lie_all, geometry=gpd.points_from_xy(sit_lie_all.longitude, sit_lie_all.latitude))

# %%
sit_lie_all_gdf.crs = {'init': "epsg:4326"}

# %%
sit_lie_all_hoods = gpd.sjoin(sit_lie_all_gdf, hoods, op='within', how="inner")

# %%
sit_lie_all_hoods.iloc[[10]]
# Out:
#       report_id arrest_date time area_id  area_name reporting_district  age  \
# 9592  190616851  2019-08-01  845       6  Hollywood                667   45
#
#      sex_code descent_code charge_group_code        charge_group_description  \
# 9592        M            B                24  Miscellaneous Other Violations
#
#      arrest_type_code     charge     charge_description     address  \
# 9592                M  41.18LAMC  LOITERING (GENERALLY)  DE LONGPRE
#
#                location  year day month   weekday hour minute  latitude  \
# 9592  34.0944, -118.319  2019   1     8  Thursday   84      5   34.0944
#
#       longitude                  geometry  index_right       slug       name  \
# 9592   -118.319  POINT (-118.319 34.0944)          106  hollywood  Hollywood
#
#                sqmi               type
# 9592  3.50639022096  segment-of-a-city

# %%
sit_lie_all_hoods_slim = sit_lie_all_hoods[['report_id','arrest_date','time','area_id','area_name','reporting_district','age','sex_code','descent_code','charge_group_code','charge_group_description','arrest_type_code','charge','charge_description','year','month','weekday','slug','name','sqmi','type']]

# %%
sit_lie_all_hoods_slim.head()
len(sit_lie_all_hoods_slim)
# Out:
# 36873

# %% [markdown]
# ### Totals by neighborhood

# %%
hood_counts = sit_lie_all_hoods_slim.groupby(['name']).agg('size').sort_values(ascending=False).reset_index(name='total')

# %%
#Large neighborhoods
hood_counts_big = hood_counts[hood_counts['total'] > 300 ].sort_values(by='total', ascending=False)

# %%
hood_counts['total'].sum()
# Out:
# 36873

# %%
hood_counts['share'] = ((hood_counts['total'] / hood_counts['total'].sum())*100).round()
hood_counts
# Out:
#                         name  total  share
# 0                   Downtown  19312   52.0
# 1                  Hollywood   5892   16.0
# 2                     Venice   4978   14.0
# 3                   Sawtelle    599    2.0
# 4     Historic South-Central    479    1.0
# 5              Vermont Vista    453    1.0
# 6                   Westlake    427    1.0
# 7             East Hollywood    374    1.0
# 8            Hollywood Hills    355    1.0
# 9            North Hollywood    329    1.0
# 10               North Hills    303    1.0
# 11                 San Pedro    252    1.0
# 12                  Van Nuys    197    1.0
# 13                 Chinatown    197    1.0
# 14                  Florence    150    0.0
# 15                South Park    140    0.0
# 16             Panorama City    122    0.0
# 17               Studio City    118    0.0
# 18                 Los Feliz     95    0.0
# 19                Pico-Union     91    0.0
# 20          West Los Angeles     91    0.0
# 21            Harbor Gateway     84    0.0
# 22                 Echo Park     79    0.0
# 23               Canoga Park     77    0.0
# 24                    Sylmar     74    0.0
# 25                  Mid-City     68    0.0
# 26           Central-Alameda     67    0.0
# 27               Harbor City     67    0.0
# 28                 Koreatown     62    0.0
# 29                  Westwood     62    0.0
# 30               Valley Glen     58    0.0
# 31              Santa Monica     50    0.0
# 32               Silver Lake     44    0.0
# 33                 Mar Vista     40    0.0
# 34               Rancho Park     40    0.0
# 35                     Palms     39    0.0
# 36            Vermont Square     37    0.0
# 37                     Watts     36    0.0
# 38                Eagle Rock     36    0.0
# 39                Sun Valley     35    0.0
# 40            Woodland Hills     35    0.0
# 41                 Brentwood     34    0.0
# 42             Highland Park     33    0.0
# 43         Montecito Heights     33    0.0
# 44                Wilmington     32    0.0
# 45           Vermont-Slauson     31    0.0
# 46           Exposition Park     30    0.0
# 47   Veterans Administration     28    0.0
# 48                  Torrance     28    0.0
# 49       Broadway-Manchester     26    0.0
# 50                   Del Rey     25    0.0
# 51                   Tarzana     23    0.0
# 52             Green Meadows     22    0.0
# 53           University Park     19    0.0
# 54            Jefferson Park     19    0.0
# 55                West Adams     19    0.0
# 56            Valley Village     19    0.0
# 57         Pacific Palisades     18    0.0
# 58                    Arleta     17    0.0
# 59              Sherman Oaks     17    0.0
# 60       Chesterfield Square     16    0.0
# 61               Westchester     16    0.0
# 62           Harvard Heights     15    0.0
# 63                Northridge     15    0.0
# 64                   Fairfax     15    0.0
# 65                    Reseda     14    0.0
# 66                   Tujunga     12    0.0
# 67    Baldwin Hills/Crenshaw     12    0.0
# 68                Long Beach     11    0.0
# 69            Vermont Knolls     11    0.0
# 70                Chatsworth     10    0.0
# 71               Toluca Lake     10    0.0
# 72             Granada Hills     10    0.0
# 73                   Pacoima      9    0.0
# 74            Pico-Robertson      9    0.0
# 75             Gramercy Park      9    0.0
# 76                 La Puente      8    0.0
# 77              Mid-Wilshire      8    0.0
# 78             Boyle Heights      8    0.0
# 79           Atwater Village      8    0.0
# 80             Glassell Park      7    0.0
# 81           Adams-Normandie      7    0.0
# 82                  Winnetka      7    0.0
# 83      Hollywood Hills West      7    0.0
# 84              Leimert Park      7    0.0
# 85             Mission Hills      6    0.0
# 86             Beverly Grove      6    0.0
# 87                West Hills      6    0.0
# 88                   Carthay      5    0.0
# 89              Bell Gardens      5    0.0
# 90                   Gardena      5    0.0
# 91                    Encino      4    0.0
# 92              Hancock Park      4    0.0
# 93                 El Sereno      3    0.0
# 94                 Inglewood      3    0.0
# 95                 Larchmont      3    0.0
# 96                 Hyde Park      3    0.0
# 97         Arlington Heights      3    0.0
# 98              Cypress Park      3    0.0
# 99             Cheviot Hills      3    0.0
# 100                   Pomona      3    0.0
# 101            Beverly Hills      2    0.0
# 102             San Fernando      2    0.0
# 103                 Westmont      2    0.0
# 104                  Sunland      2    0.0
# 105            Santa Clarita      2    0.0
# 106              Beverlywood      2    0.0
# 107          Lincoln Heights      2    0.0
# 108             Harvard Park      2    0.0
# 109             Century City      1    0.0
# 110                 Cerritos      1    0.0
# 111            Playa del Rey      1    0.0
# 112               Hansen Dam      1    0.0
# 113                  Topanga      1    0.0
# 114                Lancaster      1    0.0
# 115             Elysian Park      1    0.0
# 116           Elysian Valley      1    0.0
# 117       Florence-Firestone      1    0.0
# 118            Hermosa Beach      1    0.0
# 119           West Hollywood      1    0.0
# 120                 Glendale      1    0.0
# 121           Windsor Square      1    0.0
# 122               Montebello      1    0.0

# %%
bars = alt.Chart(hood_counts_big).mark_bar().encode(
    x=alt.X('total:Q', title="Arrests", axis=alt.Axis(format='', tickCount=6)), 
    y=alt.Y(
        'name:N',
        sort=alt.EncodingSortField(
            field="total",  # The field to use for the sort
            order="descending"  # The order to sort in
        )
    )
)
text = bars.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='total:Q'
)
(bars + text).properties(height=500, width=400)

# %%
hood_counts_years = sit_lie_all_hoods_slim.groupby(['name', 'year']).agg('size').sort_values(ascending=False).reset_index(name='total')

# %%
hood_counts_years
# Out:
#                         name  year  total
# 0                   Downtown  2017   3745
# 1                   Downtown  2016   3295
# 2                   Downtown  2013   3000
# 3                   Downtown  2014   2633
# 4                   Downtown  2015   2502
# 5                   Downtown  2012   2157
# 6                   Downtown  2018   1324
# 7                     Venice  2013    858
# 8                     Venice  2015    836
# 9                  Hollywood  2012    817
# 10                 Hollywood  2013    799
# 11                    Venice  2014    789
# 12                 Hollywood  2017    721
# 13                 Hollywood  2018    708
# 14                    Venice  2016    704
# 15                 Hollywood  2016    613
# 16                    Venice  2017    601
# 17                 Hollywood  2010    589
# 18                 Hollywood  2011    560
# 19                 Hollywood  2015    535
# 20                    Venice  2012    496
# 21                 Hollywood  2014    461
# 22                    Venice  2018    415
# 23                  Downtown  2011    353
# 24             Vermont Vista  2015    252
# 25                  Sawtelle  2018    245
# 26                  Downtown  2019    207
# 27                  Sawtelle  2017    169
# 28               North Hills  2010    156
# 29                    Venice  2019    140
# 30    Historic South-Central  2014    131
# 31            East Hollywood  2016    124
# 32                  Westlake  2018    118
# 33    Historic South-Central  2015    109
# 34             Vermont Vista  2014     97
# 35                  Downtown  2010     96
# 36                  Van Nuys  2016     95
# 37                    Venice  2010     94
# 38                 San Pedro  2018     91
# 39                 Hollywood  2019     89
# 40                  Sawtelle  2016     88
# 41    Historic South-Central  2013     88
# 42                 San Pedro  2016     81
# 43            Harbor Gateway  2010     79
# 44           North Hollywood  2018     78
# 45           Hollywood Hills  2018     73
# 46                  Westlake  2016     72
# 47                 Chinatown  2016     71
# 48                  Florence  2013     70
# 49           North Hollywood  2015     68
# 50                  Westlake  2017     65
# 51    Historic South-Central  2012     64
# 52           North Hollywood  2014     63
# 53               Harbor City  2010     59
# 54           North Hollywood  2013     56
# 55           Hollywood Hills  2012     51
# 56           Hollywood Hills  2011     50
# 57                  Westlake  2019     48
# 58           Hollywood Hills  2015     48
# 59            East Hollywood  2012     47
# 60               North Hills  2011     46
# 61             Vermont Vista  2012     46
# 62          West Los Angeles  2017     45
# 63                    Venice  2011     45
# 64           Hollywood Hills  2014     43
# 65                  Sawtelle  2019     41
# 66           Hollywood Hills  2013     38
# 67                  Westlake  2012     38
# 68                 Chinatown  2015     37
# 69                  Florence  2014     37
# 70            East Hollywood  2011     37
# 71               North Hills  2013     37
# 72                  Westlake  2013     37
# 73                 Chinatown  2017     35
# 74                 San Pedro  2017     35
# 75               Studio City  2018     34
# 76                South Park  2015     34
# 77            East Hollywood  2010     34
# 78                South Park  2012     34
# 79            East Hollywood  2018     32
# 80                  Westwood  2017     30
# 81    Historic South-Central  2011     30
# 82                    Sylmar  2013     29
# 83                South Park  2014     29
# 84                 Brentwood  2018     29
# 85                 Chinatown  2014     29
# 86             Vermont Vista  2013     29
# 87               Rancho Park  2017     29
# 88                  Van Nuys  2012     29
# 89           North Hollywood  2016     28
# 573          Vermont-Slauson  2015      1
# 574                  Fairfax  2010      1
# 575          Exposition Park  2010      1
# 576                   Encino  2015      1
# 577           Elysian Valley  2017      1
# 578           Harbor Gateway  2012      1
# 579          Harvard Heights  2013      1
# 580                La Puente  2014      1
# 581          Harvard Heights  2014      1
# 582          University Park  2018      1
# 583           Jefferson Park  2019      1
# 584                Inglewood  2012      1
# 585                Hyde Park  2016      1
# 586                Hyde Park  2014      1
# 587                Hyde Park  2013      1
# 588     Hollywood Hills West  2018      1
# 589     Hollywood Hills West  2016      1
# 590          Hollywood Hills  2019      1
# 591           Valley Village  2013      1
# 592           Valley Village  2014      1
# 593           Valley Village  2015      1
# 594   Historic South-Central  2019      1
# 595             Sherman Oaks  2018      1
# 596                 Van Nuys  2019      1
# 597           Vermont Knolls  2014      1
# 598           Vermont Square  2010      1
# 599           Vermont Square  2013      1
# 600            Highland Park  2015      1
# 601            Highland Park  2012      1
# 602           Vermont Square  2015      1
# 603            Hermosa Beach  2013      1
# 604             Harvard Park  2016      1
# 605             Harvard Park  2010      1
# 606          Harvard Heights  2018      1
# 607                 Van Nuys  2014      1
#
# [608 rows x 3 columns]

# %%
hood_counts_years_pivot = pd.pivot_table(hood_counts_years, values='total', index=['name'], columns=['year'], aggfunc=np.sum, fill_value=0).sort_values(by='2019', ascending=False).reset_index()
hood_counts_years_pivot.head(10)
# Out:
# year             name  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# 0            Downtown    96   353  2157  3000  2633  2502  3295  3745  1324
# 1              Venice    94    45   496   858   789   836   704   601   415
# 2           Hollywood   589   560   817   799   461   535   613   721   708
# 3            Westlake     2    12    38    37    18    17    72    65   118
# 4            Sawtelle     2     4     9     3    12    26    88   169   245
# 5           San Pedro    20     0     0     1     0     9    81    35    91
# 6      East Hollywood    34    37    47    27    23    14   124    24    32
# 7     Exposition Park     1    10     5     2     0     0     0     0     2
# 8       Highland Park     9     7     1     2     0     1     4     0     0
# 9      Woodland Hills     0     0     2     3     0     1     3     7    10
#
# year  2019
# 0      207
# 1      140
# 2       89
# 3       48
# 4       41
# 5       15
# 6       12
# 7       10
# 8        9
# 9        9

# %%
#Large neighborhoods
hood_counts_years_big = hood_counts_years[hood_counts_years['total'] > 50 ].sort_values(by='total', ascending=False)

# %%
hood_counts_years_big.head(10)
# Out:
#         name  year  total
# 0   Downtown  2017   3745
# 1   Downtown  2016   3295
# 2   Downtown  2013   3000
# 3   Downtown  2014   2633
# 4   Downtown  2015   2502
# 5   Downtown  2012   2157
# 6   Downtown  2018   1324
# 7     Venice  2013    858
# 8     Venice  2015    836
# 9  Hollywood  2012    817

# %%
alt.Chart(hood_counts_years_big).mark_bar().encode(
    y=alt.Y('total:Q', title="Arrests", axis=alt.Axis(format='', tickCount=6),
        sort=alt.EncodingSortField(
            field="year",  # The field to use for the sort
            order="ascending"  # The order to sort in
        )), 
    x=alt.X(
        'year:N'
    ),
    facet='name:O').properties(
    columns=3,
    width=200,
    height=200
)

# %% [markdown]
# ### Merge hood counts back to geometry
