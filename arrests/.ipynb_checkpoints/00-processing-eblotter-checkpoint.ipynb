# %%
import pandas as pd
import zipfile
import pyarrow
import os
import glob
import json
import numpy as np
from altair import datum
import altair as alt
alt.renderers.enable('notebook')
import altair_latimes as lat
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
pd.options.display.float_format = '{:.2f}'.format

# %%
arrests = pd.read_excel('input/dabis_eblotter.xlsx', skiprows=range(0,3))

# %%
arrests.columns = arrests.columns.str.strip().str.lower().str.replace(' ', '_')\
                    .str.replace('(', '').str.replace(')', '').str.replace('-','_')

# %%
arrests.head()
# Out:
#    bkg_num    bkg_dt bkg_tm arr_div                             arr_loc  \
# 0  5792555  11/07/19  00:03    4265                                 OSO
# 1  5792556  11/07/19  00:05    4212                                51ST
# 2  5792557  11/07/19  00:05    4203          23RD                    ST
# 3  5792560  11/07/19  00:12    4206  1655  N WESTERN                 AV
# 4  5792564  11/07/19  00:13    4206                      1828    WILCOX
#
#                     arr_crsst  arr_zip   last_nm    frst_nm mid_nm  ...  \
# 0                     SATICOY      nan  GONZALEZ    NATALIE   ROSE  ...
# 1                    FIGUEROA      nan      LOVE     JOSHUA    NaN  ...
# 2  FIGUEROA                ST      nan   ANTUNES       JOSE    NaN  ...
# 3                         NaN 90028.00    GULLEY    BRIANNA    NaN  ...
# 4                         NaN      nan  SIMENTAL  ELIZABETH    NaN  ...
#
#    charge.2 chg_lvl.2  bail.2   tot_bail    arr_dt  arr_tm    rel_dt rel_tm  \
# 0  602(K)PC         M 5000.00  110000.00  11/06/19   21:40       NaN    NaN
# 1       NaN       NaN     nan   25000.00  11/06/19   20:00       NaN    NaN
# 2       NaN       NaN     nan   20000.00  11/06/19   22:00       NaN    NaN
# 3       NaN       NaN     nan    2000.00  11/06/19   22:30  11/07/19  04:37
# 4       NaN       NaN     nan    2000.00  11/06/19   21:45  11/07/19  00:53
#
#   rel_reason rel_loc
# 0        NaN     nan
# 1        NaN     nan
# 2        NaN     nan
# 3         OR 4206.00
# 4         OR 4206.00
#
# [5 rows x 36 columns]

# %%
arrests.columns
# Out:
# Index(['bkg_num', 'bkg_dt', 'bkg_tm', 'arr_div', 'arr_loc', 'arr_crsst',
#        'arr_zip', 'last_nm', 'frst_nm', 'mid_nm', 'occupation', 'sex', 'desc',
#        'hair', 'eyes', 'hgt', 'wgt', 'dob', 'res_loc', 'charge', 'chg_lvl',
#        'bail', 'chg_desc', 'charge.1', 'chg_lvl.1', 'bail.1', 'charge.2',
#        'chg_lvl.2', 'bail.2', 'tot_bail', 'arr_dt', 'arr_tm', 'rel_dt',
#        'rel_tm', 'rel_reason', 'rel_loc'],
#       dtype='object')

# %%
arrests.rename(columns={
    'bkg_num':'booking_num',
    'bkg_num':'booking_date',
    'arr_div':'arr_div',
    'arr_dt':'arrest_date',
    'arr_loc':'arrest_address',
    'arr_crsst':'arrest_cross_street',
    'arr_zip':'arrest_zipcode',
    'frst_nm':'first_name',
    'mid_nm':'middle_name',
    'last_nm':'last_name',
    'occupation':'occupation',
    'sex':'gender',
    'desc':'race',
    'hair':'hair_color',
    'eyes':'eye_color',
    'hgt':'height',
    'wgt':'weight',
    'dob':'date_of_birth',
    'tot_bail':'total_bail',
    'rel_dt':'release_date',
    'rel_reason':'release_reason',
    'res_loc':'release_location',}, inplace=True)

# %%
arrests.head()
# Out:
#    booking_date    bkg_dt bkg_tm arr_div                      arrest_address  \
# 0       5792555  11/07/19  00:03    4265                                 OSO
# 1       5792556  11/07/19  00:05    4212                                51ST
# 2       5792557  11/07/19  00:05    4203          23RD                    ST
# 3       5792560  11/07/19  00:12    4206  1655  N WESTERN                 AV
# 4       5792564  11/07/19  00:13    4206                      1828    WILCOX
#
#           arrest_cross_street  arrest_zipcode last_name first_name  \
# 0                     SATICOY             nan  GONZALEZ    NATALIE
# 1                    FIGUEROA             nan      LOVE     JOSHUA
# 2  FIGUEROA                ST             nan   ANTUNES       JOSE
# 3                         NaN        90028.00    GULLEY    BRIANNA
# 4                         NaN             nan  SIMENTAL  ELIZABETH
#
#   middle_name  ...  charge.2 chg_lvl.2  bail.2 total_bail arrest_date  arr_tm  \
# 0        ROSE  ...  602(K)PC         M 5000.00  110000.00    11/06/19   21:40
# 1         NaN  ...       NaN       NaN     nan   25000.00    11/06/19   20:00
# 2         NaN  ...       NaN       NaN     nan   20000.00    11/06/19   22:00
# 3         NaN  ...       NaN       NaN     nan    2000.00    11/06/19   22:30
# 4         NaN  ...       NaN       NaN     nan    2000.00    11/06/19   21:45
#
#    release_date rel_tm release_reason rel_loc
# 0           NaN    NaN            NaN     nan
# 1           NaN    NaN            NaN     nan
# 2           NaN    NaN            NaN     nan
# 3      11/07/19  04:37             OR 4206.00
# 4      11/07/19  00:53             OR 4206.00
#
# [5 rows x 36 columns]
