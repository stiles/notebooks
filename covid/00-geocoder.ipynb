# %%
import pandas as pd
import requests
import logging
import time
#request cache

# %%
key = '<GOOGLE_API_KEY>'

# %%
logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)
# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

# %%
API_KEY = '<GOOGLE_API_KEY>'
BACKOFF_TIME = 1
output_filename = 'output/output.csv'
input_filename = 'output/addresses.csv'
address_column_name = 'address'
RETURN_FULL_RESULTS = True

# %%
data = pd.read_csv(input_filename, encoding='utf8')

if address_column_name not in data.columns:
    raise ValueError("Missing Address column in input data")

addresses = data[address_column_name].tolist()
addresses = (data[address_column_name]).tolist()

# %%
def get_google_results(address, api_key='AIzaSyC72T3bzuR5O9vVB-91FecXNr5nKa8rfdY', return_full_response=True):
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + '&key={}'.format(api_key)
        
    results = requests.get(geocode_url)
    results = results.json()
    
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
         
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

results = []
for address in addresses:
    geocoded = False
    while geocoded is not True:
        try:
            geocode_result = get_google_results(address, API_KEY, return_full_response=RETURN_FULL_RESULTS)
        except Exception as e:
            logger.exception(e)
            logger.error("Major error with {}".format(address))
            logger.error("Skipping!")
            geocoded = True
            
        if geocode_result['status'] == 'OVER_QUERY_LIMIT':
            logger.info("Hit Query Limit! Backing off for a bit.")
            time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
            geocoded = False
        else:
            if geocode_result['status'] != 'OK':
                logger.warning("Error geocoding {}: {}".format(address, geocode_result['status']))
            logger.debug("Geocoded: {}: {}".format(address, geocode_result['status']))
            results.append(geocode_result)           
            geocoded = True

    if len(results) % 500 == 0:
        logger.info("Completed {} of {} address".format(len(results), len(addresses)))
            
    if len(results) % 500 == 0:
        pd.DataFrame(results).to_csv("{}_bak".format(output_filename))

logger.info("Finished geocoding all addresses")
pd.DataFrame(results).to_csv(output_filename, encoding='utf8')
# Out:
# Geocoded: 2450 Ashby Avenue, Berkeley, CA 94705: OK
# Geocoded: 2450 Ashby Avenue, Berkeley, CA 94705: OK
# Geocoded: 2001 Dwight Way, Berkeley, CA 94704: OK
# Geocoded: 2001 Dwight Way, Berkeley, CA 94704: OK
# Geocoded: 2920 Telegraph Ave, Berkeley CA 94705: OK
# Geocoded: 2920 Telegraph Ave, Berkeley CA 94705: OK
# Geocoded: 411 Grand Ave, Oakland, CA 94610: OK
# Geocoded: 411 Grand Ave, Oakland, CA 94610: OK
# Geocoded: 3918 Fallon Road, Dublin, CA 94568: OK
# Geocoded: 3918 Fallon Road, Dublin, CA 94568: OK
# Geocoded: 20103 Lake Chabot Road, Castro Valley, CA 94546: OK
# Geocoded: 20103 Lake Chabot Road, Castro Valley, CA 94546: OK
# Geocoded: 39199 Liberty Street, Building B, Fremont, CA 94538: OK
# Geocoded: 39199 Liberty Street, Building B, Fremont, CA 94538: OK
# Geocoded: 28270 Huntwood Ave, Hayward, CA 94544: OK
# Geocoded: 28270 Huntwood Ave, Hayward, CA 94544: OK
# Geocoded: 3100 San Pablo Ave, Berkeley, CA 94702: OK
# Geocoded: 3100 San Pablo Ave, Berkeley, CA 94702: OK
# Geocoded: 5860 Owens Dr, Pleasanton, CA 94588: OK
# Geocoded: 5860 Owens Dr, Pleasanton, CA 94588: OK
# Geocoded: 2001 Dwight Way Ste. 1388, Berkeley, CA 94704: OK
# Geocoded: 2001 Dwight Way Ste. 1388, Berkeley, CA 94704: OK
# Geocoded: 4951 Arroyo Road, Livermore, CA 94550: OK
# Geocoded: 4951 Arroyo Road, Livermore, CA 94550: OK
# Geocoded: 2221 Martin Luther King Jr. Way, Oakland, CA 94612: OK
# Geocoded: 2221 Martin Luther King Jr. Way, Oakland, CA 94612: OK
# Geocoded: 5095 Telegraph Avenue, Oakland, CA 94609: OK
# Geocoded: 5095 Telegraph Avenue, Oakland, CA 94609: OK
# Geocoded: 350 Hawthorne Avenue, Oakland, CA 94609: OK
# Geocoded: 350 Hawthorne Avenue, Oakland, CA 94609: OK
# Geocoded: 2222 Bancroft Way, Berkeley, CA 94720: OK
# Geocoded: 2222 Bancroft Way, Berkeley, CA 94720: OK
# Geocoded: 75B Diamond Valley Road, Markleeville, CA 96120: OK
# Geocoded: 75B Diamond Valley Road, Markleeville, CA 96120: OK
# Geocoded: 280 Cohasset Road, Chico, CA 95926: OK
# Geocoded: 280 Cohasset Road, Chico, CA 95926: OK
# Geocoded: 2095 Diamond Blvd., Concord, CA 94520: OK
# Geocoded: 2095 Diamond Blvd., Concord, CA 94520: OK
# Geocoded: 1601 Ygnacio Valley Rd, Walnut Creek, CA 94598: OK
# Geocoded: 1601 Ygnacio Valley Rd, Walnut Creek, CA 94598: OK
# Geocoded: 2400 Balfour Rd Suite 120, Brentwood, CA 94513: OK
# Geocoded: 2400 Balfour Rd Suite 120, Brentwood, CA 94513: OK
# Geocoded: 1425 S Main St, Walnut Creek, CA 94596: OK
# Geocoded: 1425 S Main St, Walnut Creek, CA 94596: OK
# Geocoded: 150 Muir Road, Martinez, CA 94553: OK
# Geocoded: 150 Muir Road, Martinez, CA 94553: OK
# Geocoded: 460 Market Place, San Ramon, CA 94583: OK
# Geocoded: 460 Market Place, San Ramon, CA 94583: OK
# Geocoded: 3901 Lone Tree Way, Antioch, CA 94509: OK
# Geocoded: 3901 Lone Tree Way, Antioch, CA 94509: OK
# Geocoded: 2878 Ygnacio Valley Road, Walnut Creek, CA 94598: OK
# Geocoded: 2878 Ygnacio Valley Road, Walnut Creek, CA 94598: OK
# Geocoded: 2170 South Avenue, South Lake Tahoe, CA 96150: OK
# Geocoded: 2170 South Avenue, South Lake Tahoe, CA 96150: OK
# Geocoded: 2615 E. Clinton Avenue, Fresno, CA 93703: OK
# Geocoded: 2615 E. Clinton Avenue, Fresno, CA 93703: OK
# Geocoded: 930 W. Harris, Eureka, CA 95503: OK
# Geocoded: 930 W. Harris, Eureka, CA 95503: OK
# Geocoded: 3300 Renner Drive, Fortuna, CA 95540: OK
# Geocoded: 3300 Renner Drive, Fortuna, CA 95540: OK
# Geocoded: 2700 Dolbeer Street, Eureka, CA 95501: OK
# Geocoded: 2700 Dolbeer Street, Eureka, CA 95501: OK
# Geocoded: 1415 Ross Ave, El Centro, CA 92243: OK
# Geocoded: 1415 Ross Ave, El Centro, CA 92243: OK
# Geocoded: 1115 South 4th Street, El Centro, CA 92243: OK
# Geocoded: 1115 South 4th Street, El Centro, CA 92243: OK
# Geocoded: 150 Pioneer Ln, Bishop, CA 93514: OK
# Geocoded: 150 Pioneer Ln, Bishop, CA 93514: OK
# Geocoded: 1801 Westwind Drive, Bakersfield, CA 93301: OK
# Geocoded: 1801 Westwind Drive, Bakersfield, CA 93301: OK
# Geocoded: 1801 North China Lake Blvd, Ridgecrest, CA 93555: OK
# Geocoded: 1801 North China Lake Blvd, Ridgecrest, CA 93555: OK
# Geocoded: 15145 Lakeshore Drive, Clearlake, CA 95422: OK
# Geocoded: 15145 Lakeshore Drive, Clearlake, CA 95422: OK
# Geocoded: 5176 Hill Road, Lakeport, CA 95453: OK
# Geocoded: 5176 Hill Road, Lakeport, CA 95453: OK
# Geocoded: 110 Bella Way, Susanville, CA 96130: OK
# Geocoded: 110 Bella Way, Susanville, CA 96130: OK
# Geocoded: 1509 Wilson Ter, Glendale, CA 91206: OK
# Geocoded: 1509 Wilson Ter, Glendale, CA 91206: OK
# Geocoded: 1720 E Cesar E Chavez Ave, Los Angeles, CA 90033: OK
# Geocoded: 1720 E Cesar E Chavez Ave, Los Angeles, CA 90033: OK
# Geocoded: 335-B East Avenue K6, Lancaster, CA 93535: OK
# Geocoded: 335-B East Avenue K6, Lancaster, CA 93535: OK
# Geocoded: 309 W Beverly Blvd, Montebello, CA 90640: OK
# Geocoded: 309 W Beverly Blvd, Montebello, CA 90640: OK
# Geocoded: 1401 S Grand Ave, Los Angeles, CA 90015: OK
# Geocoded: 1401 S Grand Ave, Los Angeles, CA 90015: OK
# Geocoded: 2110 W Sunset Blvd Ste M, Los Angeles, CA 90026: OK
# Geocoded: 2110 W Sunset Blvd Ste M, Los Angeles, CA 90026: OK
# Geocoded: 600 E Colorado Blvd Ste 120, Pasadena, CA 91101: OK
# Geocoded: 600 E Colorado Blvd Ste 120, Pasadena, CA 91101: OK
# Geocoded: 8700 Beverly Blvd, West Hollywood, CA 90048: OK
# Geocoded: 8700 Beverly Blvd, West Hollywood, CA 90048: OK
# Geocoded: 555 E Hardy St, Inglewood, CA 90301: OK
# Geocoded: 555 E Hardy St, Inglewood, CA 90301: OK
# Geocoded: 241 N. Figueroa Street, Los Angeles, CA 90012: OK
# Geocoded: 241 N. Figueroa Street, Los Angeles, CA 90012: OK
# Geocoded: 1500 Duarte Rd, Duarte, CA 91010: OK
# Geocoded: 1500 Duarte Rd, Duarte, CA 91010: OK
# Geocoded: nan: OK
# Geocoded: nan: OK
# Geocoded: 2776 Pacific Ave, Long Beach, CA 90806: OK
# Geocoded: 2776 Pacific Ave, Long Beach, CA 90806: OK
# Geocoded: 5426 E. Olympic Boulevard, City of Commerce, CA 90040: OK
# Geocoded: 5426 E. Olympic Boulevard, City of Commerce, CA 90040: OK
# Geocoded: 250 S Grand Ave, Glendora, CA 91741: OK
# Geocoded: 250 S Grand Ave, Glendora, CA 91741: OK
# Geocoded: 210 W San Berrdino Rd, Covina, CA 91723: OK
# Geocoded: 210 W San Berrdino Rd, Covina, CA 91723: OK
# Geocoded: 10250 Santa Monica Blvd, Century City, CA 90067: OK
# Geocoded: 10250 Santa Monica Blvd, Century City, CA 90067: OK
# Geocoded: 759 America Way, Glendale, CA 91210: OK
# Geocoded: 759 America Way, Glendale, CA 91210: OK
# Geocoded: 1149 West 190th Street, Gardena, CA 90248: OK
# Geocoded: 1149 West 190th Street, Gardena, CA 90248: OK
# Geocoded: 525 N Garfield Ave, Monterey Park, CA 91754: OK
# Geocoded: 525 N Garfield Ave, Monterey Park, CA 91754: OK
# Geocoded: 1701 Santa Anita Ave, South El Monte, CA 91733: OK
# Geocoded: 1701 Santa Anita Ave, South El Monte, CA 91733: OK
# Geocoded: 1000 W Carson St, Torrance, CA 90502: OK
# Geocoded: 1000 W Carson St, Torrance, CA 90502: OK
# Geocoded: 23845 McBean Pkwy, Valencia, CA 91355: OK
# Geocoded: 23845 McBean Pkwy, Valencia, CA 91355: OK
# Geocoded: 5205 Melrose Avenue, Los Angeles, CA 90038: OK
# Geocoded: 5205 Melrose Avenue, Los Angeles, CA 90038: OK
# Geocoded: 1500 San Pablo St, Los Angeles, CA 90033: OK
# Geocoded: 1500 San Pablo St, Los Angeles, CA 90033: OK
# Geocoded: 1711 W Temple St, Los Angeles, CA 90026: OK
# Geocoded: 1711 W Temple St, Los Angeles, CA 90026: OK
# Geocoded: 340 E Avenue I Suite 108, Lancaster, CA 93535: OK
# Geocoded: 340 E Avenue I Suite 108, Lancaster, CA 93535: OK
# Geocoded: 2801 Atlantic Ave, Long Beach, CA 90806: OK
# Geocoded: 2801 Atlantic Ave, Long Beach, CA 90806: OK
# Geocoded: 351 East Temple Street, Los Angeles, CA 90012: OK
# Geocoded: 351 East Temple Street, Los Angeles, CA 90012: OK
# Geocoded: 4081 E Olympic Blvd, Los Angeles, CA 90023: OK
# Geocoded: 4081 E Olympic Blvd, Los Angeles, CA 90023: OK
# Geocoded: 2051 Marengo St, Los Angeles, CA 90033: OK
# Geocoded: 2051 Marengo St, Los Angeles, CA 90033: OK
# Geocoded: 4650 Lincoln Blvd, Marina del Rey, CA 90292: OK
# Geocoded: 4650 Lincoln Blvd, Marina del Rey, CA 90292: OK
# Geocoded: 11833 South Wilmington Avenue, Los Angeles, CA 90059: OK
# Geocoded: 11833 South Wilmington Avenue, Los Angeles, CA 90059: OK
# Geocoded: 14850 Roscoe Blvd, Panorama City, CA 91402: OK
# Geocoded: 14850 Roscoe Blvd, Panorama City, CA 91402: OK
# Geocoded: 330 W. Maple Avenue, Monrovia, CA 91016: OK
# Geocoded: 330 W. Maple Avenue, Monrovia, CA 91016: OK
# Geocoded: 14445 Olive View Dr, Sylmar, CA 91342: OK
# Geocoded: 14445 Olive View Dr, Sylmar, CA 91342: OK
# Geocoded: 13300 Van Nuys Boulevard, Pacoima, CA 91331: OK
# Geocoded: 13300 Van Nuys Boulevard, Pacoima, CA 91331: OK
# Geocoded: 11500 Brookshire Ave, Downey, CA 90241: OK
# Geocoded: 11500 Brookshire Ave, Downey, CA 90241: OK
# Geocoded: 1798 N. Garey Avenue, Pomona, CA 91767: OK
# Geocoded: 1798 N. Garey Avenue, Pomona, CA 91767: OK
# Geocoded: 15031 Rildi St, Mission Hills, CA 91345: OK
# Geocoded: 15031 Rildi St, Mission Hills, CA 91345: OK
# Geocoded: 1300 W 7th St, San Pedro, CA 90732: OK
# Geocoded: 1300 W 7th St, San Pedro, CA 90732: OK
# Geocoded: 4101 Torrance Blvd, Torrance, CA 90503: OK
# Geocoded: 4101 Torrance Blvd, Torrance, CA 90503: OK
# Geocoded: 2121 Santa Monica Blvd, Santa Monica, CA 90404: OK
# Geocoded: 2121 Santa Monica Blvd, Santa Monica, CA 90404: OK
# Geocoded: 18321 Clark St, Tarzana, CA 91356: OK
# Geocoded: 18321 Clark St, Tarzana, CA 91356: OK
# Geocoded: 7 West Foothill Blvd, Arcadia, CA 91006: OK
# Geocoded: 7 West Foothill Blvd, Arcadia, CA 91006: OK
# Geocoded: 16111 Plummer Street, North Hills, CA 91343: OK
# Geocoded: 16111 Plummer Street, North Hills, CA 91343: OK
# Geocoded: 2509 Pico Boulevard, Room 325, Santa Monica, CA 90405: OK
# Geocoded: 2509 Pico Boulevard, Room 325, Santa Monica, CA 90405: OK
# Geocoded: 757 Westwood Plaza, Los Angeles, CA 90095: OK
# Geocoded: 757 Westwood Plaza, Los Angeles, CA 90095: OK
# Geocoded: 3330 Lomita Blvd, Torrance, CA 90505: OK
# Geocoded: 3330 Lomita Blvd, Torrance, CA 90505: OK
# Geocoded: 711 Del Amo Boulevard, Torrance, CA 90502: OK
# Geocoded: 711 Del Amo Boulevard, Torrance, CA 90502: OK
# Geocoded: 2601 W Alameda Ave Ste 416, Burbank, CA 91505: OK
# Geocoded: 2601 W Alameda Ave Ste 416, Burbank, CA 91505: OK
# Geocoded: 15503 Ventura Blvd Ste 350, Encino, CA 91436: OK
# Geocoded: 15503 Ventura Blvd Ste 350, Encino, CA 91436: OK
# Geocoded: 23815 Stuart Ranch Rd Ste 301, Malibu, CA 90265: OK
# Geocoded: 23815 Stuart Ranch Rd Ste 301, Malibu, CA 90265: OK
# Geocoded: 757 Westwood Plz, Los Angeles, CA 90095: OK
# Geocoded: 757 Westwood Plz, Los Angeles, CA 90095: OK
# Geocoded: 1250 16th St, Santa Monica, CA 90404: OK
# Geocoded: 1250 16th St, Santa Monica, CA 90404: OK
# Geocoded: 501 Deep Valley Dr Ste 100, Rolling Hills Estates, CA 90274: OK
# Geocoded: 501 Deep Valley Dr Ste 100, Rolling Hills Estates, CA 90274: OK
# Geocoded: 4560 Admiralty Way Ste 100, Marina del Rey, CA 90292: OK
# Geocoded: 4560 Admiralty Way Ste 100, Marina del Rey, CA 90292: OK
# Geocoded: 514 N Prospect Ave Ste 103, Redondo Beach, CA 90277: OK
# Geocoded: 514 N Prospect Ave Ste 103, Redondo Beach, CA 90277: OK
# Geocoded: 27235 Tourney Rd Ste 2500, Santa Clarita, CA 91355: OK
# Geocoded: 27235 Tourney Rd Ste 2500, Santa Clarita, CA 91355: OK
# Geocoded: 1245 16th St Ste 125, Santa Monica, CA 90404: OK
# Geocoded: 1245 16th St Ste 125, Santa Monica, CA 90404: OK
# Geocoded: 2424 Wilshire Blvd, Santa Monica, CA 90403: OK
# Geocoded: 2424 Wilshire Blvd, Santa Monica, CA 90403: OK
# Geocoded: 6344 Topanga Canyon Blvd Ste 2040, Woodland Hills, CA 91367: OK
# Geocoded: 6344 Topanga Canyon Blvd Ste 2040, Woodland Hills, CA 91367: OK
# Geocoded: 11301 Wilshire Boulevard, Los Angeles, CA 90073: OK
# Geocoded: 11301 Wilshire Boulevard, Los Angeles, CA 90073: OK
# Geocoded: 5901 E. 7th Street, Long Beach, CA 90822: OK
# Geocoded: 5901 E. 7th Street, Long Beach, CA 90822: OK
# Geocoded: 11301 Wilshire Blvd, Los Angeles, CA 90073: OK
# Geocoded: 11301 Wilshire Blvd, Los Angeles, CA 90073: OK
# Geocoded: 7300 Medical Center Dr, West Hills, CA 91307: OK
# Geocoded: 7300 Medical Center Dr, West Hills, CA 91307: OK
# Geocoded: 9080 Colima Rd, Whittier, CA 90605: OK
# Geocoded: 9080 Colima Rd, Whittier, CA 90605: OK
# Geocoded: 10330 Pioneer Blvd Suite 180, Santa Fe Springs, CA 90670: OK
# Geocoded: 10330 Pioneer Blvd Suite 180, Santa Fe Springs, CA 90670: OK
# Geocoded: 501 N. Glendale Ave, Glendale, CA 91206: OK
# Geocoded: 501 N. Glendale Ave, Glendale, CA 91206: OK
# Geocoded: 1250 E Almond Ave  , Madera, CA 93637: OK
# Geocoded: 1250 E Almond Ave  , Madera, CA 93637: OK
# Geocoded: 40597 Westlake Drive, Oakhurst, CA 93644: OK
# Geocoded: 40597 Westlake Drive, Oakhurst, CA 93644: OK
# Geocoded: 180 Rowland Way, Novato, CA 94945: OK
# Geocoded: 180 Rowland Way, Novato, CA 94945: OK
# Geocoded: 5800 Nave Drive Suite F, Novato, CA 94949: OK
# Geocoded: 5800 Nave Drive Suite F, Novato, CA 94949: OK
# Geocoded: 1004 Northgate Drive, San Rafael, CA 94903: OK
# Geocoded: 1004 Northgate Drive, San Rafael, CA 94903: OK
# Geocoded: 630 Kings Court, Ukiah, CA 95482: OK
# Geocoded: 630 Kings Court, Ukiah, CA 95482: OK
# Geocoded: 340 E Yosemite Ave, Merced, CA 95340: OK
# Geocoded: 340 E Yosemite Ave, Merced, CA 95340: OK
# Geocoded: 333 Mercy Avenue, Merced, CA 95340: OK
# Geocoded: 333 Mercy Avenue, Merced, CA 95340: OK
# Geocoded: 741 Main Street, Cedarville, CA 96104: OK
# Geocoded: 741 Main Street, Cedarville, CA 96104: OK
# Geocoded: 85 Sierra Park Rd , Mammoth Lakes, CA 93546: OK
# Geocoded: 85 Sierra Park Rd , Mammoth Lakes, CA 93546: OK
# Geocoded: 23625 Holman Hwy, Monterey, CA 93940: OK
# Geocoded: 23625 Holman Hwy, Monterey, CA 93940: OK
# Geocoded: 201 Ninth Street, Marina, CA 93933: OK
# Geocoded: 201 Ninth Street, Marina, CA 93933: OK
# Geocoded: 1441 Constitution Blvd, Salis, CA 93906: OK
# Geocoded: 1441 Constitution Blvd, Salis, CA 93906: OK
# Geocoded: 450 East Romie Lane, Salinas, CA 93901: OK
# Geocoded: 450 East Romie Lane, Salinas, CA 93901: OK
# Geocoded: 1000 Trancas Street, Napa, CA 94558: OK
# Geocoded: 1000 Trancas Street, Napa, CA 94558: OK
# Geocoded: 155 Gladdon Way, Grass Valley, CA 95945: OK
# Geocoded: 155 Gladdon Way, Grass Valley, CA 95945: OK
# Geocoded: 2569 W Woodland Dr, Anaheim, CA 92801: OK
# Geocoded: 2569 W Woodland Dr, Anaheim, CA 92801: OK
# Geocoded: 879 Newport Center Dr, Newport Beach, CA 92660: OK
# Geocoded: 879 Newport Center Dr, Newport Beach, CA 92660: OK
# Geocoded: 12601 Garden Grove Blvd, Garden Grove, CA 92843: OK
# Geocoded: 12601 Garden Grove Blvd, Garden Grove, CA 92843: OK
# Geocoded: 23719 Moulton Parkway, Laguna Hills, CA 92653: OK
# Geocoded: 23719 Moulton Parkway, Laguna Hills, CA 92653: OK
# Geocoded: 31872 Coast Hwy Ste 100, Laguna Beach, CA 92651: OK
# Geocoded: 31872 Coast Hwy Ste 100, Laguna Beach, CA 92651: OK
# Geocoded: 31872 Coast Hwy, Laguna Beach, CA 92651: OK
# Geocoded: 31872 Coast Hwy, Laguna Beach, CA 92651: OK
# Geocoded: 27700 Medical Center Rd, Mission Viejo, CA 92691: OK
# Geocoded: 27700 Medical Center Rd, Mission Viejo, CA 92691: OK
# Geocoded: 26691 Plaza Suite 120A, Mission Viejo, CA 92691: OK
# Geocoded: 26691 Plaza Suite 120A, Mission Viejo, CA 92691: OK
# Geocoded: 24451 Health Center Dr, Lagu Hills, CA 92653: OK
# Geocoded: 24451 Health Center Dr, Lagu Hills, CA 92653: OK
# Geocoded: 1506 Brookhollow Dr, Santa Ana, CA 92705: OK
# Geocoded: 1506 Brookhollow Dr, Santa Ana, CA 92705: OK
# Geocoded: 1100 W Stewart Dr, Orange, CA 92868: OK
# Geocoded: 1100 W Stewart Dr, Orange, CA 92868: OK
# Geocoded: 101 E Valencia Mesa Dr, Fullerton, CA 92835: OK
# Geocoded: 101 E Valencia Mesa Dr, Fullerton, CA 92835: OK
# Geocoded: 3033 W Orange Ave, Anaheim, CA 92804: OK
# Geocoded: 3033 W Orange Ave, Anaheim, CA 92804: OK
# Geocoded: 11985 Heritage Oak Place, Auburn, CA 95603: OK
# Geocoded: 11985 Heritage Oak Place, Auburn, CA 95603: OK
# Geocoded: 11815 Education Street, Auburn, CA 95602: OK
# Geocoded: 11815 Education Street, Auburn, CA 95602: OK
# Geocoded: 1 Medical Center Drive, Roseville, CA 95661: OK
# Geocoded: 1 Medical Center Drive, Roseville, CA 95661: OK
# Geocoded: 1273 West Hobson Way, Blythe, CA 92225: OK
# Geocoded: 1273 West Hobson Way, Blythe, CA 92225: OK
# Geocoded: 2045 Compton Avenue, Bldg. 7, Corona, CA 92881: OK
# Geocoded: 2045 Compton Avenue, Bldg. 7, Corona, CA 92881: OK
# Geocoded: 500 Diamond Dr, Lake Elsinore, CA 92530: OK
# Geocoded: 500 Diamond Dr, Lake Elsinore, CA 92530: OK
# Geocoded: 28078 Baxter Rd., Suite 540, Murrieta, CA 92563: OK
# Geocoded: 28078 Baxter Rd., Suite 540, Murrieta, CA 92563: OK
# Geocoded: 41-990 Cook St, Bldg F Ste 1004, Palm Desert, CA 92211: OK
# Geocoded: 41-990 Cook St, Bldg F Ste 1004, Palm Desert, CA 92211: OK
# Geocoded: 26520 Cactus Ave, Moreno Valley, CA 92555: OK
# Geocoded: 26520 Cactus Ave, Moreno Valley, CA 92555: OK
# Geocoded: 500 Diamond Dr, Wildomar, CA 92595: OK
# Geocoded: 500 Diamond Dr, Wildomar, CA 92595: OK
# Geocoded: 5342 Dudley Blvd., McClellan, CA 95652: OK
# Geocoded: 5342 Dudley Blvd., McClellan, CA 95652: OK
# Geocoded: 10535 Hospital Way, Mather, CA 95655: OK
# Geocoded: 10535 Hospital Way, Mather, CA 95655: OK
# Geocoded: 1600 Exposition Blvd, Sacramento, CA 95815: OK
# Geocoded: 1600 Exposition Blvd, Sacramento, CA 95815: OK
# Geocoded: 820 E Mountain View St, Barstow, CA 92311: OK
# Geocoded: 820 E Mountain View St, Barstow, CA 92311: OK
# Geocoded: 8599 Haven Ave., Suite 102, Rancho Cucamonga, CA 91730: OK
# Geocoded: 8599 Haven Ave., Suite 102, Rancho Cucamonga, CA 91730: OK
# Geocoded: 999 San Bernardino Rd, Upland, CA 91786: OK
# Geocoded: 999 San Bernardino Rd, Upland, CA 91786: OK
# Geocoded: 26001 Redlands Blvd., Redlands, CA 92373: OK
# Geocoded: 26001 Redlands Blvd., Redlands, CA 92373: OK
# Geocoded: 11201 Benton Street, Loma Linda, CA 92357: OK
# Geocoded: 11201 Benton Street, Loma Linda, CA 92357: OK
# Geocoded: 12138 Industrial Boulevard, Victorville,, CA 92395: OK
# Geocoded: 12138 Industrial Boulevard, Victorville,, CA 92395: OK
# Geocoded: 865 3rd Avenue, Chula Vista, CA 91910: OK
# Geocoded: 865 3rd Avenue, Chula Vista, CA 91910: OK
# Geocoded: 9449 Friars Rd, San Diego, CA 92108: OK
# Geocoded: 9449 Friars Rd, San Diego, CA 92108: OK
# Geocoded: 815 East Pennsylvania Avenue, Escondido, CA 92025: OK
# Geocoded: 815 East Pennsylvania Avenue, Escondido, CA 92025: OK
# Geocoded: 4305 La Jolla Village Dr, San Diego, CA 92122: OK
# Geocoded: 4305 La Jolla Village Dr, San Diego, CA 92122: OK
# Geocoded: 8810 Rio San Diego Drive, San Diego, CA 92108: OK
# Geocoded: 8810 Rio San Diego Drive, San Diego, CA 92108: OK
# Geocoded: 1300 Rancho del Oro Drive, Oceanside, CA 92056: OK
# Geocoded: 1300 Rancho del Oro Drive, Oceanside, CA 92056: OK
# Error geocoding 1905 Calle Barcelo #21, Carlsbad, CA 92009: REQUEST_DENIED
# Error geocoding 1905 Calle Barcelo #21, Carlsbad, CA 92009: REQUEST_DENIED
# Geocoded: 1905 Calle Barcelo #21, Carlsbad, CA 92009: REQUEST_DENIED
# Geocoded: 1905 Calle Barcelo #21, Carlsbad, CA 92009: REQUEST_DENIED
# Geocoded: 299 J St, Chula Vista, CA 91910: OK
# Geocoded: 299 J St, Chula Vista, CA 91910: OK
# Geocoded: 3737 Moraga Ave, Suite B-103, San Diego, CA 92117: OK
# Geocoded: 3737 Moraga Ave, Suite B-103, San Diego, CA 92117: OK
# Geocoded: 12843 El Camino Real Suite 203, San Diego, CA 92130: OK
# Geocoded: 12843 El Camino Real Suite 203, San Diego, CA 92130: OK
# Error geocoding 7855 Ivanhoe Ave #110, La Jolla, CA 92037: REQUEST_DENIED
# Error geocoding 7855 Ivanhoe Ave #110, La Jolla, CA 92037: REQUEST_DENIED
# Geocoded: 7855 Ivanhoe Ave #110, La Jolla, CA 92037: REQUEST_DENIED
# Geocoded: 7855 Ivanhoe Ave #110, La Jolla, CA 92037: REQUEST_DENIED
# Geocoded: 555 W C St. Suite 102, San Diego, CA 92101: OK
# Geocoded: 555 W C St. Suite 102, San Diego, CA 92101: OK
# Geocoded: 77 N El Camino Real Suite A200, Encinitas, CA 92024: OK
# Geocoded: 77 N El Camino Real Suite A200, Encinitas, CA 92024: OK
# Error geocoding 4142 Adams Ave #102, San Diego, CA 92116: REQUEST_DENIED
# Error geocoding 4142 Adams Ave #102, San Diego, CA 92116: REQUEST_DENIED
# Geocoded: 4142 Adams Ave #102, San Diego, CA 92116: REQUEST_DENIED
# Geocoded: 4142 Adams Ave #102, San Diego, CA 92116: REQUEST_DENIED
# Error geocoding 6386 Alvarado Ct #101, La Jolla, CA : REQUEST_DENIED
# Error geocoding 6386 Alvarado Ct #101, La Jolla, CA : REQUEST_DENIED
# Geocoded: 6386 Alvarado Ct #101, La Jolla, CA : REQUEST_DENIED
# Geocoded: 6386 Alvarado Ct #101, La Jolla, CA : REQUEST_DENIED
# Error geocoding 9850 Genesee Ave #320, San Diego, CA : REQUEST_DENIED
# Error geocoding 9850 Genesee Ave #320, San Diego, CA : REQUEST_DENIED
# Geocoded: 9850 Genesee Ave #320, San Diego, CA : REQUEST_DENIED
# Geocoded: 9850 Genesee Ave #320, San Diego, CA : REQUEST_DENIED
# Error geocoding 3900 5th Ave #110 , San Diego, CA 92103: REQUEST_DENIED
# Error geocoding 3900 5th Ave #110 , San Diego, CA 92103: REQUEST_DENIED
# Geocoded: 3900 5th Ave #110 , San Diego, CA 92103: REQUEST_DENIED
# Geocoded: 3900 5th Ave #110 , San Diego, CA 92103: REQUEST_DENIED
# Geocoded: 8989 Rio San Diego, Suite 360, San Diego, CA 92108: OK
# Geocoded: 8989 Rio San Diego, Suite 360, San Diego, CA 92108: OK
# Geocoded: 15004 Innovation Dr, San Diego, CA 92128: OK
# Geocoded: 15004 Innovation Dr, San Diego, CA 92128: OK
# Geocoded: 130 Cedar Rd, Vista, CA 92083: OK
# Geocoded: 130 Cedar Rd, Vista, CA 92083: OK
# Geocoded: 10710 North Torrey Pines Rd., La Jolla, CA 92037: OK
# Geocoded: 10710 North Torrey Pines Rd., La Jolla, CA 92037: OK
# Geocoded: 354 Santa Fe Dr, Encinitas, CA 92024: OK
# Geocoded: 354 Santa Fe Dr, Encinitas, CA 92024: OK
# Geocoded: 9888 Genesee Ave, La Jolla, CA 92037: OK
# Geocoded: 9888 Genesee Ave, La Jolla, CA 92037: OK
# Geocoded: 4077 5th Ave, San Diego, CA 92103: OK
# Geocoded: 4077 5th Ave, San Diego, CA 92103: OK
# Geocoded: 435 H St, Chula Vista, CA 91910: OK
# Geocoded: 435 H St, Chula Vista, CA 91910: OK
# Geocoded: 10455 Sorrento Valley Road, San Diego, CA 92121: OK
# Geocoded: 10455 Sorrento Valley Road, San Diego, CA 92121: OK
# Geocoded: 3350 La Jolla Village Drive, San Diego, CA 92161: OK
# Geocoded: 3350 La Jolla Village Drive, San Diego, CA 92161: OK
# Geocoded: 1998 Market St, San Francisco, CA 94102: OK
# Geocoded: 1998 Market St, San Francisco, CA 94102: OK
# Geocoded: 55 Pacific Ave, San Francisco, CA 94111: OK
# Geocoded: 55 Pacific Ave, San Francisco, CA 94111: OK
# Geocoded: 3700 California Street, San Francisco, CA 94118: OK
# Geocoded: 3700 California Street, San Francisco, CA 94118: OK
# Geocoded: Castro and Duboce Streets, San Francisco, CA 94114: OK
# Geocoded: Castro and Duboce Streets, San Francisco, CA 94114: OK
# Geocoded: 3555 Cesar Chavez Street, San Francisco, CA 94110: OK
# Geocoded: 3555 Cesar Chavez Street, San Francisco, CA 94110: OK
# Geocoded: 2333 Buchan Street, San Francisco, CA 94115: OK
# Geocoded: 2333 Buchan Street, San Francisco, CA 94115: OK
# Geocoded: 1101 Van Ness Avenue, San Francisco, CA 94109: OK
# Geocoded: 1101 Van Ness Avenue, San Francisco, CA 94109: OK
# Geocoded: 180 Sutter St, San Francisco, CA 94104: OK
# Geocoded: 180 Sutter St, San Francisco, CA 94104: OK
# Geocoded: 4131 Geary Blvd, San Francisco, CA 94118: OK
# Geocoded: 4131 Geary Blvd, San Francisco, CA 94118: OK
# Geocoded: 2425 Geary Blvd, San Francisco, CA 94115: OK
# Geocoded: 2425 Geary Blvd, San Francisco, CA 94115: OK
# Geocoded: 3333 California St, San Francisco, CA 94118: OK
# Geocoded: 3333 California St, San Francisco, CA 94118: OK
# Geocoded: 101 Grove St, San Francisco, CA 94102: OK
# Geocoded: 101 Grove St, San Francisco, CA 94102: OK
# Geocoded: 4150 Clement Street, San Francisco, CA 94121: OK
# Geocoded: 4150 Clement Street, San Francisco, CA 94121: OK
# Geocoded: 240 King Street Suite G2, San Francisco, CA 94107: OK
# Geocoded: 240 King Street Suite G2, San Francisco, CA 94107: OK
# Geocoded: 401 3rd Street, San Francisco, CA 94107: OK
# Geocoded: 401 3rd Street, San Francisco, CA 94107: OK
# Geocoded: 505 Parssus Ave, San Francisco, CA 94143: OK
# Geocoded: 505 Parssus Ave, San Francisco, CA 94143: OK
# Geocoded: 1825 4th St, San Francisco, CA 94143: OK
# Geocoded: 1825 4th St, San Francisco, CA 94143: OK
# Geocoded: 1600 Divisadero St, San Francisco, CA 94143: OK
# Geocoded: 1600 Divisadero St, San Francisco, CA 94143: OK
# Geocoded: 7777 South Freedom Rd, French Camp, CA 95231: OK
# Geocoded: 7777 South Freedom Rd, French Camp, CA 95231: OK
# Geocoded: 1911 Johnson Ave, San Luis Obispo, CA 93401: OK
# Geocoded: 1911 Johnson Ave, San Luis Obispo, CA 93401: OK
# Geocoded: 1288 Morro Street, Ste.200, San Luis Obispo, CA 93401: OK
# Geocoded: 1288 Morro Street, Ste.200, San Luis Obispo, CA 93401: OK
# Geocoded: 1300 Crane Street, Menlo Park, CA 94025: OK
# Geocoded: 1300 Crane Street, Menlo Park, CA 94025: OK
# Geocoded: 570 Willow Road, Menlo Park, CA 94025: OK
# Geocoded: 570 Willow Road, Menlo Park, CA 94025: OK
# Geocoded: 1501 Trousdale Drive, Burlingame, CA 94010: OK
# Geocoded: 1501 Trousdale Drive, Burlingame, CA 94010: OK
# Geocoded: 1001 Sneath Lane, Suite 300, Third Floor, San Bruno, CA 94066: OK
# Geocoded: 1001 Sneath Lane, Suite 300, Third Floor, San Bruno, CA 94066: OK
# Geocoded: 1346 Saratoga Dr, San Mateo, CA 94403: OK
# Geocoded: 1346 Saratoga Dr, San Mateo, CA 94403: OK
# Geocoded: 269 E Grand Ave, South San Francisco, CA 94080: OK
# Geocoded: 269 E Grand Ave, South San Francisco, CA 94080: OK
# Geocoded: 4151 Foothill Rd, Santa Barbara, CA 93110: OK
# Geocoded: 4151 Foothill Rd, Santa Barbara, CA 93110: OK
# Geocoded: 4440 Calle Real, Santa Barbara, CA 93110: OK
# Geocoded: 4440 Calle Real, Santa Barbara, CA 93110: OK
# Geocoded: 1550 East Main Street, Santa Maria, CA 93454: OK
# Geocoded: 1550 East Main Street, Santa Maria, CA 93454: OK
# Geocoded: 795 Willow Road, Menlo Park, CA 94025: OK
# Geocoded: 795 Willow Road, Menlo Park, CA 94025: OK
# Error geocoding 4735 Hamilton Ave #80, San Jose, CA 95130: REQUEST_DENIED
# Error geocoding 4735 Hamilton Ave #80, San Jose, CA 95130: REQUEST_DENIED
# Geocoded: 4735 Hamilton Ave #80, San Jose, CA 95130: REQUEST_DENIED
# Geocoded: 4735 Hamilton Ave #80, San Jose, CA 95130: REQUEST_DENIED
# Geocoded: 4150 N 1st St, San Jose, CA 95134: OK
# Geocoded: 4150 N 1st St, San Jose, CA 95134: OK
# Geocoded: 1150 West El Camino Real, Mountain View, CA 94040: OK
# Geocoded: 1150 West El Camino Real, Mountain View, CA 94040: OK
# Geocoded: 2855 Stevens Creek Blvd, Santa Clara, CA 95050: OK
# Geocoded: 2855 Stevens Creek Blvd, Santa Clara, CA 95050: OK
# Geocoded: 497 East Calaveras Blvd., Milpitas, CA 95035: OK
# Geocoded: 497 East Calaveras Blvd., Milpitas, CA 95035: OK
# Geocoded: 580 North Rengstorff Ave Suite E, Mountain View, CA 94043: OK
# Geocoded: 580 North Rengstorff Ave Suite E, Mountain View, CA 94043: OK
# Geocoded: 1299-A Oakmead Parkway, Sunnyvale, CA 94085: OK
# Geocoded: 1299-A Oakmead Parkway, Sunnyvale, CA 94085: OK
# Geocoded: 19600 Vallco Pkwy Ste 170, Cupertino, CA 95014: OK
# Geocoded: 19600 Vallco Pkwy Ste 170, Cupertino, CA 95014: OK
# Geocoded: 685 Coleman Avenue, San Jose, CA 95110: OK
# Geocoded: 685 Coleman Avenue, San Jose, CA 95110: OK
# Geocoded: 5343 Prospect Road, San Jose, CA 95129: OK
# Geocoded: 5343 Prospect Road, San Jose, CA 95129: OK
# Geocoded: 5855 Silver Creek Valley Pl, San Jose, CA 95138: OK
# Geocoded: 5855 Silver Creek Valley Pl, San Jose, CA 95138: OK
# Geocoded: 344 Tully Rd, San Jose, CA 95111: OK
# Geocoded: 344 Tully Rd, San Jose, CA 95111: OK
# Geocoded: 3912 Rivermark Plaza, Santa Clara, CA 95054: OK
# Geocoded: 3912 Rivermark Plaza, Santa Clara, CA 95054: OK
# Error geocoding 211 Quarry Rd #102, Palo Alto, CA 94305: REQUEST_DENIED
# Error geocoding 211 Quarry Rd #102, Palo Alto, CA 94305: REQUEST_DENIED
# Geocoded: 211 Quarry Rd #102, Palo Alto, CA 94305: REQUEST_DENIED
# Geocoded: 211 Quarry Rd #102, Palo Alto, CA 94305: REQUEST_DENIED
# Error geocoding 52 Skytop St #10, San Jose, CA 95134: REQUEST_DENIED
# Error geocoding 52 Skytop St #10, San Jose, CA 95134: REQUEST_DENIED
# Geocoded: 52 Skytop St #10, San Jose, CA 95134: REQUEST_DENIED
# Geocoded: 52 Skytop St #10, San Jose, CA 95134: REQUEST_DENIED
# Geocoded: 3801 Miranda Avenue, Palo Alto, CA 94304: OK
# Geocoded: 3801 Miranda Avenue, Palo Alto, CA 94304: OK
# Geocoded: 1350 41st Ave, Suite 102, Capitola CA 95010: OK
# Geocoded: 1350 41st Ave, Suite 102, Capitola CA 95010: OK
# Geocoded: 351 Hartnell Avenue, Redding, CA 96002: OK
# Geocoded: 351 Hartnell Avenue, Redding, CA 96002: OK
# Geocoded: 101 E Oberlin Rd, Yreka, CA 96097: OK
# Geocoded: 101 E Oberlin Rd, Yreka, CA 96097: OK
# Error geocoding 1320 Travis Blvd , #Suite C, Fairfield, CA 94533: REQUEST_DENIED
# Error geocoding 1320 Travis Blvd , #Suite C, Fairfield, CA 94533: REQUEST_DENIED
# Geocoded: 1320 Travis Blvd , #Suite C, Fairfield, CA 94533: REQUEST_DENIED
# Geocoded: 1320 Travis Blvd , #Suite C, Fairfield, CA 94533: REQUEST_DENIED
# Geocoded: 103 Bodin Circle, Travis Air Force Base, Fairfield, CA 94535: OK
# Geocoded: 103 Bodin Circle, Travis Air Force Base, Fairfield, CA 94535: OK
# Geocoded: 201 Walnut Avenue, Vallejo, CA 94592: OK
# Geocoded: 201 Walnut Avenue, Vallejo, CA 94592: OK
# Error geocoding 1679 E Monte Vista Ave , #Suite 104, Vacaville, CA 95688: REQUEST_DENIED
# Error geocoding 1679 E Monte Vista Ave , #Suite 104, Vacaville, CA 95688: REQUEST_DENIED
# Geocoded: 1679 E Monte Vista Ave , #Suite 104, Vacaville, CA 95688: REQUEST_DENIED
# Geocoded: 1679 E Monte Vista Ave , #Suite 104, Vacaville, CA 95688: REQUEST_DENIED
# Geocoded: 300 Hospital Drive, Vallejo, CA 94589: OK
# Geocoded: 300 Hospital Drive, Vallejo, CA 94589: OK
# Geocoded: 411 North McDowell Blvd., Unit 41, Suite 10, Petaluma CA 94954: OK
# Geocoded: 411 North McDowell Blvd., Unit 41, Suite 10, Petaluma CA 94954: OK
# Geocoded: 3841 Brickway Blvd , Santa Rosa, CA 95403: OK
# Geocoded: 3841 Brickway Blvd , Santa Rosa, CA 95403: OK
# Geocoded: 2360 Mendacino Avenue Suite A4, Santa Rosa, CA 95403: OK
# Geocoded: 2360 Mendacino Avenue Suite A4, Santa Rosa, CA 95403: OK
# Geocoded: 3313 Chate Road, Sonoma, CA 95404: OK
# Geocoded: 3313 Chate Road, Sonoma, CA 95404: OK
# Geocoded: 30 Mark West Springs Road, Santa Rosa, CA 95403: OK
# Geocoded: 30 Mark West Springs Road, Santa Rosa, CA 95403: OK
# Geocoded: 1225 Oakdale Road, Modesto, CA 95355: OK
# Geocoded: 1225 Oakdale Road, Modesto, CA 95355: OK
# Geocoded: 1000 Sutter Street, Yuba City, CA 95991: OK
# Geocoded: 1000 Sutter Street, Yuba City, CA 95991: OK
# Geocoded: 400 W Mineral King Ave., Visalia, CA 93291: OK
# Geocoded: 400 W Mineral King Ave., Visalia, CA 93291: OK
# Geocoded: 1050 N. Cherry Street, Tulare, CA 93274: OK
# Geocoded: 1050 N. Cherry Street, Tulare, CA 93274: OK
# Geocoded: 1062 S. K Street, Tulare, CA 93274: OK
# Geocoded: 1062 S. K Street, Tulare, CA 93274: OK
# Geocoded: 13663 Mono Way, Sonora, CA 95370: OK
# Geocoded: 13663 Mono Way, Sonora, CA 95370: OK
# Geocoded: 300 Hillmont Avenue, Ventura, CA 93003: OK
# Geocoded: 300 Hillmont Avenue, Ventura, CA 93003: OK
# Geocoded: 1690 Universe Circle, Oxnard, CA 93033: OK
# Geocoded: 1690 Universe Circle, Oxnard, CA 93033: OK
# Geocoded: 6333 Telephone Rd, Suite 212, Ventura, CA 93003: OK
# Geocoded: 6333 Telephone Rd, Suite 212, Ventura, CA 93003: OK
# Geocoded: 1 Shields Ave, Davis, CA 95616: OK
# Geocoded: 1 Shields Ave, Davis, CA 95616: OK
# Geocoded: 724 Fifth Street, Marysville, CA 95901: OK
# Geocoded: 724 Fifth Street, Marysville, CA 95901: OK
# Geocoded: 425 Plumas Street, Yuba City, CA 95991: OK
# Geocoded: 425 Plumas Street, Yuba City, CA 95991: OK
# Geocoded: 3750 Harris St, Eureka, Humboldt, CA 95503: OK
# Geocoded: 3750 Harris St, Eureka, Humboldt, CA 95503: OK
# Geocoded: 171 W Bort St, Los Angeles, Los Angeles, CA 90805: OK
# Geocoded: 171 W Bort St, Los Angeles, Los Angeles, CA 90805: OK
# Geocoded: 5171 Silva Rd, Mariposa, Mariposa, CA 95338: OK
# Geocoded: 5171 Silva Rd, Mariposa, Mariposa, CA 95338: OK
# Geocoded: 601 Mercy Ave, Merced, Merced, CA 95340: OK
# Geocoded: 601 Mercy Ave, Merced, Merced, CA 95340: OK
# Geocoded: 11555 Old Oregon Trail, Redding, Shasta, CA 96003: OK
# Geocoded: 11555 Old Oregon Trail, Redding, Shasta, CA 96003: OK
# Finished geocoding all addresses
# Finished geocoding all addresses
