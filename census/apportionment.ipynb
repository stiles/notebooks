# %% [markdown]
# # U.S. Census apportionment data in 2010 and 2020

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd
import altair as alt
import altair_latimes as lat
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from vega_datasets import data

states = alt.topo_feature(data.us_10m.url, "states")

# %%
alt.themes.register("latimes", lat.theme)
alt.themes.enable("latimes")
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ### Get the data from the U.S. Census

# %%
# https://www.census.gov/data/tables/2010/dec/2010-apportionment-data.html

# %%
url2010 = "https://www2.census.gov/programs-surveys/decennial/2010/data/apportionment/apport2010-table1.xls"

# %%
df_2010 = pd.read_excel(url2010, encoding="Latin-1", skiprows=10, skipfooter=6)

# %%
df_2010.columns = ["state", "population", "drop1", "seats", "drop2", "seats_change"]

# %%
df_2010.drop(["drop1", "drop2"], axis=1, inplace=True)

# %%
df_2010.tail(10)
# Out:
#             state  population  seats  seats_change
# 40   South Dakota      819761      1             0
# 41      Tennessee     6375431      9             0
# 42          Texas    25268418     36             4
# 43           Utah     2770765      4             1
# 44        Vermont      630337      1             0
# 45       Virginia     8037736     11             0
# 46     Washington     6753369     10             1
# 47  West Virginia     1859815      3             0
# 48      Wisconsin     5698230      8             0
# 49        Wyoming      568300      1             0

# %%
df_2010["year"] = "2010"

# %%
url2020 = "https://www2.census.gov/programs-surveys/decennial/2020/data/apportionment/apportionment-2020-table01.xlsx"

# %%
df_2020 = pd.read_excel(url2020, encoding="Latin-1", skiprows=3, skipfooter=2)

# %%
df_2020.tail()
# Out:
#             STATE  APPORTIONMENT POPULATION \n(APRIL 1, 2020)  \
# 45       Virginia                                     8654542
# 46     Washington                                     7715946
# 47  West Virginia                                     1795045
# 48      Wisconsin                                     5897473
# 49        Wyoming                                      577719
#
#     NUMBER OF APPORTIONED REPRESENTATIVES BASED ON \n2020 CENSUS2  \
# 45                                                 11
# 46                                                 10
# 47                                                  2
# 48                                                  8
# 49                                                  1
#
#     CHANGE FROM \n2010 CENSUS APPORTIONMENT
# 45                                        0
# 46                                        0
# 47                                       -1
# 48                                        0
# 49                                        0

# %%
df_2020.columns = ["state", "population", "seats", "seats_change"]

# %%
df_2020["year"] = "2020"

# %%
df = pd.concat([df_2010, df_2020])

# %%
df_2020
# Out:
#              state  population  seats  seats_change  year
# 0          Alabama     5030053      7             0  2020
# 1           Alaska      736081      1             0  2020
# 2          Arizona     7158923      9             0  2020
# 3         Arkansas     3013756      4             0  2020
# 4       California    39576757     52            -1  2020
# 5         Colorado     5782171      8             1  2020
# 6      Connecticut     3608298      5             0  2020
# 7         Delaware      990837      1             0  2020
# 8          Florida    21570527     28             1  2020
# 9          Georgia    10725274     14             0  2020
# 10          Hawaii     1460137      2             0  2020
# 11           Idaho     1841377      2             0  2020
# 12        Illinois    12822739     17            -1  2020
# 13         Indiana     6790280      9             0  2020
# 14            Iowa     3192406      4             0  2020
# 15          Kansas     2940865      4             0  2020
# 16        Kentucky     4509342      6             0  2020
# 17       Louisiana     4661468      6             0  2020
# 18           Maine     1363582      2             0  2020
# 19        Maryland     6185278      8             0  2020
# 20   Massachusetts     7033469      9             0  2020
# 21        Michigan    10084442     13            -1  2020
# 22       Minnesota     5709752      8             0  2020
# 23     Mississippi     2963914      4             0  2020
# 24        Missouri     6160281      8             0  2020
# 25         Montana     1085407      2             1  2020
# 26        Nebraska     1963333      3             0  2020
# 27          Nevada     3108462      4             0  2020
# 28   New Hampshire     1379089      2             0  2020
# 29      New Jersey     9294493     12             0  2020
# 30      New Mexico     2120220      3             0  2020
# 31        New York    20215751     26            -1  2020
# 32  North Carolina    10453948     14             1  2020
# 33    North Dakota      779702      1             0  2020
# 34            Ohio    11808848     15            -1  2020
# 35        Oklahoma     3963516      5             0  2020
# 36          Oregon     4241500      6             1  2020
# 37    Pennsylvania    13011844     17            -1  2020
# 38    Rhode Island     1098163      2             0  2020
# 39  South Carolina     5124712      7             0  2020
# 40    South Dakota      887770      1             0  2020
# 41       Tennessee     6916897      9             0  2020
# 42           Texas    29183290     38             2  2020
# 43            Utah     3275252      4             0  2020
# 44         Vermont      643503      1             0  2020
# 45        Virginia     8654542     11             0  2020
# 46      Washington     7715946     10             0  2020
# 47   West Virginia     1795045      2            -1  2020
# 48       Wisconsin     5897473      8             0  2020
# 49         Wyoming      577719      1             0  2020

# %% [markdown]
# ---

# %% [markdown]
# ### Historical apportionment

# %%
hist_df = pd.read_excel(
    "https://www2.census.gov/programs-surveys/decennial/2020/data/apportionment/apportionment-2020-tableC2.xlsx",
    skiprows=4,
)

# %%
hist_df.head()
# Out:
#    Unnamed: 0  2020: Apportionment population  \
# 0     Alabama                       5030053.0
# 1      Alaska                        736081.0
# 2     Arizona                       7158923.0
# 3    Arkansas                       3013756.0
# 4  California                      39576757.0
#
#    2020: \nNumber of representatives  2020: \nSeat change  \
# 0                                7.0                  0.0
# 1                                1.0                  0.0
# 2                                9.0                  0.0
# 3                                4.0                  0.0
# 4                               52.0                 -1.0
#
#    2020: Average persons per representative  2010: Apportionment population  \
# 0                                  718579.0                       4802982.0
# 1                                  736081.0                        721523.0
# 2                                  795436.0                       6412700.0
# 3                                  753439.0                       2926229.0
# 4                                  761091.0                      37341989.0
#
#    2010: \nNumber of representatives  2010: \nSeat change  \
# 0                                7.0                  0.0
# 1                                1.0                  0.0
# 2                                9.0                  1.0
# 3                                4.0                  0.0
# 4                               53.0                  0.0
#
#    2010: Average persons per representative  Unnamed: 9  \
# 0                                  686140.0     Alabama
# 1                                  721523.0      Alaska
# 2                                  712522.0     Arizona
# 3                                  731557.0    Arkansas
# 4                                  704566.0  California
#
#    2000: Apportionment population  2000: \nNumber of representatives  \
# 0                       4461130.0                                7.0
# 1                        628933.0                                1.0
# 2                       5140683.0                                8.0
# 3                       2679733.0                                4.0
# 4                      33930798.0                               53.0
#
#    2000: \nSeat change  2000: Average persons per representative  \
# 0                  0.0                                  637304.0
# 1                  0.0                                  628933.0
# 2                  2.0                                  642585.0
# 3                  0.0                                  669933.0
# 4                  1.0                                  640204.0
#
#    1990: Apportionment population  1990: \nNumber of representatives  \
# 0                       4062608.0                                7.0
# 1                        551947.0                                1.0
# 2                       3677985.0                                6.0
# 3                       2362239.0                                4.0
# 4                      29839250.0                               52.0
#
#    1990: \nSeat change  1990: Average persons per representative Unnamed: 18  \
# 0                  0.0                                  580373.0     Alabama
# 1                  0.0                                  551947.0      Alaska
# 2                  1.0                                  612998.0     Arizona
# 3                  0.0                                  590560.0    Arkansas
# 4                  7.0                                  573832.0  California
#
#    1980: Apportionment population  1980: \nNumber of representatives  \
# 0                       3890061.0                                7.0
# 1                        400481.0                                1.0
# 2                       2717866.0                                5.0
# 3                       2285513.0                                4.0
# 4                      23668562.0                               45.0
#
#    1980: \nSeat change  1980: Average persons per representative  \
# 0                  0.0                                  555723.0
# 1                  0.0                                  400481.0
# 2                  1.0                                  543573.0
# 3                  0.0                                  571378.0
# 4                  2.0                                  525968.0
#
#    1970: Apportionment population  1970: \nNumber of representatives  ...  \
# 0                       3475885.0                                7.0  ...
# 1                        304067.0                                1.0  ...
# 2                       1787620.0                                4.0  ...
# 3                       1942303.0                                4.0  ...
# 4                      20098863.0                               43.0  ...
#
#    1960: Apportionment population  1960: \nNumber of representatives  \
# 0                       3266740.0                                8.0
# 1                        226167.0                                1.0
# 2                       1302161.0                                3.0
# 3                       1786272.0                                4.0
# 4                      15717204.0                               38.0
#
#   1960: \nSeat change  1960: Average persons per representative  \
# 0                  -1                                  408343.0
# 1                   X                                  226167.0
# 2                   1                                  434054.0
# 3                  -2                                  446568.0
# 4                   8                                  413611.0
#
#    1950: Apportionment population 1950: \nNumber of representatives  \
# 0                         3061743                                 9
# 1                               X                                 X
# 2                          749587                                 2
# 3                         1909511                                 6
# 4                        10586223                                30
#
#    1950: \nSeat change 1950: Average persons per representative Unnamed: 36  \
# 0                    0                                   340194     Alabama
# 1                    X                                        X      Alaska
# 2                    0                                   374794     Arizona
# 3                   -1                                   318252    Arkansas
# 4                    7                                   352874  California
#
#   1940: Apportionment population 1940: \nNumber of representatives  \
# 0                        2832961                                 9
# 1                              X                                 X
# 2                         499261                                 2
# 3                        1949387                                 7
# 4                        6907387                                23
#
#   1940: \nSeat change 1940: Average persons per representative  \
# 0                   0                                   314773
# 1                   X                                        X
# 2                   1                                   249631
# 3                   0                                   278484
# 4                   3                                   300321
#
#   1930: Apportionment population 1930: \nNumber of representatives  \
# 0                        2646242                                 9
# 1                              X                                 X
# 2                         389375                                 1
# 3                        1854444                                 7
# 4                        5668241                                20
#
#   1930: \nSeat change 1930: Average persons per representative Unnamed: 45  \
# 0                  -1                                   294027     Alabama
# 1                   X                                        X      Alaska
# 2                   0                                   389375     Arizona
# 3                   0                                   264921    Arkansas
# 4                   9                                   283412  California
#
#   1920: Apportionment population 1920: \nNumber of representatives  \
# 0                        2348174                                10
# 1                              X                                 X
# 2                         309495                                 1
# 3                        1752204                                 7
# 4                        3426031                                11
#
#   1920: Average persons per representative 1910: Apportionment population  \
# 0                                   234817                        2138093
# 1                                        X                              X
# 2                                   309495                              X
# 3                                   250315                        1574449
# 4                                   311457                        2376561
#
#   1910: \nNumber of representatives 1910: \nSeat change\n(since 1900)  \
# 0                                10                                 1
# 1                                 X                                 X
# 2                                 X                                 X
# 3                                 7                                 0
# 4                                11                                 3
#
#   1910: Average persons per representative
# 0                                   213809
# 1                                        X
# 2                                        X
# 3                                   224921
# 4                                   216051
#
# [5 rows x 53 columns]

# %%
hist_df.columns = [
    "name",
    "type",
    "year",
    "population",
    "pop_pct_change",
    "density",
    "density_rank",
    "reps",
    "change_reps",
    "pop_per_rep",
]

# %%
hist_df.head()
# Out:
#          name   type  year population  pop_pct_change density  density_rank  \
# 0     Alabama  State  1910  2,138,093            16.9    42.2          25.0
# 1      Alaska  State  1910     64,356             1.2     0.1          52.0
# 2     Arizona  State  1910    204,354            66.2     1.8          49.0
# 3    Arkansas  State  1910  1,574,449            20.0    30.3          30.0
# 4  California  State  1910  2,377,549            60.1    15.3          38.0
#
#    reps  change_reps pop_per_rep
# 0  10.0          1.0     213,809
# 1   NaN          NaN         NaN
# 2   NaN          NaN         NaN
# 3   7.0          0.0     224,921
# 4  11.0          3.0     216,051

# %%
hist_df_ca = hist_df[hist_df["name"] == "California"].copy()

# %%
hist_df_ca["population"] = (
    hist_df_ca["population"].str.replace(",", "", regex=False).astype(int)
)

# %%
bars = alt.Chart(hist_df_ca).mark_bar().encode(y="change_reps:Q", x="year:O")

text = bars.mark_text(
    align="left",
    baseline="middle",
    dy=-10,  # Nudges text to right so it doesn't appear on top of the bar
    dx=0,
).encode(text="change_reps:Q")

(bars + text).properties(height=400)
# Out:
# alt.LayerChart(...)

# %%
lines = alt.Chart(hist_df_ca).mark_line().encode(x="year:O", y="population:Q")

(lines).properties(height=400)
# Out:
# alt.Chart(...)

# %% [markdown]
# ---

# %% [markdown]
# ## Geography

# %% [markdown]
# ### States map

# %%
state_geo = gpd.read_file("raw/states.geojson")
state_geo.columns = state_geo.columns.str.lower()

# %% [markdown]
# ### Add A.P. states

# %%
ap_states = pd.read_csv("raw/ap_states.csv")

# %%
states_merge = state_geo.merge(ap_states, left_on="stusps", right_on="usps")

# %% [markdown]
# ### Clean up

# %%
states_merge.drop(
    ["name_x", "stusps", "statefp", "statens", "affgeoid", "lsad", "aland", "awater"],
    axis=1,
    inplace=True,
)

# %%
states_merge.rename(columns={"name_y": "name"}, inplace=True)

# %%
states_merge = states_merge[["geoid", "name", "usps", "ap", "geometry"]]

# %%
states_merge.head()
# Out:
#   geoid      name usps      ap  \
# 0    23     Maine   ME   Maine
# 1    15    Hawaii   HI  Hawaii
# 2    04   Arizona   AZ   Ariz.
# 3    05  Arkansas   AR    Ark.
# 4    10  Delaware   DE    Del.
#
#                                             geometry
# 0  MULTIPOLYGON (((-68.92401 43.88541, -68.87478 ...
# 1  MULTIPOLYGON (((-156.04965 19.78045, -156.0062...
# 2  MULTIPOLYGON (((-114.79968 32.59362, -114.8093...
# 3  MULTIPOLYGON (((-94.61792 36.49941, -94.36120 ...
# 4  MULTIPOLYGON (((-75.77379 39.72220, -75.75323 ...

# %% [markdown]
# ---

# %% [markdown]
# ## Export

# %%
df_2010.to_csv("processed/apportionment/apportionment_2010.csv", index=False)

# %%
df_2020.to_csv("processed/apportionment/apportionment_2020.csv", index=False)

# %%
df.to_csv("processed/apportionment/apportionment_2010_2020.csv", index=False)

# %%
states_merge.to_file("../../../data/GIS/states_geo_ap.geojson", driver="GeoJSON")
