# %% [markdown]
# # U.S. Census apportionment data in 2010 and 2020

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd
import altair as alt
import altair_latimes as lat
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from vega_datasets import data

states = alt.topo_feature(data.us_10m.url, "states")

# %%
alt.themes.register("latimes", lat.theme)
alt.themes.enable("latimes")
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ### Get the data from the U.S. Census

# %%
# https://www.census.gov/data/tables/2010/dec/2010-apportionment-data.html

# %%
url2010 = "https://www2.census.gov/programs-surveys/decennial/2010/data/apportionment/apport2010-table1.xls"

# %%
df_2010 = pd.read_excel(url2010, encoding="Latin-1", skiprows=10, skipfooter=6)

# %%
df_2010.columns = ["state", "population", "drop1", "seats", "drop2", "seats_change"]

# %%
df_2010.drop(["drop1", "drop2"], axis=1, inplace=True)

# %%
df_2010.tail(10)
# Out:
#             state  population  seats  seats_change
# 40   South Dakota      819761      1             0
# 41      Tennessee     6375431      9             0
# 42          Texas    25268418     36             4
# 43           Utah     2770765      4             1
# 44        Vermont      630337      1             0
# 45       Virginia     8037736     11             0
# 46     Washington     6753369     10             1
# 47  West Virginia     1859815      3             0
# 48      Wisconsin     5698230      8             0
# 49        Wyoming      568300      1             0

# %%
df_2010["year"] = "2010"

# %%
url2020 = "https://www2.census.gov/programs-surveys/decennial/2020/data/apportionment/apportionment-2020-table01.xlsx"

# %%
df_2020 = pd.read_excel(url2020, encoding="Latin-1", skiprows=3, skipfooter=2)

# %%
df_2020.tail()
# Out:
#             STATE  APPORTIONMENT POPULATION \n(APRIL 1, 2020)  \
# 45       Virginia                                     8654542
# 46     Washington                                     7715946
# 47  West Virginia                                     1795045
# 48      Wisconsin                                     5897473
# 49        Wyoming                                      577719
#
#     NUMBER OF APPORTIONED REPRESENTATIVES BASED ON \n2020 CENSUS2  \
# 45                                                 11
# 46                                                 10
# 47                                                  2
# 48                                                  8
# 49                                                  1
#
#     CHANGE FROM \n2010 CENSUS APPORTIONMENT
# 45                                        0
# 46                                        0
# 47                                       -1
# 48                                        0
# 49                                        0

# %%
df_2020.columns = ["state", "population", "seats", "seats_change"]

# %%
df_2020["year"] = "2020"

# %%
df = pd.concat([df_2010, df_2020])

# %%
df_2020.head()
# Out:
#         state  population  seats  seats_change  year
# 0     Alabama     5030053      7             0  2020
# 1      Alaska      736081      1             0  2020
# 2     Arizona     7158923      9             0  2020
# 3    Arkansas     3013756      4             0  2020
# 4  California    39576757     52            -1  2020

# %% [markdown]
# ---

# %% [markdown]
# ## Historical apportionment

# %% [markdown]
# ### Grab gnarly Census table

# %%
hist_df = pd.read_excel(
    "https://www2.census.gov/programs-surveys/decennial/2020/data/apportionment/apportionment-2020-tableC2.xlsx",
    skiprows=4,
    skipfooter=3,
)

# %% [markdown]
# ### Awesome headers and data structure, y'all

# %%
hist_df.tail()
# Out:
#        Unnamed: 0  2020: Apportionment population  \
# 45       Virginia                         8654542
# 46     Washington                         7715946
# 47  West Virginia                         1795045
# 48      Wisconsin                         5897473
# 49        Wyoming                          577719
#
#     2020: \nNumber of representatives  2020: \nSeat change  \
# 45                                 11                    0
# 46                                 10                    0
# 47                                  2                   -1
# 48                                  8                    0
# 49                                  1                    0
#
#     2020: Average persons per representative  2010: Apportionment population  \
# 45                                    786777                         8037736
# 46                                    771595                         6753369
# 47                                    897523                         1859815
# 48                                    737184                         5698230
# 49                                    577719                          568300
#
#     2010: \nNumber of representatives  2010: \nSeat change  \
# 45                                 11                    0
# 46                                 10                    1
# 47                                  3                    0
# 48                                  8                    0
# 49                                  1                    0
#
#     2010: Average persons per representative     Unnamed: 9  \
# 45                                    730703       Virginia
# 46                                    675337     Washington
# 47                                    619938  West Virginia
# 48                                    712279      Wisconsin
# 49                                    568300        Wyoming
#
#     2000: Apportionment population  2000: \nNumber of representatives  \
# 45                         7100702                                 11
# 46                         5908684                                  9
# 47                         1813077                                  3
# 48                         5371210                                  8
# 49                          495304                                  1
#
#     2000: \nSeat change  2000: Average persons per representative  \
# 45                    0                                    645518
# 46                    0                                    656520
# 47                    0                                    604359
# 48                   -1                                    671401
# 49                    0                                    495304
#
#     1990: Apportionment population  1990: \nNumber of representatives  \
# 45                         6216568                                 11
# 46                         4887941                                  9
# 47                         1801625                                  3
# 48                         4906745                                  9
# 49                          455975                                  1
#
#     1990: \nSeat change  1990: Average persons per representative  \
# 45                    1                                    565143
# 46                    1                                    543105
# 47                   -1                                    600542
# 48                    0                                    545194
# 49                    0                                    455975
#
#       Unnamed: 18  1980: Apportionment population  \
# 45       Virginia                         5346279
# 46     Washington                         4130163
# 47  West Virginia                         1949644
# 48      Wisconsin                         4705335
# 49        Wyoming                          470816
#
#     1980: \nNumber of representatives  1980: \nSeat change  \
# 45                                 10                    0
# 46                                  8                    1
# 47                                  4                    0
# 48                                  9                    0
# 49                                  1                    0
#
#     1980: Average persons per representative  1970: Apportionment population  \
# 45                                    534628                         4690742
# 46                                    516270                         3443487
# 47                                    487411                         1763331
# 48                                    522815                         4447013
# 49                                    470816                          335719
#
#     1970: \nNumber of representatives  ...  1960: Apportionment population  \
# 45                                 10  ...                         3966949
# 46                                  7  ...                         2853214
# 47                                  4  ...                         1860421
# 48                                  9  ...                         3951777
# 49                                  1  ...                          330066
#
#     1960: \nNumber of representatives 1960: \nSeat change  \
# 45                                 10                   0
# 46                                  7                   0
# 47                                  5                  -1
# 48                                 10                   0
# 49                                  1                   0
#
#     1960: Average persons per representative  1950: Apportionment population  \
# 45                                    396695                         3318680
# 46                                    407602                         2378963
# 47                                    372084                         2005552
# 48                                    395178                         3434575
# 49                                    330066                          290529
#
#    1950: \nNumber of representatives  1950: \nSeat change  \
# 45                                10                    1
# 46                                 7                    1
# 47                                 6                    0
# 48                                10                    0
# 49                                 1                    0
#
#    1950: Average persons per representative    Unnamed: 36  \
# 45                                   331868       Virginia
# 46                                   339852     Washington
# 47                                   334259  West Virginia
# 48                                   343458      Wisconsin
# 49                                   290529        Wyoming
#
#    1940: Apportionment population 1940: \nNumber of representatives  \
# 45                        2677773                                 9
# 46                        1736191                                 6
# 47                        1901974                                 6
# 48                        3137587                                10
# 49                         250742                                 1
#
#    1940: \nSeat change 1940: Average persons per representative  \
# 45                   0                                   297530
# 46                   0                                   289365
# 47                   0                                   316996
# 48                   0                                   313759
# 49                   0                                   250742
#
#    1930: Apportionment population 1930: \nNumber of representatives  \
# 45                        2421829                                 9
# 46                        1552423                                 6
# 47                        1729199                                 6
# 48                        2931721                                10
# 49                         223630                                 1
#
#    1930: \nSeat change 1930: Average persons per representative  \
# 45                  -1                                   269092
# 46                   1                                   258737
# 47                   0                                   288200
# 48                  -1                                   293172
# 49                   0                                   223630
#
#       Unnamed: 45 1920: Apportionment population  \
# 45       Virginia                        2309187
# 46     Washington                        1354596
# 47  West Virginia                        1463701
# 48      Wisconsin                        2631305
# 49        Wyoming                         193487
#
#    1920: \nNumber of representatives 1920: Average persons per representative  \
# 45                                10                                   230919
# 46                                 5                                   270919
# 47                                 6                                   243950
# 48                                11                                   239210
# 49                                 1                                   193487
#
#    1910: Apportionment population 1910: \nNumber of representatives  \
# 45                        2061612                                10
# 46                        1140134                                 5
# 47                        1221119                                 6
# 48                        2332853                                11
# 49                         144658                                 1
#
#    1910: \nSeat change\n(since 1900) 1910: Average persons per representative
# 45                                 0                                   206161
# 46                                 2                                   228027
# 47                                 1                                   203520
# 48                                 0                                   212078
# 49                                 0                                   144658
#
# [5 rows x 53 columns]

# %% [markdown]
# ### Rename the columns

# %%
hist_df.columns = [
    "name",
    "2020pop",
    "2020reps",
    "2020change",
    "2020pop_per_rep",
    "2010pop",
    "2010reps",
    "2010change",
    "2010pop_per_rep",
    "name2000",
    "2000pop",
    "2000reps",
    "2000change",
    "2000pop_per_rep",
    "1990pop",
    "1990reps",
    "1990change",
    "1990pop_per_rep",
    "name1980",
    "1980pop",
    "1980reps",
    "1980change",
    "1980pop_per_rep",
    "1970pop",
    "1970reps",
    "1970change",
    "1970pop_per_rep",
    "name1960",
    "1960pop",
    "1960reps",
    "1960change",
    "1960pop_per_rep",
    "1950pop",
    "1950reps",
    "1950change",
    "1950pop_per_rep",
    "name1940",
    "1940pop",
    "1940reps",
    "1940change",
    "1940pop_per_rep",
    "1930pop",
    "1930reps",
    "1930change",
    "1930pop_per_rep",
    "name1920",
    "1920pop",
    "1920reps",
    "1920pop_per_rep",
    "1910pop",
    "1910reps",
    "1910change",
    "1910pop_per_rep",
]

# %% [markdown]
# ### No change for 1920 in the table, so let's add it

# %%
hist_df["1920change"] = 0

# %% [markdown]
# ### Slim down the dataframe

# %%
hist_df = hist_df[
    [
        "name",
        "2020pop",
        "2020reps",
        "2020change",
        "2020pop_per_rep",
        "2010pop",
        "2010reps",
        "2010change",
        "2010pop_per_rep",
        "2000pop",
        "2000reps",
        "2000change",
        "2000pop_per_rep",
        "1990pop",
        "1990reps",
        "1990change",
        "1990pop_per_rep",
        "1980pop",
        "1980reps",
        "1980change",
        "1980pop_per_rep",
        "1970pop",
        "1970reps",
        "1970change",
        "1970pop_per_rep",
        "1960pop",
        "1960reps",
        "1960change",
        "1960pop_per_rep",
        "1950pop",
        "1950reps",
        "1950change",
        "1950pop_per_rep",
        "1940pop",
        "1940reps",
        "1940change",
        "1940pop_per_rep",
        "1930pop",
        "1930reps",
        "1930change",
        "1930pop_per_rep",
        "1920pop",
        "1920reps",
        "1920change",
        "1920pop_per_rep",
        "1910pop",
        "1910reps",
        "1910change",
        "1910pop_per_rep",
    ]
]

# %% [markdown]
# ### Melt the dataframe

# %%
hist_df_melt = pd.melt(
    hist_df,
    id_vars="name",
    value_vars=[
        "2020pop",
        "2020reps",
        "2020change",
        "2020pop_per_rep",
        "2010pop",
        "2010reps",
        "2010change",
        "2010pop_per_rep",
        "2000pop",
        "2000reps",
        "2000change",
        "2000pop_per_rep",
        "1990pop",
        "1990reps",
        "1990change",
        "1990pop_per_rep",
        "1980pop",
        "1980reps",
        "1980change",
        "1980pop_per_rep",
        "1970pop",
        "1970reps",
        "1970change",
        "1970pop_per_rep",
        "1960pop",
        "1960reps",
        "1960change",
        "1960pop_per_rep",
        "1950pop",
        "1950reps",
        "1950change",
        "1950pop_per_rep",
        "1940pop",
        "1940reps",
        "1940change",
        "1940pop_per_rep",
        "1930pop",
        "1930reps",
        "1930change",
        "1930pop_per_rep",
        "1920pop",
        "1920reps",
        "1920change",
        "1920pop_per_rep",
        "1910pop",
        "1910reps",
        "1910change",
        "1910pop_per_rep",
    ],
)

# %% [markdown]
# ### Clean up and add columns for year and category

# %%
hist_df_melt["year"] = hist_df_melt["variable"].str[:4]

# %%
hist_df_melt["category"] = hist_df_melt["variable"].str.replace("\d+", "", regex=True)

# %%
hist_df_melt.drop(["variable"], axis=1, inplace=True)

# %% [markdown]
# ### Change in number of representatives, by state and year

# %%
change = hist_df_melt[hist_df_melt["category"] == "change"]

# %%
# small_states = [
#     "Alaska",
#     "Wyoming",
#     "Montana",
#     "North Dakota",
#     "South Dakota",
#     "Vermont",
#     "Delaware",
# ]

# %%
mini_multiples_states = (
    alt.Chart(change)
    .mark_bar()
    .encode(
        y=alt.Y(
            "value:Q",
            title=" ",
            axis=alt.Axis(
                tickSize=0,
                domainOpacity=0,
                tickCount=2,
                offset=4,
                gridWidth=0.6,
                gridColor="#dddddd",
            ),
        ),
        x=alt.X(
            "year:O",
            title=" ",
            axis=alt.Axis(
                tickSize=0,
                domainOpacity=0,
                tickCount=3,
                offset=4,
                gridWidth=0.6,
                gridColor="#dddddd",
                values=["1910", "2020"],
            ),
        ),
        facet=alt.Facet(
            "name:O",
            columns=10,
            title=" ",
            header=alt.Header(labelFontSize=15, labelFont="Benton Gothic"),
        ),
        color=alt.condition(
            alt.datum.value > 0,
            alt.value("steelblue"),  # The positive color
            alt.value("red"),  # The negative color
        ),
    )
    .properties(width=80, height=80, title="Change in representatives by Census year")
    .configure_view(strokeOpacity=0)
    .configure_legend(orient="top", symbolType="square")
    .configure_axis(labelFontSize=12)
)
mini_multiples_states
# Out:
# alt.Chart(...)

# %%
mini_multiples_states.save("visuals/mini_multiples_states.png", scale_factor=1)

# %% [markdown]
# ### Alternative chart forms

# %%
alt.Chart(change).mark_rect().encode(
    x="year:O",
    y="name:O",
    color=alt.condition(
        alt.datum.value < 0,
        alt.value("red"),  # The positive color
        alt.value("lightgray"),  # The negative color
    ),
).properties(height=600, width=300, title="When states lost representation")
# Out:
# alt.Chart(...)

# %% [markdown]
# ### What's the sum of seats by state?

# %%
hist_df_melt.head()
# Out:
#          name     value  year category
# 0     Alabama   5030053  2020      pop
# 1      Alaska    736081  2020      pop
# 2     Arizona   7158923  2020      pop
# 3    Arkansas   3013756  2020      pop
# 4  California  39576757  2020      pop

# %%
hist_df_melt["value"] = hist_df_melt["value"].str.replace("X", "0", regex=False)

# %%
hist_df_melt[hist_df_melt["value"] == "X"]
# Out:
# Empty DataFrame
# Columns: [name, value, year, category]
# Index: []

# %%
hist_df_melt.head()
# Out:
#          name value  year category
# 0     Alabama   NaN  2020      pop
# 1      Alaska   NaN  2020      pop
# 2     Arizona   NaN  2020      pop
# 3    Arkansas   NaN  2020      pop
# 4  California   NaN  2020      pop

# %% [markdown]
# ### Rhode Island

# %%
hist_df_ri = hist_df_melt[hist_df_melt["name"] == "Rhode Island"].copy()

# %%
hist_df_ri[hist_df_ri["category"] == "change"]
# Out:
#               name value  year category
# 138   Rhode Island   NaN  2020   change
# 338   Rhode Island   NaN  2010   change
# 538   Rhode Island   NaN  2000   change
# 738   Rhode Island   NaN  1990   change
# 938   Rhode Island   NaN  1980   change
# 1138  Rhode Island   NaN  1970   change
# 1338  Rhode Island   NaN  1960   change
# 1538  Rhode Island   NaN  1950   change
# 1738  Rhode Island   NaN  1940   change
# 1938  Rhode Island   NaN  1930   change
# 2138  Rhode Island   NaN  1920   change
# 2338  Rhode Island   NaN  1910   change

# %% [markdown]
# ### Just California

# %%
hist_df_ca = hist_df_melt[hist_df_melt["name"] == "California"].copy()

# %%
hist_df_ca_pivot = pd.pivot_table(
    hist_df_ca,
    values="value",
    index=["name", "year"],
    columns="category",
    aggfunc=sum,
    fill_value=0,
).reset_index()

# %%
hist_df_ca_pivot.head(12)
# Out:
# category        name  year  change  pop  pop_per_rep  reps
# 0         California  1910       0    0            0     0
# 1         California  1920       0    0            0     0
# 2         California  1930       0    0            0     0
# 3         California  1940       0    0            0     0
# 4         California  1950       0    0            0     0
# 5         California  1960       0    0            0     0
# 6         California  1970       0    0            0     0
# 7         California  1980       0    0            0     0
# 8         California  1990       0    0            0     0
# 9         California  2000       0    0            0     0
# 10        California  2010       0    0            0     0
# 11        California  2020       0    0            0     0

# %%
bars = alt.Chart(hist_df_ca_pivot).mark_bar().encode(y="change:Q", x="year:O")

text = bars.mark_text(
    align="left",
    baseline="middle",
    dy=-10,  # Nudges text to right so it doesn't appear on top of the bar
    dx=-3,
).encode(text="change:Q")

(bars + text).properties(height=400)
# Out:
# alt.LayerChart(...)

# %%
lines = alt.Chart(hist_df_ca_pivot).mark_line().encode(x="year:O", y="pop:Q")

(lines).properties(height=400)
# Out:
# alt.Chart(...)

# %% [markdown]
# ---

# %% [markdown]
# ## Geography

# %% [markdown]
# ### States map

# %%
state_geo = gpd.read_file("raw/states.geojson")
state_geo.columns = state_geo.columns.str.lower()

# %% [markdown]
# ### Add A.P. states

# %%
ap_states = pd.read_csv("raw/ap_states.csv")

# %%
states_merge = state_geo.merge(ap_states, left_on="stusps", right_on="usps")

# %% [markdown]
# ### Clean up

# %%
states_merge.drop(
    ["name_x", "stusps", "statefp", "statens", "affgeoid", "lsad", "aland", "awater"],
    axis=1,
    inplace=True,
)

# %%
states_merge.rename(columns={"name_y": "name"}, inplace=True)

# %%
states_merge = states_merge[["geoid", "name", "usps", "ap", "geometry"]]

# %%
states_merge.head()
# Out:
#   geoid      name usps      ap  \
# 0    23     Maine   ME   Maine
# 1    15    Hawaii   HI  Hawaii
# 2    04   Arizona   AZ   Ariz.
# 3    05  Arkansas   AR    Ark.
# 4    10  Delaware   DE    Del.
#
#                                             geometry
# 0  MULTIPOLYGON (((-68.92401 43.88541, -68.87478 ...
# 1  MULTIPOLYGON (((-156.04965 19.78045, -156.0062...
# 2  MULTIPOLYGON (((-114.79968 32.59362, -114.8093...
# 3  MULTIPOLYGON (((-94.61792 36.49941, -94.36120 ...
# 4  MULTIPOLYGON (((-75.77379 39.72220, -75.75323 ...

# %% [markdown]
# ---

# %% [markdown]
# ## Export

# %%
df_2010.to_csv("processed/apportionment/apportionment_2010.csv", index=False)

# %%
df_2020.to_csv("processed/apportionment/apportionment_2020.csv", index=False)

# %%
df.to_csv("processed/apportionment/apportionment_2010_2020.csv", index=False)

# %%
hist_df_ca_pivot.to_csv(
    "processed/apportionment/apportionment_in_ca_1910_2020.csv", index=False
)
