# %% [markdown]
# # SCOTUS confirmation transcripts

# %%
# %load_ext lab_black

# %%
import pandas as pd
import altair as alt
from PyPDF2 import PdfFileWriter, PdfFileReader
import glob
import re
from collections import Counter

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = None

# %%
### https://www.govinfo.gov/collection/supreme-court-nomination-hearings

# %% [markdown]
# #### How many pages in each file?

# %%
# path = "scotus_confirmation_transcripts/"
# all_files = glob.glob(path + "*.pdf")

# pages = []

# for filename in all_files:
#     output = PdfFileWriter()
#     input = PdfFileReader(open(f"{filename}", "rb"))
#     pages.append(
#         f"{filename.replace('scotus_confirmation_transcripts/', '').replace('.pdf', '')}: %d pages"
#         % input.getNumPages()
#     )
#     # !PDFtoText -layout {filename}

# pages

# %% [markdown]
# #### Clean up Jackson's individual transcripts

# %%
# !cat scotus_confirmation_transcripts/text/jackson*.txt > scotus_confirmation_transcripts/text/jackson.txt
# !mv scotus_confirmation_transcripts/text/jackson-*.txt scotus_confirmation_transcripts/text/jackson

# %% [markdown]
# #### How many words in each transcript?

# %%
text_files = []
words = 0

text_path = "scotus_confirmation_transcripts/text/"
text_files = glob.glob(text_path + "*.txt")

# loop to read, split and count word of each file
for f in text_files:
    file = open(f, "r", encoding="latin-1")
    read_data = file.read()
    per_word = read_data.split()
    words += len(per_word)
    print(
        f"{f.title().replace('Scotus_Confirmation_Transcripts/Text/', '').replace('.Txt', '')}:{words}"
    )
# Out:
# Barrett:212768
# Jackson:428488
# Gorsuch:699228
# Kennedy:1071817
# Alito:1398099
# Sotomayor:1651744
# Kagan:1886709
# Scalia:2050488
# Oconnor:2249106
# Rehnquist-Chief:2718850
# Rehnquist-Powell:3022196
# Roberts:3317650
# Thomas:4528112
# Kavanaugh:5257068
# Breyer:5587991
# Souter:6091996
# Ginsburg:6427427

# %% [markdown]
# #### Concatenate Thomas

# %%
# !cat scotus_confirmation_transcripts/text/thomas* >> scotus_confirmation_transcripts/text/thomas.txt

# %% [markdown]
# #### How many words in each file?

# %%
listed_words = [
    "child pornography",
    "pornography",
    "predator",
    "trafficking",
    "marxist",
    "critical race theory",
    "race",
    "abortion",
    "roe",
    "transgender",
    "bathroom",
    "gender",
    "choice",
    "right to life",
    "taxes",
    "stare decisis",
    "federalism",
    "settled law",
    "founders",
    "laughter",
    "activism",
    "activist",
    "liberal",
    "conservative",
    "corporations",
    "ideologue",
    "right to privacy",
    "corporations",
    "crime",
    "rape",
    "hispanic",
    "book",
    "guantanamo",
    "gitmo",
    "woman",
]

# %%
text_path = "scotus_confirmation_transcripts/text/"
text_files = glob.glob(text_path + "*.txt")
listed_words_list = []

for listed_word in listed_words:
    for filename in text_files:
        file = open(f"{filename}", "rt", encoding="latin-1")
        count_specific_word = 0
        count_total_words = 0
        for line in file:
            words = line.lower().strip()
            words_clean = re.sub(r"[^\w\s]", "", words)
            count_total_words += len(words_clean)
            word_searched = listed_word
            count_specific_word += words_clean.count(word_searched)
            word_dict = {
                "word_searched": word_searched,
                "count_specific_word": count_specific_word,
                "count_total_words": count_total_words,
                "scotus_member": filename.title()
                .replace("Scotus_Confirmation_Transcripts/Text/", "")
                .replace(".Txt", ""),
            }
        listed_words_list.append(word_dict)
        file.close()
        # print(
        #     f"The word/phrase '{word_searched}' appears {count_specific_word} times out of {count_total_words} words in the {filename.title().replace('Scotus_Confirmation_Transcripts/Text/', '').replace('.Txt', '')} transcript."
        # )

# %%
src = pd.DataFrame(listed_words_list)

# %% [markdown]
# #### Word rates

# %%
src["rate_per_100000"] = (
    src["count_specific_word"] / src["count_total_words"]
) * 100000

# %%
hearing_years = {
    "Alito": "2006",
    "Barrett": "2020",
    "Breyer": "1994",
    "Ginsburg": "1993",
    "Gorsuch": "2017",
    "Jackson": "2022",
    "Kagan": "2010",
    "Kavanaugh": "2018",
    "Kennedy": "1987",
    "Oconnor": "1986",
    "Rehnquist-Chief": "1986",
    "Rehnquist-Powell": "1971",
    "Roberts": "2005",
    "Scalia": "1986",
    "Sotomayor": "2009",
    "Souter": "1990",
    "Stevens": "1975",
    "Thomas": "1991",
}

# %%
src["year"] = src["scotus_member"].map(hearing_years)

# %%
src[src["word_searched"].str.contains("gender")].sort_values(
    "rate_per_100000", ascending=False
)
# Out:
#     word_searched  count_specific_word  count_total_words     scotus_member  \
# 203        gender                  230            1901236          Ginsburg
# 202        gender                  112            2874966            Souter
# 190        gender                   74            2110430           Kennedy
# 199        gender                  220            6787590            Thomas
# 192        gender                   43            1426628         Sotomayor
# 198        gender                   36            1648775           Roberts
# 200        gender                   71            4110358         Kavanaugh
# 189        gender                   24            1451495           Gorsuch
# 188        gender                   17            1195752           Jackson
# 196        gender                   36            2598813   Rehnquist-Chief
# 201        gender                   25            1867001            Breyer
# 187        gender                   12            1186625           Barrett
# 191        gender                   14            1818889             Alito
# 193        gender                   10            1317413             Kagan
# 166   transgender                   27            4110358         Kavanaugh
# 194        gender                    6             914566            Scalia
# 155   transgender                    6            1451495           Gorsuch
# 195        gender                    3            1119577           Oconnor
# 153   transgender                    2            1186625           Barrett
# 154   transgender                    2            1195752           Jackson
# 197        gender                    1            1708549  Rehnquist-Powell
# 163   transgender                    0            1708549  Rehnquist-Powell
# 162   transgender                    0            2598813   Rehnquist-Chief
# 164   transgender                    0            1648775           Roberts
# 161   transgender                    0            1119577           Oconnor
# 169   transgender                    0            1901236          Ginsburg
# 168   transgender                    0            2874966            Souter
# 160   transgender                    0             914566            Scalia
# 159   transgender                    0            1317413             Kagan
# 158   transgender                    0            1426628         Sotomayor
# 157   transgender                    0            1818889             Alito
# 156   transgender                    0            2110430           Kennedy
# 167   transgender                    0            1867001            Breyer
# 165   transgender                    0            6787590            Thomas
#
#      rate_per_100000  year
# 203        12.097393  1993
# 202         3.895698  1990
# 190         3.506394  1987
# 199         3.241209  1991
# 192         3.014100  2009
# 198         2.183439  2005
# 200         1.727343  2018
# 189         1.653468  2017
# 188         1.421699  2022
# 196         1.385248  1986
# 201         1.339046  1994
# 187         1.011271  2020
# 191         0.769701  2006
# 193         0.759063  2010
# 166         0.656877  2018
# 194         0.656049  1986
# 155         0.413367  2017
# 195         0.267958  1986
# 153         0.168545  2020
# 154         0.167259  2022
# 197         0.058529  1971
# 163         0.000000  1971
# 162         0.000000  1986
# 164         0.000000  2005
# 161         0.000000  1986
# 169         0.000000  1993
# 168         0.000000  1990
# 160         0.000000  1986
# 159         0.000000  2010
# 158         0.000000  2009
# 157         0.000000  2006
# 156         0.000000  1987
# 167         0.000000  1994
# 165         0.000000  1991

# %%
alt.Chart(src[src["word_searched"] == "child pornography"]).mark_bar(
    color="#00d4d8"
).encode(
    x=alt.X(
        "scotus_member:N",
        sort=alt.EncodingSortField(field="year", order="ascending"),
    ),
    y="count_specific_word",
    facet=alt.Facet("word_searched", columns=5),
).properties(
    width=650, height=400
)
# Out:
# alt.Chart(...)

# %%
child_porn = src[src["word_searched"] == "child pornography"].sort_values(
    "year", ascending=False
)

# %%
child_porn["display"] = child_porn["scotus_member"] + " (" + child_porn["year"] + ")"

# %%
child_porn[["display", "count_specific_word", "count_total_words"]].to_csv(
    "data/processed/kbj-child-porn-confirmation-hearings.csv", index=False
)

# %%
alt.Chart(src[src["word_searched"] != "kavanaugh"]).mark_bar(color="#00d4d8").encode(
    y=alt.Y(
        "scotus_member:N",
        sort=alt.EncodingSortField(field="year", order="ascending"),
    ),
    x="count_specific_word",
    facet=alt.Facet("word_searched", columns=5),
).properties(width=150, height=150)
# Out:
# alt.Chart(...)
