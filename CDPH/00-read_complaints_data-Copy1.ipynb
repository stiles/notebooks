# %% [markdown]
# # CDPH complaints

# %% [markdown]
# ### Import Python tools and Jupyter configuration

# %%
# %load_ext lab_black

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import altair as alt
import altair_latimes as lat

alt.themes.register("latimes", lat.theme)
alt.themes.enable("latimes")
# Out:
# ThemeRegistry.enable('latimes')

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = None
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ---

# %%
complaints_src = pd.read_excel(
    "data/raw/CDPHComplaints.xlsx", skiprows=4, sheet_name="DETAIL"
)

# %%
complaints_src
# Out:
#         CA00000010  Complaint  \
# 0       CA00000013  Complaint
# 1       CA00000015  Complaint
# 2       CA00000016  Complaint
# 3       CA00000017        ERI
# 4       CA00000018        ERI
# ...            ...        ...
# 667576  CA00746046        ERI
# 667577  CA00746076        ERI
# 667578  CA00746079        ERI
# 667579  CA00746100        ERI
# 667580  CA00746145        ERI
#
#                                    Quality of Care/Treatment  \
# 0                             Resident/Patient/Client Rights
# 1       Resident/Patient/Client Abuse @ Employee to Resident
# 2                              Resident/Patient/Client Abuse
# 3                              Resident/Patient/Client Abuse
# 4                     Resident/Patient/Client Abuse @ Sexual
# ...                                                      ...
# 667576                                     Infection Control
# 667577                                                   NaN
# 667578                                                   NaN
# 667579                             Quality of Care/Treatment
# 667580                             Quality of Care/Treatment
#
#        2002-06-06 00:00:00                     Unsubstantiated  \
# 0               2002-02-05                     Unsubstantiated
# 1               2000-12-05                     Unsubstantiated
# 2               2002-06-13  Substantiated without deficiencies
# 3               2002-06-13  Substantiated without deficiencies
# 4               2002-05-14  Substantiated without deficiencies
# ...                    ...                                 ...
# 667576          2021-07-29         Z2_Missing_Completed/Closed
# 667577          2021-07-29         Z2_Missing_Completed/Closed
# 667578          2021-07-29         Z2_Missing_Completed/Closed
# 667579          2021-07-21         Z2_Missing_Completed/Closed
# 667580          2021-07-27         Z2_Missing_Completed/Closed
#
#                                  HERMAN HEALTH CARE CENTER  \
# 0       LAGUNA HONDA HOSPITAL & REHABILITATION CTR D/P SNF
# 1                       JEWISH HOME & REHAB CENTER D/P SNF
# 2         WINDSOR GARDENS REHABILITATION CENTER OF SALINAS
# 3         WINDSOR GARDENS REHABILITATION CENTER OF SALINAS
# 4                                 EMPRESS CARE CENTER, LLC
# ...                                                    ...
# 667576                                          BUILD HOME
# 667577                              SOUTH COAST POST ACUTE
# 667578                                MAINPLACE POST ACUTE
# 667579                                             CASA #1
# 667580                    GRAND TERRACE HEALTH CARE CENTER
#
#              2295 PLUMMER AVENUE       SAN JOSE  95125  \
# 0         375 LAGUNA HONDA BLVD.  SAN FRANCISCO  94116
# 1              302 SILVER AVENUE  SAN FRANCISCO  94112
# 2            637 EAST ROMIE LANE        SALINAS  93901
# 3            637 EAST ROMIE LANE        SALINAS  93901
# 4          1299 S. BASCOM AVENUE       SAN JOSE  95128
# ...                          ...            ...    ...
# 667576       2110 SEVENTH STREET       BERKELEY  94710
# 667577         1030 W WARNER AVE      SANTA ANA  92707
# 667578  1835 WEST LA VETA AVENUE         ORANGE  92868
# 667579     1372  N SECOND AVENUE         UPLAND  91786
# 667580    12000 MT VERNON AVENUE  GRAND TERRACE  92313
#
#                         Skilled Nursing Facility
# 0                       Skilled Nursing Facility
# 1                       Skilled Nursing Facility
# 2                       Skilled Nursing Facility
# 3                       Skilled Nursing Facility
# 4                       Skilled Nursing Facility
# ...                                          ...
# 667576  Intermediate Care Facility-DD/H/N/CN/IID
# 667577                  Skilled Nursing Facility
# 667578                  Skilled Nursing Facility
# 667579  Intermediate Care Facility-DD/H/N/CN/IID
# 667580                  Skilled Nursing Facility
#
# [667581 rows x 10 columns]
