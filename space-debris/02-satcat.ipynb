# %% [markdown]
# # Get SPACE TRACK data

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd
import altair as alt
from datetime import timedelta
import numpy as np
import glob
import json

# %%
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = None

# %% [markdown]
# ## Jonathan McDowell's catalogue

# %%
src = pd.read_csv(
    "https://planet4589.org/space/gcat/tsv/derived/currentcat.tsv",
    sep="\t",
    low_memory=False,
    skiprows=0,
)

# %%
src.columns = src.columns.str.lower()

# %%
src_df = src.drop([0])

# %%
src_df.active.value_counts()
# Out:
# D    24777
# C    15047
# P     9814
# R     6954
# A     4957
# Z        8
# Name: active, dtype: int64

# %%
debris_categories = ["D", "C", "R", "P"]

# %%
df = src_df[
    (src_df["expandedstatus"].str.contains("In Earth orbit|Attached to"))
    & (src_df["active"].isin(debris_categories))
].copy()

# %%
df.active.value_counts()
# Out:
# D    12731
# P     3446
# C     3128
# R     1976
# Name: active, dtype: int64

# %% [markdown]
# #### Get the debris types

# %%
types = {
    "P": "Payload",
    "C": "Litter",
    "R": "Rocket stage",
    "D": "Debris",
}

# %%
df["active_desc"] = df["active"].map(types)

# %%
df.head()
# Out:
#      #jcat deepcat satcat       piece active          type            name  \
# 5   S00005       -  00005  1958 BET 2      P  P                 Vanguard I
# 11  S00011       -  00011  1959 ALP 1      P  P                Vanguard II
# 12  S00012       -  00012  1959 ALP 2      R  R3            GRC 33-KS-2800
# 16  S00016       -  00016  1958 BET 1      R  R3            GRC 33-KS-2800
# 20  S00020       -  00020    1959 ETA      P  P A             Vanguard III
#
#           ldate  parent             sdate               expandedstatus ddate  \
# 5   1958 Mar 17  S00016  1958 Mar 17 1224               In Earth orbit     -
# 11  1959 Feb 17  S00012  1959 Feb 17 1605               In Earth orbit     -
# 12  1959 Feb 17  R02749  1959 Feb 17 1604               In Earth orbit     -
# 16  1958 Mar 17  R02064  1958 Mar 17 1223               In Earth orbit     -
# 20  1959 Sep 18  A00034  1959 Sep 18 0529  Attached to A00034 X-248-A2     -
#
#            odate   perigee pf    apogee af      inc   if   active_desc
# 5   2022 Feb 13        652         3830      34.25   NaN       Payload
# 11  2022 Feb 14        553         2935      32.87   NaN       Payload
# 12  2022 Feb 14        553         3324      32.90   NaN  Rocket stage
# 16  2022 Feb 14        650         4225      34.27   NaN  Rocket stage
# 20             -         -  -         -  -        -    -       Payload

# %% [markdown]
# #### Debris type descriptions

# %%
df["active_desc"].value_counts()
# Out:
# Debris          12731
# Payload          3446
# Litter           3128
# Rocket stage     1976
# Name: active_desc, dtype: int64

# %% [markdown]
# #### Split the messy separation date column

# %%
df[["year", "month", "day", "other1", "other2"]] = (
    df["sdate"].str.replace("?", "", regex=False).str.split(" ", expand=True)
)

# %% [markdown]
# #### Fill in missing days

# %%
df.day = df.day.fillna("1")

# %%
df["day"] = 1

# %% [markdown]
# #### Clean up months

# %%
df["month"] = (
    df["month"]
    .str.replace("Jan", "1", regex=False)
    .str.replace("Feb", "2", regex=False)
    .str.replace("Mar", "3", regex=False)
    .str.replace("Apr", "4", regex=False)
    .str.replace("May", "5", regex=False)
    .str.replace("Jun", "6", regex=False)
    .str.replace("Jul", "7", regex=False)
    .str.replace("Aug", "8", regex=False)
    .str.replace("Sep", "9", regex=False)
    .str.replace("Oct", "10", regex=False)
    .str.replace("Nov", "11", regex=False)
    .str.replace("Dec", "12", regex=False)
)

# %%
df["separation_date"] = pd.to_datetime(df[["year", "month", "day"]])

# %%
df["separation_year"] = df["year"]

# %%
df.head()
# Out:
#      #jcat deepcat satcat       piece active          type            name  \
# 5   S00005       -  00005  1958 BET 2      P  P                 Vanguard I
# 11  S00011       -  00011  1959 ALP 1      P  P                Vanguard II
# 12  S00012       -  00012  1959 ALP 2      R  R3            GRC 33-KS-2800
# 16  S00016       -  00016  1958 BET 1      R  R3            GRC 33-KS-2800
# 20  S00020       -  00020    1959 ETA      P  P A             Vanguard III
#
#           ldate  parent             sdate               expandedstatus ddate  \
# 5   1958 Mar 17  S00016  1958 Mar 17 1224               In Earth orbit     -
# 11  1959 Feb 17  S00012  1959 Feb 17 1605               In Earth orbit     -
# 12  1959 Feb 17  R02749  1959 Feb 17 1604               In Earth orbit     -
# 16  1958 Mar 17  R02064  1958 Mar 17 1223               In Earth orbit     -
# 20  1959 Sep 18  A00034  1959 Sep 18 0529  Attached to A00034 X-248-A2     -
#
#            odate   perigee pf    apogee af      inc   if   active_desc  year  \
# 5   2022 Feb 13        652         3830      34.25   NaN       Payload  1958
# 11  2022 Feb 14        553         2935      32.87   NaN       Payload  1959
# 12  2022 Feb 14        553         3324      32.90   NaN  Rocket stage  1959
# 16  2022 Feb 14        650         4225      34.27   NaN  Rocket stage  1958
# 20             -         -  -         -  -        -    -       Payload  1959
#
#    month  day other1 other2 separation_date separation_year
# 5      3    1   1224   None      1958-03-01            1958
# 11     2    1   1605   None      1959-02-01            1959
# 12     2    1   1604   None      1959-02-01            1959
# 16     3    1   1223   None      1958-03-01            1958
# 20     9    1   0529   None      1959-09-01            1959

# %%
df_slim = df[
    [
        "piece",
        "name",
        "active_desc",
        "separation_date",
        "separation_year",
    ]
].copy()

# %%
df_slim.separation_year.value_counts()
# Out:
# 2007    3088
# 2021    1690
# 2009    1685
# 2015     832
# 1981     783
# 2020     715
# 1991     545
# 1977     500
# 2019     457
# 2018     432
# 1985     429
# 1970     414
# 1992     407
# 2000     333
# 2014     328
# 1975     319
# 2006     288
# 1973     287
# 1990     285
# 2010     283
# 2017     273
# 1993     271
# 2001     258
# 1984     253
# 1999     252
# 1965     244
# 1988     237
# 1987     236
# 1961     227
# 2004     227
# 1976     227
# 1996     226
# 1998     226
# 1989     211
# 2016     210
# 2013     209
# 1983     203
# 1986     199
# 1994     198
# 2002     181
# 2008     172
# 1978     172
# 1968     156
# 1980     151
# 1982     149
# 2011     147
# 1971     146
# 2012     143
# 2005     138
# 1997     138
# 2003     131
# 1969     127
# 1979     124
# 1995     115
# 1963     100
# 1967      99
# 1972      97
# 1974      93
# 1966      88
# 1964      60
# 1962      32
# 2022      15
# 1960      12
# 1959       5
# 1958       3
# Name: separation_year, dtype: int64

# %%
cum_sum_year = (
    df_slim.groupby(["separation_year"])
    .agg({"piece": "size"})["piece"]
    .cumsum()
    .reset_index()
)

# %%
alt.Chart(cum_sum_year).mark_line().encode(x="separation_year", y="piece").properties(
    width=650, height=350
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ---

# %% [markdown]
# ## Aggregate

# %% [markdown]
# #### How many of each type of debris, by year

# %%
# create month period column  for correct ordering
df_slim["month"] = df_slim["separation_date"].dt.to_period("m")

# %%
df_slim["active_desc"] = df_slim["active_desc"].str.lower()

# %%
year_count_category = (
    df_slim.groupby(by=["separation_year", "active_desc"])
    .agg({"piece": "size"})
    .reset_index()
)

# %%
year_count_category_pivot = (
    year_count_category.pivot_table(
        columns="active_desc", values="piece", index="separation_year"
    )
    .reset_index()
    .fillna(0)
)

# %%
year_count_category_melt = pd.melt(
    year_count_category_pivot,
    id_vars="separation_year",
    value_vars=["debris", "litter", "payload", "rocket stage"],
    var_name="type",
    value_name="count",
)

# %%
categories_years = (
    year_count_category_melt.groupby(["separation_year", "type"])
    .sum()
    .groupby(level=1)
    .cumsum()
    .reset_index()
)

# %%
alt.Chart(categories_years).mark_area().encode(
    x="separation_year", y="count", color="type"
).properties(width=350, height=400)
# Out:
# alt.Chart(...)

# %%
categories_years_pivot = categories_years.pivot_table(
    columns="type", index="separation_year", values="count"
).reset_index()

# %%
categories_years_pivot
# Out:
# type separation_year   debris  litter  payload  rocket stage
# 0               1958      0.0     1.0      1.0           1.0
# 1               1959      0.0     1.0      4.0           3.0
# 2               1960      0.0     6.0      8.0           6.0
# 3               1961    190.0    25.0     20.0          12.0
# 4               1962    190.0    36.0     35.0          18.0
# 5               1963    203.0    94.0     57.0          25.0
# 6               1964    203.0   115.0     83.0          38.0
# 7               1965    337.0   153.0    134.0          59.0
# 8               1966    340.0   186.0    167.0          78.0
# 9               1967    342.0   216.0    212.0         100.0
# 10              1968    420.0   247.0    243.0         116.0
# 11              1969    482.0   269.0    271.0         131.0
# 12              1970    810.0   295.0    308.0         154.0
# 13              1971    858.0   316.0    358.0         181.0
# 14              1972    858.0   340.0    405.0         207.0
# 15              1973   1071.0   354.0    450.0         222.0
# 16              1974   1072.0   373.0    500.0         245.0
# 17              1975   1271.0   400.0    561.0         277.0
# 18              1976   1361.0   437.0    632.0         306.0
# 19              1977   1723.0   482.0    688.0         343.0
# 20              1978   1731.0   527.0    770.0         380.0
# 21              1979   1771.0   542.0    816.0         403.0
# 22              1980   1812.0   570.0    873.0         428.0
# 23              1981   2427.0   614.0    954.0         471.0
# 24              1982   2429.0   655.0   1023.0         508.0
# 25              1983   2445.0   717.0   1108.0         548.0
# 26              1984   2488.0   789.0   1198.0         596.0
# 27              1985   2703.0   873.0   1285.0         639.0
# 28              1986   2747.0   908.0   1363.0         681.0
# 29              1987   2827.0   950.0   1437.0         721.0
# 30              1988   2890.0  1008.0   1514.0         760.0
# 31              1989   2962.0  1042.0   1585.0         794.0
# 32              1990   3036.0  1107.0   1687.0         838.0
# 33              1991   3381.0  1177.0   1774.0         881.0
# 34              1992   3624.0  1227.0   1851.0         918.0
# 35              1993   3754.0  1268.0   1922.0         947.0
# 36              1994   3793.0  1310.0   1998.0         988.0
# 37              1995   3796.0  1331.0   2055.0        1022.0
# 38              1996   3895.0  1374.0   2112.0        1049.0
# 39              1997   3896.0  1408.0   2195.0        1069.0
# 40              1998   3980.0  1437.0   2280.0        1097.0
# 41              1999   4070.0  1472.0   2378.0        1126.0
# 42              2000   4219.0  1535.0   2458.0        1167.0
# 43              2001   4362.0  1582.0   2503.0        1190.0
# 44              2002   4373.0  1672.0   2555.0        1218.0
# 45              2003   4387.0  1713.0   2598.0        1251.0
# 46              2004   4490.0  1765.0   2643.0        1278.0
# 47              2005   4529.0  1809.0   2672.0        1304.0
# 48              2006   4666.0  1899.0   2703.0        1334.0
# 49              2007   7595.0  1985.0   2748.0        1362.0
# 50              2008   7604.0  2064.0   2796.0        1398.0
# 51              2009   9062.0  2207.0   2840.0        1438.0
# 52              2010   9190.0  2289.0   2872.0        1479.0
# 53              2011   9195.0  2370.0   2897.0        1515.0
# 54              2012   9220.0  2425.0   2925.0        1550.0
# 55              2013   9271.0  2492.0   2971.0        1595.0
# 56              2014   9434.0  2556.0   3021.0        1646.0
# 57              2015  10133.0  2614.0   3051.0        1691.0
# 58              2016  10203.0  2675.0   3088.0        1733.0
# 59              2017  10215.0  2739.0   3247.0        1771.0
# 60              2018  10386.0  2860.0   3333.0        1825.0
# 61              2019  10659.0  2934.0   3389.0        1879.0
# 62              2020  11227.0  3004.0   3427.0        1918.0
# 63              2021  12731.0  3118.0   3445.0        1972.0
# 64              2022  12731.0  3128.0   3446.0        1976.0

# %%
categories_years_pivot.to_csv(
    "data/processed/stacked_categories_debris_years.csv", index=False
)
