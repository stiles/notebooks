# %% [markdown]
# ### setup

# %%
# %load_ext lab_black

# %%
import pandas as pd
import requests
import pageviewapi
import datetime as dt
from bs4 import BeautifulSoup
import altair as alt
import datetime as dt

# %%
import altair_stiles as altstiles

alt.themes.register("stiles", altstiles.theme)
alt.themes.enable("stiles")
# Out:
# ThemeRegistry.enable('grid')

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = None

# %%
from datawrapper import Datawrapper

dw = Datawrapper(
    access_token="FtIwtvFtoGLaRT9a3gjX69PLu4wSuRyKddoOz6SOPw3k9wWyNICMHTkcPhOGCR5Z"
)

# %% [markdown]
# ### read in data

# %%
df = pd.read_csv("data/Discovery StatisticsPrintDownload.csv")

# %%
df.columns = df.columns.str.lower()

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
# dw.create_chart(
#    "Discovery of nearby asteroids over time", chart_type="d3-area", data=df_years
# )
chart_id = "ST80x"
dw.add_data(chart_id=chart_id, data=df_slim)
# Out:
# <Response [204]>

# %%
df["pha_nea_km"] = df["pha-km"] + df["nea-km"]
df_slim = df[["date", "pha", "nea", "pha_nea_km"]]

# %%
df_slim
# Out:
#           date   pha    nea  pha_nea_km
# 0   2022-09-18  2286  29724        1008
# 1   2022-09-01  2281  29597        1006
# 2   2022-08-01  2278  29367        1006
# 3   2022-07-01  2271  29210        1006
# 4   2022-06-01  2266  29075        1006
# 5   2022-05-01  2261  28889        1005
# 6   2022-04-01  2254  28663        1005
# 7   2022-03-01  2249  28419        1005
# 8   2022-02-01  2242  28130        1005
# 9   2022-01-01  2228  27827        1003
# 10  2021-12-01  2223  27674        1003
# 11  2021-11-01  2214  27310        1003
# 12  2021-10-01  2202  26911        1002
# 13  2021-09-01  2195  26552        1002
# 14  2021-08-01  2184  26303        1000
# 15  2021-07-01  2177  26178        1000
# 16  2021-06-01  2170  26007         999
# 17  2021-05-01  2164  25759         999
# 18  2021-04-01  2155  25452         997
# 19  2021-03-01  2151  25253         997
# 20  2021-02-01  2143  24988         997
# 21  2021-01-01  2136  24736         997
# ...
