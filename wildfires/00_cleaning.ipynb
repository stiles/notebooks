# %% [markdown]
# # Cleaning California wildfire perimeters data

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import json
import jenkspy
import altair_latimes as lat
import altair as alt
alt.renderers.enable('notebook')
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
# Out:
# ThemeRegistry.enable('latimes')

# %%
# https://frap.fire.ca.gov/
# metadata: https://frap.fire.ca.gov/frap-projects/fire-perimeters/
wildfires = gpd.read_file('/Users/mhustiles/data/data/GIS/wildfires/FRAP/input/wildfires_frap.geojson')

# %%
wildfires.dtypes
# Out:
# OBJECTID      float64
# YEAR_          object
# STATE          object
# AGENCY         object
# UNIT_ID        object
# FIRE_NAME      object
# INC_NUM        object
# ALARM_DATE     object
# CONT_DATE      object
# CAUSE         float64
# COMMENTS       object
# REPORT_AC     float64
# GIS_ACRES     float64
# C_METHOD      float64
# OBJECTIVE     float64
# FIRE_NUM       object
# Shape_Leng    float64
# Shape_Area    float64
# geometry       object
# dtype: object

# %%
wildfires.columns = wildfires.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
wildfires.head()
# Out:
#    objectid year_ state agency unit_id fire_name   inc_num  \
# 0       1.0  2007    CA    CCO     LAC   OCTOBER  00246393
# 1       2.0  2007    CA    CCO     LAC     MAGIC  00233077
# 2       3.0  2007    CA    USF     ANF     RANCH  00000166
# 3       4.0  2007    CA    CCO     LAC      EMMA  00201384
# 4       5.0  2007    CA    CCO     LAC    CORRAL  00259483
#
#             alarm_date            cont_date  cause comments  report_ac  \
# 0  2007-10-21T00:00:00  2007-10-23T00:00:00   14.0     None        NaN
# 1  2007-10-22T00:00:00  2007-10-25T00:00:00   14.0     None        NaN
# 2  2007-10-20T00:00:00  2007-11-15T00:00:00    2.0     None    54716.0
# 3  2007-09-11T00:00:00  2007-09-11T00:00:00   14.0     None        NaN
# 4  2007-11-24T00:00:00  2007-11-27T00:00:00   14.0     None        NaN
#
#       gis_acres  c_method  objective  fire_num     shape_leng    shape_area  \
# 0     25.736713       8.0        1.0  00233414    1902.439051  1.041528e+05
# 1   2824.877197       8.0        1.0  00233077   20407.965662  1.143187e+07
# 2  58410.335938       7.0        1.0  00000166  169150.715690  2.363782e+08
# 3    172.214951       8.0        1.0  00201384    6117.777086  6.969292e+05
# 4   4707.997070       8.0        1.0  00259483   22907.182174  1.905259e+07
#
#                                             geometry
# 0  (POLYGON ((-118.4985124819225 34.3824189370447...
# 1  (POLYGON ((-118.5844782794717 34.4197766738174...
# 2  (POLYGON ((-118.7564468802518 34.5965130520924...
# 3  (POLYGON ((-118.0727716195954 34.5019812566583...
# 4  (POLYGON ((-118.7440804532698 34.0812976688129...

# %%
wildfires[['cause', 'objectid', 'c_method', 'objective', 'report_ac']] = \
wildfires[['cause', 'objectid', 'c_method', 'objective', 'report_ac']].astype(str)
wildfires['cause'] = wildfires['cause'].str.replace('.0','', regex=False)
wildfires['cause'] = wildfires['cause'].str.replace('.0','', regex=False)
wildfires['report_ac'] = wildfires['report_ac'].str.replace('.0','', regex=False)
wildfires['c_method'] = wildfires['c_method'].str.replace('.0','', regex=False)
wildfires['objective'] = wildfires['objective'].str.replace('.0','', regex=False)
wildfires['objectid'] = wildfires['objectid'].str.replace('.0','', regex=False)
wildfires['sqmiles'] = (wildfires['gis_acres'] / 640).round(2) 
wildfires.drop(columns=['shape_area', 'shape_leng'], inplace=True)

# %%
wildfires['alarm_date'] = wildfires['alarm_date'].str.replace('T00:00:00', '')

# %%
wildfires['cont_date'] = wildfires['cont_date'].str.replace('T00:00:00', '')

# %%
wildfires['alarm_date'] = pd.to_datetime(wildfires['alarm_date'], format='%Y/%m/%d')
wildfires['alarm_year'] = wildfires['alarm_date'].dt.year
wildfires['alarm_quarter'] = wildfires['alarm_date'].dt.quarter
wildfires['alarm_day'] = wildfires['alarm_date'].dt.day
wildfires['alarm_month'] = wildfires['alarm_date'].dt.month
wildfires['alarm_monthname'] = wildfires['alarm_date'].dt.month_name()

# %%
wildfires['alarm_year'] = wildfires['alarm_year'].astype(str)
wildfires['alarm_quarter'] = wildfires['alarm_quarter'].astype(str)
wildfires['alarm_day'] = wildfires['alarm_day'].astype(str)
wildfires['alarm_month'] = wildfires['alarm_month'].astype(str)

# %%
cause_codes = {
'1':'Lightning',
'2':'Equipment Use',
'3':'Smoking',
'4':'Campfire',
'5':'Debris',
'6':'Railroad',
'7':'Arson',
'8':'Playing with Fire',
'9':'Miscellaneous',
'10':'Vehicle',
'11':'Power Line',
'12':'Firefighter Training',
'13':'Non-Firefighter Training',
'14':'Unknown/Unidentified',
'15':'Structure',
'16':'Aircraft',
'17':'Volcanic',
'18':'Escaped Prescribed Burn',
'19':'Illegal Alien Campfire',
}

# %%
wildfires['cause_description'] = wildfires['cause'].map(cause_codes)

# %%
agencies = {
'BIA':'USDI Bureau of Indian Affairs',
'BLM':'Bureau of Land Management',
'CDF':'California Department of Forestry and Fire Protection',
'CCO':'Contract Counties',
'DOD':'Department of Defense',
'FWS':'USDI Fish and Wildlife Service',
'LRA':'Local Response Area',
'NOP':'No Protection',
'NPS':'National Park Service',
'PVT':'Private',
'USF':'United States Forest Service',
'OTH':'Other',
}

# %%
wildfires['agency_description'] = wildfires['agency'].map(agencies)

# %%
wildfires.head()
# Out:
#   objectid year_ state agency unit_id fire_name   inc_num alarm_date  \
# 0        1  2007    CA    CCO     LAC   OCTOBER  00246393 2007-10-21
# 1        2  2007    CA    CCO     LAC     MAGIC  00233077 2007-10-22
# 2        3  2007    CA    USF     ANF     RANCH  00000166 2007-10-20
# 3        4  2007    CA    CCO     LAC      EMMA  00201384 2007-09-11
# 4        5  2007    CA    CCO     LAC    CORRAL  00259483 2007-11-24
#
#     cont_date cause  ...  fire_num  \
# 0  2007-10-23    14  ...  00233414
# 1  2007-10-25    14  ...  00233077
# 2  2007-11-15     2  ...  00000166
# 3  2007-09-11    14  ...  00201384
# 4  2007-11-27    14  ...  00259483
#
#                                             geometry  sqmiles alarm_year  \
# 0  (POLYGON ((-118.4985124819225 34.3824189370447...     0.04       2007
# 1  (POLYGON ((-118.5844782794717 34.4197766738174...     4.41       2007
# 2  (POLYGON ((-118.7564468802518 34.5965130520924...    91.27       2007
# 3  (POLYGON ((-118.0727716195954 34.5019812566583...     0.27       2007
# 4  (POLYGON ((-118.7440804532698 34.0812976688129...     7.36       2007
#
#   alarm_quarter alarm_day alarm_month  alarm_monthname     cause_description  \
# 0             4        21          10          October  Unknown/Unidentified
# 1             4        22          10          October  Unknown/Unidentified
# 2             4        20          10          October         Equipment Use
# 3             3        11           9        September  Unknown/Unidentified
# 4             4        24          11         November  Unknown/Unidentified
#
#              agency_description
# 0             Contract Counties
# 1             Contract Counties
# 2  United States Forest Service
# 3             Contract Counties
# 4             Contract Counties
#
# [5 rows x 25 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Woolsey fire

# %%
woolsey = wildfires[wildfires['fire_name'] == 'WOOLSEY']

# %%
woolsey.head()
# Out:
#      objectid year_ state agency unit_id fire_name   inc_num alarm_date  \
# 9501    20986  2018    CA    CCO     LAC   WOOLSEY  00338981 2018-11-08
#
#        cont_date cause  ... fire_num  \
# 9501  2018-11-08    14  ...     None
#
#                                                geometry  sqmiles alarm_year  \
# 9501  (POLYGON ((-118.7921470114273 34.2424586745584...   151.48       2018
#
#      alarm_quarter alarm_day alarm_month  alarm_monthname  \
# 9501             4         8          11         November
#
#          cause_description agency_description
# 9501  Unknown/Unidentified  Contract Counties
#
# [1 rows x 25 columns]

# %% [markdown]
# ### Aggregates by years

# %%
years = wildfires.groupby(['year_']).agg({'objectid': 'size', 'sqmiles': 'sum' })\
.reset_index().sort_values('year_', ascending=False).rename(columns={'year_':'year', 'objectid': 'count' })

# %%
years
# Out:
#     year  count  sqmiles
# 38  2018    411  2484.34
# 37  2017    607  2225.83
# 36  2016    347   830.75
# 35  2015    311  1232.99
# 34  2014    238   891.96
# 33  2013    298   890.30
# 32  2012    350  1324.49
# 31  2011    317   316.24
# 30  2010    209   158.66
# 29  2009    254   681.00
# 28  2008    431  2155.90
# 27  2007    346  1623.97
# 26  2006    315  1163.69
# 25  2005    306   399.23
# 24  2004    274   413.81
# 23  2003    340  1512.17
# 22  2002    243  1506.08
# 21  2001    204   374.27
# 20  2000    176   382.62
# 19  1999    259  1214.55
# 18  1998    143   238.74
# 17  1997    166   329.21
# 16  1996    285   990.84
# 15  1995    178   286.05
# 14  1994    194   561.73
# 13  1993    144   483.19
# 12  1992    150   309.40
# 11  1991     74    56.18
# 10  1990    136   519.27
# 9   1989    152   188.30
# 8   1988    219   445.80
# 7   1987    251  1323.22
# 6   1986    151   157.34
# 5   1985    184   835.42
# 4   1984    198   303.23
# 3   1983    148   128.83
# 2   1982    132   209.81
# 1   1981    239   469.01
# 0   1980    263   513.00

# %% [markdown]
# ---

# %% [markdown]
# ### Export cleaned dataframe to GeoJSON

# %%
wildfires.head()
# Out:
#   objectid year_ state agency unit_id fire_name   inc_num alarm_date  \
# 0        1  2007    CA    CCO     LAC   OCTOBER  00246393 2007-10-21
# 1        2  2007    CA    CCO     LAC     MAGIC  00233077 2007-10-22
# 2        3  2007    CA    USF     ANF     RANCH  00000166 2007-10-20
# 3        4  2007    CA    CCO     LAC      EMMA  00201384 2007-09-11
# 4        5  2007    CA    CCO     LAC    CORRAL  00259483 2007-11-24
#
#     cont_date cause  ...  fire_num  \
# 0  2007-10-23    14  ...  00233414
# 1  2007-10-25    14  ...  00233077
# 2  2007-11-15     2  ...  00000166
# 3  2007-09-11    14  ...  00201384
# 4  2007-11-27    14  ...  00259483
#
#                                             geometry  sqmiles alarm_year  \
# 0  (POLYGON ((-118.4985124819225 34.3824189370447...     0.04       2007
# 1  (POLYGON ((-118.5844782794717 34.4197766738174...     4.41       2007
# 2  (POLYGON ((-118.7564468802518 34.5965130520924...    91.27       2007
# 3  (POLYGON ((-118.0727716195954 34.5019812566583...     0.27       2007
# 4  (POLYGON ((-118.7440804532698 34.0812976688129...     7.36       2007
#
#   alarm_quarter alarm_day alarm_month  alarm_monthname     cause_description  \
# 0             4        21          10          October  Unknown/Unidentified
# 1             4        22          10          October  Unknown/Unidentified
# 2             4        20          10          October         Equipment Use
# 3             3        11           9        September  Unknown/Unidentified
# 4             4        24          11         November  Unknown/Unidentified
#
#              agency_description
# 0             Contract Counties
# 1             Contract Counties
# 2  United States Forest Service
# 3             Contract Counties
# 4             Contract Counties
#
# [5 rows x 25 columns]

# %%
wildfires.to_file('/Users/mhustiles/data/data/GIS/wildfires/FRAP/output/wildfires.geojson', driver='GeoJSON')
