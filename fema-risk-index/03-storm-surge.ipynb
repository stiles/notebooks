# %% [markdown]
# # Storm surge

# %% [markdown]
# #### Import Python tools

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd
import altair as alt
import altair_stiles as altstiles
import numpy as np

# %%
alt.themes.register("stiles", altstiles.theme)
alt.themes.enable("grid")
# Out:
# ThemeRegistry.enable('grid')

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ---

# %% [markdown]
# ## Read data

# %% [markdown]
# #### Storm surge records from [SURGEDAT](https://surge.climate.lsu.edu/data.html#GlobalMap)

# %%
src = pd.read_csv("data/raw/globalpeaksurgedb.csv", encoding="Latin-1")

# %%
len(src)
# Out:
# 745

# %%
src.columns = src.columns.str.replace(" ", "_").str.lower()

# %%
src_usa = src[src["country"] == "US"].dropna(subset=["lat", "lon"])

# %%
src_usa
# Out:
#      year   storm_name     storm_dates time  reg  sub_reg country state  \
# 334  1880      Unnamed       Aug 04-14  NaN  5.0      1.0      US    TX
# 335  1886  ÐIndianolaÓ       Aug 12-21  NaN  5.0      1.0      US    TX
# 336  1886      Unnamed        Oct 8-13  NaN  5.0      1.0      US    LA
# 337  1886      Unnamed       Jun 13-15  NaN  5.0      1.0      US    TX
# 338  1886      Unnamed       Sep 16-24  NaN  5.0      1.0      US    TX
# ..    ...          ...             ...  ...  ...      ...     ...   ...
# 682  2008          Fay       8/15-8/28  NaN  5.0      2.0      US    FL
# 683  2010         Earl  Aug 24 - Sep 6  NaN  5.0      2.0      US    NC
# 684  2011        Irene         8/27/11  NaN  5.0      2.0      US    NY
# 685  2012        Sandy             NaN  NaN  5.0      2.0      US    NY
# 734  1992        Iniki        Sep 5-13  NaN  6.0      2.0      US    HI
#
#                                     location      lat       lon surge_m  \
# ...
