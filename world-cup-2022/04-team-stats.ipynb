# %% [markdown]
# # FIFA API: World Cup team stats

# %% [markdown]
# #### Python tools

# %%
# %load_ext lab_black

# %%
import pandas as pd
import altair as alt
import altair_stiles as altstiles
import numpy as np
import re

# %%
alt.themes.register("stiles", altstiles.theme)
alt.themes.enable("stiles")
# Out:
# ThemeRegistry.enable('stiles')

# %%
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000

# %% [markdown]
# ---

# %% [markdown]
# ## Get data

# %% [markdown]
# #### Read the teams into a dataframe

# %%
teams = pd.read_csv("data/processed/world_cup_teams.csv", dtype={"idteam": str})[
    ["idteam", "shortclubname", "abbreviation"]
]

# %%
teams.head()
# Out:
#   idteam shortclubname abbreviation
# 0  43922     Argentina          ARG
# 1  43976     Australia          AUS
# 2  43935       Belgium          BEL
# 3  43924        Brazil          BRA
# 4  43849      Cameroon          CMR

# %% [markdown]
# #### Read results from FIFA API for each team

# %%
teams_data = []

for team, teamname in zip(teams["idteam"], teams["shortclubname"]):
    team_url = f"https://fdh-api.fifa.com/v1/stats/season/255711/team/{team}.json"
    teams_data.append(
        pd.read_json(team_url)
        .drop([2], axis=1)
        .assign(team_name=teamname, team_id=team)
    )

# %%
df = pd.concat(teams_data).reset_index(drop=True)

# %%
df = df.rename(columns={0: "stat", 1: "value"})

# %%
df["stat"] = (
    df["stat"]
    .astype(str)
    .str.replace(r"(?<=\w)([A-Z])", r" \1", regex=True)
    .str.strip()
    .str.capitalize()
)

# %%
df["value"] = df["value"].round(0)

# %% [markdown]
# ---

# %%
df_pivot = df.pivot_table(
    index=["team_name", "team_id"], columns="stat", values="value"
).reset_index()

# %%
df_pivot.columns = df_pivot.columns.str.lower().str.replace(" ", "_", regex=False)

# %%
df_pivot.sort_values("offsides", ascending=False).head()
# Out:
# stat   team_name team_id  assists  attempt_at_goal  attempt_at_goal_against  \
# 0      Argentina   43922      8.0            104.0                     43.0
# 18       Morocco   43872      4.0             61.0                     73.0
# 11        France   43946     12.0            101.0                     78.0
# 6     Costa Rica   43901      1.0             12.0                     63.0
# 17        Mexico   43911      1.0             42.0                     23.0
#
# stat  attempt_at_goal_blocked  attempt_at_goal_from_free_kicks  \
# 0                         8.0                              3.0
# 18                       11.0                              4.0
# 11                       19.0                              2.0
# 6                         2.0                              0.0
# 17                       11.0                              5.0
#
# stat  attempt_at_goal_inside_the_penalty_area  \
# 0                                        69.0
# 18                                       34.0
# 11                                       73.0
# 6                                         7.0
# 17                                       21.0
#
# stat  attempt_at_goal_inside_the_penalty_area_on_target  \
# 0                                                  36.0
# 18                                                 10.0
# 11                                                 26.0
# 6                                                   6.0
# 17                                                  6.0
#
# stat  attempt_at_goal_off_target  attempt_at_goal_on_target  \
# 0                           42.0                       48.0
# 18                          28.0                       17.0
# 11                          42.0                       35.0
# 6                            2.0                        7.0
# 17                          15.0                       15.0
#
# stat  attempt_at_goal_outside_the_penalty_area  \
# 0                                         35.0
# 18                                        27.0
# 11                                        28.0
# 6                                          5.0
# 17                                        21.0
#
# stat  attempt_at_goal_outside_the_penalty_area_on_target  \
# 0                                                  12.0
# 18                                                  7.0
# 11                                                  9.0
# 6                                                   1.0
# 17                                                  9.0
#
# stat  attempted_ball_progressions  attempted_switches_of_play  clean_sheets  \
# 0                           173.0                        44.0           3.0
# 18                          139.0                        73.0           4.0
# 11                          183.0                        32.0           1.0
# 6                            42.0                        14.0           1.0
# 17                           52.0                        17.0           1.0
#
# stat  completed_ball_progressions  completed_switches_of_play  corners  \
# 0                           139.0                        38.0     39.0
# 18                          100.0                        58.0     12.0
# 11                          150.0                        28.0     38.0
# 6                            32.0                        12.0      1.0
# 17                           42.0                        15.0     16.0
#
# stat  crosses  crosses_completed  defensive_pressures_applied  \
# 0       115.0               30.0                       1688.0
# 18       86.0               19.0                       2516.0
# 11      146.0               49.0                       1986.0
# 6        22.0                3.0                       1257.0
# 17       84.0               18.0                        749.0
#
# stat  direct_defensive_pressures_applied  direct_free_kicks  \
# 0                                  332.0              116.0
# 18                                 397.0               84.0
# 11                                 383.0               84.0
# 6                                  155.0               39.0
# 17                                 160.0               51.0
#
# stat  distance_high_speed_running  distance_high_speed_sprinting  \
# 0                         98287.0                        17109.0
# 18                       102556.0                        17034.0
# 11                        98839.0                        17271.0
# 6                         41405.0                         4725.0
# 17                        38345.0                         7073.0
#
# stat  distance_jogging  distance_low_speed_sprinting  distance_walking  \
# 0             331628.0                       45687.0          334463.0
# 18            345468.0                       49019.0          298970.0
# 11            314479.0                       44044.0          328254.0
# 6             144331.0                       17472.0          123609.0
# 17            133114.0                       18131.0          125868.0
#
# stat  distributions_completed_under_pressure  distributions_under_pressure  \
# 0                                     1987.0                        2647.0
# 18                                    1084.0                        1557.0
# 11                                    1398.0                        1933.0
# 6                                      422.0                         600.0
# 17                                     445.0                         705.0
#
# stat  final_third_entries_reception_central_channel  \
# 0                                              53.0
# 18                                             24.0
# 11                                             29.0
# 6                                               7.0
# 17                                              5.0
#
# stat  final_third_entries_reception_inside_left_channel  \
# 0                                                  46.0
# 18                                                 11.0
# 11                                                 41.0
# 6                                                   5.0
# 17                                                 12.0
#
# stat  final_third_entries_reception_inside_right_channel  \
# 0                                                  42.0
# 18                                                 21.0
# 11                                                 29.0
# 6                                                   2.0
# 17                                                 12.0
#
# stat  final_third_entries_reception_left_channel  \
# 0                                           90.0
# 18                                          62.0
# 11                                         113.0
# 6                                           20.0
# 17                                          44.0
#
# stat  final_third_entries_reception_right_channel  forced_turnovers  \
# 0                                           101.0             494.0
# 18                                           73.0             544.0
# 11                                          103.0             524.0
# 6                                             6.0             221.0
# 17                                           54.0             216.0
#
# stat  fouls_against  fouls_for  free_kicks  goal_kicks  \
# 0             100.0      113.0       123.0        39.0
# 18             97.0       81.0       102.0        71.0
# 11             69.0       85.0        98.0        65.0
# 6              24.0       37.0        45.0        31.0
# 17             51.0       49.0        55.0        26.0
#
# stat  goalkeeper_defensive_actions_inside_penalty_area  \
# 0                                                110.0
# 18                                               131.0
# 11                                               137.0
# 6                                                 97.0
# 17                                                43.0
#
# stat  goalkeeper_defensive_actions_outside_penalty_area  \
# 0                                                   1.0
# 18                                                  1.0
# 11                                                  1.0
# 6                                                   0.0
# 17                                                  1.0
#
# stat  goalkeeper_goal_preventions  goals  goals_conceded  \
# 0                            45.0   15.0             8.0
# 18                           77.0    6.0             5.0
# 11                           80.0   16.0             8.0
# 6                            63.0    3.0            11.0
# 17                           23.0    2.0             3.0
#
# stat  goals_conceded_from_attempt_at_goal_against  \
# 0                                             0.0
# 18                                            0.0
# 11                                            0.0
# 6                                             0.0
# 17                                            0.0
#
# stat  goals_from_direct_free_kicks  goals_inside_the_penalty_area  \
# 0                              0.0                           14.0
# 18                             0.0                            5.0
# 11                             0.0                           15.0
# 6                              0.0                            3.0
# 17                             1.0                            1.0
#
# stat  goals_outside_the_penalty_area  headed_attempt_at_goal  \
# 0                                1.0                    11.0
# 18                               1.0                    10.0
# 11                               1.0                    22.0
# 6                                0.0                     1.0
# 17                               1.0                     4.0
#
# stat  indirect_free_kicks  linebreaks_attempted  \
# 0                     7.0                1335.0
# 18                   18.0                 997.0
# 11                   14.0                1081.0
# 6                     6.0                 427.0
# 17                    4.0                 495.0
#
# stat  linebreaks_attempted_all_lines  \
# 0                               64.0
# 18                              52.0
# 11                              33.0
# 6                               15.0
# 17                              38.0
#
# stat  linebreaks_attempted_attacking_and_midfield_line  \
# 0                                                174.0
# 18                                               158.0
# 11                                               137.0
# 6                                                 83.0
# 17                                                79.0
#
# stat  linebreaks_attempted_attacking_line  \
# 0                                   459.0
# 18                                  433.0
# 11                                  354.0
# 6                                   178.0
# 17                                  169.0
#
# stat  linebreaks_attempted_attacking_line_completed  \
# 0                                             340.0
# 18                                            283.0
# 11                                            236.0
# 6                                             107.0
# 17                                            113.0
#
# stat  linebreaks_attempted_completed  linebreaks_attempted_defensive_line  \
# 0                              935.0                                171.0
# 18                             596.0                                104.0
# 11                             729.0                                124.0
# 6                              246.0                                 28.0
# 17                             304.0                                 78.0
#
# stat  linebreaks_attempted_defensive_line_completed  \
# 0                                              96.0
# 18                                             50.0
# 11                                             82.0
# 6                                               8.0
# 17                                             40.0
#
# stat  linebreaks_attempted_midfield_and_defensive_line  \
# 0                                                103.0
# 18                                                67.0
# 11                                                72.0
# 6                                                 18.0
# 17                                                54.0
#
# stat  linebreaks_attempted_midfield_line  \
# 0                                  705.0
# 18                                 460.0
# 11                                 603.0
# 6                                  221.0
# 17                                 248.0
#
# stat  linebreaks_attempted_midfield_line_completed  \
# 0                                            499.0
# 18                                           263.0
# 11                                           411.0
# 6                                            131.0
# 17                                           151.0
#
# stat  linebreaks_attempted_under_pressure  linebreaks_completed_all_lines  \
# 0                                   825.0                            29.0
# 18                                  491.0                            14.0
# 11                                  506.0                            14.0
# 6                                   219.0                             4.0
# 17                                  295.0                            17.0
#
# stat  linebreaks_completed_attacking_and_midfield_line  \
# 0                                                174.0
# 18                                               158.0
# 11                                               137.0
# 6                                                 83.0
# 17                                                79.0
#
# stat  linebreaks_completed_midfield_and_defensive_line  \
# 0                                                 55.0
# 18                                                26.0
# 11                                                47.0
# 6                                                  6.0
# 17                                                24.0
#
# stat  linebreaks_completed_under_pressure  matches_played  \
# 0                                   558.0             7.0
# 18                                  290.0             7.0
# 11                                  346.0             7.0
# 6                                   137.0             3.0
# 17                                  178.0             3.0
#
# stat  offers_to_receive_in_behind  offers_to_receive_in_between  \
# 0                           888.0                        1710.0
# 18                          727.0                        1435.0
# 11                          739.0                        1279.0
# 6                           229.0                         437.0
# 17                          400.0                         511.0
#
# stat  offers_to_receive_in_front  offers_to_receive_inside  \
# 0                         1997.0                    2107.0
# 18                        1358.0                    1683.0
# 11                        1739.0                    1802.0
# 6                          357.0                     487.0
# 17                         501.0                     663.0
#
# stat  offers_to_receive_outside  offers_to_receive_total  offsides  own_goals  \
# 0                        2488.0                   4595.0      23.0        1.0
# 18                       1837.0                   3520.0      19.0        1.0
# 11                       1955.0                   3757.0      16.0        0.0
# 6                         536.0                   1023.0      13.0        0.0
# 17                        749.0                   1412.0      13.0        0.0
#
# stat  passes  passes_completed  penalties  penalties_scored  \
# 0     4375.0            3841.0        5.0               4.0
# 18    2690.0            2219.0        0.0               0.0
# 11    3656.0            3192.0        2.0               2.0
# 6     1022.0             810.0        0.0               0.0
# 17    1253.0            1045.0        0.0               0.0
#
# stat  received_offers_to_receive  \
# 0                         1827.0
# 18                        1184.0
# 11                        1465.0
# 6                          345.0
# 17                         448.0
#
# stat  receptions_between_midfield_and_defensive_line  receptions_in_behind  \
# 0                                              862.0                  99.0
# 18                                             438.0                  60.0
# 11                                             640.0                  86.0
# 6                                              223.0                  12.0
# 17                                             251.0                  42.0
#
# stat  receptions_under_direct_pressure  receptions_under_indirect_pressure  \
# 0                                137.0                              1530.0
# 18                               111.0                               967.0
# 11                               167.0                              1104.0
# 6                                 47.0                               369.0
# 17                                50.0                               451.0
#
# stat  receptions_under_no_pressure  receptions_under_pressure  red_cards  \
# 0                           2831.0                     1667.0        0.0
# 18                          1715.0                     1078.0        1.0
# 11                          2570.0                     1271.0        0.0
# 6                            594.0                      416.0        0.0
# 17                           829.0                      501.0        0.0
#
# stat  substitutions_in  substitutions_out  take_ons_completed  throw_ins  \
# 0                 36.0               36.0                28.0      151.0
# 18                35.0               35.0                24.0      126.0
# 11                28.0               28.0                24.0      135.0
# 6                 14.0               14.0                 5.0       43.0
# 17                12.0               12.0                 5.0       63.0
#
# stat  time_played  total_distance  yellow_cards
# 0           742.0        827188.0          16.0
# 18          696.0        813073.0           9.0
# 11          718.0        802876.0           8.0
# 6           284.0        331530.0           6.0
# 17          296.0        322532.0           7.0

# %%
df_pivot.columns
# Out:
# Index(['team_name', 'team_id', 'assists', 'attempt_at_goal',
#        'attempt_at_goal_against', 'attempt_at_goal_blocked',
#        'attempt_at_goal_from_free_kicks',
#        'attempt_at_goal_inside_the_penalty_area',
#        'attempt_at_goal_inside_the_penalty_area_on_target',
#        'attempt_at_goal_off_target', 'attempt_at_goal_on_target',
#        'attempt_at_goal_outside_the_penalty_area',
#        'attempt_at_goal_outside_the_penalty_area_on_target',
#        'attempted_ball_progressions', 'attempted_switches_of_play',
#        'clean_sheets', 'completed_ball_progressions',
#        'completed_switches_of_play', 'corners', 'crosses', 'crosses_completed',
#        'defensive_pressures_applied', 'direct_defensive_pressures_applied',
#        'direct_free_kicks', 'distance_high_speed_running',
#        'distance_high_speed_sprinting', 'distance_jogging',
#        'distance_low_speed_sprinting', 'distance_walking',
#        'distributions_completed_under_pressure',
#        'distributions_under_pressure',
#        'final_third_entries_reception_central_channel',
#        'final_third_entries_reception_inside_left_channel',
#        'final_third_entries_reception_inside_right_channel',
#        'final_third_entries_reception_left_channel',
#        'final_third_entries_reception_right_channel', 'forced_turnovers',
#        'fouls_against', 'fouls_for', 'free_kicks', 'goal_kicks',
#        'goalkeeper_defensive_actions_inside_penalty_area',
#        'goalkeeper_defensive_actions_outside_penalty_area',
#        'goalkeeper_goal_preventions', 'goals', 'goals_conceded',
#        'goals_conceded_from_attempt_at_goal_against',
#        'goals_from_direct_free_kicks', 'goals_inside_the_penalty_area',
#        'goals_outside_the_penalty_area', 'headed_attempt_at_goal',
#        'indirect_free_kicks', 'linebreaks_attempted',
#        'linebreaks_attempted_all_lines',
#        'linebreaks_attempted_attacking_and_midfield_line',
#        'linebreaks_attempted_attacking_line',
#        'linebreaks_attempted_attacking_line_completed',
#        'linebreaks_attempted_completed', 'linebreaks_attempted_defensive_line',
#        'linebreaks_attempted_defensive_line_completed',
#        'linebreaks_attempted_midfield_and_defensive_line',
#        'linebreaks_attempted_midfield_line',
#        'linebreaks_attempted_midfield_line_completed',
#        'linebreaks_attempted_under_pressure', 'linebreaks_completed_all_lines',
#        'linebreaks_completed_attacking_and_midfield_line',
#        'linebreaks_completed_midfield_and_defensive_line',
#        'linebreaks_completed_under_pressure', 'matches_played',
#        'offers_to_receive_in_behind', 'offers_to_receive_in_between',
#        'offers_to_receive_in_front', 'offers_to_receive_inside',
#        'offers_to_receive_outside', 'offers_to_receive_total', 'offsides',
#        'own_goals', 'passes', 'passes_completed', 'penalties',
#        'penalties_scored', 'received_offers_to_receive',
#        'receptions_between_midfield_and_defensive_line',
#        'receptions_in_behind', 'receptions_under_direct_pressure',
#        'receptions_under_indirect_pressure', 'receptions_under_no_pressure',
#        'receptions_under_pressure', 'red_cards', 'substitutions_in',
#        'substitutions_out', 'take_ons_completed', 'throw_ins', 'time_played',
#        'total_distance', 'yellow_cards'],
#       dtype='object', name='stat')

# %%
df_slim = df_pivot[
    [
        "team_name",
        "time_played",
        "matches_played",
        "passes",
        "passes_completed",
        "attempt_at_goal",
        "assists",
        "goals",
        "goals_conceded",
        "penalties",
        "red_cards",
        "yellow_cards",
        "offsides",
        "fouls_against",
        "fouls_for",
        "free_kicks",
        "goal_kicks",
        "total_distance",
    ]
].copy()

# %%
for c in [
    # "team_name",
    # "time_played",
    # "matches_played",
    "passes",
    "passes_completed",
    "attempt_at_goal",
    "assists",
    "goals",
    "goals_conceded",
    "penalties",
    "red_cards",
    "yellow_cards",
    "offsides",
    "fouls_against",
    "fouls_for",
    "free_kicks",
    "goal_kicks",
    "total_distance",
]:
    df_slim[f"{c}_pg"] = (df_slim[f"{c}"] / df_slim["matches_played"]).round(2)

# %%
df_slim[
    [
        "team_name",
        "passes_pg",
        "passes_completed_pg",
        "attempt_at_goal_pg",
        "assists_pg",
        "goals_pg",
        "goals_conceded_pg",
        "penalties_pg",
        "red_cards_pg",
        "yellow_cards_pg",
        "offsides_pg",
        "fouls_against_pg",
        "fouls_for_pg",
        "free_kicks_pg",
        "goal_kicks_pg",
        "total_distance_pg",
    ]
].sort_values("total_distance_pg", ascending=False)
# Out:
# stat       team_name  passes_pg  passes_completed_pg  attempt_at_goal_pg  \
# 26             Spain     954.75               881.75               12.75
# 7            Croatia     610.29               532.00               11.57
# 29               USA     508.25               444.25               11.50
# 1          Australia     384.00               301.50                6.25
# 15             Japan     398.25               324.50               10.50
# 14           IR Iran     327.33               245.00               11.67
# 19       Netherlands     560.80               488.40                8.00
# 0          Argentina     625.00               548.71               14.86
# 12           Germany     633.00               561.67               22.33
# 25            Serbia     464.00               388.00               10.33
# 5             Canada     499.33               429.33               11.67
# 18           Morocco     384.29               317.00                8.71
# 3             Brazil     601.80               539.20               18.00
# 21          Portugal     595.40               523.00               12.40
# 2            Belgium     593.00               522.67               11.33
# 11            France     522.29               456.00               14.43
# 28           Tunisia     405.33               321.33                9.67
# 8            Denmark     593.67               521.00               11.67
# 30           Uruguay     454.67               375.33               10.67
# 10           England     610.40               544.60               12.00
# 23      Saudi Arabia     374.67               293.67                9.67
# 31             Wales     414.00               331.67                8.00
# 16    Korea Republic     466.50               401.75               12.25
# 13             Ghana     391.00               321.00                8.33
# 27       Switzerland     475.00               403.25                9.00
# 20            Poland     353.00               282.25                7.75
# 24           Senegal     389.00               319.00               12.75
# 6         Costa Rica     340.67               270.00                4.00
# 4           Cameroon     386.33               311.33                9.00
# 22             Qatar     444.33               376.00                7.00
# 17            Mexico     417.67               348.33               14.00
# 9            Ecuador     445.67               369.00                9.00
#
# stat  assists_pg  goals_pg  goals_conceded_pg  penalties_pg  red_cards_pg  \
# 26          1.50      2.25               0.75          0.25          0.00
# 7           1.14      1.14               1.00          0.00          0.00
# 29          0.75      0.75               1.00          0.00          0.00
# 1           0.75      1.00               1.50          0.00          0.00
# 15          1.00      1.25               1.00          0.00          0.00
# 14          0.67      1.33               2.33          0.33          0.00
# 19          1.60      2.00               0.80          0.00          0.20
# 0           1.14      2.14               1.14          0.71          0.00
# 12          1.67      2.00               1.67          0.33          0.00
# 25          1.33      1.67               2.67          0.00          0.00
# 5           0.33      0.67               2.33          0.33          0.00
# 18          0.57      0.86               0.71          0.00          0.14
# 3           1.20      1.60               0.60          0.20          0.00
# 21          1.60      2.40               1.20          0.40          0.00
# 2           0.33      0.33               0.67          0.00          0.00
# 11          1.71      2.29               1.14          0.29          0.00
# 28          0.33      0.33               0.33          0.00          0.00
# 8           0.33      0.33               1.00          0.00          0.00
# 30          0.33      0.67               0.67          0.00          0.00
# 10          2.20      2.60               0.80          0.40          0.00
# 23          0.67      1.00               1.67          0.33          0.00
# 31          0.00      0.33               2.00          0.33          0.33
# 16          0.75      1.25               2.00          0.00          0.00
# 13          1.33      1.67               2.33          0.33          0.00
# 27          1.00      1.25               2.25          0.00          0.00
# 20          0.25      0.75               1.25          0.50          0.00
# 24          0.50      1.25               1.75          0.25          0.00
# 6           0.33      1.00               3.67          0.00          0.00
# 4           1.33      1.33               1.33          0.00          0.33
# 22          0.33      0.33               2.33          0.00          0.00
# 17          0.33      0.67               1.00          0.00          0.00
# 9           0.67      1.33               1.00          0.33          0.00
#
# stat  yellow_cards_pg  offsides_pg  fouls_against_pg  fouls_for_pg  \
# 26               0.50         2.75             10.25         11.25
# 7                1.14         1.57             12.86         12.86
# 29               1.25         1.25             11.25          9.75
# 1                1.75         0.25             13.00          8.50
# 15               1.50         2.25             14.50          9.00
# 14               2.33         2.00             12.33          8.67
# 19               2.40         1.40             17.40         10.20
# 0                2.29         3.29             14.29         16.14
# 12               1.00         4.00              8.67          9.00
# 25               4.00         1.33             14.33          9.00
# 5                2.67         2.67             11.00         12.33
# 18               1.29         2.71             13.86         11.57
# 3                1.20         1.60             12.60         14.80
# 21               1.20         2.60             11.20         13.00
# 2                1.67         1.00             10.00         11.67
# 11               1.14         2.29              9.86         12.14
# 28               1.67         2.33             13.33          9.33
# 8                1.67         1.67              9.33          7.33
# 30               2.67         1.00             11.33         12.00
# 10               0.20         1.00             10.60         13.00
# 23               4.67         1.00             18.67         12.67
# 31               1.67         1.33             11.67         11.00
# 16               1.50         1.75             11.25          8.75
# 13               2.67         1.33             15.33         12.67
# 27               2.25         1.50             13.00         12.25
# 20               1.75         0.25             12.00         11.75
# 24               1.75         2.00             12.00         14.50
# 6                2.00         4.33              8.00         12.33
# 4                2.67         0.67             10.67         12.67
# 22               2.33         2.33             10.33         14.67
# 17               2.33         4.33             17.00         16.33
# 9                1.00         2.67             16.67         12.33
#
# stat  free_kicks_pg  goal_kicks_pg  total_distance_pg
# 26            16.25           6.00          122943.50
# 7             15.14           7.14          122306.86
# 29            11.50           5.25          122021.50
# 1             12.00           9.50          120610.25
# 15            11.25           6.25          120164.25
# 14            10.67           7.67          119635.00
# 19            13.40           8.00          118453.00
# 0             17.57           5.57          118169.71
# 12            13.00           5.00          117135.67
# 25            10.00           7.00          117041.00
# 5             14.00           5.00          116488.00
# 18            14.57          10.14          116153.29
# 3             17.00           5.40          115939.80
# 21            14.80           7.40          115520.00
# 2             14.33          12.00          114731.00
# 11            14.00           9.29          114696.57
# 28            11.00           6.67          114678.00
# 8              9.33           5.33          114204.33
# 30            14.33           8.00          113154.00
# 10            14.80           7.20          112763.80
# 23            18.67          10.00          112523.67
# 31            12.33           8.33          112395.67
# 16            10.25           7.25          112057.00
# 13            13.67          10.33          111633.00
# 27            14.25           7.25          111572.75
# 20            13.50          10.50          110828.00
# 24            15.75           7.00          110677.00
# 6             15.00          10.33          110510.00
# 4             15.33          11.33          109697.33
# 22            19.33           8.33          108428.00
# 17            18.33           8.67          107510.67
# 9             15.67           7.00          105464.33

# %% [markdown]
# ---

# %% [markdown]
# ## Exports

# %%
df.to_csv("data/processed/world_cup_team_stats.csv", index=False)
df.query('team_name == "USA"').to_csv(
    "data/processed/world_cup_team_stats_usa.csv", index=False
)

# %%
df_pivot.query('team_name == "USA"').to_csv(
    "data/processed/world_cup_team_stats_usa_wide.csv", index=False
)
