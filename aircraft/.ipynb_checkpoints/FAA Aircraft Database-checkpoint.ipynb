# %% [markdown]
# # FAA Aircraft Registration Database

# %%
import pandas as pd
import requests
import matplotlib as mpl
import geopandas as gpd
import descartes
import geojson
import json
import numpy as np
import altair as alt
import altair_latimes as lat
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
pd.options.display.float_format = '{:,.0f}'.format
pd.set_option('display.max_colwidth', 100)

# %%
# https://www.faa.gov/licenses_certificates/aircraft_certification/aircraft_registry/releasable_aircraft_download/

# %%
master = pd.read_csv('/Users/mhustiles/data/data/FAA_Aircraft_Database/MASTER.txt', low_memory=False)

# %%
reference = pd.read_csv('/Users/mhustiles/data/data/FAA_Aircraft_Database/ACFTREF.txt', low_memory=False)

# %%
master.columns = master.columns.str.strip().str.lower().str.replace(' ', '_')\
                    .str.replace('(', '').str.replace(')', '').str.replace('-','_')

# %%
reference.columns = reference.columns.str.strip().str.lower().str.replace(' ', '_')\
                    .str.replace('(', '').str.replace(')', '').str.replace('-','_')

# %%
reference.loc[44307]
# Out:
# code                                     0563500
# mfr               GREGORY T HEDDERLY
# model                       PJ260 SENIOR AERO SP
# type_acft                                      4
# type_eng                                       8
# ac_cat                                         1
# build_cert_ind                                 1
# no_eng                                         1
# no_seats                                       2
# ac_weight                                CLASS 1
# speed                                          0
# unnamed:_11                                  NaN
# Name: 44307, dtype: object

# %%
master.name = master.name.str.strip()
master.certification = master.certification.str.strip()
master.type_registrant = master.type_registrant.str.strip()

# %%
owners = master.groupby(['name', 'type_registrant', 'certification']).agg('size').reset_index(name='planes')

# %%
owners.head()
# Out:
#   name type_registrant certification  planes
# 0                                        160
# 1                                  1      33
# 2                                 1B       2
# 3                                 1N      37
# 4                                1NA       2

# %%
corptrans = owners[(owners['planes'] > 20) & (owners['certification'] == '1T')]

# %%
airlines = ['DELTA AIR LINES INC', 'AMERICAN AIRLINES INC', 'SKYWEST AIRLINES INC', 'SWIFT AIR LLC',\
'UNITED AIRLINES INC', 'SOUTHWEST AIRLINES CO', 'JETBLUE AIRWAYS CORP', 'HORIZON AIR INDUSTRIES',\
'ALASKA AIRLINES INC', 'REPUBLIC AIRWAYS INC', 'SPIRIT AIRLINES INC', 'MESA AIRLINES INC']

# %%
airlines
# Out:
# ['DELTA AIR LINES INC',
#  'AMERICAN AIRLINES INC',
#  'SKYWEST AIRLINES INC',
#  'SWIFT AIR LLC',
#  'UNITED AIRLINES INC',
#  'SOUTHWEST AIRLINES CO',
#  'JETBLUE AIRWAYS CORP',
#  'HORIZON AIR INDUSTRIES',
#  'ALASKA AIRLINES INC',
#  'REPUBLIC AIRWAYS INC',
#  'SPIRIT AIRLINES INC',
#  'MESA AIRLINES INC']

# %%
cargo = ['UNITED PARCEL SERVICE CO','FEDERAL EXPRESS CORP', 'FEDERAL EXPRESS CORPORATION',\
            'CARGO AIRCRAFT MANAGEMENT INC', 'ATLAS AIR INC']

# %%
cargo
# Out:
# ['UNITED PARCEL SERVICE CO',
#  'FEDERAL EXPRESS CORP',
#  'FEDERAL EXPRESS CORPORATION',
#  'CARGO AIRCRAFT MANAGEMENT INC',
#  'ATLAS AIR INC']

# %%
private = ['NETJETS SALES INC', 'FLEXJET LLC']

# %%
corptrans.sort_values(by='planes', ascending=False).head()
# Out:
#                                    name type_registrant certification  planes
# 220089  WELLS FARGO TRUST CO NA TRUSTEE               3            1T    1231
# 54055               DELTA AIR LINES INC               3            1T     979
# 8943              AMERICAN AIRLINES INC               3            1T     910
# 211582              UNITED AIRLINES INC               3            1T     861
# 16036              BANK OF UTAH TRUSTEE               3            1T     787

# %%
airline_planes = master[master['name'].isin(airlines)]

# %%
airline_planes_slim = airline_planes[['name','n_number']]

# %%
airline_planes_slim.to_csv('output/airline_planes.csv')

# %% [markdown]
# ### Airline planes

# %%
american = master[master['name'].str.contains('AMERICAN AIRLINES')]

# %%
american.iloc[583]
# Out:
# n_number                                                         766AN
# serial_number                           32880
# mfr_mdl_code                                                   1385213
# eng_mfr_mdl                                                      54555
# year_mfr                                                          2003
# type_registrant                                                      3
# name                                             AMERICAN AIRLINES INC
# street                               1 SKYVIEW DR
# street2                              MD 8B369
# city                                                FORT WORTH
# state                                                               TX
# zip_code                                                    76155
# region                                                               2
# county                                                             439
# country                                                             US
# last_action_date                                              20190801
# cert_issue_date                                               20030702
# certification                                                       1T
# type_aircraft                                                        5
# type_engine                                                          5
# status_code                                                         V
# mode_s_code                                                   52453737
# fract_owner
# air_worth_date                                                20030627
# other_names1
# other_names2
# other_names3
# other_names4
# other_names5
# expiration_date                                               20201231
# unique_id                                                       573827
# kit_mfr
# kit_model
# mode_s_code_hex                                             AA57DF
# unnamed:_34                                                        NaN
# Name: 220253, dtype: object

# %%
master['n_number'] = 'N' + master['n_number']

# %%
src = master.merge(reference, left_on='mfr_mdl_code', right_on='code')

# %%
src.loc[580]
# Out:
# n_number                                                        N3088B
# serial_number                           5175
# mfr_mdl_code                                                   7100510
# eng_mfr_mdl                                                      17003
# year_mfr                                                          1940
# type_registrant                                                      1
# name                                                     ROTH DONALD C
# street                               31 MAPLE ST
# street2
# city                                                NORWALK
# state                                                               OH
# zip_code                                                    448572023
# region                                                               C
# county                                                             077
# country                                                             US
# last_action_date                                              20180423
# cert_issue_date                                               20150602
# certification                                                       1N
# type_aircraft                                                        4
# type_engine                                                          1
# status_code                                                         V
# mode_s_code                                                   50640174
# fract_owner
# air_worth_date                                                19690717
# other_names1
# other_names2
# other_names3
# other_names4
# other_names5
# expiration_date                                               20210630
# unique_id                                                       571333
# kit_mfr
# kit_model
# mode_s_code_hex                                             A3407C
# unnamed:_34                                                        NaN
# code                                                           7100510
# mfr                                     PIPER
# model                                             J3C-65
# type_acft                                                            4
# type_eng                                                             1
# ac_cat                                                               1
# build_cert_ind                                                       0
# no_eng                                                               1
# no_seats                                                             2
# ac_weight                                                      CLASS 1
# speed                                                               67
# unnamed:_11                                                        NaN
# Name: 580, dtype: object

# %%
lapd = ['AIR SUPPORT DIVISION', 
        'LAPD', 
        'LOS ANGELES POLICE']

# %%
lapd_county = ['LOS ANGELES COUNTY', 
        'LA COUNTY',
        'CONSOLIDATED FIRE PROTECTION', 
        'LACOUNTY', 
        'LAPD', 
        'LOS ANGELES POLICE',
       'COUNTY OF LOS ANGELES',
       'COUNTY OF LA',
              'CITY OF LOS ANGELES',
              'LOS ANGELES FIRE',
              'LOS ANGELES FIRE DEPARTMENT',
              'LOS ANGELES CITY']

# %%
la_cops_choppers = src[(src['name'].str.contains('|'.join(lapd_county))) \
                       & (src['state'] == 'CA') \
               & (src['county'] == '037') \
              & (src['type_aircraft'] == '6')]

# %%
la_safety_choppers_slim = la_cops_choppers\
    [[ 'n_number', 'name', 'mfr','model','street','city','year_mfr','no_seats' ]]

# %%
len(la_safety_choppers_slim)
# Out:
# 55

# %%
la_safety_choppers_slim.to_csv('output/la_safety_choppers_slim.csv')

# %%
src[src['name'].str.contains('LOS ANGELES')\
   & (src['state'] == 'CA') \
              & (src['type_aircraft'] == '6')\
   & (src['county'] == '037')]
# Out:
#        n_number                   serial_number mfr_mdl_code eng_mfr_mdl  \
# 59003    N306FD  4646                                1181519       54181
# 59006    N664PD  4643                                1181519       54181
# 81236    N3202Q  3938                                1181511       03020
# 81442    N601CC  4565                                1181511
# 87527    N120LA  36455                               1182157       52168
# 94225    N73985  2894                                1181028       41526
# 112242   N703WP  8362                                1145005       60080
# 112244   N704WP  8369                                1145005       60080
# 138780   N14LA   36393                               1182205       51525
# 138781   N21844  36229                               1182205       52102
# 144902   N228LA  3316                                8680950       60030
# 144903   N229LA  3317                                8680950       60030
# 144904   N232LA  3356                                8680950       60030
# 144905   N233LA  3366                                8680950       60030
# 145021   N80NT   4352                                8680950       60053
# 145041   N961SD  3516                                8680950       60053
# 145042   N963SD  3579                                8680950       60053
# 145044   N966SD  3637                                8680950       60053
# 162788   N301FD  41557                               0260400       52174
# 162789   N304FD  41528                               0260400       52174
# 183119   N303FD  41012                               0260111       52174
# 183120   N305FD  41009                               0260111       52174
# 206476   N950LA  4930                                1145100       60053
# 206477   N951LA  4933                                1145100       60053
# 206478   N953LA  4990                                1145100       60053
# 206479   N954LA  4999                                1145100       60053
# 206480   N955LA  7018                                1145100       60053
# 206481   N956LA  7047                                1145100       60053
# 206482   N957LA  7072                                1145100       60053
# 206483   N958LA  7085                                1145100       60053
# 206484   N959LA  7092                                1145100
# 206485   N960LA  7120                                1145100
# 206486   N961LA  7129                                1145100
# 206487   N962LA  7009                                1145100
# 207667   N302FD  41239                               0260106       52174
# 222956   N668PD  4654                                1145000       60053
# 228509   N17LA   36044                               1182202       52103
# 228510   N18LA   36043                               1182202       52103
# 234225   N15LA   702846                              8140711       30029
# 234226   N160LA  702453                              8140711
# 234227   N190LA  702479                              8140711
# 253227   N822LA  704024                              05633JZ       30155
# 288266   N950SG  9007                                8680941
# 288267   N951LB  9003                                8680941       60040
# 288268   N952JH  9004                                8680941       60040
#
#        year_mfr type_registrant  \
# 59003      2007               5
# 59006      2007               5
# 81236      1986               5
# 81442                         5
# 87527      2007               5
# 94225      1963               5
# 112242     2017               5
# 112244     2017               5
# 138780     2005               5
# 138781     1999               5
# 144902     2000               5
# 144903     2000               5
# 144904     2000               5
# 144905     2000               5
# 145021     2007               5
# 145041     2001               5
# 145042     2002               5
# 145044     2003               5
# 162788     2019               5
# 162789     2017               5
# 183119     2008               5
# 183120     2008               5
# 206476     2010               5
# 206477     2010               5
# 206478     2010               5
# 206479     2010               5
# 206480     2010               5
# 206481     2010               5
# 206482     2010               5
# 206483     2010               5
# 206484                        5
# 206485                        5
# 206486                        5
# 206487                        5
# 207667     2011               5
# 222956     2009               5
# 228509     1992               5
# 228510     1992               5
# 234225                        5
# 234226                        5
# 234227                        5
# 253227     2017               5
# 288266                        5
# 288267     2003               5
# 288268     2003               5
#
#                                                     name  \
# 59003                                CITY OF LOS ANGELES
# 59006                                CITY OF LOS ANGELES
# 81236                                CITY OF LOS ANGELES
# 81442                                CITY OF LOS ANGELES
# 87527                    COUNTY OF LOS ANGELES FIRE DEPT
# 94225                                CITY OF LOS ANGELES
# 112242                               CITY OF LOS ANGELES
# 112244                               CITY OF LOS ANGELES
# 138780                             COUNTY OF LOS ANGELES
# 138781      LOS ANGELES POLICE DEPT AIR SUPPORT DIVISION
# 144902                               CITY OF LOS ANGELES
# 144903                               CITY OF LOS ANGELES
# 144904                               CITY OF LOS ANGELES
# 144905                               CITY OF LOS ANGELES
# 145021       LOS ANGELES INTERAGENCY METROPOLITAN POLICE
# 145041         COUNTY OF LOS ANGELES SHERIFFS DEPARTMENT
# 145042                             COUNTY OF LOS ANGELES
# 145044                             COUNTY OF LOS ANGELES
# 162788                       LOS ANGELES FIRE DEPARTMENT
# 162789                               CITY OF LOS ANGELES
# 183119                                  LOS ANGELES CITY
# 183120                               CITY OF LOS ANGELES
# 206476                             COUNTY OF LOS ANGELES
# 206477                             COUNTY OF LOS ANGELES
# 206478                             COUNTY OF LOS ANGELES
# 206479                             COUNTY OF LOS ANGELES
# 206480                             COUNTY OF LOS ANGELES
# 206481                             COUNTY OF LOS ANGELES
# 206482                             COUNTY OF LOS ANGELES
# 206483                             COUNTY OF LOS ANGELES
# 206484                             COUNTY OF LOS ANGELES
# 206485                             COUNTY OF LOS ANGELES
# 206486                             COUNTY OF LOS ANGELES
# 206487                             COUNTY OF LOS ANGELES
# 207667                                  LOS ANGELES CITY
# 222956      LOS ANGELES POLICE DEPT AIR SUPPORT DIVISION
# 228509             COUNTY OF LOS ANGELES FIRE DEPARTMENT
# 228510             COUNTY OF LOS ANGELES FIRE DEPARTMENT
# 234225                             COUNTY OF LOS ANGELES
# 234226    COUNTY OF LOS ANGELES FIRE DEPT AIR OPERATIONS
# 234227             COUNTY OF LOS ANGELES FIRE DEPARTMENT
# 253227  CONSOLIDATED FIRE PROTECTION DIST OF LOS ANGELES
# 288266                             COUNTY OF LOS ANGELES
# 288267                             COUNTY OF LOS ANGELES
# 288268                             COUNTY OF LOS ANGELES
#
#                                    street                            street2  \
# 59003   C/O LOS ANGELES FIRE DEPARTMENT    16617 ARMINTA ST
# 59006   555 RAMIREZ ST SPC 475
# 81236   555 RAMIREZ ST SPC 475
# 81442   C/O LOS ANGELES FIRE DEPT          16617 ARMINTA ST
# 87527   BARTON HELIPORT                    12605 OSBORNE ST
# 94225   C/O LOS ANGELES FIRE DEPARTMENT    16617 ARMINTA ST
# 112242  14401 SATICOY ST BLG 6 3RD FLOOR
# 112244  14401 SATICOY ST BLDG 6 3RD FL
# 138780  AIR OPERATIONS/BARTON HELIPORT     12605 OSBORNE ST
# 138781  555 RAMIREZ ST SPC 475
# 144902  555 RAMIREZ ST SPACE 475
# 144903  555 RAMIREZ ST STE 475
# 144904  555 RAMIREZ ST STE 475
# 144905  555 RAMIREZ ST SPACE 475
# 145021  5700 S EASTERN AVE
# 145041  3235 N LAKEWOOD BLVD
# 145042  C/O SHERIFFS DEPARTMENT            3235 N LAKEWOOD BLVD
# 145044  C/O SHERIFFS DEPARTMENT            3235 LAKEWOOD BLVD
# 162788  16617 ARMINTA ST
# 162789  16617 ARMINTA ST
# 183119  C/0 LOS ANGELES FIRE DEPARTMENT    16617 ARMINTA ST
# 183120  C/O AIR OPERATIONS SECTION         16617 ARMINTA ST
# 206476  AERO BUREAU                        3235 N LAKEWOOD BLVD
# 206477  C/O SHERIFF'S DEPARTMENT           3235 LAKEWOOD BLVD
# 206478  C/O SHERIFFS DEPT                  3235 N LAKEWOOD BLVD
# 206479  3235 N LAKEWOOD BLVD
# 206480  C/O SHERIFF'S DEPARTMENT           3235 N LAKEWOOD BLVD
# 206481  C/O SHERIFFS DEPT                  3235 N LAKEWOOD BLVD
# 206482  C/O SHERIFFS DEPT                  3235 N LAKEWOOD BLVD
# 206483  C/O SHERIFFS DEPT                  3235 N LAKEWOOD BLVD
# 206484  C/O SHERIFFS DEPT                  3235 N LAKEWOOD BLVD
# 206485  C/O SHERIFFS DEPT                  3235 LAKEWOOD BLVD
# 206486  C/O SHERIFFS DEPARTMENT            3235 N LAKEWOOD BLVD
# 206487  3235 N LAKEWOOD BLVD
# 207667  C/O LOS ANGELES FIRE DEPARTMENT    AIR OPS SECTION 16617 ARMINTA ST
# 222956  555 RAMIREZ ST SPC 475
# 228509  12605 OSBORNE ST
# 228510  12605 OSBORNE STREET
# 234225  12605 OSBORNE ST
# 234226  1320 N EASTERN AVE
# 234227  1320 N EASTERN AVE
# 253227  1320 N EASTERN AVE
# 288266  3235 N LAKEWOOD BLVD
# 288267  3235 N LAKEWOOD BLVD
# 288268  C/O SHERIFFS DEPT - AERO BUREAU    3235 N LAKEWOOD BLVD
#
#                       city  ...                 model type_acft type_eng  \
# 59003   VAN NUYS            ...  206B                         6        3
# 59006   LOS ANGELES         ...  206B                         6        3
# 81236   LOS ANGELES         ...  206B                         6        3
# 81442   VAN NUYS            ...  206B                         6        3
# 87527   PACOIMA             ...  412EP                        6        3
# 94225   VAN NUYS            ...  47G-3B-1                     6        1
# 112242  VAN NUYS            ...  AS350B3                      6        3
# 112244  VAN NUYS            ...  AS350B3                      6        3
# 138780  PACOIMA             ...  412EP                        6        3
# 138781  LOS ANGELES         ...  412EP                        6        3
# 144902  LOS ANGELES         ...  AS 350 B2                    6        3
# 144903  LOS ANGELES         ...  AS 350 B2                    6        3
# 144904  LOS ANGELES         ...  AS 350 B2                    6        3
# 144905  LOS ANGELES         ...  AS 350 B2                    6        3
# 145021  COMMERCE            ...  AS 350 B2                    6        3
# 145041  LONG BEACH          ...  AS 350 B2                    6        3
# 145042  LONG BEACH          ...  AS 350 B2                    6        3
# 145044  LONG BEACH          ...  AS 350 B2                    6        3
# 162788  VAN NUYS            ...  AW139                        6        3
# 162789  VAN NUYS            ...  AW139                        6        3
# 183119  VAN NUYS            ...  AW139                        6        3
# 183120  VAN NUYS            ...  AW139                        6        3
# 206476  LONG BEACH          ...  AS350B2                      6        3
# 206477  LONG BEACH          ...  AS350B2                      6        3
# 206478  LONG BEACH          ...  AS350B2                      6        3
# 206479  LONG BEACH          ...  AS350B2                      6        3
# 206480  LONG BEACH          ...  AS350B2                      6        3
# 206481  LONG BEACH          ...  AS350B2                      6        3
# 206482  LONG BEACH          ...  AS350B2                      6        3
# 206483  LONG BEACH          ...  AS350B2                      6        3
# 206484  LONG BEACH          ...  AS350B2                      6        3
# 206485  LONG BEACH          ...  AS350B2                      6        3
# 206486  LONG BEACH          ...  AS350B2                      6        3
# 206487  LONG BEACH          ...  AS350B2                      6        3
# 207667  VAN NUYS            ...  AW139                        6        3
# 222956  LOS ANGELES         ...  AS350B2                      6        3
# 228509  PACOIMA             ...  412                          6        3
# 228510  PACOIMA             ...  412                          6        3
# 234225  PACOIMA             ...  S-70A                        6        3
# 234226  LOS ANGELES         ...  S-70A                        6        3
# 234227  LOS ANGELES         ...  S-70A                        6        3
# 253227  LOS ANGELES         ...  S-70I                        6        3
# 288266  LONG BEACH          ...  AS332L1                      6        3
# 288267  LONG BEACH          ...  AS332L1                      6        3
# 288268  LONG BEACH          ...  AS332L1                      6        3
#
#        ac_cat build_cert_ind  no_eng no_seats ac_weight speed  unnamed:_11
# 59003       1              0       1        5   CLASS 1     0          nan
# 59006       1              0       1        5   CLASS 1     0          nan
# 81236       1              0       1        5   CLASS 1   112          nan
# 81442       1              0       1        5   CLASS 1   112          nan
# 87527       1              0       2       15   CLASS 1     0          nan
# 94225       1              0       1        3   CLASS 1    78          nan
# 112242      1              0       1        7   CLASS 1     0          nan
# 112244      1              0       1        7   CLASS 1     0          nan
# 138780      1              0       2       15   CLASS 1     0          nan
# 138781      1              0       2       15   CLASS 1     0          nan
# 144902      1              0       1        6   CLASS 1     0          nan
# 144903      1              0       1        6   CLASS 1     0          nan
# 144904      1              0       1        6   CLASS 1     0          nan
# 144905      1              0       1        6   CLASS 1     0          nan
# 145021      1              0       1        6   CLASS 1     0          nan
# 145041      1              0       1        6   CLASS 1     0          nan
# 145042      1              0       1        6   CLASS 1     0          nan
# 145044      1              0       1        6   CLASS 1     0          nan
# 162788      1              0       2       17   CLASS 2     0          nan
# 162789      1              0       2       17   CLASS 2     0          nan
# 183119      1              0       2       17   CLASS 2     0          nan
# 183120      1              0       2       17   CLASS 2     0          nan
# 206476      1              0       1        7   CLASS 1     0          nan
# 206477      1              0       1        7   CLASS 1     0          nan
# 206478      1              0       1        7   CLASS 1     0          nan
# 206479      1              0       1        7   CLASS 1     0          nan
# 206480      1              0       1        7   CLASS 1     0          nan
# 206481      1              0       1        7   CLASS 1     0          nan
# 206482      1              0       1        7   CLASS 1     0          nan
# 206483      1              0       1        7   CLASS 1     0          nan
# 206484      1              0       1        7   CLASS 1     0          nan
# 206485      1              0       1        7   CLASS 1     0          nan
# 206486      1              0       1        7   CLASS 1     0          nan
# 206487      1              0       1        7   CLASS 1     0          nan
# 207667      1              0       2       17   CLASS 3     0          nan
# 222956      1              0       1        7   CLASS 1     0          nan
# 228509      1              0       2       15   CLASS 1     0          nan
# 228510      1              0       2       15   CLASS 1     0          nan
# 234225      1              0       2       39   CLASS 3     0          nan
# 234226      1              0       2       39   CLASS 3     0          nan
# 234227      1              0       2       39   CLASS 3     0          nan
# 253227      1              1       2       15   CLASS 1     0          nan
# 288266      1              0       2       26   CLASS 2     0          nan
# 288267      1              0       2       26   CLASS 2     0          nan
# 288268      1              0       2       26   CLASS 2     0          nan
#
# [45 rows x 47 columns]

# %% [markdown]
# ---
