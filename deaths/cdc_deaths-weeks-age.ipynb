# %% [markdown]
# # Analyzing CDC excess deaths by age and sex

# %% [markdown]
# ### Import Python tools and Jupyter configuration

# %%
# %load_ext lab_black

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
import altair as alt
import altair_latimes as lat

# %%
alt.themes.register("latimes", lat.theme)
alt.themes.enable("latimes")
# Out:
# ThemeRegistry.enable('latimes')

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
alt.data_transformers.disable_max_rows()
pd.set_option("display.max_colwidth", None)

# %%
url = "https://data.cdc.gov/api/views/m74n-4hbs/rows.csv?accessType=DOWNLOAD"

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   AnalysisDate Time Period  MMWRyear  MMWRweek  Weekending  \
# 0   04/04/2021   2015-2019      2015         1  01/10/2015
# 1   04/04/2021   2015-2019      2016         1  01/09/2016
# 2   04/04/2021   2015-2019      2017         1  01/07/2017
# 3   04/04/2021   2015-2019      2018         1  01/06/2018
# 4   04/04/2021   2015-2019      2019         1  01/05/2019
#
#                RaceEthnicity        Sex    AgeGroup  Deaths (weighted)  \
# 0  All Race/Ethnicity Groups  All Sexes  0-14 Years                624
# 1  All Race/Ethnicity Groups  All Sexes  0-14 Years                617
# 2  All Race/Ethnicity Groups  All Sexes  0-14 Years                614
# 3  All Race/Ethnicity Groups  All Sexes  0-14 Years                634
# 4  All Race/Ethnicity Groups  All Sexes  0-14 Years                586
#
#    COVID19 (weighted)  Deaths (unweighted)  COVID19 (unweighted)  \
# 0                   0                  624                     0
# 1                   0                  617                     0
# 2                   0                  614                     0
# 3                   0                  634                     0
# 4                   0                  586                     0
#
#    Average number of deaths (weighted)  Average number of deaths (unweighted)  \
# 0                                  615                                    615
# 1                                  615                                    615
# 2                                  615                                    615
# 3                                  615                                    615
# 4                                  615                                    615
#
#    Number above average (weighted)  Percent above average (weighted)  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#    Number above average (unweighted)  Percent above average (unweighted)  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#   Footnote      Geography
# 0      NaN  United States
# 1      NaN  United States
# 2      NaN  United States
# 3      NaN  United States
# 4      NaN  United States

# %%
df.columns = (
    df.columns.str.strip()
    .str.lower()
    .str.replace(" ", "_", regex=False)
    .str.replace(":", "", regex=False)
    .str.replace("/", "_", regex=False)
    .str.replace(",", "_", regex=False)
    .str.replace("*", "", regex=False)
    .str.replace("(s)", "s", regex=False)
)

# %%
df.head()
# Out:
#   analysisdate time_period  mmwryear  mmwrweek  weekending  \
# 0   04/04/2021   2015-2019      2015         1  01/10/2015
# 1   04/04/2021   2015-2019      2016         1  01/09/2016
# 2   04/04/2021   2015-2019      2017         1  01/07/2017
# 3   04/04/2021   2015-2019      2018         1  01/06/2018
# 4   04/04/2021   2015-2019      2019         1  01/05/2019
#
#                raceethnicity        sex    agegroup  deaths_(weighted)  \
# 0  All Race/Ethnicity Groups  All Sexes  0-14 Years                624
# 1  All Race/Ethnicity Groups  All Sexes  0-14 Years                617
# 2  All Race/Ethnicity Groups  All Sexes  0-14 Years                614
# 3  All Race/Ethnicity Groups  All Sexes  0-14 Years                634
# 4  All Race/Ethnicity Groups  All Sexes  0-14 Years                586
#
#    covid19_(weighted)  deaths_(unweighted)  covid19_(unweighted)  \
# 0                   0                  624                     0
# 1                   0                  617                     0
# 2                   0                  614                     0
# 3                   0                  634                     0
# 4                   0                  586                     0
#
#    average_number_of_deaths_(weighted)  average_number_of_deaths_(unweighted)  \
# 0                                  615                                    615
# 1                                  615                                    615
# 2                                  615                                    615
# 3                                  615                                    615
# 4                                  615                                    615
#
#    number_above_average_(weighted)  percent_above_average_(weighted)  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#    number_above_average_(unweighted)  percent_above_average_(unweighted)  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#   footnote      geography
# 0      NaN  United States
# 1      NaN  United States
# 2      NaN  United States
# 3      NaN  United States
# 4      NaN  United States
