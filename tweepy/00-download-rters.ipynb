# %% [markdown]
# # Using Tweepy to sniff out Twitter bots

# %% [markdown]
# ### Load python tools

# %%
import pandas as pd
import numpy as np
import tweepy
import twint
import json
import glob
import os

# %% [markdown]
# ### Get authenticated

# %%
consumer_key="0EtWySJEum7PpQ7ubreQgLwH5"
consumer_secret="6DPNvqyx44VlJWL3AAdNj53hmkiNAh0uGrvjfVH0ixmyLLqQe7"
access_token="14790314-YvDi7tRrBMQNqPo2BEKqAx7n7lo8fBnA3InySZcg9"
access_token_secret="iKL0A2Hl5oBlbV3m0ffYGWsjK4EVnS9VxvjFRPCCfW5XZ"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth, retry_delay=100, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
rt = api.retweets('1316821974115479552')

# %%
ID = 1332552283553476608

# %%
count = 100

# %%
status = api.get_status(ID)

# %%
status._json
# Out:
# {'created_at': 'Sat Nov 28 05:09:56 +0000 2020',
#  'id': 1332552283553476608,
#  'id_str': '1332552283553476608',
#  'text': 'The 1,126,940 votes were created out of thin air. I won Pennsylvania by a lot, perhaps more than anyone will ever k… https://t.co/uAn4z5JL6E',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/uAn4z5JL6E',
#     'expanded_url': 'https://twitter.com/i/web/status/1332552283553476608',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 25073877,
#   'id_str': '25073877',
#   'name': 'Donald J. Trump',
#   'screen_name': 'realDonaldTrump',
# ...

# %% [markdown]
# ### Search results for "VoteNoOnHolly"

# %%
# results = api.search(q='VoteNoOnHolly', count=100)

# %% [markdown]
# ### Get our list of retweets the @VoteNoOnHolly tweet

# %%
retweets_list = api.retweets(ID, count)

# %% [markdown]
# ### Create a list of retweeters by screen_name

# %%
rters = []

for retweet in retweets_list: 
    rters.append(retweet.user.screen_name)

# %% [markdown]
# ### Get user information for each retweeter

# %%
df_users = []

for r in rters:
    screen_name = r
    user = api.get_user(screen_name)
    df_users.append(user._json)

# %% [markdown]
# ### Users into a dataframe

# %%
df = pd.DataFrame(df_users)

# %%
dfslim = pd.DataFrame(df[['name', 'screen_name', 'location', 'description', 'followers_count','friends_count', \
    'created_at', 'favourites_count', 'statuses_count','profile_image_url',]])

# %%
dfslim['created'] = pd.to_datetime(dfslim['created_at']).dt.date

# %%
dfslim = dfslim.drop(['created_at'], axis=1)

# %%
dfslim.head(40)
# Out:
#                           name      screen_name           location  \
# 0                      Дмитрий  KNNMgw9eUKOaFMf
# 1                    aleksandr  aleksan32030133
# 2                       Norayr   Norayr09895905
# 3                Сергеи Иванов  qOb28mnrRnuR7ry
# 4             Svetlana Khomyak  KhomyakSvetlana
# 5                   vladimir65      vladimir657  Краснодар, Россия
# 6                         saga     saga34551856     Брянск, Россия
# 7                       Даниил  8mmYbQBb9Umasq5
# 8                        رتوج.           Recx8_
# 9               Полина Немцева  bvuY85A80bknG3X             Россия
# 10                      Meshok      Nel12143644
# 11                     николяй  lBelD1R3YhdcPrJ
# 12  Александр Александрович!!!    Sylvester_161
# 13             Dje Bensoultane     DBensoultane
# 14                     Vakjjon          vakjjon
# 15              Ольга Смирнова       smirnovlya
# 16               Tofik Tofikov         TTofikov
# ...

# %%
dfslim.to_csv('data/raw/rters_list.csv', index=False)

# %%
# list(dfslim.screen_name)

# %% [markdown]
# ---

# %%
# for user in tweepy.Cursor(api.friends, screen_name="qOb28mnrRnuR7ry").items():
#     print('friend: ' + user.screen_name)

# %%
# for s in dfslim.screen_name:
#     for user in tweepy.Cursor(api.followers, screen_name="'{s}'").items():
#         print(user.screen_name)

# %% [markdown]
# ### Get all the people who follow the rters

# %%
# rters_followers = []

# for i in dfslim.screen_name[0:1]:
#     !twint -u '{i}' --followers -ho -o data/raw/followers/'{i}'

# %% [markdown]
# ### Get all the people the rters follow

# %%
# rters_following = []

# for i in dfslim.screen_name:
#     !twint -u '{i}' --following -ho -o data/raw/following/'{i}'.txt

# %% [markdown]
# ### Concatentate the list of people the RTers follow

# %%
path = 'data/raw/following/'
files = glob.glob(os.path.join(path, "*.txt"))

# %%
file_df = (pd.read_csv(f, encoding = "ISO-8859-1", low_memory=False,sep=" ", header=None, names=["user_followed", "user"])\
           .assign(user=os.path.basename(f)) for f in files)

# %%
following_df = pd.concat(file_df, ignore_index=True, axis=0)

# %%
following_df.user = following_df.user.str.replace('.txt', '')

# %%
following_df.head()
# Out:
#      user_followed             user
# 0     420Beercules  te2KfjWmgMIvI3Y
# 1            niixo  te2KfjWmgMIvI3Y
# 2  officiallebrron  te2KfjWmgMIvI3Y
# 3       irshad2005  te2KfjWmgMIvI3Y
# 4         suleesly  te2KfjWmgMIvI3Y

# %%
following_df.to_csv('data/processed/following_df.csv', index=False)

# %% [markdown]
# ### Concatentate the lists of RTers' followers

# %%
path = 'data/raw/followers/'
files = glob.glob(os.path.join(path, "*.txt"))

# %%
file_df = (pd.read_csv(f, encoding = "ISO-8859-1", low_memory=False,sep=" ", header=None, names=["user_followed", "user"])\
           .assign(user=os.path.basename(f)) for f in files)

# %%
follower_df = pd.concat(file_df, ignore_index=True, axis=0)

# %%
follower_df.user = follower_df.user.str.replace('.txt', '')

# %%
follower_df.head()
# Out:
#      user_followed             user
# 0       Vyul_24540          ajjgul1
# 1  YZ3GBodUcDCmSh9          ajjgul1
# 2  andreybaranov27          ajjgul1
# 3       Drozzd_Oll          ajjgul1
# 4     LoraineMurpy  te2KfjWmgMIvI3Y

# %%
follower_df.to_csv('data/processed/follower_df.csv', index=False)

# %% [markdown]
# ### Do any of the RTers follow another RTer?

# %% [markdown]
# ---

# %% [markdown]
# ### (Quietly) get all the photos!

# %%
dfslim['profile_image_url'] = dfslim['profile_image_url'].str.replace('_normal', '')

# %%
# for photo in dfslim.profile_image_url:
#     !wget -c -q '{photo}' -P 'images/'

# %% [markdown]
# ---
