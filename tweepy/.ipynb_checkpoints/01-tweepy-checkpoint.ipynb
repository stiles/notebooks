# %% [markdown]
# # Using Tweepy

# %% [markdown]
# ### Load python tools

# %%
import pandas as pd
import numpy as np
import tweepy
import twint
import glob
import os
import json

# %% [markdown]
# ### Get authenticated

# %%
consumer_key="0EtWySJEum7PpQ7ubreQgLwH5"
consumer_secret="6DPNvqyx44VlJWL3AAdNj53hmkiNAh0uGrvjfVH0ixmyLLqQe7"
access_token="14790314-YvDi7tRrBMQNqPo2BEKqAx7n7lo8fBnA3InySZcg9"
access_token_secret="iKL0A2Hl5oBlbV3m0ffYGWsjK4EVnS9VxvjFRPCCfW5XZ"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth, retry_delay=100, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
results = api.search(q='@stiles', count=100)

json_data = [r._json for r in results]

df = pd.json_normalize(json_data)

# %%
df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Nov 29 17:00:58 +0000 2020  1333093606639407111  1333093606639407111
# 1  Sun Nov 29 08:37:41 +0000 2020  1332966953607053315  1332966953607053315
# 2  Sun Nov 29 04:12:49 +0000 2020  1332900297040138240  1332900297040138240
# 3  Sun Nov 29 02:52:42 +0000 2020  1332880136513810434  1332880136513810434
# 4  Sun Nov 29 01:12:04 +0000 2020  1332854810459049984  1332854810459049984
#
#                                                 text  truncated  \
# 0  @stiles If you don't mind sweet snacks, here i...      False
# 1                    @stiles https://t.co/3MW0XkCSOn      False
# 2  @stiles Breaded, fried sweet potatoes were com...      False
# 3  @vicjkim @stiles Niiice. Do they sell the 호박고구...       True
# 4  @stiles This spicy sweet potato is the annual ...       True
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/android" ...           1.332758e+18
# 1  <a href="http://twitter.com/download/iphone" r...           1.332758e+18
# 2  <a href="https://mobile.twitter.com" rel="nofo...           1.332853e+18
# 3  <a href="http://twitter.com/download/android" ...           1.332833e+18
# 4  <a href="http://twitter.com/download/iphone" r...           1.332853e+18
#
#   in_reply_to_status_id_str  in_reply_to_user_id in_reply_to_user_id_str  ...  \
# 0       1332758278384848897           14790314.0                14790314  ...
# 1       1332758278384848897           14790314.0                14790314  ...
# 2       1332852713114136576           14790314.0                14790314  ...
# 3       1332832545625391106           54643600.0                54643600  ...
# 4       1332852713114136576           14790314.0                14790314  ...
#
#   retweeted_status.quoted_status.coordinates  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   retweeted_status.quoted_status.place  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   retweeted_status.quoted_status.contributors  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   retweeted_status.quoted_status.is_quote_status  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   retweeted_status.quoted_status.retweet_count  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    retweeted_status.quoted_status.favorite_count  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    retweeted_status.quoted_status.favorited  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    retweeted_status.quoted_status.retweeted  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    retweeted_status.quoted_status.possibly_sensitive  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    retweeted_status.quoted_status.lang
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
# [5 rows x 229 columns]
