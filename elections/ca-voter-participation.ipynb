# %% [markdown]
# # Historical voter registration and participation in statewide general elections 1924-2020

# %% [markdown]
# ### Import Python tools and Jupyter configuration

# %%
# %load_ext lab_black

# %%
import pandas as pd
import requests
import altair as alt
import altair_latimes as lat
import matplotlib.pyplot as plt

# %%
alt.themes.register("latimes", lat.theme)
alt.themes.enable("latimes")
# Out:
# ThemeRegistry.enable('latimes')

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
alt.data_transformers.disable_max_rows()
pd.options.display.max_colwidth = None

# %% [markdown]
# ### Read data from Secretary of State

# %%
# https://elections.cdn.sos.ca.gov/sov/2020-general/sov/04-historical-voter-reg-participation.pdf

# %%
df = pd.read_csv(
    "data/tabula-04-historical-voter-reg-participation.csv", parse_dates=["date"]
)

# %%
df.sort_values("date", ascending=False).head(20)
# Out:
#          date primary  eligible_votes  democratic  republican    other  \
# 24 2020-11-03       P        25090517    10170317     5334323  6542808
# 55 2018-11-06       G        25200451     8557427     4735054  6403890
# 23 2016-11-08       P        24875293     8720417     5048398  5642956
# 54 2014-11-04       G        24288145     7708683     5005422  5089718
# 22 2012-11-06       P        23802577     7966422     5356608  4922940
# 53 2010-11-02       G        23551699     7620240     5361875  4303768
# 30 2009-05-19       S        23385819     7642108     5325558  4185346
# 21 2008-11-04       P        23208710     7683495     5428052  4192544
# 52 2006-11-07       G        22652190     6727908     5436314  3672886
# 29 2005-11-08       S        22487768     6785188     5524609  3581685
# 20 2004-11-02       P        22075036     7120425     5745518  3691330
# 28 2003-10-07       S        21833141     6718111     5429256  3236059
# ...
