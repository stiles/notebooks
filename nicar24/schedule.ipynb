# %% [markdown]
# # NICAR '24 schedule

# %% [markdown]
# #### Load Python tools and Jupyter config

# %%
import json
import requests
import pandas as pd
import jupyter_black
import altair as alt
import geopandas as gpd

# %%
jupyter_black.load()
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = None
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
place = "NICAR"
place_formal = "NICAR"

# %% [markdown]
# ---

# %% [markdown]
# ## Read data

# %% [markdown]
# #### Get the schedule in JSON format

# %%
src = pd.read_json("https://schedules.ire.org/nicar-2024/nicar-2024-schedule.json")

# %% [markdown]
# #### Get a session date and clean start/end times for each row

# %%
src["date"] = (
    pd.to_datetime(src["start_time"]).dt.tz_convert("US/Eastern").dt.strftime("%b. %-d")
)

src["start_time"] = (
    pd.to_datetime(src["start_time"]).dt.tz_convert("US/Eastern").dt.strftime("%-I %p")
)

src["end_time"] = (
    pd.to_datetime(src["end_time"]).dt.tz_convert("US/Eastern").dt.strftime("%-I %p")
)

# %%
df = src[
    [
        "session_id",
        "day",
        "start_time",
        "end_time",
        "session_title",
        "description",
        "session_type",
        "track",
        "duration_mins",
        "skill_level",
        "speakers",
        "room",
    ]
].copy()

# %%
df.query('day == "Friday"')
# Out:
#      session_id     day start_time end_time  \
# 24         2089  Friday       7 AM     8 AM
# 25         2045  Friday       9 AM    10 AM
# 26         2110  Friday      10 AM    11 AM
# 27         2043  Friday      10 AM    11 AM
# 28         2108  Friday      10 AM    11 AM
# 29         2093  Friday      11 AM    12 PM
# 30         2122  Friday      11 AM    12 PM
# 31         2116  Friday       2 PM     3 PM
# 32         2125  Friday       2 PM     3 PM
# 33         2109  Friday       2 PM     3 PM
# 34         2117  Friday       3 PM     4 PM
# 35         2124  Friday       3 PM     4 PM
# 36         2127  Friday       3 PM     4 PM
# 37         2113  Friday       5 PM     6 PM
# 107        1101  Friday       9 AM    10 AM
# 108        1084  Friday       9 AM    10 AM
# 109        2019  Friday       9 AM    10 AM
# 110        2149  Friday       9 AM    10 AM
# 111        2033  Friday       9 AM    10 AM
# 112        1093  Friday       9 AM    10 AM
# 113        1055  Friday       9 AM    10 AM
# 114        1067  Friday       9 AM    10 AM
# 115        1094  Friday       9 AM    10 AM
# 116        2003  Friday       9 AM    12 PM
# 117        1011  Friday       9 AM    10 AM
# 118        2178  Friday      10 AM    11 AM
# 119        1140  Friday      10 AM    11 AM
# 120        1087  Friday      10 AM    11 AM
# 121        2018  Friday      10 AM    11 AM
# 122        1029  Friday      10 AM    11 AM
# 123        1131  Friday      10 AM    11 AM
# 124        2163  Friday      10 AM    11 AM
# 125        2171  Friday      10 AM    11 AM
# 126        2145  Friday      10 AM    11 AM
# 127        2146  Friday      11 AM    12 PM
# 128        1110  Friday      11 AM    12 PM
# 129        2144  Friday      11 AM    12 PM
# 130        1021  Friday      11 AM    12 PM
# 131        2017  Friday      11 AM    12 PM
# 132        1102  Friday      11 AM    12 PM
# 133        1152  Friday      11 AM    12 PM
# 134        2172  Friday      11 AM    12 PM
# 135        1012  Friday      11 AM    12 PM
# 136        1181  Friday      11 AM    12 PM
# 137        1130  Friday       2 PM     3 PM
# 138        2185  Friday       2 PM     3 PM
# 139        2006  Friday       2 PM     4 PM
# 140        1033  Friday       2 PM     3 PM
# 142        2173  Friday       2 PM     3 PM
# 143        2183  Friday       2 PM     3 PM
# 144        1141  Friday       2 PM     3 PM
# 145        2004  Friday       2 PM     4 PM
# 146        1031  Friday       2 PM     3 PM
# 147        2195  Friday       3 PM     4 PM
# 148        2028  Friday       3 PM     4 PM
# 149        1127  Friday       3 PM     4 PM
# 150        1032  Friday       3 PM     4 PM
# 151        2030  Friday       5 PM     6 PM
# 152        2158  Friday       6 PM     8 PM
#
#                                                                                session_title  \
# 24                                          Mentor program breakfast - invitation-only event
# 25                                            Bringing data journalism to the sports section
# 26                                     First automated chart: Taking Datawrapper to the moon
# 27                                                         QGIS 2: Analyzing geographic data
# 28                                                                     Visual investigations
# 29                                               Behind the story: 2023 Philip Meyer winners
# 30                                                       Networking for journalists of color
# 31                                                          Finding the story in health data
# 32                        Navigating press freedom: A conversation about journalists' safety
# 33                                                                  Web APIs in R with httr2
# 34                                                          15 health datasets in 60 minutes
# 35                                                                           Go dox yourself
# 36                                                       Google Trends for election coverage
# 37                                                                  Data wrangling with code
# 107                                         Data storytelling to empower migrant communities
# 108                                                     Findings and using undocumented APIs
# 109                                                   Google Sheets: Importing and data prep
# 110                              Parsing federal campaign finance data with FastFEC (repeat)
# 111                                                   QGIS 1: Spatial analysis for beginners
# 112                                                     Reconsidering data on mass shootings
# 113                                                             Scraping without programming
# 114                    Starting, growing and maintaining a data desk at student publications
# 115                          The 411 on 311: How to use 311 data to report on your community
# 116                                                             Web scraping in R with rvest
# 117                                         Women in data: Community-building and networking
# 118                                    Building a sustainable data journalism infrastructure
# 119                                               Finding and using data about LGBTQ+ people
# 120                                         Finding needles in haystacks with fuzzy matching
# 121                        Google Sheets: Using string functions to manipulate data (repeat)
# 122         Large-scale scraping projects: Best practices for doing it legally and ethically
# 123                         Navigating federal campaign finance data ahead of 2024 elections
# 124                                         New Google tools for reporting and fact-checking
# 125                                                              R 1: Intro to R and RStudio
# 126                                                      Weathering the stormy news business
# 127            AI 101: Coaching ChatGPT to help you with your coding and data tasks (repeat)
# 128   Datasette: An ecosystem of tools for exploring data and collaborating on data projects
# 129                                               Find public records and leaks: OCCRP Aleph
# 130                Fire, smoke and prevention: Using data to investigate the wildfire crisis
# 131                                            Google Sheets: Advanced pivot tables (repeat)
# 132                                                Mapping disparities in the news with QGIS
# 133                                                   Navigating the world of nonprofit data
# 134                                                          R 2: Data analysis and plotting
# 135                                                          Scraping the worst of the worst
# 136                  Understanding the impact of Asian American voters: From data to stories
# 137                                         Finding the story: Beyond the horse race in 2024
# 138              Layer Cake: How to build reusable, customizable graphics with D3 and Svelte
# 139                                                                Let's make mapping better
# 140                              Publishable charts with R: Make ggplot2 submit to your will
# 142                                                         R 3: Gathering and cleaning data
# 143                                      Survival guide for entering the journalism industry
# 144                                             Undercovered stories about trans communities
# 145                                                                   Upping your Excel game
# 146                                            Using data in government and policy reporting
# 147                                                                  In memoriam: Fazil Khan
# 148                                             Regular expressions: Puzzling out clean data
# 149  Unleashing the power of data in investigations to expose political influence operations
# 150             Using CAPTCHA-solving services to automate CAPTCHA solutions in web scraping
# 151                                                                       Lightning Talks ⚡️
# 152                                                                          Friday NIghtCAR
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               description  \
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            If you signed up for the conference mentor program, come meet your match at this invitation-only breakfast.
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Sports is absolutely drowning in data and there is a large and hungry audience for sports content. Alongside that, there's a large and growing open-source sports analytics community that data journalists should be a part of. In this hands-on class, speakers will take you through examples of ways to use traditional data journalism tools like R and the Tidyverse to bring in up-to-the-moment sports data and do sophisticated analysis that you can immediately visualize to add context to seasons, leagues and sports.\n\nLaptops will be provided.
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Learn how you can use Python and the Datawrapper API to create a limitless number of charts and maps.\n\nLaptops will be provided.
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Build on your existing knowledge of QGIS and learn how to explore, manipulate and analyze geographic datasets to gain new insights.\n\nThis session is good for: Those who attended the QGIS I workshop or already know the basics of visualizing geographic data in QGIS. Laptops will be provided.
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                You’ve done all the work, now you need to visualize it. See examples of how data journalists use graphics, animations, photographs and video to explain and display their work on a variety of platforms. Panelists will share how we gather, parse and produce visual evidence and how to incorporate it into investigations in a clear and concise way. This session is for everyone.
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              A data deep dive into the 2023 Philip Meyer Award winners. Hear from reporters on how they gathered, cleaned, analyzed and visualized the data behind some of the year's biggest stories.
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Mix and mingle, meet friends old and new, and build your professional community in this fun and informal networking session.\n\nThis session is for journalists of color.
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Want to use federal data to investigate doctors and their treatments? The aim of this hands-on training is to illuminate the various federal data resources that can help you examine physicians and their treatment pattern. The data wizards from health analytics group CareSet will also show attendees how to use CareSet’s unique doctor referral data set, which tracks how physicians interact with each other. Attendees will gain access to this unique data resource.\n\nThis session is good for all: we will show attendees how to use this data in excel, and will provide some R script templates for more advanced analysis. Laptops will be provided.
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Hear from panelists on how they keep themselves, sources, data and documents safe. Top leaders in the industry discuss what their newsrooms do when faced with political threats, unlawful arrests and detainments, surveillance and more.\n\nThis session is sponsored by Dow Jones. IRE retains control of content, including the topic and speaker selection, for all conference sessions.
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         httr2 is an R package that helps you generate and perform HTTP requests then process the responses. In this talk, I'll introduce you to httr2 and the basics of HTTP, so you can learn what powers so much of the modern internet, and how you can work with it from R.\n\nhttr2 is the successor to httr and has been under development for around two years. Compared to httr, httr2 has an explicit request object which leads to a more familiar interface where you can iteratively build up complex requests with the pipe. There's no need to stop using httr, as we'll continue to maintain it for many years to come, but for new projects, I'd highly recommend giving httr2 a shot.
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Illness, disease and death, oh my! Health data can be a scary subject full of unreliable methods and incomplete data. We'll show you 15 reliable health-related databases and demonstrate how they can be used to localize national trends. \nThis session is best for someone who is comfortable using Google Sheets. Attendees will need to bring their own laptop (no tablets) for the training.
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     In this session, we'll cover why doxxing is a threat to journalists and suggest some tools and techniques for cleaning up your online footprint.\n\nThis session is good for: Anyone. Attendees will need to bring their own laptop (no tablets) for the training.
# 36                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Learn how to use Google Trends to track search interest in real-time and support election coverage. We’ll show you how to watch for major spikes in searches, get national and regional-level data and use search insights to find inspiration for your next story.\n\nThis session is sponsored by Google Trends. IRE retains control of content, including the topic and speaker selection, for all conference sessions.
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Data journalists want data in tidy rows and columns with standardized values and consistent datatypes. Does data usually come this way? NO! Often data are messy, dirty, unstructured and at times seemingly unusable. In this session we'll talk through some strategies for wrangling that dirty data using code, primarily Python and R (though we'll also dabble in some command line utilities). \n\nThis session is good for anyone who read the description and nodded knowingly. You don't need to be an expert programmer. Laptops will be provided.
# 107                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             The barriers facing migrant communities in accessing fair working conditions are rarely covered through data since reliable data is so hard to come by. This has changed recently through groundbreaking reporting that center the information needs of affected communities, including Rappler's coverage of trafficking of domestic workers, The New Arab's coverage of the fate of Syrian doctors and Lighthouse Report's coverage of the victims of brain waste in Europe. Each story collects data on otherwise invisible communities to map the extent of exploitation, identify barriers to implementing policy solutions and identifying ways communities themselves can take action to protect their own rights.
# 108                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      This tutorial will introduce reporters to an exciting and often overlooked data source found on every website. You will learn how to find and use hidden APIs as a reporting resource, and hear about how this data source has been used in past reporting. We'll be working off this scripted documented: https://inspectelement.org/apis\n\nThis session is for reporters who want to diversify their data sources. You don't need to write code: we'll teach participants to find hidden APIs in your web browser, but knowing some coding will let you to unlock detailed and rich datasets hidden in plain sight. Laptops will be provided.
# 109                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Don't give up if your data isn't presented in a neat spreadsheet. This session will teach you how to get data into a spreadsheet and prepare it for analysis. We will look at how to import text files, deal with data in a PDF, and get a table on a web page into a spreadsheet.\n\nThis session is good for: Anyone comfortable working in Google Sheets. Attendees will need to bring their own laptop (no tablets) for the training and will need a free Google account to participate.
# 110                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    On campaign finance filing deadlines, journalists rush to sift through huge amounts of data on how much money campaigns have — and where it came from. Come learn how to use FastFEC, an open-source tool developed at The Washington Post to rapidly parse FEC filings. \n\nThis session is good for people who are comfortable using the command line. Laptops will be provided.
# 111                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Learn to how to make your own maps using free, open-source software called QGIS. This class will teach you how to get started importing and displaying geographic data. Not all datasets need to be mapped, but some do! We'll go over how to find publicly available data, prepare it for mapping, and join together different datasets.\n\nThis session is good for: Beginners looking to learn the basics of visualizing geographic data. Laptops will be provided.
# 112                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                In the past decade, many news organizations have grappled with defining the term "mass shooting" and assessing the data we use to count these events. Different data sources (including from the government, advocacy organizations, and news outlets) use slightly different definitions of the term, and these discrepancies can be confusing for readers and make analysis of the phenomenon more complicated. This panel conversation among editors from publications that frequently cover mass shootings will consider how we think about the term, the available data on mass shootings, and data on gun violence more broadly.
# 113                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Yes, you can scrape data without using code -- in fact, all you need is Google Sheets! We'll be using Excel-type formulas (don't worry if you don't know what those are, either) to make simple scrapers that automatically pull data into Google Sheets. It’s the best way to get around clunky websites and unhelpful PIOs!\n\nThis session is good for: Beginners who want to start using data for their stories. Attendees will need to bring their own laptop (no tablets) for the training and must have a Google account.
# 114                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Every data desk operates differently, and starting and maintaining a data desk at a student-run publication often requires a lot of trial and error. How can you publish more data-centered reporting as a student? What does the process of starting a data desk from scratch look like? Data editors and reporters from student-run publications will walk through how they began their data desks, what the organization and editing processes look like, how their data desks have grown and shifted and advice for anyone hopeful to bring more data reporting to their student newsrooms.
# 115                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    311 data, or “customer service” data from your city’s citizen complaints department, can help you feed the daily/online beast while also feeding into bigger-picture stories. In this session, you won’t have to lift a mouse finger: We’ll go through examples of stories done using this data, talk about how you can do the same, and you’ll leave with a long list of potential story ideas.\n\nThis session is good for: People comfortable with Python and Jupyter notebook. Taking or having taken "introduction to Python for data analysis" or "first Python notebook" is strongly recommended. Laptops will be provided.
# 116                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                In this tutorial, you'll learn the basics of web scraping with R, using the rvest package. We'll discuss the basic structure of an HTML page, and how to find the elements your interested in with selectorgadget or the browser's developer tools. You'll then learn how to programmatically extract with rvest, turning web pages into tidy data frames.\n\nWe'll also touch on scraping multiple pages, using a combination of httr2 to downloading many pages at once, then purrr to parse them and extract the values you care about.\n\nThis session is good for those with some experience using R and RStudio.
# 117                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     In this session, women, trans and non-binary folks in data journalism and investigative reporting will discuss the unique challenges they face, including the nuances of working in the field, issues of imposter syndrome and how to be our own advocates. Participants will have a safe space to ask questions, share experiences and network with one another.
# ...
# 150                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [{'first': 'Ryan', 'last': 'Little', 'affiliation': 'The Baltimore Banner', 'bio': 'Ryan Little is the data editor at The Baltimore Banner, where he leads a team of data reporters and a visual investigator. His work analyzing large datasets and scraping the web has won multiple national awards and led to at least one Department of Justice investigation. Little is a dedicated mentor to aspiring data journalists and frequently speaks on the role of data in uncovering vital stories.', 'social': [{'label': 'X', 'url': 'https://twitter.com/ryanlittlee'}, {'label': 'GitHub', 'url': 'https://github.com/ryanelittle'}, {'label': 'LinkedIn', 'url': 'https://www.linkedin.com/in/ryan-little-b89060193/'}]}]
# 151                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [{'first': 'Lucio', 'last': 'Villa', 'affiliation': 'The Washington Post', 'bio': 'Lucio Villa is a first-generation Latino, software engineer and web designer who is currently working at The Washington Post as a senior software engineer.', 'social': [{'label': 'X', 'url': 'https://twitter.com/luciovilla'}, {'label': 'GitHub', 'url': 'https://github.com/luciovilla'}, {'label': 'LinkedIn', 'url': 'https://www.linkedin.com/in/luciovilla'}]}]
# 152                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          []
#
#                                                                                           room
# 24                        {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor C'}
# 25             {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Galena'}
# 26           {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Laurel C'}
# 27           {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Falkland'}
# 28                       {'level': 'Fourth floor', 'recorded': False, 'room_name': 'Harbor A'}
# 29                       {'level': 'Fourth floor', 'recorded': False, 'room_name': 'Harbor A'}
# 30                       {'level': 'Fourth floor', 'recorded': False, 'room_name': 'Harbor B'}
# 31           {'level': 'Fourth floor', 'os': 'Mac', 'recorded': False, 'room_name': 'Essex A'}
# 32                       {'level': 'Fourth floor', 'recorded': False, 'room_name': 'Harbor A'}
# 33                        {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor C'}
# 34     {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Kent C'}
# 35   {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Laurel A'}
# 36                       {'level': 'Fourth floor', 'recorded': False, 'room_name': 'Harbor B'}
# 37            {'level': 'Fourth floor', 'os': 'Mac', 'recorded': False, 'room_name': 'Kent A'}
# 107                       {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor D'}
# 108    {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Kent C'}
# 109   {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Essex C'}
# 110          {'level': 'Fourth floor', 'os': 'Mac', 'recorded': False, 'room_name': 'Essex A'}
# 111          {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Falkland'}
# 112                       {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor E'}
# 113  {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Laurel A'}
# 114                      {'level': 'Fourth floor', 'recorded': False, 'room_name': 'Harbor B'}
# 115          {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Laurel C'}
# 116           {'level': 'Fourth floor', 'os': 'Mac', 'recorded': False, 'room_name': 'Kent A'}
# 117                      {'level': 'Fourth floor', 'recorded': False, 'room_name': 'Harbor A'}
# 118                       {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor C'}
# 119                       {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor D'}
# 120          {'level': 'Fourth floor', 'os': 'Mac', 'recorded': False, 'room_name': 'Essex A'}
# 121   {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Essex C'}
# 122                       {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor E'}
# 123    {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Kent C'}
# 124  {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Laurel A'}
# 125            {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Galena'}
# 126                      {'level': 'Fourth floor', 'recorded': False, 'room_name': 'Harbor B'}
# 127  {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Laurel A'}
# 128          {'level': 'Fourth floor', 'os': 'Mac', 'recorded': False, 'room_name': 'Essex A'}
# 129          {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Falkland'}
# 130                       {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor D'}
# 131   {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Essex C'}
# 132          {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Laurel C'}
# 133                       {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor E'}
# 134            {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Galena'}
# 135    {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Kent C'}
# 136                       {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor C'}
# 137  {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Laurel A'}
# 138    {'level': 'Fourth floor', 'os': 'BYO laptop', 'recorded': False, 'room_name': 'Kent C'}
# 139           {'level': 'Fourth floor', 'os': 'Mac', 'recorded': False, 'room_name': 'Kent A'}
# 140          {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Laurel C'}
# 142            {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Galena'}
# 143                      {'level': 'Fourth floor', 'recorded': False, 'room_name': 'Harbor B'}
# 144                       {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor D'}
# 145          {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Falkland'}
# 146                       {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor E'}
# 147          {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Laurel C'}
# 148            {'level': 'Fourth floor', 'os': 'PC', 'recorded': False, 'room_name': 'Galena'}
# 149                       {'level': 'Fourth floor', 'recorded': True, 'room_name': 'Harbor D'}
# 150          {'level': 'Fourth floor', 'os': 'Mac', 'recorded': False, 'room_name': 'Essex A'}
# 151               {'level': 'Fourth floor', 'recorded': False, 'room_name': 'Harbor Ballroom'}
# 152                      {'level': 'Fourth floor', 'recorded': False, 'room_name': 'Harbor B'}

# %% [markdown]
# ---

# %% [markdown]
# ## Exports

# %% [markdown]
# #### JSON

# %%
df.to_json(
    f"data/processed/{place.lower().replace(' ', '_')}_locations.json",
    indent=4,
    orient="records",
)

# %% [markdown]
# #### CSV

# %%
df.to_csv(
    f"data/processed/{place.lower().replace(' ', '_')}_locations.csv", index=False
)

# %% [markdown]
# #### GeoJSON

# %%
gdf.to_file(
    f"data/processed/{place.lower().replace(' ', '_')}_locations.geojson",
    driver="GeoJSON",
)
