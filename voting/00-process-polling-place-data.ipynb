# %% [markdown]
# # Polling closures from U.S. Election Assistance Commission [survey](https://www.eac.gov/research-and-data/datasets-codebooks-and-surveys)

# %%
# %load_ext lab_black

# %%
import pandas as pd

# %%
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = None

# %% [markdown]
# ### 2020 survey

# %%
url_2020 = "https://www.eac.gov/sites/default/files/EAVS%202020/2020_EAVS_for_Public_Release_nolabel_V2.csv"

# %%
src_2020 = pd.read_csv(url_2020, dtype={"FIPSCode": str})

# %%
places2020 = src_2020[
    ["FIPSCode", "Jurisdiction_Name", "State_Abbr", "A1a", "C1a", "D1a", "D3a", "D4a"]
].copy()

# %%
places2020.rename(
    columns={
        "FIPSCode": "fips",
        "State_Abbr": "state",
        "Jurisdiction_Name": "place",
        "A1a": "total_reg_voters",
        "C1a": "mail_ballots_sent",
        "D1a": "total_votes_cast",
        "D3a": "poll_place_elect_day",
        "D4a": "poll_place_early",
    },
    inplace=True,
)

# %%
places2020["year"] = "2020"

# %%
places2020[
    [
        "total_reg_voters",
        "mail_ballots_sent",
        "total_votes_cast",
        "poll_place_elect_day",
        "poll_place_early",
    ]
] = places2020[
    [
        "total_reg_voters",
        "mail_ballots_sent",
        "total_votes_cast",
        "poll_place_elect_day",
        "poll_place_early",
    ]
].astype(
    float
)

# %%
places2020.head()
# Out:
#          fips           place state  total_reg_voters  mail_ballots_sent  \
# 0  0100100000  AUTAUGA COUNTY    AL           43695.0             1329.0
# 1  0100300000  BALDWIN COUNTY    AL          176668.0            11147.0
# 2  0100500000  BARBOUR COUNTY    AL           17850.0              726.0
# 3  0100700000     BIBB COUNTY    AL           15014.0              332.0
# 4  0100900000   BLOUNT COUNTY    AL           41927.0             1032.0
#
#    total_votes_cast  poll_place_elect_day  poll_place_early  year
# 0           24217.0                  18.0               1.0  2020
# 1           96609.0                  50.0               1.0  2020
# 2            9234.0                  16.0               1.0  2020
# 3            9031.0                   8.0               1.0  2020
# 4           25823.0                  24.0               1.0  2020

# %% [markdown]
# ---

# %% [markdown]
# ### 2016

# %% [markdown]
# #### Registered voters

# %%
src_2016a = pd.read_excel(
    "input/EAVS 2016 Final Data for Public Release v.4.xls", dtype={"FIPSCode": str}
)

# %%
src_2016a = src_2016a[["FIPSCode", "JurisdictionName", "State", "A1a"]].copy()

# %%
src_2016a.rename(
    columns={
        "FIPSCode": "fips",
        "JurisdictionName": "place",
        "State": "state",
        "A1a": "total_reg_voters",
    },
    inplace=True,
)

# %%
src_2016a.head()
# Out:
#          fips           place state total_reg_voters
# 0  0200000000          ALASKA    AK           587303
# 1  0100100000  AUTAUGA COUNTY    AL            38187
# 2  0100300000  BALDWIN COUNTY    AL           146824
# 3  0100500000  BARBOUR COUNTY    AL            17102
# 4  0100700000     BIBB COUNTY    AL            13510

# %% [markdown]
# #### Mail ballots sent

# %%
src_2016c = pd.read_excel(
    "input/EAVS 2016 Final Data for Public Release v.4.xls",
    sheet_name="SECTION C",
    dtype={"FIPSCode": str},
)

# %%
src_2016c = src_2016c[["FIPSCode", "JurisdictionName", "State", "C1a"]].copy()

# %%
src_2016c.rename(
    columns={
        "FIPSCode": "fips",
        "JurisdictionName": "place",
        "State": "state",
        "C1a": "mail_ballots_sent",
    },
    inplace=True,
)

# %%
src_2016c.head()
# Out:
#          fips           place state mail_ballots_sent
# 0  0200000000          ALASKA    AK             31817
# 1  0100100000  AUTAUGA COUNTY    AL              1290
# 2  0100300000  BALDWIN COUNTY    AL              5317
# 3  0100500000  BARBOUR COUNTY    AL               652
# 4  0100700000     BIBB COUNTY    AL               244

# %% [markdown]
# #### Votes cast

# %%
src_2016f = pd.read_excel(
    "input/EAVS 2016 Final Data for Public Release v.4.xls",
    sheet_name="SECTION F",
    dtype={"FIPSCode": str},
)

# %%
src_2016f = src_2016f[["FIPSCode", "JurisdictionName", "State", "F1a"]].copy()

# %%
src_2016f.rename(
    columns={
        "FIPSCode": "fips",
        "JurisdictionName": "place",
        "State": "state",
        "F1a": "total_votes_cast",
    },
    inplace=True,
)

# %%
src_2016f.head()
# Out:
#          fips           place state total_votes_cast
# 0  0200000000          ALASKA    AK           323288
# 1  0100100000  AUTAUGA COUNTY    AL            25146
# 2  0100300000  BALDWIN COUNTY    AL            96229
# 3  0100500000  BARBOUR COUNTY    AL            10544
# 4  0100700000     BIBB COUNTY    AL             8853

# %% [markdown]
# #### Polling places

# %%
src_2016d = pd.read_excel(
    "input/EAVS 2016 Final Data for Public Release v.4.xls",
    sheet_name="SECTION D",
    dtype={"FIPSCode": str},
)

# %%
src_2016d = src_2016d[["FIPSCode", "JurisdictionName", "State", "D2a", "D2e"]].copy()

# %%
src_2016d.rename(
    columns={
        "FIPSCode": "fips",
        "JurisdictionName": "place",
        "State": "state",
        "D2a": "poll_place_elect_day",
        "D2e": "poll_place_early",
    },
    inplace=True,
)

# %%
src_2016d.head()
# Out:
#          fips           place state poll_place_elect_day  \
# 0  0200000000          ALASKA    AK                  624
# 1  0100100000  AUTAUGA COUNTY    AL                   17
# 2  0100300000  BALDWIN COUNTY    AL                   87
# 3  0100500000  BARBOUR COUNTY    AL                   21
# 4  0100700000     BIBB COUNTY    AL                   16
#
#               poll_place_early
# 0                          178
# 1  -999999: Data Not Available
# 2      -888888: Not Applicable
# 3      -888888: Not Applicable
# 4      -888888: Not Applicable

# %% [markdown]
# ### Merge 'em

# %%
from functools import reduce

# %%
src_2016_all = reduce(
    lambda x, y: pd.merge(x, y, on=["state", "fips"], how="inner"),
    [src_2016a, src_2016c, src_2016f, src_2016d],
)

# %%
src_2016_all.head()
# Out:
#          fips         place_x state total_reg_voters         place_y  \
# 0  0200000000          ALASKA    AK           587303          ALASKA
# 1  0100100000  AUTAUGA COUNTY    AL            38187  AUTAUGA COUNTY
# 2  0100300000  BALDWIN COUNTY    AL           146824  BALDWIN COUNTY
# 3  0100500000  BARBOUR COUNTY    AL            17102  BARBOUR COUNTY
# 4  0100700000     BIBB COUNTY    AL            13510     BIBB COUNTY
#
#   mail_ballots_sent         place_x total_votes_cast         place_y  \
# 0             31817          ALASKA           323288          ALASKA
# 1              1290  AUTAUGA COUNTY            25146  AUTAUGA COUNTY
# 2              5317  BALDWIN COUNTY            96229  BALDWIN COUNTY
# 3               652  BARBOUR COUNTY            10544  BARBOUR COUNTY
# 4               244     BIBB COUNTY             8853     BIBB COUNTY
#
#   poll_place_elect_day             poll_place_early
# 0                  624                          178
# 1                   17  -999999: Data Not Available
# 2                   87      -888888: Not Applicable
# 3                   21      -888888: Not Applicable
# 4                   16      -888888: Not Applicable

# %%
src_2016_all.rename(
    columns={"place_x": "place", "place_y": "place"}, inplace=True,
)

# %%
src_2016_all = src_2016_all.loc[:, ~src_2016_all.columns.duplicated()]

# %%
src_2016_all.head()
# Out:
#          fips           place state total_reg_voters mail_ballots_sent  \
# 0  0200000000          ALASKA    AK           587303             31817
# 1  0100100000  AUTAUGA COUNTY    AL            38187              1290
# 2  0100300000  BALDWIN COUNTY    AL           146824              5317
# 3  0100500000  BARBOUR COUNTY    AL            17102               652
# 4  0100700000     BIBB COUNTY    AL            13510               244
#
#   total_votes_cast poll_place_elect_day             poll_place_early
# 0           323288                  624                          178
# 1            25146                   17  -999999: Data Not Available
# 2            96229                   87      -888888: Not Applicable
# 3            10544                   21      -888888: Not Applicable
# 4             8853                   16      -888888: Not Applicable

# %%
places2016 = src_2016_all.copy()

# %%
places2016.head(200)
# Out:
#            fips                   place state total_reg_voters  \
# 0    0200000000                  ALASKA    AK           587303
# 1    0100100000          AUTAUGA COUNTY    AL            38187
# 2    0100300000          BALDWIN COUNTY    AL           146824
# 3    0100500000          BARBOUR COUNTY    AL            17102
# 4    0100700000             BIBB COUNTY    AL            13510
# 5    0100900000           BLOUNT COUNTY    AL            37718
# 6    0101100000          BULLOCK COUNTY    AL             7424
# 7    0101300000           BUTLER COUNTY    AL            13805
# 8    0101500000          CALHOUN COUNTY    AL            74433
# 9    0101700000         CHAMBERS COUNTY    AL            24020
# 10   0101900000         CHEROKEE COUNTY    AL            16970
# 11   0102100000          CHILTON COUNTY    AL            28579
# 12   0102300000          CHOCTAW COUNTY    AL            10990
# 13   0102500000           CLARKE COUNTY    AL            19400
# 14   0102700000             CLAY COUNTY    AL            10204
# 15   0102900000         CLEBURNE COUNTY    AL            10845
# 16   0103100000           COFFEE COUNTY    AL            33524
# 17   0103300000          COLBERT COUNTY    AL            38334
# 18   0103500000          CONECUH COUNTY    AL            10488
# 19   0103700000            COOSA COUNTY    AL             8123
# 20   0103900000        COVINGTON COUNTY    AL            25347
# 21   0104100000         CRENSHAW COUNTY    AL             9958
# 22   0104300000          CULLMAN COUNTY    AL            55908
# 23   0104500000             DALE COUNTY    AL            31420
# 24   0104700000           DALLAS COUNTY    AL            32530
# 25   0104900000           DEKALB COUNTY    AL            40824
# 26   0105100000           ELMORE COUNTY    AL            54061
# 27   0105300000         ESCAMBIA COUNTY    AL            24374
# 28   0105500000           ETOWAH COUNTY    AL            69355
# 29   0105700000          FAYETTE COUNTY    AL            12155
# 30   0105900000         FRANKLIN COUNTY    AL            19001
# 31   0106100000           GENEVA COUNTY    AL            17935
# 32   0106300000           GREENE COUNTY    AL             7322
# 33   0106500000             HALE COUNTY    AL            12432
# 34   0106700000            HENRY COUNTY    AL            12761
# 35   0106900000          HOUSTON COUNTY    AL            69602
# 36   0107100000          JACKSON COUNTY    AL            36977
# 37   0107300000        JEFFERSON COUNTY    AL           456895
# 38   0107500000            LAMAR COUNTY    AL            10899
# 39   0107700000       LAUDERDALE COUNTY    AL            60540
# 40   0107900000         LAWRENCE COUNTY    AL            23477
# 41   0108100000              LEE COUNTY    AL           103424
# 42   0108300000        LIMESTONE COUNTY    AL            58229
# 43   0108500000          LOWNDES COUNTY    AL            10461
# 44   0108700000            MACON COUNTY    AL            18504
# 45   0108900000          MADISON COUNTY    AL           262751
# 46   0109100000          MARENGO COUNTY    AL            16507
# 47   0109300000           MARION COUNTY    AL            20342
# 48   0109500000         MARSHALL COUNTY    AL            55733
# 49   0109700000           MOBILE COUNTY    AL           284776
# 50   0109900000           MONROE COUNTY    AL            16390
# 51   0110100000       MONTGOMERY COUNTY    AL           154622
# 52   0110300000           MORGAN COUNTY    AL            75787
# 53   0110500000            PERRY COUNTY    AL             8542
# 54   0110700000          PICKENS COUNTY    AL            14011
# 55   0110900000             PIKE COUNTY    AL            22557
# 56   0111100000         RANDOLPH COUNTY    AL            16822
# 57   0111300000          RUSSELL COUNTY    AL            36351
# 58   0111500000        ST. CLAIR COUNTY    AL            58425
# 59   0111700000           SHELBY COUNTY    AL           142813
# 60   0111900000           SUMTER COUNTY    AL            10233
# 61   0112100000        TALLADEGA COUNTY    AL            53564
# 62   0112300000       TALLAPOOSA COUNTY    AL            30217
# 63   0112500000       TUSCALOOSA COUNTY    AL           132600
# 64   0112700000           WALKER COUNTY    AL            46384
# 65   0112900000       WASHINGTON COUNTY    AL            13669
# 66   0113100000           WILCOX COUNTY    AL             9288
# 67   0113300000          WINSTON COUNTY    AL            16691
# 68   0500100000         ARKANSAS COUNTY    AR            10385
# 69   0500300000           ASHLEY COUNTY    AR            12578
# 70   0500500000           BAXTER COUNTY    AR            28875
# 71   0500700000           BENTON COUNTY    AR           143035
# 72   0500900000            BOONE COUNTY    AR            24402
# 73   0501100000          BRADLEY COUNTY    AR             5476
# 74   0501300000          CALHOUN COUNTY    AR             3422
# 75   0501500000          CARROLL COUNTY    AR            15806
# 76   0501700000           CHICOT COUNTY    AR             6436
# 77   0501900000            CLARK COUNTY    AR            12392
# 78   0502100000             CLAY COUNTY    AR             8350
# 79   0502300000         CLEBURNE COUNTY    AR            18122
# 80   0502500000        CLEVELAND COUNTY    AR             4964
# 81   0502700000         COLUMBIA COUNTY    AR            14487
# 82   0502900000           CONWAY COUNTY    AR            11346
# 83   0503100000        CRAIGHEAD COUNTY    AR            59905
# 84   0503300000         CRAWFORD COUNTY    AR            33430
# 85   0503500000       CRITTENDEN COUNTY    AR            30461
# 86   0503700000            CROSS COUNTY    AR            10471
# 87   0503900000           DALLAS COUNTY    AR             4337
# 88   0504100000            DESHA COUNTY    AR             7831
# 89   0504300000             DREW COUNTY    AR            10597
# 90   0504500000         FAULKNER COUNTY    AR            75257
# 91   0504700000         FRANKLIN COUNTY    AR             9896
# 92   0504900000           FULTON COUNTY    AR             6787
# 93   0505100000          GARLAND COUNTY    AR            65604
# 94   0505300000            GRANT COUNTY    AR            11030
# 95   0505500000           GREENE COUNTY    AR            20878
# 96   0505700000        HEMPSTEAD COUNTY    AR            11860
# 97   0505900000       HOT SPRING COUNTY    AR            19409
# 98   0506100000           HOWARD COUNTY    AR             7148
# 99   0506300000     INDEPENDENCE COUNTY    AR            21825
# 100  0506500000            IZARD COUNTY    AR             8061
# 101  0506700000          JACKSON COUNTY    AR             8505
# 102  0506900000        JEFFERSON COUNTY    AR            42463
# 103  0507100000          JOHNSON COUNTY    AR            14806
# 104  0507300000        LAFAYETTE COUNTY    AR             4281
# 105  0507500000         LAWRENCE COUNTY    AR             8983
# 106  0507700000              LEE COUNTY    AR             4948
# 107  0507900000          LINCOLN COUNTY    AR             6037
# 108  0508100000     LITTLE RIVER COUNTY    AR             7232
# 109  0508300000            LOGAN COUNTY    AR            12718
# 110  0508500000           LONOKE COUNTY    AR            43330
# 111  0508700000          MADISON COUNTY    AR             9769
# 112  0508900000           MARION COUNTY    AR            10076
# 113  0509100000           MILLER COUNTY    AR            25840
# 114  0509300000      MISSISSIPPI COUNTY    AR            21542
# 115  0509500000           MONROE COUNTY    AR             4483
# 116  0509700000       MONTGOMERY COUNTY    AR             4945
# 117  0509900000           NEVADA COUNTY    AR             5720
# 118  0510100000           NEWTON COUNTY    AR             6283
# 119  0510300000         OUACHITA COUNTY    AR            16726
# 120  0510500000            PERRY COUNTY    AR             6235
# 121  0510700000         PHILLIPS COUNTY    AR            13044
# 122  0510900000             PIKE COUNTY    AR             5560
# 123  0511100000         POINSETT COUNTY    AR            12550
# 124  0511300000             POLK COUNTY    AR            12469
# 125  0511500000             POPE COUNTY    AR            33765
# 126  0511700000          PRAIRIE COUNTY    AR             4843
# 127  0511900000          PULASKI COUNTY    AR           246876
# 128  0512100000         RANDOLPH COUNTY    AR            10332
# 129  0512300000      ST. FRANCIS COUNTY    AR            13966
# 130  0512500000           SALINE COUNTY    AR            75050
# 131  0512700000            SCOTT COUNTY    AR             5310
# 132  0512900000           SEARCY COUNTY    AR             5587
# 133  0513100000        SEBASTIAN COUNTY    AR            74228
# 134  0513300000           SEVIER COUNTY    AR             6684
# 135  0513500000            SHARP COUNTY    AR            11161
# 136  0513700000            STONE COUNTY    AR             7992
# 137  0513900000            UNION COUNTY    AR            27899
# 138  0514100000        VAN BUREN COUNTY    AR            10077
# 139  0514300000       WASHINGTON COUNTY    AR           130374
# 140  0514500000            WHITE COUNTY    AR            43055
# 141  0514700000         WOODRUFF COUNTY    AR             4496
# 142  0514900000             YELL COUNTY    AR            10410
# 143  0400100000           APACHE COUNTY    AZ            53020
# 144  0400300000          COCHISE COUNTY    AZ            75256
# 145  0400500000         COCONINO COUNTY    AZ            94277
# 146  0400700000             GILA COUNTY    AZ            35793
# 147  0400900000           GRAHAM COUNTY    AZ            21028
# 148  0401100000         GREENLEE COUNTY    AZ             5140
# 149  0401200000           LA PAZ COUNTY    AZ            11727
# 150  0401300000         MARICOPA COUNTY    AZ          2438481
# 151  0401500000           MOHAVE COUNTY    AZ           142180
# 152  0401700000           NAVAJO COUNTY    AZ            69670
# 153  0401900000             PIMA COUNTY    AZ           616901
# 154  0402100000            PINAL COUNTY    AZ           227343
# 155  0402300000       SANTA CRUZ COUNTY    AZ            28708
# 156  0402500000          YAVAPAI COUNTY    AZ           155684
# 192                           23                            0
# 193                          410                            4
# 194                         1378                            0
# 195                          577                            0
# 196                          306                            0
# 197                          141                            0
# 198                          348                            1
# 199                           92                            0

# %%
places2016["year"] = "2016"

# %% [markdown]
# ### Minnesota mess

# %%
places2016[places2016["state"] == "MN"].head()
# Out:
#             fips            place state total_reg_voters mail_ballots_sent  \
# 2278  2700100000    AITKIN COUNTY    MN            10626
# 2279  2700300000     ANOKA COUNTY    MN           219336
# 2280  2700500000    BECKER COUNTY    MN            20371
# 2281  2700700000  BELTRAMI COUNTY    MN            26614
# 2282  2700900000    BENTON COUNTY    MN            23934
#
#         C1b                              total_votes_cast  \
# 2278   2578  Minnesota does not have provisional ballots.
# 2279  39840  Minnesota does not have provisional ballots.
# 2280   4076  Minnesota does not have provisional ballots.
# 2281   5867  Minnesota does not have provisional ballots.
# 2282   2750  Minnesota does not have provisional ballots.
#
#      poll_place_elect_day             poll_place_early  year
# 2278                       -999999: Data Not Available  2016
# 2279                       -999999: Data Not Available  2016
# 2280                       -999999: Data Not Available  2016
# 2281                       -999999: Data Not Available  2016
# 2282                       -999999: Data Not Available  2016

# %% [markdown]
# ---

# %% [markdown]
# ### 2012

# %% [markdown]
# #### Total voters

# %%
src_2012a = pd.read_excel("input/2012EAVS_NVRAData.xlsx", dtype={"FIPSCode": str})

# %%
src_2012a = src_2012a[["State", "Jurisdiction", "FIPSCode", "QA1a"]].copy()

# %%
src_2012a.rename(columns={"QA1a": "total_reg_voters"}, inplace=True)

# %%
src_2012a.head()
# Out:
#   State    Jurisdiction    FIPSCode  total_reg_voters
# 0    AK          ALASKA  0200000000          579304.0
# 1    AL  AUTAUGA COUNTY  0100100000           37170.0
# 2    AL  BALDWIN COUNTY  0100300000          126703.0
# 3    AL  BARBOUR COUNTY  0100500000           17318.0
# 4    AL     BIBB COUNTY  0100700000           12819.0

# %% [markdown]
# #### Absentee ballots

# %%
src_2012b = pd.read_excel("input/2012EAVS_UOCAVAData.xls", dtype={"FIPSCode": str})

# %%
src_2012b = src_2012b[["State", "Jurisdiction", "FIPSCode", "QB1a"]]

# %%
src_2012b.rename(columns={"QB1a": "mail_ballots_sent"}, inplace=True)

# %%
src_2012b.head()
# Out:
#   State    Jurisdiction    FIPSCode  mail_ballots_sent
# 0    AK          ALASKA  0200000000            11935.0
# 1    AL  AUTAUGA COUNTY  0100100000               75.0
# 2    AL  BALDWIN COUNTY  0100300000              253.0
# 3    AL  BARBOUR COUNTY  0100500000               25.0
# 4    AL     BIBB COUNTY  0100700000                3.0

# %% [markdown]
# #### Polling places

# %%
src_2012d = pd.read_excel(
    "input/Excel Files-Part 1/Section D.xls", dtype={"FIPSCode": str}
)

# %%
src_2012d = src_2012d[["State", "Jurisdiction", "FIPSCode", "QD2a", "QD2e"]]

# %%
src_2012d.rename(
    columns={"QD2a": "poll_place_elect_day", "QD2e": "poll_place_early"}, inplace=True
)

# %%
src_2012d.head()
# Out:
#   State    Jurisdiction    FIPSCode  poll_place_elect_day  poll_place_early
# 0    AK          ALASKA  0200000000                 533.0              75.0
# 1    AL  AUTAUGA COUNTY  0100100000                  17.0         -999999.0
# 2    AL  BALDWIN COUNTY  0100300000                  46.0         -999999.0
# 3    AL  BARBOUR COUNTY  0100500000                  17.0         -999999.0
# 4    AL     BIBB COUNTY  0100700000                   8.0         -999999.0

# %% [markdown]
# #### Votes cast

# %%
src_2012f = pd.read_excel("input/Section F.xls", dtype={"FIPSCode": str})

# %%
src_2012f = src_2012f[["State", "Jurisdiction", "FIPSCode", "QF1a"]]

# %%
src_2012f.rename(columns={"QF1a": "total_votes_cast"}, inplace=True)

# %%
src_2012f.head()
# Out:
#   State    Jurisdiction    FIPSCode  total_votes_cast
# 0    AK          ALASKA  0200000000          302465.0
# 1    AL  AUTAUGA COUNTY  0100100000           24065.0
# 2    AL  BALDWIN COUNTY  0100300000           85873.0
# 3    AL  BARBOUR COUNTY  0100500000           11534.0
# 4    AL     BIBB COUNTY  0100700000            8454.0

# %% [markdown]
# ### Merge 'em

# %%
from functools import reduce

# %%
src_2012_all = reduce(
    lambda x, y: pd.merge(x, y, on=["State", "FIPSCode"], how="inner"),
    [src_2012a, src_2012b, src_2012f, src_2012d],
)

# %%
src_2012_all.rename(
    columns={"Jurisdiction_x": "Jurisdiction", "Jurisdiction_y": "Jurisdiction"},
    inplace=True,
)

# %%
src_2012_all = src_2012_all.loc[:, ~src_2012_all.columns.duplicated()]

# %%
src_2012_all.head()
# Out:
#   State    Jurisdiction    FIPSCode  total_reg_voters  mail_ballots_sent  \
# 0    AK          ALASKA  0200000000          579304.0            11935.0
# 1    AL  AUTAUGA COUNTY  0100100000           37170.0               75.0
# 2    AL  BALDWIN COUNTY  0100300000          126703.0              253.0
# 3    AL  BARBOUR COUNTY  0100500000           17318.0               25.0
# 4    AL     BIBB COUNTY  0100700000           12819.0                3.0
#
#    total_votes_cast  poll_place_elect_day  poll_place_early
# 0          302465.0                 533.0              75.0
# 1           24065.0                  17.0         -999999.0
# 2           85873.0                  46.0         -999999.0
# 3           11534.0                  17.0         -999999.0
# 4            8454.0                   8.0         -999999.0

# %%
places2012 = src_2012_all.copy()

# %%
places2012.rename(
    columns={"FIPSCode": "fips", "State": "state", "Jurisdiction": "place",},
    inplace=True,
)

# %%
places2012["year"] = "2012"

# %%
places2012.head()
# Out:
#   state           place        fips  total_reg_voters  mail_ballots_sent  \
# 0    AK          ALASKA  0200000000          579304.0            11935.0
# 1    AL  AUTAUGA COUNTY  0100100000           37170.0               75.0
# 2    AL  BALDWIN COUNTY  0100300000          126703.0              253.0
# 3    AL  BARBOUR COUNTY  0100500000           17318.0               25.0
# 4    AL     BIBB COUNTY  0100700000           12819.0                3.0
#
#    total_votes_cast  poll_place_elect_day  poll_place_early  year
# 0          302465.0                 533.0              75.0  2012
# 1           24065.0                  17.0         -999999.0  2012
# 2           85873.0                  46.0         -999999.0  2012
# 3           11534.0                  17.0         -999999.0  2012
# 4            8454.0                   8.0         -999999.0  2012

# %% [markdown]
# ---

# %% [markdown]
# ### Concatenate the dataframes

# %%
src = pd.concat([places2020, places2016, places2012]).reset_index(drop=True)

# %%
src["fips"] = src["fips"].str.zfill(10)

# %% [markdown]
# ---

# %%
src.to_csv("output/polling_places_analysis.csv", index=False)
