# %% [markdown]
# # Analyzing Barstool Sports post metadata

# %% [markdown]
# #### Python tools and notebook settings

# %%
# %load_ext lab_black

# %%
import pandas as pd
import altair as alt
import altair_stiles as altstiles
import datetime as dt

# %%
alt.themes.register("stiles", altstiles.theme)
alt.themes.enable("stiles")
# Out:
# ThemeRegistry.enable('grid')

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = None

# %%
today = dt.date.today().strftime("%Y-%m-%d")

# %% [markdown]
# ---

# %%
src_df = pd.read_csv(
    "/Users/stiles/data/barstool.csv",
    parse_dates=["week_start", "published_date", "timestamp"],
    dtype={"id": str},
)

# %%
len(src_df)
# Out:
# 220809

# %% [markdown]
# #### Parse dates for aggregates

# %%
src_df["year"] = src_df["published_date"].dt.year
src_df["month"] = src_df["published_date"].dt.month
src_df["month_year"] = pd.to_datetime(
    (src_df["year"].astype(str) + "-" + src_df["month"].astype(str) + "-" + "01")
)
src_df.drop(["timestamp", "week_start"], axis=1, inplace=True)

# %%
df = src_df.copy()

# %%
df[df["title"].fillna("").str.contains("Rundown")]
# Out:
#              id               type  \
# 145     3431374  barstool_original
# 237     3431129  barstool_original
# 309     3430904  barstool_original
# 385     3430692  barstool_original
# 571     3430222  barstool_original
# ...         ...                ...
# 206200   189223      standard_post
# 206256  1080450  barstool_original
# 206319   188695      standard_post
# 206371    86889      standard_post
# 206993  1079788  barstool_original
#
#                                                                                        title  \
# 145          Tommy's Office Hookup Brings The Roof Down | Barstool Rundown September 1, 2022
# 237     The New Winnie The Pooh Movie Is Nightmare Fuel - Barstool Rundown - August 31, 2022
# 309              Jersey Jerry Reflects On Pooping Pants - Barstool Rundown - August 30, 2022
# 385             Is Yung Gravy Dating Addison Rae's Mom? - Barstool Rundown - August 29, 2022
# 571                               Week 0 of CFB Is Here - Barstool Rundown - August 25, 2022
# ...                                                                                      ...
# 206200                                                           Barstool Rundown - March 31
# 206256                                                                  Gronk On The Rundown
# 206319                                                         Barstool Rundown - March 27th
# 206371                                           Barstool Sports Internet Rundown March 26th
# 206993                                            Internet Royal Rumble (First Ever Rundown)
#
#            author_name  comment_count          brand_name  \
# 145     Michael Angelo             14    Barstool Rundown
# 237     Michael Angelo              4    Barstool Rundown
# 309     Michael Angelo              6    Barstool Rundown
# 385     Michael Angelo              8    Barstool Rundown
# 571     Michael Angelo              5    Barstool Rundown
# ...                ...            ...                 ...
# 206200           hubbs              0                 NaN
# 206256           Dante              0  Barstool Originals
# 206319      Ohios Tate              0                 NaN
# 206371    Jersey Jerry              0                 NaN
# 206993          Jordie              0                 NaN
#
#                         branch_url  \
# 145        https://bars.tl/3431374
# 237        https://bars.tl/3431129
# 309        https://bars.tl/3430904
# 385        https://bars.tl/3430692
# 571        https://bars.tl/3430222
# ...                            ...
# 206200                         NaN
# 206256  https://bars.tl/eM8lAoDCZP
# 206319                         NaN
# 206371                         NaN
# 206993  https://bars.tl/vltZW8IjYP
#
#                                                                                                                                         img_url  \
# 145                                https://chumley.barstoolsports.com/union/2022/09/01/9.1-THUMBNAIL.8532d31d.jpeg?crop=4%3A3%2Csmart&width=560
# 237                                   https://chumley.barstoolsports.com/union/2022/08/31/THUMB-8.31.22336043.jpeg?crop=4%3A3%2Csmart&width=560
# 309                                   https://chumley.barstoolsports.com/union/2022/08/30/8.30-THUMB.5ef9b1bd.jpeg?crop=4%3A3%2Csmart&width=560
# 385                                   https://chumley.barstoolsports.com/union/2022/08/29/8.29-THUMB.f8cc43f9.jpeg?crop=4%3A3%2Csmart&width=560
# 571               https://chumley.barstoolsports.com/union/2022/08/25/THUMBNAIL-8.25-Large.193338f6.jpeg?canvas=4%3A3&bg-color=000000&width=560
# ...                                                                                                                                         ...
# 206200              https://chumley.barstoolsports.com/union/getty/2022/07/25/GettyImages-1410364892.c004d22e.jpeg?crop=4%3A3%2Csmart&width=560
# 206256              https://chumley.barstoolsports.com/union/getty/2022/07/23/GettyImages-1217774756.8669e696.jpeg?crop=4%3A3%2Csmart&width=560
# 206319                   https://chumley.barstoolsports.com/union/2022/07/21/bdc.58cbe6ea.jpg?crop=0.66%2C0.33%2Cx0.12%2Cy0.67%2Csafe&width=560
# 206371              https://chumley.barstoolsports.com/union/getty/2021/05/03/GettyImages-1307507053.466a7f47.jpeg?crop=4%3A3%2Csmart&width=560
# 206993  https://chumley.barstoolsports.com/union/2022/07/07/Butler-Tucker-Embiid.d69fd6fd.jpg?crop=0.98%2C0.99%2Cx0.02%2Cy0.00%2Csafe&width=560
#
#                                                                                                                                                                tags  \
# 145                                                                                                                                                              []
# 237                                                                         ['rundown', 'the-rundown', 'winnie-the-pooh', 'hilary-duff', 'mlb', 'barstool-chicago']
# 309                                                                                                                                                              []
# 385     ['sports', 'nfl', 'el-presidente', 'college-football', 'nebraska', 's', 'aaron-rodger', 'aaron-donald', 'cleveland-browns', 'sydney-sweeney', 'yung-gravy']
# 571                                                                         ['sports', 'college', 'el-presidente', 'chicago', 'week-0', 'monkey-pox', 'len-dawson']
# ...                                                                                                                                                             ...
# 206200                                                                                                                                                           []
# 206256                                                                                                                       ['gold', 'throwback', 'barstool gold']
# 206319                                                                                                                                                           []
# 206371                                                                                                                                                           []
# 206993                                                                                            ['gold', 'royal rumble', 'rundown', 'throwback', 'barstool gold']
#
#        published_date  published_hour published_day first_tag category_name  \
# 145        2022-09-01              18      Thursday       NaN        Boston
# 237        2022-08-31              18     Wednesday   rundown        Boston
# 309        2022-08-30              18       Tuesday       NaN        Boston
# 385        2022-08-29              18        Monday    sports        Boston
# 571        2022-08-25              18      Thursday    sports        Boston
# ...               ...             ...           ...       ...           ...
# 206200     2014-03-31              19        Monday       NaN     BarstoolU
# 206256     2014-03-30              10        Sunday      gold       Chicago
# 206319     2014-03-27              20      Thursday       NaN        Boston
# 206371     2014-03-26              22     Wednesday       NaN      New York
# 206993     2014-03-11              15       Tuesday      gold        Philly
#
#         year  month month_year
# 145     2022      9 2022-09-01
# 237     2022      8 2022-08-01
# 309     2022      8 2022-08-01
# 385     2022      8 2022-08-01
# 571     2022      8 2022-08-01
# ...      ...    ...        ...
# 206200  2014      3 2014-03-01
# 206256  2014      3 2014-03-01
# 206319  2014      3 2014-03-01
# 206371  2014      3 2014-03-01
# 206993  2014      3 2014-03-01
#
# [2073 rows x 17 columns]
