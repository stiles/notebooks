# %% [markdown]
# # 2022 Senate elections

# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/2022_United_States_Senate_elections'

# %%
page = pd.read_html(url, header=0)

# %%
src = pd.DataFrame(page[9])

# %%
src = src[['Constituency', 'Incumbent', 'Incumbent.1', '2022 election ratings']]

# %%
src.rename(columns={'Constituency':'state', 'Incumbent':'incumbent', 'Incumbent.1':'last_election', '2022 election ratings':'cook_rating'}, inplace=True)

# %%
src[[ 'trash', 'party', 'trashy']] = src['last_election'].str.split(' ', expand=True)

# %%
src.drop([0, 35], inplace=True)

# %%
src.drop(['trash', "trashy"], axis=1, inplace=True)

# %%
src.head()
# Out:
#         state                 incumbent             last_election cook_rating  \
# 1     Alabama  Richard Shelby(retiring)                   64.0% R     Solid R
# 2      Alaska            Lisa Murkowski                   44.4% R     Solid R
# 3     Arizona                Mark Kelly  51.2% D(2020 special)[d]      Tossup
# 4    Arkansas              John Boozman                   59.8% R     Solid R
# 5  California              Alex Padilla        Appointed(2021)[e]     Solid D
#
#     party
# 1       R
# 2       R
# 3  D(2020
# 4       R
# 5    None

# %%
src.loc[src['party'] == 'D(2020', 'party'] = 'D'
src.loc[src['incumbent'] == 'Alex Padilla', 'party'] = 'D'

# %%
src['last_election'] = src['last_election'].str.replace('(2020 special)[f]', "", regex=False).str.replace('(2020 special)[d]', "", regex=False).str.replace('Appointed(2021)[e]', "", regex=False)
src['incumbent'] = src['incumbent'].str.replace('(retiring)', "", regex=False)

# %%
src.head(100)
# Out:
#              state               incumbent last_election cook_rating party
# 1          Alabama          Richard Shelby       64.0% R     Solid R     R
# 2           Alaska          Lisa Murkowski       44.4% R     Solid R     R
# 3          Arizona              Mark Kelly       51.2% D      Tossup     D
# 4         Arkansas            John Boozman       59.8% R     Solid R     R
# 5       California            Alex Padilla                   Solid D     D
# 6         Colorado          Michael Bennet       50.0% D     Solid D     D
# 7      Connecticut      Richard Blumenthal       63.2% D     Solid D     D
# 8          Florida             Marco Rubio       52.0% R      Lean R     R
# 9          Georgia         Raphael Warnock       51.0% D      Tossup     D
# 10          Hawaii            Brian Schatz       73.6% D     Solid D     D
# 11           Idaho              Mike Crapo       66.1% R     Solid R     R
# 12        Illinois         Tammy Duckworth       54.9% D     Solid D     D
# 13         Indiana              Todd Young       52.1% R     Solid R     R
# 14            Iowa          Chuck Grassley       60.1% R     Solid R     R
# 15          Kansas             Jerry Moran       62.2% R     Solid R     R
# 16        Kentucky               Rand Paul       57.3% R     Solid R     R
# 17       Louisiana            John Kennedy       60.7% R     Solid R     R
# 18        Maryland        Chris Van Hollen       60.9% D     Solid D     D
# 19        Missouri               Roy Blunt       49.2% R     Solid R     R
# 20          Nevada  Catherine Cortez Masto       47.1% D      Tossup     D
# 21   New Hampshire           Maggie Hassan       48.0% D      Lean D     D
# 22        New York           Chuck Schumer       70.6% D     Solid D     D
# 23  North Carolina            Richard Burr       51.1% R      Tossup     R
# 24    North Dakota             John Hoeven       78.5% R     Solid R     R
# 25            Ohio             Rob Portman       58.0% R      Lean R     R
# 26        Oklahoma          James Lankford       67.7% R     Solid R     R
# 27          Oregon               Ron Wyden       56.6% D     Solid D     D
# 28    Pennsylvania              Pat Toomey       48.8% R      Tossup     R
# 29  South Carolina               Tim Scott       60.6% R     Solid R     R
# 30    South Dakota              John Thune       71.8% R     Solid R     R
# 31            Utah                Mike Lee       68.2% R     Solid R     R
# 32         Vermont           Patrick Leahy       61.3% D     Solid D     D
# 33      Washington            Patty Murray       58.8% D     Solid D     D
# 34       Wisconsin             Ron Johnson       50.2% R      Tossup     R

# %%
df = src.copy()

# %%
df[['last_election_winner_margin', 'last_election_winner_party']] = df['last_election'].str.split(' ', expand=True)

# %%
df.loc[df['incumbent'] == 'Alex Padilla', 'last_election_winner_party'] = ''

# %%
df.drop(['last_election'], axis=1, inplace=True)

# %%
df.rename(columns={'party':"incumbent_party"}, inplace=True)

# %%
df['last_election_winner_margin'] = df['last_election_winner_margin'].str.replace('%', "", regex=False)

# %%
df.incumbent_party.value_counts()
# Out:
# R    20
# D    14
# Name: incumbent_party, dtype: int64

# %%
df.head()
# Out:
#         state       incumbent cook_rating incumbent_party  \
# 1     Alabama  Richard Shelby     Solid R               R
# 2      Alaska  Lisa Murkowski     Solid R               R
# 3     Arizona      Mark Kelly      Tossup               D
# 4    Arkansas    John Boozman     Solid R               R
# 5  California    Alex Padilla     Solid D               D
#
#   last_election_winner_margin last_election_winner_party
# 1                        64.0                          R
# 2                        44.4                          R
# 3                        51.2                          D
# 4                        59.8                          R
# 5

# %% [markdown]
# ---

# %%
ap_states = {
    "Alabama": "Ala.",
    "Alaska": "Alaska",
    "Arizona": "Ariz.",
    "Arkansas": "Ark.",
    "California": "Calif.",
    "Colorado": "Colo.",
    "Connecticut": "Conn.",
    "Delaware": "Del.",
    "Florida": "Fla.",
    "Georgia": "Ga.",
    "Hawaii": "Hawaii",
    "Idaho": "Iowa",
    "Illinois": "Idaho",
    "Indiana": "Ill.",
    "Iowa": "Ind.",
    "Kansas": "Kan.",
    "Kentucky": "Ky.",
    "Louisiana": "La.",
    "Maine": "Md.",
    "Maryland": "Mass.",
    "Massachusetts": "Maine",
    "Michigan": "Mich.",
    "Minnesota": "Minn.",
    "Mississippi": "Miss.",
    "Missouri": "Mo.",
    "Montana": "Mont.",
    "Nebraska": "Neb.",
    "Nevada": "Nev.",
    "New Hampshire": "N.H.",
    "New Jersey": "N.J.",
    "New Mexico": "N.M.",
    "New York": "N.Y.",
    "North Carolina": "N.C.",
    "North Dakota": "N.D.",
    "Ohio": "Ohio",
    "Oklahoma": "Okla.",
    "Oregon": "Ore.",
    "Pennsylvania": "Pa.",
    "Rhode Island": "R.I.",
    "South Carolina": "S.C.",
    "South Dakota": "S.D.",
    "Tennessee": "Tenn.",
    "Texas": "Texas",
    "Utah": "Utah",
    "Vermont": "Vt.",
    "Virginia": "Va.",
    "Washington": "Wash.",
    "West Virginia": "W.Va.",
    "Wisconsin": "Wis.",
    "Wyoming": "Wyo",
}

# %%
ap_states_postal = {
    "Ala.": "AL",
    "Alaska":"AK", 
    "Ariz.": "AZ",
    "Ark.": "AR",
    "Calif.":"CA", 
    "Colo.": "CO",
    "Conn.": "CT",
    "Del.": "DE",
    "Fla.": "FL",
    "Ga.": "GA",
    "Hawaii":"HI", 
    "Iowa": "IA",
    "Idaho": "ID",
    "Ill.": "IL",
    "Ind.": "IN",
    "Kan.": "KS",
    "Ky.": "KY",
    "La.": "LA",
    "Md.": "MD",
    "Mass.": "MA",
    "Maine": "ME",
    "Mich.": "MI",
    "Minn.": "MN",
    "Miss.": "MS",
    "Mo.": "MO",
    "Mont.": "MT",
    "Neb.": "NE",
    "Nev.": "NV",
    "N.H.": "NH",
    "N.J.": "NJ",
    "N.M.": "NM",
    "N.Y.": "NY",
    "N.C.": "NC",
    "N.D.": "ND",
    "Ohio": "OH",
    "Okla.": "OK",
    "Ore.": "OR",
    "Pa.": "PA",
    "R.I.": "RI",
    "S.C.": "SC",
    "S.D.": "SD",
    "Texas": "TX",
    "Tenn.": "TN",
    "Vt.": "VT",
    "Va.": "VA",
    "Wash.": "WA",
    "W.Va.": "WV",
    "Wis.": "WI",
    "Wyo": "WY",
}

# %%
df["state_ap"] = df["state"].map(ap_states)
df["state_postal"] = df["state_ap"].map(ap_states_postal)

# %%
df.head()
# Out:
#         state       incumbent cook_rating incumbent_party  \
# 1     Alabama  Richard Shelby     Solid R               R
# 2      Alaska  Lisa Murkowski     Solid R               R
# 3     Arizona      Mark Kelly      Tossup               D
# 4    Arkansas    John Boozman     Solid R               R
# 5  California    Alex Padilla     Solid D               D
#
#   last_election_winner_margin last_election_winner_party state_ap state_postal
# 1                        64.0                          R     Ala.           AL
# 2                        44.4                          R   Alaska           AK
# 3                        51.2                          D    Ariz.           AZ
# 4                        59.8                          R     Ark.           AR
# 5                                                          Calif.           CA

# %% [markdown]
# ---

# %% [markdown]
# ### Export

# %%
df.to_csv('data/processed/2022_senate_elections.csv', index=False)
