# %% [markdown]
# # US household debt indicators
# > This notebook downloads, processes and charts data related to household debt from the US Federal Reserve.

# %% [markdown]
# ---

# %% [markdown]
# #### Import Python tools and Jupyter config

# %%
import os
import us
import json
import requests
import pandas as pd
# import jupyter_black
import altair as alt
import geopandas as gpd
import altair_cnn as altcnn
from IPython.display import Image
from datawrapper import Datawrapper
# Out:
# /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /var/folders/q0/1clc4jf97cxf003x4xgh89680000gr/T/ipykernel_57709/1261260140.py:8: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
# jupyter_black.load()
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = None
alt.themes.register("cnn", altcnn.theme)
alt.themes.enable("cnn")
# Out:
# ThemeRegistry.enable('cnn')

# %%
dw_token = os.environ.get("dw_api")
dw = Datawrapper(access_token=dw_token)
today = pd.Timestamp("today").strftime("%Y-%m-%d")

# %% [markdown]
# ---

# %% [markdown]
# ## Fetch indicators

# %% [markdown]
# #### 1. Quarterly household debt service ratio
# > This [measure](https://fred.stlouisfed.org/series/TDSP) is the ratio of total required household debt payments to total disposable income.

# %%
debt_ratio_url = f"https://fred.stlouisfed.org/graph/fredgraph.csv?id=TDSP"

# %%
debt_ratio_df = pd.read_csv(debt_ratio_url, names=["date", "value"], header=0).round(2)

# %%
debt_ratio_df.head()
# Out:
#          date  value
# 0  1980-01-01  10.61
# 1  1980-04-01  10.63
# 2  1980-07-01  10.40
# 3  1980-10-01  10.25
# 4  1981-01-01  10.29

# %% [markdown]
# #### Last decade

# %%
recent = debt_ratio_df.query('date>"2014-12-31"').copy()

# %%
recent
# Out:
#            date  value
# 140  2015-01-01  10.00
# 141  2015-04-01  10.04
# 142  2015-07-01  10.10
# 143  2015-10-01  10.04
# 144  2016-01-01  10.00
# 145  2016-04-01  10.11
# 146  2016-07-01  10.16
# 147  2016-10-01  10.13
# 148  2017-01-01  10.08
# 149  2017-04-01  10.04
# 150  2017-07-01  10.03
# 151  2017-10-01  10.03
# 152  2018-01-01   9.97
# 153  2018-04-01   9.92
# 154  2018-07-01   9.90
# 155  2018-10-01   9.93
# 156  2019-01-01   9.90
# 157  2019-04-01   9.95
# 158  2019-07-01   9.97
# 159  2019-10-01   9.97
# 160  2020-01-01   9.90
# 161  2020-04-01   8.93
# 162  2020-07-01   9.19
# 163  2020-10-01   9.37
# 164  2021-01-01   8.31
# 165  2021-04-01   9.13
# 166  2021-07-01   9.36
# 167  2021-10-01   9.49
# 168  2022-01-01   9.73
# 169  2022-04-01   9.79
# 170  2022-07-01   9.83
# 171  2022-10-01   9.89
# 172  2023-01-01   9.71
# 173  2023-04-01   9.70
# 174  2023-07-01   9.77
# 175  2023-10-01   9.80

# %% [markdown]
# #### Export to Datawrapper

# %%
#### https://app.datawrapper.de/chart/tXaoi/publish

debt_ratio_id = "tXaoi"
dw.add_data(
    chart_id=f"{debt_ratio_id}",
    data=recent,
)
# Out:
# <Response [204]>

# %% [markdown]
# ---

# %% [markdown]
# #### 2. Debt report from the [New York Fed Consumer Credit Panel/Equifax](https://www.newyorkfed.org/microeconomics/hhdc)

# %%
url = "https://www.newyorkfed.org/medialibrary/interactives/householdcredit/data/xls/HHD_C_Report_2023Q4"

# %%
xlsx_file = pd.read_excel(url, sheet_name="TABLE OF CONTENTS", skiprows=5, skipfooter=8)

# %%
sheet_names = pd.ExcelFile(url).sheet_names

# %% [markdown]
# ---

# %% [markdown]
# ## Delinquency rates

# %% [markdown]
# #### Percentage of debt 90+ days delinquent
# > Aggregate delinquency rates increased in the fourth quarter of 2023. As of December, 3.1% of outstanding debt was in some stage of delinquency, up by 0.1 percentage point from the third quarter. Still, overall delinquency rates remain 1.6 percentage points lower than the fourth quarter of 2019.

# %%
del_df = (
    pd.read_excel(url, sheet_name="Page 12 Data", skiprows=3)
    .drop(["Unnamed: 8", "Unnamed: 9"], axis=1)
    .round(2)
).rename(
    columns={
        "Unnamed: 0": "quarter",
        "MORTGAGE": "mortgage",
        "HELOC": "heloc",
        "AUTO": "auto",
        "CC": "credit_card",
        "STUDENT LOAN": "student_loan",
        "OTHER": "other",
        "ALL": "all",
    }
)

# %% [markdown]
# #### Clean dates

# %%
del_df["year"] = "20" + del_df["quarter"].str.split(":", expand=True)[0]
del_df["quarter"] = del_df["quarter"].str.split(":", expand=True)[1]

# %%
del_melt = del_df.melt(
    id_vars=["year", "quarter"],
    value_vars=[
        "mortgage",
        "heloc",
        "auto",
        "credit_card",
        "student_loan",
        "other",
        "all",
    ],
)

# %%
del_melt["date"] = pd.to_datetime(
    del_melt["year"].astype(str) + del_melt["quarter"].str.replace("Q", "") + "1",
    format="%Y%m%d",
)

# %%
del_melt["value_pct"] = del_melt["value"] / 100
del_melt["variable"] = (
    del_melt["variable"]
    .str.replace("_", " ")
    .str.title()
    .str.replace("Heloc", "Home Equity")
)

# %%
del_melt.head()
# Out:
#    year quarter  variable  value       date  value_pct
# 0  2003      Q1  Mortgage   1.21 2003-01-01     0.0121
# 1  2003      Q2  Mortgage   1.14 2003-02-01     0.0114
# 2  2003      Q3  Mortgage   1.10 2003-03-01     0.0110
# 3  2003      Q4  Mortgage   1.06 2003-04-01     0.0106
# 4  2004      Q1  Mortgage   1.01 2004-01-01     0.0101

# %%
alt.Chart(del_melt.query('variable != "All" and year > "2016"')).mark_area(
    interpolate="step"
).encode(
    x=alt.X(
        "date:T",
        title="",
        axis=alt.Axis(format="%Y", tickCount=2),
    ),
    y=alt.Y("value_pct:Q", title="", axis=alt.Axis(format="%", tickCount=3)),
    facet=alt.Facet("variable:N", columns=3, title=""),
).properties(
    width=150,
    height=150,
    title="Percentage in serious delinquency (90 days)",
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ---

# %% [markdown]
# ## Total debt balance

# %% [markdown]
# #### By composition

# %%
debt_df = pd.read_excel(url, sheet_name="Page 3 Data", skiprows=3).rename(
    columns={"Unnamed: 0": "quarter"}
)
debt_df.columns = debt_df.columns.str.lower().str.replace(" ", "_")

# %%
debt_df["year"] = "20" + debt_df["quarter"].str.split(":", expand=True)[0]
debt_df["quarter"] = debt_df["quarter"].str.split(":", expand=True)[1]

# %%
debt_df["date"] = pd.to_datetime(
    debt_df["year"].astype(str) + debt_df["quarter"].str.replace("Q", "") + "1",
    format="%Y%m%d",
)

# %%
debt_melt = pd.melt(
    debt_df,
    id_vars=["year", "quarter", "date"],
    value_vars=[
        "mortgage",
        "he_revolving",
        "auto_loan",
        "credit_card",
        "student_loan",
        "other",
        # "total",
    ],
)

# %%
housing_variables = ["mortgage", "he_revolving"]

# %%
area = (
    alt.Chart(debt_melt.query(f"~variable.isin({housing_variables})"))
    .mark_area()
    .encode(x="date:T", y="value:Q", color="variable:N")
)

# %%
area
# Out:
# alt.Chart(...)

# %%
lines = (
    alt.Chart(debt_melt.query(f"~variable.isin({housing_variables})"))
    .mark_bar(interpolate="monotone")
    .encode(
        x=alt.X("date:T"), y=alt.Y("value:Q"), color=alt.Color("variable:N", title="")
    )
)
lines.configure_legend(orient="top")
# Out:
# alt.Chart(...)

# %%
debt_melt.query(f"~variable.isin({housing_variables})").pivot(index=['year','quarter','date'],columns='variable',values='value').reset_index().rename(columns={'auto_loan':'Auto','credit_card':'Credit card','student_loan':'Student loan','other':'Other'})
# Out:
# variable  year quarter       date    Auto  Credit card   Other  Student loan
# 0         2003      Q1 2003-01-01  0.6410       0.6880  0.4776      0.240700
# 1         2003      Q2 2003-02-01  0.6220       0.6930  0.4860      0.242900
# 2         2003      Q3 2003-03-01  0.6840       0.6930  0.4773      0.248800
# 3         2003      Q4 2003-04-01  0.7040       0.6980  0.4486      0.252900
# 4         2004      Q1 2004-01-01  0.7200       0.6950  0.4465      0.259800
# 5         2004      Q2 2004-02-01  0.7430       0.6970  0.4231      0.262900
# 6         2004      Q3 2004-03-01  0.7510       0.7060  0.4100      0.330000
# 7         2004      Q4 2004-04-01  0.7280       0.7170  0.4229      0.345700
# 8         2005      Q1 2005-01-01  0.7250       0.7100  0.3941      0.363600
# 9         2005      Q2 2005-02-01  0.7740       0.7170  0.4024      0.374400
# 10        2005      Q3 2005-03-01  0.8300       0.7320  0.4054      0.377700
# 11        2005      Q4 2005-04-01  0.7920       0.7360  0.4155      0.391700
# 12        2006      Q1 2006-01-01  0.7880       0.7230  0.4183      0.434500
# 13        2006      Q2 2006-02-01  0.7960       0.7390  0.4232      0.438900
# 14        2006      Q3 2006-03-01  0.8210       0.7540  0.4417      0.446700
# 15        2006      Q4 2006-04-01  0.8210       0.7670  0.4057      0.481600
# 16        2007      Q1 2007-01-01  0.7940       0.7640  0.4039      0.506400
# 17        2007      Q2 2007-02-01  0.8070       0.7960  0.4078      0.514000
# 18        2007      Q3 2007-03-01  0.8180       0.8170  0.4130      0.528500
# 19        2007      Q4 2007-04-01  0.8150       0.8390  0.4221      0.547500
# 20        2008      Q1 2008-01-01  0.8080       0.8370  0.4153      0.579200
# 21        2008      Q2 2008-02-01  0.8100       0.8500  0.4008      0.586300
# 22        2008      Q3 2008-03-01  0.8090       0.8580  0.4115      0.610900
# 23        2008      Q4 2008-04-01  0.7910       0.8660  0.4116      0.639300
# 24        2009      Q1 2009-01-01  0.7660       0.8430  0.4088      0.662800
# 25        2009      Q2 2009-02-01  0.7430       0.8240  0.3888      0.675400
# 26        2009      Q3 2009-03-01  0.7390       0.8120  0.3815      0.694500
# 27        2009      Q4 2009-04-01  0.7219       0.7950  0.3785      0.721300
# 28        2010      Q1 2010-01-01  0.7047       0.7624  0.3629      0.757800
# 29        2010      Q2 2010-02-01  0.7022       0.7444  0.3491      0.761700
# 30        2010      Q3 2010-03-01  0.7100       0.7311  0.3427      0.778200
# 31        2010      Q4 2010-04-01  0.7110       0.7296  0.3410      0.811800
# 32        2011      Q1 2011-01-01  0.7056       0.6964  0.3287      0.839200
# 33        2011      Q2 2011-02-01  0.7130       0.6943  0.3303      0.851400
# 34        2011      Q3 2011-03-01  0.7304       0.6933  0.3266      0.870200
# 35        2011      Q4 2011-04-01  0.7341       0.7040  0.3300      0.873600
# 36        2012      Q1 2012-01-01  0.7365       0.6788  0.3185      0.903656
# 37        2012      Q2 2012-02-01  0.7500       0.6720  0.3120      0.914000
# 38        2012      Q3 2012-03-01  0.7680       0.6740  0.3110      0.956000
# 39        2012      Q4 2012-04-01  0.7830       0.6790  0.3170      0.966000
# 40        2013      Q1 2013-01-01  0.7940       0.6600  0.3070      0.986000
# 41        2013      Q2 2013-02-01  0.8140       0.6680  0.2960      0.994000
# 42        2013      Q3 2013-03-01  0.8450       0.6720  0.3040      1.027000
# 43        2013      Q4 2013-04-01  0.8630       0.6830  0.3170      1.080000
# 44        2014      Q1 2014-01-01  0.8750       0.6590  0.3140      1.111000
# 45        2014      Q2 2014-02-01  0.9050       0.6690  0.3230      1.118000
# 46        2014      Q3 2014-03-01  0.9340       0.6800  0.3270      1.126000
# 47        2014      Q4 2014-04-01  0.9550       0.7000  0.3350      1.157000
# 48        2015      Q1 2015-01-01  0.9680       0.6840  0.3290      1.189000
# 49        2015      Q2 2015-02-01  1.0060       0.7030  0.3390      1.190000
# 50        2015      Q3 2015-03-01  1.0450       0.7140  0.3510      1.203000
# 51        2015      Q4 2015-04-01  1.0640       0.7330  0.3510      1.232000
# 52        2016      Q1 2016-01-01  1.0710       0.7120  0.3540      1.261000
# 53        2016      Q2 2016-02-01  1.1030       0.7290  0.3560      1.259000
# 54        2016      Q3 2016-03-01  1.1350       0.7470  0.3670      1.279000
# 55        2016      Q4 2016-04-01  1.1570       0.7790  0.3770      1.310000
# 56        2017      Q1 2017-01-01  1.1670       0.7640  0.3670      1.344000
# 57        2017      Q2 2017-02-01  1.1900       0.7840  0.3780      1.344000
# 58        2017      Q3 2017-03-01  1.2130       0.8080  0.3860      1.357000
# 59        2017      Q4 2017-04-01  1.2210       0.8340  0.3890      1.378000
# 60        2018      Q1 2018-01-01  1.2290       0.8150  0.3850      1.407000
# 61        2018      Q2 2018-02-01  1.2380       0.8290  0.3900      1.405000
# 62        2018      Q3 2018-03-01  1.2650       0.8440  0.3990      1.442000
# 63        2018      Q4 2018-04-01  1.2740       0.8700  0.4070      1.457000
# 64        2019      Q1 2019-01-01  1.2800       0.8480  0.4040      1.486000
# 65        2019      Q2 2019-02-01  1.2970       0.8680  0.4120      1.478000
# 66        2019      Q3 2019-03-01  1.3150       0.8810  0.4250      1.498000
# 67        2019      Q4 2019-04-01  1.3310       0.9270  0.4320      1.508000
# 68        2020      Q1 2020-01-01  1.3460       0.8930  0.4270      1.535000
# 69        2020      Q2 2020-02-01  1.3430       0.8170  0.4180      1.537000
# 70        2020      Q3 2020-03-01  1.3600       0.8070  0.4170      1.546000
# 71        2020      Q4 2020-04-01  1.3740       0.8190  0.4190      1.555000
# 72        2021      Q1 2021-01-01  1.3820       0.7700  0.4130      1.584000
# 73        2021      Q2 2021-02-01  1.4150       0.7870  0.4210      1.570000
# 74        2021      Q3 2021-03-01  1.4430       0.8040  0.4230      1.584000
# 75        2021      Q4 2021-04-01  1.4580       0.8560  0.4380      1.576000
# 76        2022      Q1 2022-01-01  1.4690       0.8410  0.4450      1.590000
# 77        2022      Q2 2022-02-01  1.5020       0.8870  0.4700      1.589000
# 78        2022      Q3 2022-03-01  1.5240       0.9250  0.4910      1.574000
# 79        2022      Q4 2022-04-01  1.5520       0.9860  0.5070      1.595000
# 80        2023      Q1 2023-01-01  1.5620       0.9860  0.5120      1.604000
# 81        2023      Q2 2023-02-01  1.5820       1.0310  0.5270      1.569000
# 82        2023      Q3 2023-03-01  1.5950       1.0790  0.5290      1.599000
# 83        2023      Q4 2023-04-01  1.6070       1.1290  0.5540      1.601000

# %%
dw_debt=dw_debt

# %%
#dw.add_data(chart_id='U2lZt',data=dw_debt)

# %%
dw_debt[dw_debt['date']>="2015-01-01"]
# Out:
# variable  year quarter       date   Auto  Credit card  Other  Student loan
# 48        2015      Q1 2015-01-01  0.968        0.684  0.329         1.189
# 49        2015      Q2 2015-02-01  1.006        0.703  0.339         1.190
# 50        2015      Q3 2015-03-01  1.045        0.714  0.351         1.203
# 51        2015      Q4 2015-04-01  1.064        0.733  0.351         1.232
# 52        2016      Q1 2016-01-01  1.071        0.712  0.354         1.261
# 53        2016      Q2 2016-02-01  1.103        0.729  0.356         1.259
# 54        2016      Q3 2016-03-01  1.135        0.747  0.367         1.279
# 55        2016      Q4 2016-04-01  1.157        0.779  0.377         1.310
# 56        2017      Q1 2017-01-01  1.167        0.764  0.367         1.344
# 57        2017      Q2 2017-02-01  1.190        0.784  0.378         1.344
# 58        2017      Q3 2017-03-01  1.213        0.808  0.386         1.357
# 59        2017      Q4 2017-04-01  1.221        0.834  0.389         1.378
# 60        2018      Q1 2018-01-01  1.229        0.815  0.385         1.407
# 61        2018      Q2 2018-02-01  1.238        0.829  0.390         1.405
# 62        2018      Q3 2018-03-01  1.265        0.844  0.399         1.442
# 63        2018      Q4 2018-04-01  1.274        0.870  0.407         1.457
# 64        2019      Q1 2019-01-01  1.280        0.848  0.404         1.486
# 65        2019      Q2 2019-02-01  1.297        0.868  0.412         1.478
# 66        2019      Q3 2019-03-01  1.315        0.881  0.425         1.498
# 67        2019      Q4 2019-04-01  1.331        0.927  0.432         1.508
# 68        2020      Q1 2020-01-01  1.346        0.893  0.427         1.535
# 69        2020      Q2 2020-02-01  1.343        0.817  0.418         1.537
# 70        2020      Q3 2020-03-01  1.360        0.807  0.417         1.546
# 71        2020      Q4 2020-04-01  1.374        0.819  0.419         1.555
# 72        2021      Q1 2021-01-01  1.382        0.770  0.413         1.584
# 73        2021      Q2 2021-02-01  1.415        0.787  0.421         1.570
# 74        2021      Q3 2021-03-01  1.443        0.804  0.423         1.584
# 75        2021      Q4 2021-04-01  1.458        0.856  0.438         1.576
# 76        2022      Q1 2022-01-01  1.469        0.841  0.445         1.590
# 77        2022      Q2 2022-02-01  1.502        0.887  0.470         1.589
# 78        2022      Q3 2022-03-01  1.524        0.925  0.491         1.574
# 79        2022      Q4 2022-04-01  1.552        0.986  0.507         1.595
# 80        2023      Q1 2023-01-01  1.562        0.986  0.512         1.604
# 81        2023      Q2 2023-02-01  1.582        1.031  0.527         1.569
# 82        2023      Q3 2023-03-01  1.595        1.079  0.529         1.599
# 83        2023      Q4 2023-04-01  1.607        1.129  0.554         1.601

# %% [markdown]
# ---

# %% [markdown]
# ## Aggregate

# %% [markdown]
# #### Groupby state, etc.

# %% [markdown]
# ---

# %% [markdown]
# ## Charts

# %% [markdown]
# #### Save the chart

# %%
chart.save("visuals/chart.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/q0/1clc4jf97cxf003x4xgh89680000gr/T/ipykernel_57709/2497254709.py in <cell line: 1>()
# ----> 1 chart.save("visuals/chart.png")
#
# NameError: name 'chart' is not defined

# %% [markdown]
# #### Make sure the chart is visible on Github

# %%
Image(filename="visuals/chart.png")

# %% [markdown]
# ---

# %% [markdown]
# ## Metadata

# %% [markdown]
# #### Data provenance, column descriptions, etc.

# %% [markdown]
# ---

# %% [markdown]
# ## Exports

# %% [markdown]
# #### XyXy subset in CSV format to `processed`

# %% [markdown]
# #### JSON, GeoJSON, etc., to `processed`
