# %% [markdown]
# # US household debt indicators
# > This notebook downloads, processes and charts data related to household debt from the US Federal Reserve.

# %% [markdown]
# ---

# %% [markdown]
# #### Import Python tools and Jupyter config

# %%
# %pip install cpi
# Out:
# Requirement already satisfied: cpi in /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages (1.1.4)
# Requirement already satisfied: pandas in /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from cpi) (1.5.3)
# Requirement already satisfied: click in /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from cpi) (8.1.3)
# Requirement already satisfied: python-dateutil in /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from cpi) (2.8.1)
# Requirement already satisfied: requests in /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from cpi) (2.28.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from pandas->cpi) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from pandas->cpi) (1.24.1)
# Requirement already satisfied: six>=1.5 in /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from python-dateutil->cpi) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from requests->cpi) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from requests->cpi) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from requests->cpi) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from requests->cpi) (3.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cpi
import requests
import pandas as pd
# import jupyter_black
import altair as alt
import geopandas as gpd
import altair_cnn as altcnn
from IPython.display import Image
from datawrapper import Datawrapper
# Out:
# /Users/almatthews/.pyenv/versions/3.9.16/lib/python3.9/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /var/folders/q0/1clc4jf97cxf003x4xgh89680000gr/T/ipykernel_55315/4231823431.py:7: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
# jupyter_black.load()
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = None
alt.themes.register("cnn", altcnn.theme)
alt.themes.enable("cnn")
# Out:
# ThemeRegistry.enable('cnn')

# %%
dw_token = os.environ.get("dw_api")
dw = Datawrapper(access_token=dw_token)
today = pd.Timestamp("today").strftime("%Y-%m-%d")

# %% [markdown]
# ---

# %% [markdown]
# ## Fetch

# %% [markdown]
# #### Debt report from the [New York Fed Consumer Credit Panel/Equifax](https://www.newyorkfed.org/microeconomics/hhdc)

# %%
url = "https://www.newyorkfed.org/medialibrary/interactives/householdcredit/data/xls/HHD_C_Report_2024Q1"

# %%
xlsx_file = pd.read_excel(url, sheet_name="TABLE OF CONTENTS", skiprows=5, skipfooter=8)
sheet_names = pd.ExcelFile(url).sheet_names

# %% [markdown]
# ---

# %% [markdown]
# #### Quarterly household debt service ratio
# > This [measure](https://fred.stlouisfed.org/series/TDSP) is the ratio of total required household debt payments to total disposable income.

# %%
debt_ratio_url = f"https://fred.stlouisfed.org/graph/fredgraph.csv?id=TDSP"

# %%
debt_ratio_df = pd.read_csv(debt_ratio_url, names=["date", "value"], header=0).round(2)

# %%
debt_ratio_df
# Out:
#            date  value
# 0    1980-01-01  10.61
# 1    1980-04-01  10.63
# 2    1980-07-01  10.40
# 3    1980-10-01  10.25
# 4    1981-01-01  10.29
# ..          ...    ...
# 171  2022-10-01   9.89
# 172  2023-01-01   9.71
# 173  2023-04-01   9.70
# 174  2023-07-01   9.77
# 175  2023-10-01   9.80
#
# [176 rows x 2 columns]

# %% [markdown]
# #### Last decade

# %%
recent = debt_ratio_df.query('date>"1999-12-31"').copy()

# %% [markdown]
# #### Export to Datawrapper [chart](https://app.datawrapper.de/chart/tXaoi/publish)

# %%
debt_ratio_id = "tXaoi"
dw.add_data(
    chart_id=f"{debt_ratio_id}",
    data=recent,
)

# %% [markdown]
# ---

# %% [markdown]
# #### Percentage of debt 90+ days delinquent
# > Aggregate delinquency rates increased in the fourth quarter of 2023. As of December, 3.1% of outstanding debt was in some stage of delinquency, up by 0.1 percentage point from the third quarter. Still, overall delinquency rates remain 1.6 percentage points lower than the fourth quarter of 2019.

# %%
del_df = (
    pd.read_excel(url, sheet_name="Page 12 Data", skiprows=3)
    .drop(["Unnamed: 8", "Unnamed: 9"], axis=1)
    .round(2)
).rename(
    columns={
        "Unnamed: 0": "quarter",
        "MORTGAGE": "mortgage",
        "HELOC": "heloc",
        "AUTO": "auto",
        "CC": "credit_card",
        "STUDENT LOAN": "student_loan",
        "OTHER": "other",
        "ALL": "all",
    }
)

# %% [markdown]
# #### Clean dates

# %%
del_df["year"] = "20" + del_df["quarter"].str.split(":", expand=True)[0]
del_df["quarter"] = del_df["quarter"].str.split(":", expand=True)[1]

# %%
quarter_to_date = {
    "Q1": "-01-01",  # January 1st
    "Q2": "-04-01",  # April 1st
    "Q3": "-07-01",  # July 1st
    "Q4": "-10-01",  # October 1st
}

# %%
del_df["date"] = pd.to_datetime(
    del_df["year"].astype(str) + del_df["quarter"].map(quarter_to_date)
).dt.strftime("%Y-%m-%d")

# %%
del_df.head()
# Out:
#   quarter  mortgage  heloc  auto  credit_card  student_loan  other   all  \
# 0      Q1      1.21   0.35  2.33         8.84          6.13   7.23  2.57
# 1      Q2      1.14   0.28  2.26         8.90          6.14   7.13  2.49
# 2      Q3      1.10   0.22  2.16         8.67          6.27   6.88  2.39
# 3      Q4      1.06   0.31  2.16         9.24          6.23   7.47  2.35
# 4      Q1      1.01   0.21  2.32         9.27          6.34   7.68  2.31
#
#    year        date
# 0  2003  2003-01-01
# 1  2003  2003-04-01
# 2  2003  2003-07-01
# 3  2003  2003-10-01
# 4  2004  2004-01-01

# %% [markdown]
# #### Export to DW

# %%
# https://app.datawrapper.de/chart/4xRqa/publish
#del_df_id = "4xRqa"
#dw.add_data(chart_id=f"{del_df_id}", data=del_df.query('year > "2014"'))
# Out:
# <Response [204]>

# %% [markdown]
# ---

# %% [markdown]
# #### Total debt balance

# %% [markdown]
# #### By composition

# %%
debt_df = pd.read_excel(url, sheet_name="Page 3 Data", skiprows=3).rename(
    columns={"Unnamed: 0": "quarter"}
)
debt_df.columns = debt_df.columns.str.lower().str.replace(" ", "_")

# %%
debt_df["year"] = "20" + debt_df["quarter"].str.split(":", expand=True)[0]
debt_df["quarter"] = debt_df["quarter"].str.split(":", expand=True)[1]

# %%
debt_df["date"] = pd.to_datetime(
    debt_df["year"].astype(str) + debt_df["quarter"].map(quarter_to_date)
).dt.strftime("%Y-%m-%d")
debt_df["date"] = pd.to_datetime(debt_df["date"])

# %%
debt_df.head()
# Out:
#   quarter  mortgage  he_revolving  auto_loan  credit_card  student_loan  \
# 0      Q1     4.942         0.242      0.641        0.688        0.2407
# 1      Q2     5.080         0.260      0.622        0.693        0.2429
# 2      Q3     5.183         0.269      0.684        0.693        0.2488
# 3      Q4     5.660         0.302      0.704        0.698        0.2529
# 4      Q1     5.840         0.328      0.720        0.695        0.2598
#
#     other   total  year       date
# 0  0.4776  7.2313  2003 2003-01-01
# 1  0.4860  7.3839  2003 2003-04-01
# 2  0.4773  7.5551  2003 2003-07-01
# 3  0.4486  8.0655  2003 2003-10-01
# 4  0.4465  8.2893  2004 2004-01-01

# %% [markdown]
# #### Function to adjust for inflation

# %%
def adjust_for_inflation(row, column_name):
    # Adjusts to 2023 dollars
    year_of_data = row["date"].year
    return cpi.inflate(row[column_name], year_or_month=year_of_data, to=2023)

# %% [markdown]
# #### Apply inflation adjustment
# > Use the non-housing measures. Other balances include retail cards and other consumer loans.

# %%
columns_to_adjust = [
    # "mortgage",
    # "he_revolving",
    "auto_loan",
    "credit_card",
    "student_loan",
    "other",
    # "total",
]

# %%
for column in columns_to_adjust:
    debt_df[column + "_infl_adj"] = debt_df[:84].apply(
        adjust_for_inflation, column_name=column, axis=1
    ).round(3)

# %%
debt_df[debt_df['date']>="2015-01-01"]
# Out:
#    quarter  mortgage  he_revolving  auto_loan  credit_card  student_loan  \
# 48      Q1     8.171         0.510      0.968        0.684         1.189
# 49      Q2     8.116         0.499      1.006        0.703         1.190
# 50      Q3     8.260         0.492      1.045        0.714         1.203
# 51      Q4     8.249         0.487      1.064        0.733         1.232
# 52      Q1     8.369         0.485      1.071        0.712         1.261
# 53      Q2     8.362         0.478      1.103        0.729         1.259
# 54      Q3     8.350         0.472      1.135        0.747         1.279
# 55      Q4     8.480         0.473      1.157        0.779         1.310
# 56      Q1     8.627         0.456      1.167        0.764         1.344
# 57      Q2     8.691         0.452      1.190        0.784         1.344
# 58      Q3     8.743         0.448      1.213        0.808         1.357
# 59      Q4     8.882         0.444      1.221        0.834         1.378
# 60      Q1     8.939         0.436      1.229        0.815         1.407
# 61      Q2     8.999         0.432      1.238        0.829         1.405
# 62      Q3     9.140         0.422      1.265        0.844         1.442
# 63      Q4     9.124         0.412      1.274        0.870         1.457
# 64      Q1     9.244         0.406      1.280        0.848         1.486
# 65      Q2     9.406         0.399      1.297        0.868         1.478
# 66      Q3     9.437         0.396      1.315        0.881         1.498
# 67      Q4     9.557         0.390      1.331        0.927         1.508
# 68      Q1     9.713         0.386      1.346        0.893         1.535
# 69      Q2     9.776         0.375      1.343        0.817         1.537
# 70      Q3     9.861         0.362      1.360        0.807         1.546
# 71      Q4    10.043         0.349      1.374        0.819         1.555
# 72      Q1    10.160         0.335      1.382        0.770         1.584
# 73      Q2    10.442         0.322      1.415        0.787         1.570
# 74      Q3    10.672         0.317      1.443        0.804         1.584
# 75      Q4    10.930         0.318      1.458        0.856         1.576
# 76      Q1    11.180         0.317      1.469        0.841         1.590
# 77      Q2    11.387         0.319      1.502        0.887         1.589
# 78      Q3    11.669         0.322      1.524        0.925         1.574
# 79      Q4    11.923         0.336      1.552        0.986         1.595
# 80      Q1    12.044         0.339      1.562        0.986         1.604
# 81      Q2    12.014         0.340      1.582        1.031         1.569
# 82      Q3    12.140         0.349      1.595        1.079         1.599
# 83      Q4    12.252         0.360      1.607        1.129         1.601
# 84      Q1    12.442         0.376      1.616        1.115         1.595
#
#     other   total  year       date  auto_loan_infl_adj  credit_card_infl_adj  \
# 48  0.329  11.851  2015 2015-01-01               1.244                 0.879
# 49  0.339  11.853  2015 2015-04-01               1.293                 0.904
# 50  0.351  12.065  2015 2015-07-01               1.343                 0.918
# 51  0.351  12.116  2015 2015-10-01               1.368                 0.942
# 52  0.354  12.252  2016 2016-01-01               1.360                 0.904
# 53  0.356  12.287  2016 2016-04-01               1.400                 0.926
