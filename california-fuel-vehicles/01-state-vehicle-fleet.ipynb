# %% [markdown]
# # California state vehicle fleet

# %%
import pandas as pd
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt
import geojson
import json
import jenkspy
import numpy as np
from pywaffle import Waffle
from altair import datum
import altair as alt
import altair_latimes as lat
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000
pd.options.display.float_format = '{:,.2f}'.format
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
df = pd.read_csv('https://data.ca.gov/dataset/1b31c08e-b1a7-4459-8aef-41cfff61fc5e/resource/5c42e9f6-e172-4db4-9a51-ca1256b03a26/download/fleet-asset-management-system-open-data-2015-2019.csv', low_memory=False, encoding='Latin-1')

# %%
df.head()
# Out:
#                                 Agency  Report_Year Disposed Equipment_Number  \
# 0  African American Museum, California         2015       No         caam0103
# 1  African American Museum, California         2015       No             Null
# 2  African American Museum, California         2016       No         caam0103
# 3  African American Museum, California         2016       No             Null
# 4  African American Museum, California         2017       No         caam0103
#
#   Asset_Category Model_Year      Make_Model Postal_Code Asset_Type  \
# 0         Ground       2003  FORD ECONOLINE       90037        Van
# 1        No Data       Null  Not Applicable       90037    No Data
# 2         Ground       2003  FORD ECONOLINE       90037        Van
# 3        No Data       Null  Not Applicable       90037    No Data
# 4         Ground       2003  FORD ECONOLINE       90037        Van
#
#   Weight_Class Passenger_Vehicle Payload_Rating  Shipping_Weight   \
# ...

# %%
df[df['Report_Year'] == 2019].Fuel_Type.value_counts(normalize=True)
# Out:
# Gasoline                        0.42
# 85% Ethanol                     0.19
# Diesel                          0.16
# Not Applicable                  0.11
# Electricity (battery powered)   0.10
# LPG/Propane                     0.02
# Compressed Natural Gas          0.00
# Hydrogen                        0.00
# 85% Methanol                    0.00
# Liquid Natural Gas              0.00
# Biodiesel                       0.00
# Renewable Diesel                0.00
# Name: Fuel_Type, dtype: float64
