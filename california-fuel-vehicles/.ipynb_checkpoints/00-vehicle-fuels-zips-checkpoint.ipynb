# %% [markdown]
# # How many zero and low emissions vehicles are registered in California?

# %% [markdown]
# ### Load Python tools

# %%
import pandas as pd
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt
import json
import jenkspy
import numpy as np
from pywaffle import Waffle
from altair import datum
import altair as alt
import altair_latimes as lat
# Out:
# /Users/mhustiles/.local/share/virtualenvs/notebooks-xu8v5Vvv/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %%
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000
pd.options.display.float_format = '{:,.2f}'.format
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
# CARB looks for ways to meet our 5 million zero-emission vehicle target by 2030, the conversion of public and private fleets to zero emission cars and trucks offers an important opportunity to get a large number of carbon-polluting fleet vehicles off the road.
# https://ww2.arb.ca.gov/sites/default/files/2018-12/zero_emission_fleet_letter_080118.pdf

# %% [markdown]
# ### Read data from California Department of Motor Vehicles - current as of Jan. 1, 2020

# %%
# https://data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code
url = 'https://data.ca.gov/dataset/15179472-adeb-4df6-920a-20640d02b08c/resource/4254a06d-9937-4083-9441-65597dd267e8/download/vehicle-count-as-of-1-1-2020.csv'

# %%
src = pd.read_csv(url, low_memory=False)

# %% [markdown]
# ### Clean up field names

# %%
src.columns = src.columns.str.strip().str.lower().str.replace(' ', '_', regex=False)\
                    .str.replace('(', '', regex=False).str.replace(')', '', regex=False).str.replace('-','_', regex=False)

# %%
src.rename(columns={"zip_code": "zip"}, inplace=True)

# %% [markdown]
# ### How many vehicles are we talking about?

# %%
'{:,.0f}'.format(src.vehicles.sum())
# Out:
# '31,233,841'

# %%
src.model_year.value_counts()
# Out:
# <2007    86632
# 2017     48075
# 2016     44892
# 2015     44780
# 2018     44322
# 2014     42015
# 2013     41089
# 2019     40583
# 2012     38944
# 2007     34198
# 2011     34037
# 2008     33778
# 2010     29790
# 2009     26670
# 2020     11342
# Unk       1232
# 2021        15
# Name: model_year, dtype: int64

# %% [markdown]
# ### Remove older vehicles

# %%
vehicles = src[src['model_year'] != '<2007']

# %%
'{:,.0f}'.format(vehicles.vehicles.sum())
# Out:
# '20,302,263'

# %% [markdown]
# ### How many don't rely solely on gasoline?

# %%
nogas = vehicles[(vehicles['fuel'] != 'Gasoline')]

# %%
zev = vehicles[vehicles['fuel'] == 'Battery Electric']

# %%
cvrp = vehicles[(vehicles['fuel'] == 'Battery Electric') |\
               (vehicles['fuel'] == 'Hydrogen Fuel Cell') |\
              (vehicles['fuel'] == 'Plug-in Hybrid')]

# %%
'{:,.0f}'.format(nogas.vehicles.sum())
# Out:
# '3,449,912'

# %% [markdown]
# ### How many are battery electric, or otherwise CVRP eligible?

# %%
'{:,.0f}'.format(cvrp.vehicles.sum())
# Out:
# '561,323'

# %%
'{:,.0f}'.format(zev.vehicles.sum())
# Out:
# '306,297'

# %% [markdown]
# ### Share of newer CA vehicles that don't rely solely on gas?

# %%
'{:,.1f}%'.format((nogas.vehicles.sum() / vehicles.vehicles.sum())*100)
# Out:
# '17.0%'

# %% [markdown]
# ### Share of CA vehicles that are battery electric, or otherwise CVRP eligible?

# %%
'{:,.1f}%'.format((cvrp.vehicles.sum() / vehicles.vehicles.sum())*100)
# Out:
# '2.8%'

# %% [markdown]
# ---

# %% [markdown]
# ### ZIP codes points

# %%
zips_point = gpd.read_file('../../../data/gis/zipcodes.geojson')

# %%
zips_point['zip'] = zips_point['zip'].astype(str)

# %%
ca_zips_point = zips_point[zips_point['state'] == 'CA']

# %% [markdown]
# ### ZIP codes boundaries

# %%
# Filtered CA from this national file maintained by Esri: 
# https://services.arcgis.com/P3ePLMYs2RVChkJx/arcgis/rest/services/USA_ZIP_Code_Areas_anaylsis/FeatureServer/0/
zips_poly_pop = gpd.read_file('../../../data/gis/ca-zip-codes-esri.geojson')
zips_poly = gpd.read_file('../../../data/gis/ca-zip-codes-esri-demographics.geojson')

# %%
zips_poly.columns = zips_poly.columns.str.strip().str.lower().str.replace(' ', '_', regex=False)\
                    .str.replace('(', '', regex=False).str.replace(')', '', regex=False).str.replace('-','_', regex=False)

# %%
zips_poly.dropna(inplace=True)

# %%
zips_poly.rename(columns={"zip_code": "zip"}, inplace=True)

# %%
zips_poly.head()
# Out:
#    objectid    zip     po_name  pop2012  white  black  ameri_es  asian  \
# 0      4800  94002     Belmont    26832  19634    477        84   5762
# 1      4801  94010  Burlingame    41102  31610    482        93  10244
# 2      4900  93442   Morro Bay    10873   9395     47       104    281
# 3      4901  93445      Oceano     7633   4683     60       114    155
# 4      4802  94015   Daly City    61575  14279   2138       168  35940
#
#    hawn_pi  hispanic  other  mult_race  med_age  ave_hh_sz  marhh_chd  \
# 0      221      3517   1170       1744    41.00       2.42       2925
# 1      188      5133   1865       2166    42.60       2.43       4798
# 2       10      1602    645        322    48.90       2.09        593
# 3        7      3389   1477        283    34.70       2.86        541
# 4      482      9775   4520       2939    39.00       3.10       4637
#
#    families  ave_fam_sz  hse_units  sqmi  \
# 0      7671        2.98      12304  5.90
# 1     12179        3.06      20020 13.00
# 2      2749        2.70       6609 43.20
# 3      1582        3.42       2871  2.00
# 4     13991        3.54      20103  5.70
#
#                                             geometry
# 0  POLYGON ((-122.27703 37.53436, -122.27687 37.5...
# 1  POLYGON ((-122.37728 37.60562, -122.37738 37.6...
# 2  POLYGON ((-120.77255 35.46196, -120.77270 35.4...
# 3  POLYGON ((-120.63624 35.12213, -120.63591 35.1...
# 4  POLYGON ((-122.50283 37.70813, -122.50242 37.7...

# %% [markdown]
# ---

# %% [markdown]
# ### ZIP codes demographics from mapping giant Esri

# %%
#https://services.arcgis.com/P3ePLMYs2RVChkJx/arcgis/rest/services/WealthiestZipCodes2017/FeatureServer/0/
zips_wealth = gpd.read_file('../../../data/gis/WealthiestZipCodesCA.geojson')

# %%
zips_wealth.head()
# Out:
#    OBJECTID     ID         NAME ST_ABBREV  HAI_CY  INCMORT_CY  WLTHRNK_CY  \
# 0     29014  90001  Los Angeles        CA      55       44.10   27,675.00
# 1     29015  90002  Los Angeles        CA      59       41.20   27,690.00
# 2     29016  90003  Los Angeles        CA      52       46.60   28,202.00
# 3     29017  90004  Los Angeles        CA      21      114.50   20,202.00
# 4     29018  90005  Los Angeles        CA      22      111.50   26,028.00
#
#   DOMSTATE DOMCOUNTY         COUNTY_NAME DOMCBSA  \
# 0       06     06037  Los Angeles County   31080
# 1       06     06037  Los Angeles County   31080
# 2       06     06037  Los Angeles County   31080
# 3       06     06037  Los Angeles County   31080
# 4       06     06037  Los Angeles County   31080
#
#                                            CBSA_NAME  TOTPOP_CY  TOTHH_CY  \
# 0  Los Angeles-Long Beach-Anaheim, CA Metropolita...      59907     13454
# 1  Los Angeles-Long Beach-Anaheim, CA Metropolita...      53573     12115
# 2  Los Angeles-Long Beach-Anaheim, CA Metropolita...      71967     16771
# 3  Los Angeles-Long Beach-Anaheim, CA Metropolita...      63987     23021
# 4  Los Angeles-Long Beach-Anaheim, CA Metropolita...      41844     17067
#
#    MEDAGE_CY  AVGHINC_CY  AVGVAL_CY  AVGNW_CY   Shape__Area  Shape__Length  \
# 0      27.10       46931     377591     82915 12,747,932.74      17,936.35
# 1      26.70       46332     331694     96786 11,348,270.82      16,650.99
# 2      27.10       43020     358057     66091 13,659,740.57      23,821.37
# 3      35.80       65893     909580    232653 10,904,998.97      22,878.23
# 4      35.80       53191     836569    105569  5,390,883.48      19,394.84
#
#                                             geometry
# 0  POLYGON ((-118.24754 33.98908, -118.24776 33.9...
# 1  POLYGON ((-118.24745 33.96015, -118.25169 33.9...
# 2  MULTIPOLYGON (((-118.28268 33.98926, -118.2826...
# 3  MULTIPOLYGON (((-118.33852 34.06891, -118.3371...
# 4  POLYGON ((-118.31879 34.05514, -118.31861 34.0...

# %%
zips_wealth_slim = zips_wealth[['ID','NAME', 'AVGHINC_CY', 'AVGNW_CY', 'TOTPOP_CY']]

# %%
zips_esri = zips_wealth_slim.rename(columns={"ID": "zip",
                                                    'NAME':'name',
                                 'AVGHINC_CY':'avg_house_income',
                                 'AVGNW_CY':'avg_net_worth',
                                 'TOTPOP_CY':'population', })

# %%
zips_esri.head()
# Out:
#      zip         name  avg_house_income  avg_net_worth  population
# 0  90001  Los Angeles             46931          82915       59907
# 1  90002  Los Angeles             46332          96786       53573
# 2  90003  Los Angeles             43020          66091       71967
# 3  90004  Los Angeles             65893         232653       63987
# 4  90005  Los Angeles             53191         105569       41844

# %%
zips_esri.to_csv('../../usc/data/cars/zip_demographics.csv', index=False)
vehicles[vehicles['zip'] != 'OOS'].to_csv('../../usc/data/cars/vehicle-count.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ### Group the vehicles and count them by the registration ZIP code

# %%
zipcodes = vehicles.groupby(['zip']).agg({'vehicles':'sum'}).reset_index()

# %%
zipcodes.sort_values(by='vehicles', ascending=False).head(10)
zipcodes['zip'] = zipcodes['zip'].astype(str)

# %% [markdown]
# ### Merge the registration zip codes and merge with Esri zipcode polygons

# %%
zips = pd.merge(zips_esri, zipcodes, left_on='zip', right_on='zip')

# %%
zips.head()
# Out:
#      zip         name  avg_house_income  avg_net_worth  population  vehicles
# 0  90001  Los Angeles             46931          82915       59907     17803
# 1  90002  Los Angeles             46332          96786       53573     16227
# 2  90003  Los Angeles             43020          66091       71967     21244
# 3  90004  Los Angeles             65893         232653       63987     22734
# 4  90005  Los Angeles             53191         105569       41844     12518

# %% [markdown]
# ---

# %% [markdown]
# ### Group by duty. Which are most common among ALL vehicles?

# %%
# About 2.5 are listed as OTHER/UNK
duty_totals = vehicles.groupby(['duty']).agg('sum').reset_index()
duty_totals.head()
# Out:
#     duty  vehicles
# 0  Heavy    635013
# 1  Light  19667250

# %% [markdown]
# ### Group by make. Which are most common?

# %%
# About 2.5 are listed as OTHER/UNK
make = vehicles[vehicles['make'] != 'OTHER/UNK'].groupby(['make', 'zip']).agg('sum').reset_index()

# %%
most_make = make.groupby(['make']).agg('sum').reset_index().sort_values(by='vehicles', ascending=False)

# %%
most_make.head()
# Out:
#          make  vehicles
# 87     TOYOTA   3511211
# 33      HONDA   2403082
# 26       FORD   1744654
# 63     NISSAN   1380468
# 18  CHEVROLET   1316712

# %%
makelist = most_make.make.to_list()

# %%
popular_makes = make[make['make'].isin(makelist)]

# %%
make_zip = pd.DataFrame(pd.pivot_table(popular_makes, values='vehicles', \
                            index=['zip'], columns=['make'], aggfunc=np.sum, fill_value=0).reset_index())

# %%
make_zip.columns = make_zip.columns.str.strip().str.lower().str.replace(' ', '_', regex=False)\
                    .str.replace('(', '', regex=False).str.replace(')', '', regex=False).str.replace('-','_', regex=False)

# %% [markdown]
# ### Which make is most common in each ZIP code?

# %%
make_zip["total"] = make_zip[['acura', 'alexander_dennis', 'alfa_romeo', 'allianz',
       'am_general', 'american_lafrance', 'aston_martin', 'audi', 'autocar',
       'bentley', 'blue_bird', 'bluebird', 'bmw', 'buick', 'cadillac',
       'capacity', 'capacity_of_texas_inc', 'caterpillar', 'chevrolet',
       'chrysler', 'crane_carrier', 'dodge', 'emergency_one', 'evobus',
       'ferrari', 'fiat', 'ford', 'freightliner', 'genesis', 'gillig', 'gmc',
       'hino', 'hme', 'honda', 'hummer', 'hyundai', 'ic_bus', 'ic_bus,_llc',
       'infiniti', 'international', 'isuzu', 'jaguar', 'jeep', 'kalmar',
       'kalmar_industries_usa_llc', 'kenworth', 'kia',
       'kovatch_moblie_equipment_corp.', 'lamborghini', 'land_rover', 'lexus',
       'lincoln', 'mack', 'maserati', 'mazda', 'mercedes_benz', 'mercury',
       'mini', 'mitsubishi', 'mitsubishi_fuso', 'motor_coach_industries',
       'new_flyer', 'newflyer', 'nissan', 'north_american_bus_industries',
       'orion', 'peterbilt', 'pierce', 'pierce_manufacturing', 'pontiac',
       'porsche', 'prevost', 'ram', 'rolls_royce', 'saab', 'saturn', 'scion',
       'smart', 'smith', 'spartan', 'sterling', 'subaru', 'suzuki', 'temsa',
       'tesla', 'thomas_built_buses', 'thomas_bus', 'toyota', 'ud_trucks',
       'unk', 'van_hool', 'volkswagen', 'volvo', 'vpg', 'western_star',
       'workhorse']].sum(axis=1)

# %%
make_zip.sort_values(by='total', ascending=False).head(5)
# Out:
# make    zip  acura  alexander_dennis  alfa_romeo  allianz  am_general  \
# 1604    OOS   2816                 0          67        0           0
# 42    90045    316                 0          14        0           0
# 957   94080    758                 0           0        0           0
# 487   92336    440                 0           0        0           0
# 417   92154    370                 0           0        0           0
#
# make  american_lafrance  aston_martin  audi  autocar  bentley  blue_bird  \
# 1604                  0             0  4486       35       48         13
# 42                    0             0   750        0        0          0
# 957                   0             0   463        0        0          0
# 487                   0             0   461        0        0          0
# 417                   0             0   309        0        0          0
#
# make  bluebird   bmw  buick  cadillac  capacity  capacity_of_texas_inc  \
# 1604        20  6959   1494      4456        18                      0
# 42           0  1859   1628       605         0                      0
# 957          0  1570    434       571         0                      0
# 487          0  1412    158       440         0                      0
# 417          0  1103    185       209         0                      0
#
# make  caterpillar  chevrolet  chrysler  crane_carrier  dodge  emergency_one  \
# 1604            0      58535      4594              0  28449              0
# 42              0       9801      3347              0   8409              0
# 957             0      13569      1761              0   4681              0
# 487             0       5573       502              0   1248              0
# 417             0       2988       484              0   1353              0
#
# make  evobus  ...    ram  rolls_royce  saab  saturn  scion  smart  smith  \
# 1604       0  ...  18597            0    32     292   1481     90     91
# 42         0  ...   1442            0     0       0     59      0      0
# 957       28  ...    992            0     0      16    286      0      0
# 487        0  ...    459            0     0      68    589      0      0
# 417        0  ...    298            0     0      88    448      0      0
#
# make  spartan  sterling  subaru  suzuki  temsa  tesla  thomas_built_buses  \
# 1604        0        87    8481      39      0   2422                  12
# 42          0         0     624       0      0    352                   0
# 957         0         0    1139       0     13    334                   0
# 487         0         0     585       0      0    218                   0
# 417         0        92     564      13      0     65                   0
#
# make  thomas_bus  toyota  ud_trucks    unk  van_hool  volkswagen  volvo  vpg  \
# 1604         105   54844          0  28266        53        9682   2785    0
# 42             0   17164          0   7300         0        3324    266    0
# 957            0   16979          0   3917         0        2415     81    0
# 487            0    9746          0    723         0         869    329    0
# 417            0    8078          0    358         0        2050    292    0
#
# make  western_star  workhorse   total
# 1604             0         20  581522
# 42               0          0  118622
# 957              0          0  105927
# 487              0          0   53255
# 417              0          0   48944
#
# [5 rows x 98 columns]

# %%
make_zip[['zip', 'total']].to_csv('output/total_makes_zip.csv')

# %%
make_total = pd.DataFrame(make_zip[['zip', 'total']])

# %%
make_zip['winner'] = make_zip[['acura', 'alexander_dennis', 'alfa_romeo', 'allianz',
       'am_general', 'american_lafrance', 'aston_martin', 'audi', 'autocar',
       'bentley', 'blue_bird', 'bluebird', 'bmw', 'buick', 'cadillac',
       'capacity', 'capacity_of_texas_inc', 'caterpillar', 'chevrolet',
       'chrysler', 'crane_carrier', 'dodge', 'emergency_one', 'evobus',
       'ferrari', 'fiat', 'ford', 'freightliner', 'genesis', 'gillig', 'gmc',
       'hino', 'hme', 'honda', 'hummer', 'hyundai', 'ic_bus', 'ic_bus,_llc',
       'infiniti', 'international', 'isuzu', 'jaguar', 'jeep', 'kalmar',
       'kalmar_industries_usa_llc', 'kenworth', 'kia',
       'kovatch_moblie_equipment_corp.', 'lamborghini', 'land_rover', 'lexus',
       'lincoln', 'mack', 'maserati', 'mazda', 'mercedes_benz', 'mercury',
       'mini', 'mitsubishi', 'mitsubishi_fuso', 'motor_coach_industries',
       'new_flyer', 'newflyer', 'nissan', 'north_american_bus_industries',
       'orion', 'peterbilt', 'pierce', 'pierce_manufacturing', 'pontiac',
       'porsche', 'prevost', 'ram', 'rolls_royce', 'saab', 'saturn', 'scion',
       'smart', 'smith', 'spartan', 'sterling', 'subaru', 'suzuki', 'temsa',
       'tesla', 'thomas_built_buses', 'thomas_bus', 'toyota', 'ud_trucks',
       'unk', 'van_hool', 'volkswagen', 'volvo', 'vpg', 'western_star',
       'workhorse']].idxmax(axis=1)

# %%
make_zip.head(10)
# Out:
# make    zip  acura  alexander_dennis  alfa_romeo  allianz  am_general  \
# 0     90001     52                 0           0        0           0
# 1     90002     20                 0           0        0           0
# 2     90003     83                 0           0        0           0
# 3     90004    227                 0          32        0           0
# 4     90005     62                 0           0        0           0
# 5     90006     62                 0           0        0           0
# 6     90007      0                 0           0        0           0
# 7     90008     36                 0           0        0           0
# 8     90010      0                 0           0        0           0
# 9     90011    171                 0           0        0           0
#
# make  american_lafrance  aston_martin  audi  autocar  bentley  blue_bird  \
# 0                     0             0    11        0        0          0
# 1                     0             0    13        0        0          0
# 2                     0             0    41        0        0          0
# 3                     0             0   563        0        0          0
# 4                     0             0   241        0        0          0
# 5                     0             0   113        0        0          0
# 6                     0             0   182        0        0          0
# 7                     0             0   200        0        0          0
# 8                     0             0    81        0        0          0
# 9                     0             0   101        0        0          0
#
# make  bluebird   bmw  buick  cadillac  capacity  capacity_of_texas_inc  \
# 0            0   344     14        57         0                      0
# 1            0   240     13        72         0                      0
# 2            0   332     11       102         0                      0
# 3            0  1075      0        37         0                      0
# 4            0   759      0         0         0                      0
# 5            0   564      0         0         0                      0
# 6            0   414      0         0         0                      0
# 7            0   499     49       171         0                      0
# 8            0   317      0        77         0                      0
# 9            0   416      0       127         0                      0
#
# make  caterpillar  chevrolet  chrysler  crane_carrier  dodge  emergency_one  \
# 0               0       1670       181              0    663              0
# 1               0       1561       193              0    641              0
# 2               0       1808       252              0    818              0
# 3               0        680        11              0    220              0
# 4               0        260         0              0     52              0
# 5               0        664        12              0    203              0
# 6               0        509        14              0    153              0
# 7               0        785       159              0    273              0
# 8               0         60         0              0     60              0
# 9               0       2643       267              0   1071              0
#
# make  evobus  ...  rolls_royce  saab  saturn  scion  smart  smith  spartan  \
# 0          0  ...            0     0      27    235      0      0        0
# 1          0  ...            0     0      38    221      0      0        0
# 2          0  ...            0     0      37    338      0      0        0
# 3          0  ...            0     0       0    238      0      0        0
# 4          0  ...            0     0       0     39      0      0        0
# 5          0  ...            0     0       0    178      0      0        0
# 6          0  ...            0     0       0     57      0      0        0
# 7          0  ...            0     0       0     14      0      0        0
# 8          0  ...            0     0       0      0      0      0        0
# 9          0  ...            0     0      49    416      0      0        0
#
# make  sterling  subaru  suzuki  temsa  tesla  thomas_built_buses  thomas_bus  \
# 0            0      51       0      0      0                   0           0
# 1            0      41       0      0      0                   0           0
# 2            0      25       0      0      0                   0           0
# 3            0     422       0      0    200                   0           0
# 4            0     192       0      0     58                   0           0
# 5            0     119       0      0     26                   0           0
# 6            0      90       0      0     27                   0           0
# 7            0      91       0      0     54                   0           0
# 8            0      17       0      0     39                   0           0
# 9            0     115       0      0      0                   0           0
#
# make  toyota  ud_trucks  unk  van_hool  volkswagen  volvo  vpg  western_star  \
# 0       3306          0  158         0         191      0    0             0
# 1       3009          0  111         0         212      0    0             0
# 2       4355          0  159         0         277      0    0             0
# 3       5250          0  179         0         678    114    0             0
# 4       2638          0  108         0         320      0    0             0
# 5       4477          0  131         0         320     28    0             0
# 6       2206          0  102         0         287      0    0             0
# 7       1801          0   55         0         328     25    0             0
# 8       1455          0  364         0          12     15    0             0
# 9       5994          0  195         0         394     11    0             0
#
# make  workhorse  total  winner
# 0             0  16031  toyota
# 1             0  14720  toyota
# 2             0  19648  toyota
# 3             0  21021  toyota
# 4             0  10873  toyota
# 5             0  15710  toyota
# 6             0   9051  toyota
# 7             0  10786  toyota
# 8             0   4959  toyota
# 9             0  27191  toyota
#
# [10 rows x 99 columns]

# %%
make_zip_top_ten = pd.DataFrame(make_zip[['zip','toyota','honda','ford','chevrolet','nissan',\
                               'bmw','hyundai','lexus','mercedes_benz','kia', 'total']])

# %%
make_zip_top_ten.to_csv('output/make_zip_top_ten.csv')

# %%
make_zip_top_ten.head()
# Out:
# make    zip  toyota  honda  ford  chevrolet  nissan   bmw  hyundai  lexus  \
# 0     90001    3306   2471  1032       1670    2564   344      398    170
# 1     90002    3009   2149   926       1561    2447   240      371    176
# 2     90003    4355   2978  1179       1808    3106   332      433    247
# 3     90004    5250   3144   774        680    1812  1075      778   1176
# 4     90005    2638   1769   341        260     877   759      610    822
#
# make  mercedes_benz   kia  total
# 0               169  1034  16031
# 1               174  1113  14720
# 2               303  1408  19648
# 3               889   686  21021
# 4               640   401  10873

# %% [markdown]
# ---

# %% [markdown]
# ## Isolate vehicle makes to include only Teslas

# %%
tesla = vehicles[(vehicles['make'] == 'TESLA')]

# %%
len(tesla)
# Out:
# 3212

# %% [markdown]
# ### Group by ZIP code and count the vehicles

# %%
tesla_grouped = tesla.groupby(['zip']).agg({'vehicles':'sum'}).reset_index()

# %% [markdown]
# ### Merge with dataframe that includes all vehicle counts by ZIP code

# %%
tesla_zips = pd.merge(tesla_grouped, zips, on='zip')

# %% [markdown]
# ### Rename the columns

# %%
tesla_zips.rename(columns={'median': 'income','zip': 'zip', \
                           'vehicles_x':'teslas', 'vehicles_y':'all_vehicles'}, inplace=True)

# %% [markdown]
# ### Normalize Tesla ownership to a rate per 1,000 vehicles

# %%
tesla_zips['tesla_rate_1k'] = ((tesla_zips.teslas / tesla_zips.all_vehicles) * 1000).round(2)

# %%
tesla_zips.sort_values(by='tesla_rate_1k', ascending=False).head(10)
# Out:
#        zip  teslas            name  avg_house_income  avg_net_worth  \
# 563  94027     527        Atherton            297732        3680197
# 560  94022    1227       Los Altos            248970        3041961
# 608  94301     764       Palo Alto            224861        1760729
# 561  94024    1210       Los Altos            259185        3442702
# 744  95070    1586        Saratoga            243915        3157204
# 564  94028     358  Portola Valley            263238        3322715
# 416  92657     573   Newport Coast            244565        2836260
# 640  94539    1931         Fremont            198198        2070851
# 731  95030     568       Los Gatos            233429        2476366
# 772  95138     710        San Jose            181584        1376395
#
#      population  all_vehicles  tesla_rate_1k
# 563        7230          5156         102.21
# 560       20626         13820          88.78
# 608       18694          9376          81.48
# 561       23198         14929          81.05
# 744       32730         21471          73.87
# 564        6639          4854          73.75
# 416       11464          8343          68.68
# 640       54673         31788          60.75
# 731       13618          9373          60.60
# 772       19789         11943          59.45

# %%
tesla_breaks \
= jenkspy.jenks_breaks(tesla_zips.tesla_rate_1k, nb_class=6)
tesla_breaks
# Out:
# [0.33, 5.64, 12.65, 23.47, 39.12, 60.75, 102.21]

# %%
tesla_zips.to_csv('output/tesla_zips.csv')

# %%
tesla_zips_slim = pd.DataFrame(tesla_zips[['zip','name','teslas','all_vehicles','tesla_rate_1k', 'avg_house_income', 'avg_net_worth']])

# %%
tesla_zips_slim.sort_values(by='tesla_rate_1k', ascending=False).head(10)
# Out:
#        zip            name  teslas  all_vehicles  tesla_rate_1k  \
# 563  94027        Atherton     527          5156         102.21
# 560  94022       Los Altos    1227         13820          88.78
# 608  94301       Palo Alto     764          9376          81.48
# 561  94024       Los Altos    1210         14929          81.05
# 744  95070        Saratoga    1586         21471          73.87
# 564  94028  Portola Valley     358          4854          73.75
# 416  92657   Newport Coast     573          8343          68.68
# 640  94539         Fremont    1931         31788          60.75
# 731  95030       Los Gatos     568          9373          60.60
# 772  95138        San Jose     710         11943          59.45
#
#      avg_house_income  avg_net_worth
# 563            297732        3680197
# 560            248970        3041961
# 608            224861        1760729
# 561            259185        3442702
# 744            243915        3157204
# 564            263238        3322715
# 416            244565        2836260
# 640            198198        2070851
# 731            233429        2476366
# 772            181584        1376395

# %% [markdown]
# ### How predictive is income

# %%
tesla_zips.head()
# Out:
#      zip  teslas         name  avg_house_income  avg_net_worth  population  \
# 0  90004     200  Los Angeles             65893         232653       63987
# 1  90005      58  Los Angeles             53191         105569       41844
# 2  90006      26  Los Angeles             42242          39289       61184
# 3  90007      27  Los Angeles             38564          39966       45381
# 4  90008      54  Los Angeles             56286         284531       34600
#
#    all_vehicles  tesla_rate_1k
# 0         22734           8.80
# 1         12518           4.63
# 2         17324           1.50
# 3         10707           2.52
# 4         12611           4.28

# %%
tesla_zips_corr = tesla_zips_slim[['tesla_rate_1k', 'avg_house_income']]

# %%
corr = tesla_zips_corr.corr(method ='pearson')

# %%
print(corr)
# Out:
#                   tesla_rate_1k  avg_house_income
# tesla_rate_1k              1.00              0.83
# avg_house_income           0.83              1.00

# %%
alt.Chart(tesla_zips_slim).mark_circle(size=60).encode(
    x=alt.X('tesla_rate_1k:Q', title='Tesla rate per 1,000 vehicles', axis=alt.Axis(tickCount=6)),
    y=alt.Y('avg_net_worth:Q', title='Avg net worth', axis=alt.Axis(tickCount=5, format='$,N')),
    tooltip=['zip:N', 'teslas:O', 'avg_net_worth:Q', 'tesla_rate_1k:Q']
).properties(width=500, height=500)
# Out:
# alt.Chart(...)

# %%
tesla_zips_slim.to_csv('output/tesla_zips_slim.csv')

# %% [markdown]
# ---

# %% [markdown]
# ### Group by model year. Which years have the most vehicles?

# %%
model_year = vehicles.groupby(['model_year']).agg('sum').reset_index()

# %%
model_year.sort_values(by='model_year', ascending=False)
# Out:
#    model_year  vehicles
# 15        Unk      2966
# 14       2021        45
# 13       2020    278197
# 12       2019   1883333
# 11       2018   2106886
# 10       2017   2131800
# 9        2016   1980056
# 8        2015   1977629
# 7        2014   1646052
# 6        2013   1601310
# 5        2012   1331478
# 4        2011   1056720
# 3        2010    967912
# 2        2009    797522
# 1        2008   1174404
# 0        2007   1365953

# %%
model_year_chart = alt.Chart(model_year).mark_bar().encode(
).mark_bar().encode(
    y=alt.Y('model_year:N', title=" ", axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("vehicles:Q", title="Vehicles", axis=alt.Axis(format='', tickCount=5))
)

model_year_chart_text = model_year_chart.mark_text(
    align='left',
    baseline='middle',
    dx=5
).encode(text=alt.Text('vehicles:Q', format=',')
)

(model_year_chart + model_year_chart_text).properties(height=500, \
                                                      width=700, title='California vehicles, by model year')
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Export model year table for graphics

# %%
model_year.to_csv('output/model_year.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## Fuel types

# %% [markdown]
# ### Which types of alternative fuel models are most common?

# %%
fuel = vehicles.groupby(['fuel']).agg('sum').reset_index()

# %%
fuel.head(9)
# Out:
#                        fuel  vehicles
# 0          Battery Electric    306297
# 1  Diesel and Diesel Hybrid    804002
# 2                 Flex-Fuel   1033910
# 3                  Gasoline  16852351
# 4           Hybrid Gasoline   1026857
# 5        Hydrogen Fuel Cell      6638
# 6               Natural Gas     21096
# 7                     Other      2724
# 8            Plug-in Hybrid    248388

# %%
fuel.fuel.tolist()
# Out:
# ['Battery Electric',
#  'Diesel and Diesel Hybrid',
#  'Flex-Fuel',
#  'Gasoline',
#  'Hybrid Gasoline',
#  'Hydrogen Fuel Cell',
#  'Natural Gas',
#  'Other',
#  'Plug-in Hybrid']

# %%
# Diesel and Diesel Hybrid + Flex-Fuel + Gasoline + Hybrid Gasoline
'{:,.0f}'.format((fuel.iloc[1,1] + fuel.iloc[2,1] + fuel.iloc[3,1] + fuel.iloc[4,1]))
# Out:
# '19,717,120'

# %% [markdown]
# # Chart the fuel type counts

# %%
chart_fuels = alt.Chart(fuel).mark_bar().encode(
    y=alt.Y('fuel:N', title=' ',
        sort=alt.EncodingSortField(
            field="vehicles",  # The field to use for the sort
            op="sum",  # The operation to run on the field prior to sorting
            order="descending"  # The order to sort in
        ), axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("sum(vehicles):Q", title="Vehicles", axis=alt.Axis(format='', tickCount=5))
)

chart_fuels_text = chart_fuels.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(text=alt.Text('sum(vehicles)', format=',')
)


(chart_fuels + chart_fuels_text)\
.properties(height=400, width=500, title='CA alternative fuel vehicles by type')
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Export fuel type count table for graphics

# %%
fuel.to_csv('output/fuel.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## Where are these vehicles?

# %%
zip_code = vehicles.groupby(['zip']).agg('sum').reset_index()

# %%
zip_code_zev = zev.groupby(['zip']).agg('sum').reset_index()

# %% [markdown]
# ### Which ZIP codes have the most alternative fuel vehicles? (Airport areas, it seems)

# %%
zip_code_zev.sort_values(by='vehicles',\
    ascending=False).head(10)
# Out:
#         zip  vehicles
# 1991    OOS      3706
# 1225  94539      2902
# 1381  95014      2596
# 1250  94568      2197
# 1262  94582      2098
# 1418  95070      2085
# 1224  94538      2035
# 1394  95035      1872
# 508   92130      1862
# 1138  94087      1860

# %% [markdown]
# ### Pivot on ZIP code and widen out the dataframe to count vehicle types across them

# %%
sum_by_zip = pd.pivot_table(vehicles, values='vehicles', \
                            index=['zip'], columns=['fuel'], aggfunc=np.sum, fill_value=0).reset_index()

sum_by_zip.columns = sum_by_zip.columns.str.strip().str.lower().str.replace(' ', '_', regex=False)\
                    .str.replace('(', '', regex=False).str.replace(')', '', regex=False).str.replace('-','_', regex=False)

# %% [markdown]
# ### Which type is most common in each ZIP code?

# %%
sum_by_zip["total"] = sum_by_zip.sum(axis=1)
# Out:
# /var/folders/hm/zcc9d9vn2q15_wh0_0k06ckw0000gn/T/ipykernel_25191/2740973148.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sum_by_zip["total"] = sum_by_zip.sum(axis=1)

# %%
sum_by_zip.sort_values(by='total', ascending=False).head(5)
# Out:
# fuel    zip  battery_electric  diesel_and_diesel_hybrid  flex_fuel  gasoline  \
# 4771    OOS              3706                     47674      62755    447534
# 45    90045               573                       580       9879    104244
# 2393  94080               538                      1366       5482     96815
# 1269  92336               370                      2061       2448     48045
# 1112  92154               173                      4660       2134     42547
#
# fuel  hybrid_gasoline  hydrogen_fuel_cell  natural_gas  other  plug_in_hybrid  \
# 4771            18479                  72         1182     73            2167
# 45               4717                  25          154      1             468
# 2393             3912                   7           32      0             329
# 1269             1884                  11           31      1             555
# 1112             1366                   0            8      0             175
#
# fuel   total
# 4771  583642
# 45    120641
# 2393  108481
# 1269   55406
# 1112   51063

# %% [markdown]
# ### Group the lesser-used fuel types into an 'other' category

# %%
sum_by_zip['other'] = sum_by_zip.apply\
    (lambda x: x['hydrogen_fuel_cell'] + x['natural_gas'] + x['other'], axis=1)
sum_by_zip.drop(['hydrogen_fuel_cell', 'natural_gas'], axis=1, inplace=True)
sum_by_zip.drop([0], inplace=True)

# %% [markdown]
# ### Which non-gas vehicle is most popular — the 'winner' — in each zip?

# %%
sum_by_zip['winner'] = \
sum_by_zip[['hybrid_gasoline','battery_electric','diesel_and_diesel_hybrid',\
                   'flex_fuel','plug_in_hybrid', 'other']].idxmax(axis=1)

# %%
sum_by_zip.sort_values(by='total', ascending=False).head(10)
# Out:
# fuel    zip  battery_electric  diesel_and_diesel_hybrid  flex_fuel  gasoline  \
# 4771    OOS              3706                     47674      62755    447534
# 45    90045               573                       580       9879    104244
# 2393  94080               538                      1366       5482     96815
# 1269  92336               370                      2061       2448     48045
# 1112  92154               173                      4660       2134     42547
# 792   91709               931                      1170       1672     42517
# 329   90650               211                      1129       2005     42688
# 793   91710               415                      2493       2617     38839
# 1548  92683               524                       697       1281     41328
# 619   91342               220                      1799       2205     40115
#
# fuel  hybrid_gasoline  other  plug_in_hybrid   total                    winner
# 4771            18479   1327            2167  583642                 flex_fuel
# 45               4717    180             468  120641                 flex_fuel
# 2393             3912     39             329  108481                 flex_fuel
# 1269             1884     43             555   55406                 flex_fuel
# 1112             1366      8             175   51063  diesel_and_diesel_hybrid
# 792              2516     75             908   49789           hybrid_gasoline
# 329              1470     43             329   47875                 flex_fuel
# 793              1628    907             539   47438                 flex_fuel
# 1548             2291     58             587   46766           hybrid_gasoline
# 619              1913     18             368   46638                 flex_fuel

# %% [markdown]
# ### De-slugify the 'winner' category

# %%
sum_by_zip['winner'] = sum_by_zip['winner'].str.replace('_', ' ', regex=False).str.capitalize()

# %%
sum_by_zip['altshare'] = (((sum_by_zip['total']-sum_by_zip['gasoline'])/sum_by_zip['total'])*100).round()

# %%
sum_by_zip['batteryshare'] = ((sum_by_zip['battery_electric']/sum_by_zip['total'])*100)

# %%
sum_by_zip.sort_values(by='batteryshare', ascending=False).head(10)
# Out:
# fuel    zip  battery_electric  diesel_and_diesel_hybrid  flex_fuel  gasoline  \
# 2332  94007                 1                         0          0         0
# 4504  98456                 1                         0          0         0
# 100   90106                 1                         0          0         0
# 2321  93965                 1                         0          0         0
# 119   90203                 1                         0          0         0
# 3006  95217                 1                         0          0         1
# 547   91217                 1                         0          0         1
# 2353  94031                 1                         0          0         1
# 2693  94656                 1                         0          0         1
# 2800  94944                 1                         0          0         1
#
# fuel  hybrid_gasoline  other  plug_in_hybrid  total            winner  \
# 2332                0      0               0      1  Battery electric
# 4504                0      0               0      1  Battery electric
# 100                 0      0               0      1  Battery electric
# 2321                0      0               0      1  Battery electric
# 119                 0      0               0      1  Battery electric
# 3006                0      0               0      2  Battery electric
# 547                 0      0               0      2  Battery electric
# 2353                0      0               0      2  Battery electric
# 2693                0      0               0      2  Battery electric
# 2800                0      0               0      2  Battery electric
#
# fuel  altshare  batteryshare
# 2332    100.00        100.00
# 4504    100.00        100.00
# 100     100.00        100.00
# 2321    100.00        100.00
# 119     100.00        100.00
# 3006     50.00         50.00
# 547      50.00         50.00
# 2353     50.00         50.00
# 2693     50.00         50.00
# 2800     50.00         50.00

# %% [markdown]
# ### Use the "jenks" method to set fair breaks for total field

# %%
breaks \
= jenkspy.jenks_breaks(sum_by_zip.batteryshare, nb_class=7)

# %%
breaks
# Out:
# [0.0,
#  1.0714285714285714,
#  3.6193029490616624,
#  9.129231156411224,
#  20.0,
#  33.33333333333333,
#  50.0,
#  100.0]

# %% [markdown]
# ---

# %% [markdown]
# ### Export merged polygon geodataframe as GeoJSON

# %%
zips_poly.to_file('../../../data/gis/zips_poly.geojson', driver='GeoJSON')

# %%
zips_poly_merged = zips_poly.merge(sum_by_zip, on='zip')

# %%
zips_poly_merged.columns
# Out:
# Index(['objectid', 'zip', 'po_name', 'pop2012', 'white', 'black', 'ameri_es',
#        'asian', 'hawn_pi', 'hispanic', 'other_x', 'mult_race', 'med_age',
#        'ave_hh_sz', 'marhh_chd', 'families', 'ave_fam_sz', 'hse_units', 'sqmi',
#        'geometry', 'battery_electric', 'diesel_and_diesel_hybrid', 'flex_fuel',
#        'gasoline', 'hybrid_gasoline', 'other_y', 'plug_in_hybrid', 'total',
#        'winner', 'altshare', 'batteryshare'],
#       dtype='object')

# %%
# zips_poly_merged_drop = ['objectid', 'zip', 'po_name', 'sqmi', 
#                         'battery_electric', 'diesel_and_diesel_hybrid', 'flex_fuel',
#                          'gasoline', 'hybrid_gasoline', 'other_y', 'plug_in_hybrid', 'total',
#                          'winner', 'altshare']
# zips_poly_merged.drop(zips_poly_merged_drop, inplace=True, axis=1)

# %%
zips_poly_merged.to_file('/Users/mhustiles/data/data/GIS/zips_poly_merged.geojson', driver='GeoJSON')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_create()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Failed to create GeoJSON datasource: /Users/mhustiles/data/data/GIS/zips_poly_merged.geojson: /Users/mhustiles/data/data/GIS/zips_poly_merged.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# /var/folders/hm/zcc9d9vn2q15_wh0_0k06ckw0000gn/T/ipykernel_25191/2699038602.py in <module>
# ----> 1 zips_poly_merged.to_file('/Users/mhustiles/data/data/GIS/zips_poly_merged.geojson', driver='GeoJSON')
#
# ~/.local/share/virtualenvs/notebooks-xu8v5Vvv/lib/python3.8/site-packages/geopandas/geodataframe.py in to_file(self, filename, driver, schema, index, **kwargs)
#    1084         from geopandas.io.file import _to_file
#    1085
# -> 1086         _to_file(self, filename, driver, schema, index, **kwargs)
#    1087
#    1088     def set_crs(self, crs=None, epsg=None, inplace=False, allow_override=False):
#
# ~/.local/share/virtualenvs/notebooks-xu8v5Vvv/lib/python3.8/site-packages/geopandas/io/file.py in _to_file(df, filename, driver, schema, index, mode, crs, **kwargs)
#     325         elif crs:
#     326             crs_wkt = crs.to_wkt("WKT1_GDAL")
# --> 327         with fiona.open(
#     328             filename, mode=mode, driver=driver, crs_wkt=crs_wkt, schema=schema, **kwargs
#     329         ) as colxn:
#
# ~/.local/share/virtualenvs/notebooks-xu8v5Vvv/lib/python3.8/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     406     def wrapper(*args, **kwargs):
#     407         if local._env:
# --> 408             return f(*args, **kwargs)
#     409         else:
#     410             if isinstance(args[0], str):
#
# ~/.local/share/virtualenvs/notebooks-xu8v5Vvv/lib/python3.8/site-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     270             else:
#     271                 this_schema = None
# --> 272             c = Collection(path, mode, crs=crs, driver=driver, schema=this_schema,
#     273                            encoding=encoding, layer=layer, enabled_drivers=enabled_drivers, crs_wkt=crs_wkt,
#     274                            **kwargs)
#
# ~/.local/share/virtualenvs/notebooks-xu8v5Vvv/lib/python3.8/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     163             elif self.mode in ('a', 'w'):
#     164                 self.session = WritingSession()
# --> 165                 self.session.start(self, **kwargs)
#     166         except IOError:
#     167             self.session = None
#
# fiona/ogrext.pyx in fiona.ogrext.WritingSession.start()
#
# fiona/ogrext.pyx in fiona.ogrext.WritingSession.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_create()
#
# DriverError: Failed to create GeoJSON datasource: /Users/mhustiles/data/data/GIS/zips_poly_merged.geojson: /Users/mhustiles/data/data/GIS/zips_poly_merged.geojson: No such file or directory

# %% [markdown]
# ### Export with Tesla totals

# %%
tesla_zips_poly_merged = zips_poly.merge(tesla_zips_slim, on='zip')

# %%
tesla_zips_poly_merged.to_file('/Users/mhustiles/data/github/notebooks/\
california-fuel-vehicles/output/tesla_zips.geojson', driver='GeoJSON')

# %%
tesla_zips_poly_merged.head()

# %% [markdown]
# ### Merge ZIP points with Tesla & electric totals

# %%
teslas_poimt_merged = ca_zips_point.merge(tesla_zips_slim, on='zip')

# %%
teslas_poimt_merged.sort_values(by='tesla_rate_1k', ascending=False).head(10)

# %%
teslas_poimt_merged.to_file('output/teslas_point_merged.geojson', driver='GeoJSON')

# %% [markdown]
# ### Merge ZIP points with all vehicle totals

# %%
ca_zips_point_merged = ca_zips_point.merge(sum_by_zip, on='zip')

# %%
ca_zips_point_merged.plot()

# %% [markdown]
# ### Export merged points geodataframe as GeoJSON

# %%
ca_zips_point_merged.head(5)

# %%
ca_zips_point_merged.to_file('/Users/mhustiles/data/data/fuel/ca_zips_point_merged.geojson', driver='GeoJSON')

# %% [markdown]
# ### Convert polygons to mbtiles for Mapbox. Export.

# %%
# !tippecanoe --force -r1 -pk -pf -Z5 -z13 -o \
/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/output/ca_zips_poly_merged.mbtiles \
/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/output/ca_zips_poly_merged.geojson

# %% [markdown]
# ### Convert points to mbtiles for Mapbox. Export.

# %%
# !tippecanoe --force -r1 -pk -pf -Z5 -z13 -o \
/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/output/ca_zips_point_merged.mbtiles \
/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/output/ca_zips_point_merged.geojson

# %% [markdown]
# ### Convert Tesla polygons to mbtiles for Mapbox. Export.

# %%
# !tippecanoe --force -r1 -pk -pf -Z5 -z13 -o \
/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/output/teslas_poly_merged.mbtiles \
/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/output/teslas_poly_merged.geojson

# %% [markdown]
# ---

# %% [markdown]
# ## Waffle plot

# %%
fuel.head(9)

# %%
fuel.vehicles.sum()

# %%
fuel.iloc[0,1] + fuel.iloc[5,1] + fuel.iloc[6,1] + fuel.iloc[7,1]

# %%
fuel['per_1000'] =  ((fuel['vehicles'] / 18911128) * 1000).round(2)

# %%
fuel

# %%
fig = plt.figure(
    FigureClass=Waffle, 
    rows=21,
    values=fuel.per_1000,
    labels=list(fuel.fuel),
    figsize=(30,20),
    icons='car-side',
    colors=['#ec8431','#e6e6e6','#e6e6e6','#e6e6e6','#e6e6e6','#e6e6e6','#e6e6e6', '#e6e6e6', '#e6e6e6'],
    legend={
        'loc': 'lower left',
        'bbox_to_anchor': (0, -0.4),
        'ncol': len(fuel),
        'framealpha': 0,
        'fontsize': 0
    }
)

# %% [markdown]
# See related [Twitter thread](https://twitter.com/stiles/status/1193416749116358656)
