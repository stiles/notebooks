# %% [markdown]
# # California vehicle fuel type count by zip code

# %% [markdown]
# ### Load Python tools

# %%
import pandas as pd
import geopandas as gpd
import squarify
import matplotlib
import matplotlib.pyplot as plt
import geojson
import json
import jenkspy
import numpy as np
from earthpy import clip as cl
from altair import datum
import weightedcalcs as wc
import altair as alt
alt.renderers.enable('notebook')
import altair_latimes as lat
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Read data from California Department of Motor Vehicles - current as of October 2018

# %%
#https://data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code
src = pd.read_csv('https://data.ca.gov/dataset/15179472-adeb-4df6-920a-20640d02b08c/\
resource/d304108a-06c1-462f-a144-981dd0109900/\
download/vehicle-fuel-type-count-by-zip-code.csv', low_memory=False)

# %%
src.head()
# Out:
#         Date Zip Code Model Year                      Fuel       Make   Duty  \
# 0  10/1/2018    90000       2006                  Gasoline  OTHER/UNK  Light
# 1  10/1/2018    90000       2014                  Gasoline  OTHER/UNK  Light
# 2  10/1/2018    90000       2016                  Gasoline  OTHER/UNK  Light
# 3  10/1/2018    90000       2017                  Gasoline  OTHER/UNK  Light
# 4  10/1/2018    90000      <2006  Diesel and Diesel Hybrid  OTHER/UNK  Heavy
#
#    Vehicles
# 0         1
# 1         1
# 2         1
# 3         1
# 4        55

# %% [markdown]
# ### Clean up headers and header names

# %%
src.columns = src.columns.str.strip().str.lower().str.replace(' ', '_')\
                    .str.replace('(', '').str.replace(')', '').str.replace('-','_')

# %%
src.rename(columns={"zip_code": "zip"}, inplace=True)

# %% [markdown]
# ### How many vehicles are we talking about?

# %%
src.vehicles.sum()
# Out:
# 31137994

# %% [markdown]
# ### Remove few 2019 models, older models and those listed as out of service

# %%
src = src[(src['model_year'] != '2019') & (src['zip'] != 'OOS')]

# %% [markdown]
# ### What's left?

# %%
src.vehicles.sum()
# Out:
# 30379178

# %% [markdown]
# ### How many don't rely solely on gasoline?

# %%
nongas = src[(src['fuel'] != 'Gasoline')]

# %%
nongas.vehicles.sum()
# Out:
# 3993359

# %% [markdown]
# ### Group by make. Which are most common?

# %%
make = src.groupby(['make']).agg('sum').reset_index()

# %%
make.sort_values(by='vehicles', ascending=False).head(10)
# Out:
#               make  vehicles
# 101         TOYOTA   5452588
# 42           HONDA   3462031
# 32            FORD   3296757
# 79       OTHER/UNK   3144851
# 16       CHEVROLET   2690915
# 73          NISSAN   1850511
# 63   MERCEDES-BENZ    862216
# 22           DODGE    856044
# 56           LEXUS    853288
# 11             BMW    822824

# %% [markdown]
# ### Group by model year. Which years have the most vehicles?

# %%
model_year = src.groupby(['model_year', 'fuel']).agg('sum').reset_index()

# %%
model_year.sort_values(by='vehicles', ascending=False).head()
# Out:
#     model_year      fuel  vehicles
# 109      <2006  Gasoline  10114132
# 91        2017  Gasoline   1774407
# 82        2016  Gasoline   1721587
# 73        2015  Gasoline   1652144
# 65        2014  Gasoline   1365405

# %% [markdown]
# ### Which types of alternative fuel models are most common?

# %%
fuel = nongas.groupby(['fuel']).agg('sum').reset_index()

# %%
fuel.sort_values(by='vehicles', ascending=False)
# Out:
#                        fuel  vehicles
# 2                 Flex-Fuel   1241424
# 1  Diesel and Diesel Hybrid   1221419
# 3           Hybrid Gasoline   1059428
# 0          Battery Electric    223505
# 7            Plug-in Hybrid    201969
# 5               Natural Gas     33304
# 6                     Other      7209
# 4        Hydrogen Fuel Cell      5101

# %% [markdown]
# ### Chart the fuel type counts

# %%
chart_fuels = alt.Chart(fuel).mark_bar().encode(
    y=alt.Y('fuel:N', title=' ',
        sort=alt.EncodingSortField(
            field="vehicles",  # The field to use for the sort
            op="sum",  # The operation to run on the field prior to sorting
            order="descending"  # The order to sort in
        ), axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("sum(vehicles):Q", title="Vehicles", axis=alt.Axis(format='', tickCount=5))
)

chart_fuels_text = chart_fuels.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(text=alt.Text('sum(vehicles)', format=',')
)


(chart_fuels + chart_fuels_text)\
.properties(height=400, width=500, title='CA alternative fuel vehicles by type')

# %%
squarify.plot(sizes=fuel['vehicles'], label=fuel['fuel'], alpha=.8,\
              color=[
'#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02','#a6761d',
])
plt.axis('off')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Where are these vehicles?

# %%
zip_code = src.groupby(['zip']).agg('sum').reset_index()

# %%
zip_code_nongas = nongas.groupby(['zip']).agg('sum').reset_index()

# %% [markdown]
# ### Which ZIP codes have the most alternative fuel vehicles? (Airport areas, it seems)

# %%
zip_code_nongas.sort_values(by='vehicles',\
    ascending=False).head(10)
# Out:
#         zip  vehicles
# 45    90045     18515
# 12    90012     14072
# 1516  94080     11819
# 929   92626     11257
# 1206  93308     11226
# 775   92335     11091
# 426   91710     10905
# 1050  92868     10535
# 655   92154     10349
# 609   92101      9580

# %% [markdown]
# ### Pivot on ZIP code and widen out the dataframe to count vehicle types across them

# %%
sum_by_zip = pd.pivot_table(src, values='vehicles', \
                            index=['zip'], columns=['fuel'], aggfunc=np.sum, fill_value=0).reset_index()

sum_by_zip.columns = sum_by_zip.columns.str.strip().str.lower().str.replace(' ', '_')\
                    .str.replace('(', '').str.replace(')', '').str.replace('-','_')

# %% [markdown]
# ### Which type is most common in each ZIP code?

# %%
sum_by_zip["total"] = sum_by_zip.sum(axis=1)

# %%
sum_by_zip.sort_values(by='total', ascending=False).head(5)
# Out:
# fuel    zip  battery_electric  diesel_and_diesel_hybrid  flex_fuel  gasoline  \
# 45    90045               433                       823      12125    116762
# 1528  94080               309                      2074       4131    111769
# 661   92154               121                      5685       3045     67483
# 192   90650               136                      1810       2779     69793
# 782   92335                51                      6442       3267     65082
#
# fuel  hybrid_gasoline  hydrogen_fuel_cell  natural_gas  other  plug_in_hybrid  \
# 45               4569                  19          159      3             384
# 1528             4980                   9           60     17             239
# 661              1327                   0           23      8             140
# 192              1540                   5           94     15             251
# 782               773                   1          443     17              97
#
# fuel   total
# 45    135277
# 1528  123588
# 661    77832
# 192    76423
# 782    76173

# %% [markdown]
# ### Group the lesser-used fuel types into an 'other' category

# %%
sum_by_zip['other'] = sum_by_zip.apply\
    (lambda x: x['hydrogen_fuel_cell'] + x['natural_gas'] + x['other'], axis=1)
sum_by_zip.drop(['hydrogen_fuel_cell', 'natural_gas'], axis=1, inplace=True)
sum_by_zip.drop([0], inplace=True)

# %% [markdown]
# ### Which non-gas vehicle is most popular — the 'winner' — in each zip?

# %%
sum_by_zip['winner'] = \
sum_by_zip[['hybrid_gasoline','battery_electric','diesel_and_diesel_hybrid',\
                   'flex_fuel','plug_in_hybrid', 'other']].idxmax(axis=1)

# %%
sum_by_zip.sort_values(by='total', ascending=False).head(5)
# Out:
# fuel    zip  battery_electric  diesel_and_diesel_hybrid  flex_fuel  gasoline  \
# 45    90045               433                       823      12125    116762
# 1528  94080               309                      2074       4131    111769
# 661   92154               121                      5685       3045     67483
# 192   90650               136                      1810       2779     69793
# 782   92335                51                      6442       3267     65082
#
# fuel  hybrid_gasoline  other  plug_in_hybrid   total                    winner
# 45               4569    181             384  135277                 flex_fuel
# 1528             4980     86             239  123588           hybrid_gasoline
# 661              1327     31             140   77832  diesel_and_diesel_hybrid
# 192              1540    114             251   76423                 flex_fuel
# 782               773    461              97   76173  diesel_and_diesel_hybrid

# %% [markdown]
# ### De-slugify the 'winner' category

# %%
sum_by_zip['winner'] = sum_by_zip['winner'].str.replace('_', ' ', regex=False).str.capitalize()

# %%
sum_by_zip.head()
# Out:
# fuel    zip  battery_electric  diesel_and_diesel_hybrid  flex_fuel  gasoline  \
# 1     90001                10                       865       1276     31865
# 2     90002                22                       557       1114     28658
# 3     90003                16                       693       1341     38503
# 4     90004               250                       398        603     30600
# 5     90005                71                       182        310     16073
#
# fuel  hybrid_gasoline  other  plug_in_hybrid  total           winner
# 1                 466     23              44  34549        Flex fuel
# 2                 417     18              27  30813        Flex fuel
# 3                 594     32              39  41218        Flex fuel
# 4                1972     20             251  34094  Hybrid gasoline
# 5                 896     12             105  17649  Hybrid gasoline

# %% [markdown]
# ### Use the "jenks" method to set fair breaks for total field

# %%
total_breaks = jenkspy.jenks_breaks(sum_by_zip.total, nb_class=7)

# %%
total_breaks
# Out:
# [10.0, 5454.0, 15501.0, 26093.0, 37557.0, 52030.0, 77832.0, 135277.0]

# %% [markdown]
# ---

# %% [markdown]
# ### Share of alternative vehicles by ZIP code

# %%
sum_by_zip['share'] =\
(((sum_by_zip['total'] - sum_by_zip['gasoline'])/sum_by_zip['total'])*100).round(2)

sum_by_zip['share_hybrid_gas'] =\
((sum_by_zip['hybrid_gasoline']/sum_by_zip['total'])*100).round(2)

# %%
x_scale = alt.Scale(domain=[0, 100])

alt.Chart(sum_by_zip).mark_bar().encode(
    x=alt.X('share:Q',
          bin=alt.Bin(maxbins=40, extent=x_scale.domain),
          stack=None,
          title='% share of "green" cars'
         ),
    y=alt.Y('count()', title='Frequency of ZIP codes'),
).properties(width=600, height=400)

# %% [markdown]
# ### Split the zips up into above and below average groups

# %%
sum_by_lg_zip = sum_by_zip[sum_by_zip['total'] > 12000]
sum_by_sm_zip = sum_by_zip[sum_by_zip['total'] < 565]

# %% [markdown]
# ### Chart histograms for small (< 1000 vehicles), large (>10,000) and all ZIP codes

# %%
hist_share_lg = alt.Chart(sum_by_lg_zip).mark_bar().encode(
    x=alt.X('share:Q',
          bin=alt.Bin(maxbins=20, extent=x_scale.domain),
          stack=None,
          title='% share of "green" cars'
         ),
    y=alt.Y('count()', title='Frequency among LARGE zips'),
).properties(width=225, height=250)

hist_share_sm = alt.Chart(sum_by_sm_zip).mark_bar().encode(
    x=alt.X('share:Q',
          bin=alt.Bin(maxbins=20, extent=x_scale.domain),
          stack=None,
          title='% share of "green" cars'
         ),
    y=alt.Y('count()', title='Frequency among SMALL zips'),
).properties(width=225, height=250)

hist_share_all = alt.Chart(sum_by_zip).mark_bar().encode(
    x=alt.X('share:Q',
          bin=alt.Bin(maxbins=20, extent=x_scale.domain),
          stack=None,
          title='% share of "green" cars'
         ),
    y=alt.Y('count()', title='Frequency among ALL zips'),
).properties(width=225, height=250)


(hist_share_sm|hist_share_lg|hist_share_all)

# %% [markdown]
# ---

# %% [markdown]
# # Geography data

# %% [markdown]
# ### Southern California

# %%
supes = gpd.read_file('/Users/mhustiles/data/data/GIS/\
la/la_county_gis_supervisors/la_county_gis_supervisors_1566093928265.geojson')
supes.plot()

# %%
socal = gpd.read_file('/Users/mhustiles/data/data/GIS/la/\
la_county_gis_countybdry/la_county_gis_countybdry_1566095292363.geojson')
socal.plot()

# %%
lacounty = gpd.read_file('/Users/mhustiles/data/data/GIS/la/los-angeles-county-2012/county (2012).shp')
lacounty.plot()

# %%
lacountyzips = gpd.read_file('/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/\
input/la_county_GIS_zipcodes/la_county_GIS_zipcodes_1573426614084.geojson')
lacountyzips.plot()

# %% [markdown]
# ### ZIP code points

# %%
zips_point = gpd.read_file('/Users/mhustiles/data/data/GIS/zipcodes.geojson')

# %%
zips_point['zip'] = zips_point['zip'].astype(str)

# %%
ca_zips_point = zips_point[zips_point['state'] == 'CA']

# %% [markdown]
# ### ZIP code boundaries

# %%
zips_poly = gpd.read_file('/Users/mhustiles/data/data/GIS/californiazips.geojson')

# %%
zips_poly.plot()

# %%
zips_poly.rename(columns={"ZCTA5CE10": "zip"}, inplace=True)

# %% [markdown]
# ### Merge with pivoted zip totals

# %%
ca_zips_poly_merged =  zips_poly.merge(sum_by_zip, on='zip')

# %%
ca_zips_poly_merged.plot()

# %%
ca_zips_poly_merged.loc[0]
# Out:
# zip                                                                     94118
# INTPTLAT10                                                        +37.7800933
# INTPTLON10                                                       -122.4626054
# geometry                    (POLYGON ((-122.470081 37.787399, -122.467989 ...
# battery_electric                                                          303
# diesel_and_diesel_hybrid                                                  472
# flex_fuel                                                                 273
# gasoline                                                                18301
# hybrid_gasoline                                                          1816
# other                                                                      10
# plug_in_hybrid                                                            200
# total                                                                   21375
# winner                                                        Hybrid gasoline
# share                                                                   14.38
# share_hybrid_gas                                                          8.5
# Name: 0, dtype: object

# %% [markdown]
# ### Export merged polygon geodataframe as GeoJSON

# %%
ca_zips_poly_merged.to_file('/Users/mhustiles/data/github/notebooks/\
california-fuel-vehicles/output/ca_zips_poly_merged.geojson', driver='GeoJSON')

# %% [markdown]
# ### Merge ZIP points with vehicle totals

# %%
ca_zips_point_merged = ca_zips_point.merge(sum_by_zip, on='zip')

# %%
ca_zips_point_merged.plot()

# %% [markdown]
# ### Export merged points geodataframe as GeoJSON

# %%
ca_zips_point_merged.to_file('/Users/mhustiles/data/github/notebooks\
/california-fuel-vehicles/output/ca_zips_point_merged.geojson', driver='GeoJSON')

# %% [markdown]
# ### Convert polygons to mbtiles for Mapbox. Export.

# %%
# !tippecanoe --force -r1 -pk -pf -Z5 -z13 -o \
/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/output/ca_zips_poly_merged.mbtiles \
/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/output/ca_zips_poly_merged.geojson
# Out:
# For layer 0, using name "ca_zips_poly_merged"
# 1760 features, 9365844 bytes of geometry, 67650 bytes of separate metadata, 97834 bytes of string pool
#   99.9%  13/1458/3289

# %% [markdown]
# ### Convert points to mbtiles for Mapbox. Export.

# %%
# !tippecanoe --force -r1 -pk -pf -Z5 -z13 -o \
/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/output/ca_zips_point_merged.mbtiles \
/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/output/ca_zips_point_merged.geojson
# Out:
# For layer 0, using name "ca_zips_point_merged"
# 2422 features, 171454 bytes of geometry, 16 bytes of separate metadata, 70996 bytes of string pool
#   99.9%  13/1410/3273

# %% [markdown]
# ---

# %% [markdown]
# ### What's going on in Los Angeles County?

# %%
lacounty.crs = {'init': 'epsg:4326'}
lacounty.to_crs = {'init': 'epsg:4326'}

# %%
la_county_zips_poly = gpd.sjoin(lacounty, ca_zips_poly_merged, how="inner", op='intersects')

# %%
la_county_zips_poly_merged = lacountyzips.merge(
    la_county_zips_poly[['zip','total','winner','share']],
    left_on="ZIPCODE",
    right_on="zip"
)

# %%
la_county_zips_poly_merged.head()
# Out:
#   ZIPCODE  OBJECTID                                           geometry    zip  \
# 0   90001         1  POLYGON ((-118.2433805350907 33.98923611416206...  90001
# 1   90011        10  POLYGON ((-118.2434804835407 34.00247313430746...  90011
# 2   90012        12  POLYGON ((-118.2313525101508 34.04587009126384...  90012
# 3   90014        13  POLYGON ((-118.254664324685 34.04861210001001,...  90014
# 4   90015        14  POLYGON ((-118.2748235124077 34.0518416186684,...  90015
#
#    total           winner  share
# 0  34549        Flex fuel   7.77
# 1  57914        Flex fuel   6.42
# 2  35941            Other  39.15
# 3   3485  Hybrid gasoline  13.72
# 4  12141  Hybrid gasoline  10.93

# %%
la_county_zips_poly_merged.drop(['ZIPCODE','OBJECTID'], axis=1, inplace=True)

# %%
la_county_zips_poly_merged.to_file('/Users/mhustiles/data/github/notebooks\
/california-fuel-vehicles/output/la_county_zips_poly_merged.geojson', driver='GeoJSON')

# %%
# !tippecanoe --force -r1 -pk -pf -Z5 -z13 -o \
/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/output/la_county_zips_poly_merged.mbtiles \
/Users/mhustiles/data/github/notebooks/california-fuel-vehicles/output/la_county_zips_poly_merged.geojson
# Out:
# For layer 0, using name "la_county_zips_poly_merged"
# 304 features, 1320996 bytes of geometry, 790 bytes of separate metadata, 5955 bytes of string pool
#   99.9%  13/1391/3269

# %%
la_county_zips_poly_merged.head()
# Out:
#                                             geometry    zip  total  \
# 0  POLYGON ((-118.2433805350907 33.98923611416206...  90001  34549
# 1  POLYGON ((-118.2434804835407 34.00247313430746...  90011  57914
# 2  POLYGON ((-118.2313525101508 34.04587009126384...  90012  35941
# 3  POLYGON ((-118.254664324685 34.04861210001001,...  90014   3485
# 4  POLYGON ((-118.2748235124077 34.0518416186684,...  90015  12141
#
#             winner  share
# 0        Flex fuel   7.77
# 1        Flex fuel   6.42
# 2            Other  39.15
# 3  Hybrid gasoline  13.72
# 4  Hybrid gasoline  10.93

# %%
la_county_breaks = jenkspy.jenks_breaks(la_county_zips_poly_merged.share, nb_class=7)

# %%
la_county_breaks
# Out:
# [6.25, 9.83, 12.76, 16.63, 23.3, 32.69, 43.84, 62.83]

# %%
def get_group(value):
    for i, b in enumerate(la_county_breaks):
        if value <= la_county_breaks[i+1]:
            return i

# %%
la_county_zips_poly_merged['share_group'] = la_county_zips_poly_merged.share.apply(get_group)

# %%
la_county_zips_poly_merged.plot()

# %%
la_county_zips_poly_merged['centroid_x'] = la_county_zips_poly_merged.geometry.centroid.x
la_county_zips_poly_merged['centroid_y'] = la_county_zips_poly_merged.geometry.centroid.y

# %%
la_county_zips_poly_merged.plot()

# %%
geojson = json.loads(la_county_zips_poly_merged.to_json())
features = alt.Data(values=geojson['features'])

# %% [markdown]
# See related [Twitter thread](https://twitter.com/stiles/status/1193416749116358656)
