# %% [markdown]
# # LAPD crimes database: 2010-present

# %%
#https://data.lacity.org/A-Safe-City/Crime-Data-from-2010-to-Present/63jg-8b9z

# %%
import pandas as pd
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt
import geojson
import json
import jenkspy
import numpy as np
from earthpy import clip as cl
from altair import datum
import altair as alt
alt.renderers.enable('notebook')
import altair_latimes as lat
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000

# %%
# https://data.lacity.org/api/views/yru6-6re4/rows.csv?accessType=DOWNLOAD
crimes = pd.read_csv('/Users/mhustiles/data/data/LA/Crime_Data_from_2010_to_Present.csv')

# %%
crimes.columns = crimes.columns.str.strip().str.lower()\
.str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
crimes.head()
# Out:
#        dr_no               date_rptd                date_occ  time_occ  area  \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350    13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45    14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515    13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150     6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100     1
#
#    area_name  rpt_dist_no  part_1-2  crm_cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                                crime         mocodes  \
# 0                           VIOLATION OF COURT ORDER  0913 1814 2000
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...            0329
# ...

# %%
crimes.rename(columns = {'crm_cd_desc': 'crime', }, inplace = True)

# %%
crimes.columns
# Out:
# Index(['dr_no', 'date_rptd', 'date_occ', 'time_occ', 'area', 'area_name',
#        'rpt_dist_no', 'part_1-2', 'crm_cd', 'crime', 'mocodes', 'vict_age',
#        'vict_sex', 'vict_descent', 'premis_cd', 'premis_desc',
#        'weapon_used_cd', 'weapon_desc', 'status', 'status_desc', 'crm_cd_1',
#        'crm_cd_2', 'crm_cd_3', 'crm_cd_4', 'location', 'cross_street', 'lat',
#        'lon'],
#       dtype='object')

# %%
len(crimes)
# Out:
# 2058218

# %%
crimes.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc         Mocodes  \
# 0                           VIOLATION OF COURT ORDER  0913 1814 2000
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...            0329
# ...

# %%
mocrimes = crimes.dropna(subset=['Mocodes'])
homicides = crimes[crimes['Crm Cd Desc'].str.contains('CRIMINAL HOMICIDE', na=False)]

# %%
len(mocrimes)
# Out:
# 1836146

# %%
homelessvictims = crimes[crimes['Mocodes'].str.contains('1218', na=False)]
homelesssuspects = crimes[crimes['Mocodes'].str.contains('2004', na=False)]

# %%
# MO Code 1218 is to be used when a victim is homeless
# MO Code 2004 is to be used when a suspect is homeless
mocodes = crimes.groupby(['Mocodes']).size()

# %%
len(homelessvictims)
# Out:
# 19039

# %%
len(homelesssuspects)
# Out:
# 38329

# %%
homelessvictims.groupby(['Crm Cd Desc']).size().sort_values(ascending=False)
# Out:
# Crm Cd Desc
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT              4708
# BATTERY - SIMPLE ASSAULT                                    3578
# ROBBERY                                                     2206
# THEFT PLAIN - PETTY ($950 & UNDER)                          1960
# INTIMATE PARTNER - SIMPLE ASSAULT                           1821
# INTIMATE PARTNER - AGGRAVATED ASSAULT                        693
# RAPE, FORCIBLE                                               544
# BRANDISH WEAPON                                              435
# CRIMINAL THREATS - NO WEAPON DISPLAYED                       389
# ATTEMPTED ROBBERY                                            313
# THEFT, PERSON                                                303
# THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD     257
# BATTERY WITH SEXUAL CONTACT                                  179
# CRIMINAL HOMICIDE                                            159
# ...

# %%
homelesssuspects.groupby(['Crm Cd Desc']).size().sort_values(ascending=False)
# Out:
# Crm Cd Desc
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT              5469
# BATTERY - SIMPLE ASSAULT                                    5328
# TRESPASSING                                                 3106
# ROBBERY                                                     3067
# SHOPLIFTING - PETTY THEFT ($950 & UNDER)                    2722
# INTIMATE PARTNER - SIMPLE ASSAULT                           2202
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)     1592
# THEFT PLAIN - PETTY ($950 & UNDER)                          1571
# CRIMINAL THREATS - NO WEAPON DISPLAYED                      1361
# BURGLARY                                                    1248
# BRANDISH WEAPON                                             1121
# VANDALISM - MISDEAMEANOR ($399 OR UNDER)                     893
# INTIMATE PARTNER - AGGRAVATED ASSAULT                        802
# VIOLATION OF RESTRAINING ORDER                               750
# ...

# %%
homicides.head()
# Out:
#           DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 113   100100811  04/16/2010 12:00:00 AM  04/16/2010 12:00:00 AM       510
# 404   100101605  11/15/2010 12:00:00 AM  11/14/2010 12:00:00 AM      1245
# 524   100104269  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM      1030
# 2488  100110330  05/05/2010 12:00:00 AM  01/15/2010 12:00:00 AM      1200
# 3459  100112967  06/24/2010 12:00:00 AM  06/24/2010 12:00:00 AM      2000
#
#       AREA  AREA NAME  Rpt Dist No  Part 1-2  Crm Cd        Crm Cd Desc  \
# 113       1   Central          154         1     110  CRIMINAL HOMICIDE
# 404       1   Central          157         1     110  CRIMINAL HOMICIDE
# 524       1   Central          138         1     110  CRIMINAL HOMICIDE
# 2488      1   Central          134         1     110  CRIMINAL HOMICIDE
# 3459      1   Central          166         1     110  CRIMINAL HOMICIDE
#
#              Mocodes  Vict Age Vict Sex Vict Descent  Premis Cd  \
# ...
