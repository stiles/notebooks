# %% [markdown]
# # LAPD crimes database: 2010-present

# %% [markdown]
# ### Import data tools

# %%
import pandas as pd
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt
import geojson
import json
import jenkspy
import numpy as np
from earthpy import clip as cl
from altair import datum
import weightedcalcs as wc
import altair as alt
alt.renderers.enable('notebook')
import altair_latimes as lat
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Read crimes CSV downloaded from LA City data portal

# %%
# https://data.lacity.org/A-Safe-City/Crime-Data-from-2010-to-Present/63jg-8b9z
src = pd.read_csv('/Users/mhustiles/data/data/LA/Crime_Data_from_2010_to_Present.csv')

# %%
crimes = src

# %%
crimes.columns = crimes.columns.str.strip().str.lower()\
.str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %% [markdown]
# ### These data are super messy...

# %%
crimes.rename(columns = { 
'dr_no':'record_id',
'date_rptd':'date_reported',
'date_occ':'date_occurred',
'time_occ':'time_occurred',
'area':'division',
'area_name':'division_name',
'rpt_dist_no':'reporting_district',
'part_1-2':'part_type',
'crm_cd':'crime_code',
'crm_cd_desc':'crime_code_description',
'mocodes':'modus_operandi_code',
'vict_age':'victim_age',
'vict_sex':'victim_sex',
'vict_descent':'victim_descent',
'premis_cd':'premises_code',
'premis_desc':'premises_description',
'weapon_used_cd':'weapon_code',
'weapon_desc':'weapon_description',
'status':'status_code',
'status_desc':'status_code_description',
'crm_cd_1':'crm_cd_1',
'crm_cd_2':'crm_cd_2',
'crm_cd_3':'crm_cd_3',
'crm_cd_4':'crm_cd_4',
'location':'address',
'cross_street':'cross_street',
'lat':'latitude',
'lon':'longitide',
 }, inplace = True)

# %% [markdown]
# ### ... contunued

# %%
crimes['date_reported'] = crimes['date_reported'].str.replace(' 12:00:00 AM','')
crimes['date_occurred'] = crimes['date_occurred'].str.replace(' 12:00:00 AM','')
crimes['date_occurred'] = pd.to_datetime(crimes['date_occurred'], format='%m/%d/%Y')
crimes['year'] = crimes['date_occurred'].dt.year
crimes['quarter'] = crimes['date_occurred'].dt.quarter
crimes['day'] = crimes['date_occurred'].dt.day
crimes['month'] = crimes['date_occurred'].dt.month
crimes['weekday'] = crimes['date_occurred'].dt.weekday_name
crimes['monthname'] = crimes['date_occurred'].dt.month_name()

# %%
crimes[[ 'record_id', 
    'time_occurred', 
    'division', 
    'reporting_district', 
    'part_type',
    'crm_cd_1',
    'crm_cd_2',
    'crm_cd_3',
    'crm_cd_4',
    'crime_code', 
    'premises_code', 
    'weapon_code',
    'year',
    'quarter',
    'day',
    'month', ]] = crimes[[
    'record_id', 
    'time_occurred', 
    'division', 
    'reporting_district', 
    'part_type',
    'crm_cd_1',
    'crm_cd_2',
    'crm_cd_3',
    'crm_cd_4',
    'crime_code', 
    'premises_code', 
    'weapon_code',
    'year',
    'quarter',
    'day',
    'month',]].astype(str)

# %%
descent_recode = { 'A':"Asian",'B':"Black",'C':"Asian",'D':"Asian",'F':"Asian",'G':"Asian",\
                 'H':"Hispanic",'I':"American Indian/Alaskan Native",'J':"Asian",\
                 'K':"Asian",'L':"Asian",'O':"Other",'P':"Asian",'S':"Asian",\
                 'U':"Asian",'V':"Asian",'W':"White",'X':"Other",'Z':"Asian" }

# %%
crimes['descent_description'] = crimes['victim_descent'].map(descent_recode)

# %%
victim_sex_recode = { 'F':"Female",'M':"Male",'X':"Unknown",'-':"Unknown",'N':"Unknown",'H':"Unknown" }

# %%
crimes['victim_sex'] = crimes['victim_sex'].map(victim_sex_recode)

# %%
crimes['premises_code'] = crimes['premises_code'].str.replace('.0','', regex=False)
crimes['premises_code'] = crimes['premises_code'].str.replace('.0','', regex=False)
crimes['crm_cd_1'] = crimes['crm_cd_1'].str.replace('.0','', regex=False)
crimes['crm_cd_2'] = crimes['crm_cd_2'].str.replace('.0','', regex=False)

# %%
crimes['premises_description'] = crimes['premises_description'].str.capitalize()
crimes['crime_code_description'] = crimes['crime_code_description'].str.capitalize()
crimes['weapon_description'] = crimes['weapon_description'].str.capitalize()

# %%
monthnames = ['January','February','March','April','May','June','July','August','September','October','November','December']

# %%
crimes['time_occurred'] = crimes['time_occurred'].str.replace('.0','', regex=False)
crimes['time_occurred'] = crimes['time_occurred'].str.zfill(4)
crimes['hour'] = crimes['time_occurred'].str[:2]
crimes['minute'] = crimes['time_occurred'].str[2:]
crimes = crimes[crimes['hour'] != '0n']
crimes = crimes[crimes['hour'] != '24']

# %%
homicides = crimes[crimes['crime_code_description'].str.contains('CRIMINAL HOMICIDE', na=False)]

# %% [markdown]
# ---

# %% [markdown]
# ## Now that it's clean, what can we learn from this data?

# %% [markdown]
# ### Share of crimes by UCR type

# %%
crimes['part_type'].value_counts('normalize').round(3)*100
# Out:
# 1    55.4
# 2    44.6
# Name: part_type, dtype: float64

# %%
cases_grouped = crimes.groupby(['crime_code_description', 'part_type', 'victim_sex'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
cases_grouped.head()
# Out:
#                 crime_code_description part_type victim_sex  total
# 14            Battery - simple assault         2     Female  96977
# 15            Battery - simple assault         2       Male  89384
# 208  Intimate partner - simple assault         2     Female  89306
# 61               Burglary from vehicle         1       Male  87075
# 58                            Burglary         1       Male  81418

# %% [markdown]
# ### Cases involving suspects or victimes defined by LAPD as 'homeless'

# %%
mocrimes = crimes.dropna(subset=['modus_operandi_code'])

# %%
mocodes = pd.read_csv('mo_codes.csv')
mocodes.head()
# Out:
#   mo_code  mo_code_description
# 0    0100  Suspect Impersonate
# 1    0101           Aid victim
# 2    0102                Blind
# 3    0103             Crippled
# 4    0104             Customer

# %% [markdown]
# ### Isolating just cases involving homeless people

# %%
# MO Code 1218 is to be used when a victim is homeless
# MO Code 2004 is to be used when a suspect is homeless
mocodes_homeless = mocodes[mocodes['mo_code_description'].str.lower().str.contains('homeless')]
mocodes_homeless.head()
# Out:
#     mo_code            mo_code_description
# 361    1218  Victim was Homeless/Transient
# 521    2004  Suspect is homeless/transient

# %% [markdown]
# ### Limit homeless crime data to recent years to account for coding issues

# %%
homeless_dates = ['2017', '2018', '2019']

# %% [markdown]
# ### Various filters

# %%
# My street
rubens = crimes[crimes['address'].str.contains('RUBENS', na=False)]
# Crimes tagged by specific modus operandi code
bunco = crimes[crimes['modus_operandi_code'].str.contains('0800', na=False) ]

#Homeless people codes
homeless_victims = crimes[(crimes['modus_operandi_code'].str.contains('1218', na=False)) & (crimes['year'].isin(homeless_dates))]
homeless_suspects = crimes[(crimes['modus_operandi_code'].str.contains('2004', na=False)) & (crimes['year'].isin(homeless_dates))]
homeless_homicides = homeless_victims[(homeless_victims['crime_code_description']\
                    .str.contains('Criminal homicide', na=False))\
                    & (homeless_victims['year'].isin(homeless_dates))]

# %%
homeless_victims_women = homeless_victims[homeless_victims['victim_sex'] == 'F']

# %% [markdown]
# ### How many cases do we have involving homeless people?

# %%
len(homeless_victims_women)
# Out:
# 0

# %%
len(homeless_victims)
# Out:
# 11984

# %%
len(homeless_suspects)
# Out:
# 25907

# %%
homeless_victims.columns
# Out:
# Index(['record_id', 'date_reported', 'date_occurred', 'time_occurred',
#        'division', 'division_name', 'reporting_district', 'part_type',
#        'crime_code', 'crime_code_description', 'modus_operandi_code',
#        'victim_age', 'victim_sex', 'victim_descent', 'premises_code',
#        'premises_description', 'weapon_code', 'weapon_description',
#        'status_code', 'status_code_description', 'crm_cd_1', 'crm_cd_2',
#        'crm_cd_3', 'crm_cd_4', 'address', 'cross_street', 'latitude',
#        'longitide', 'year', 'quarter', 'day', 'month', 'weekday', 'monthname',
#        'descent_description', 'hour', 'minute'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ### Homeless homicides

# %%
homeless_homicides.head()
# Out:
#          record_id date_reported date_occurred time_occurred division  \
# 1445612  171718643    10/06/2017    2017-10-06          1200       17
# 1455557  171601265    11/24/2017    2017-11-24          1805       16
# 1459244  170108868    03/16/2017    2017-03-16          1049        1
# 1459401  170408627    04/15/2017    2017-04-15          0001        4
# 1485854  170105663    01/29/2017    2017-01-29          0850        1
#
#         division_name reporting_district part_type crime_code  \
# 1445612    Devonshire               1723         1        110
# 1455557      Foothill               1602         1        110
# 1459244       Central                166         1        110
# 1459401    Hollenbeck                412         1        110
# 1485854       Central                147         1        110
#
#         crime_code_description  \
# 1445612      Criminal homicide
# 1455557      Criminal homicide
# 1459244      Criminal homicide
# 1459401      Criminal homicide
# 1485854      Criminal homicide
#
#                                        modus_operandi_code  victim_age  \
# 1445612                 1218 0444 0429 0344 0216 1309 1202          71
# 1455557  0906 1270 0302 1218 1414 1822 1409 0430 1100 1309          19
# 1459244                                1218 0411 2004 0906          23
# 1459401                 1100 0430 0906 1407 0302 1402 1218          35
# 1485854                                1100 0430 1218 2004          42
#
#         victim_sex victim_descent premises_code premises_description  \
# 1445612     Female              W           108          Parking lot
# 1455557       Male              H           102             Sidewalk
# 1459244       Male              B           101               Street
# 1459401     Female              H           101               Street
# 1485854       Male              H           102             Sidewalk
#
#         weapon_code                              weapon_description  \
# 1445612       400.0  Strong-arm (hands, fist, feet or bodily force)
# 1455557       106.0                                 Unknown firearm
# 1459244       218.0                        Other cutting instrument
# 1459401       109.0                           Semi-automatic pistol
# 1485854       102.0                                        Hand gun
#
#         status_code status_code_description crm_cd_1 crm_cd_2 crm_cd_3  \
# 1445612          AA            Adult Arrest      110      nan      nan
# 1455557          IC             Invest Cont      110      998      nan
# 1459244          AA            Adult Arrest      110      nan      nan
# 1459401          IC             Invest Cont      110      998      nan
# 1485854          AA            Adult Arrest      110      nan      nan
#
#         crm_cd_4                                   address  \
# 1445612      nan  21000    DEVONSHIRE                   ST
# 1455557      nan  11700    BROMONT                      AV
# 1459244      nan    600    SAN JULIAN                   ST
# 1459401      nan           BARRANCA                     ST
# 1485854      nan                                       5TH
#
#                             cross_street  latitude  longitide  year quarter  \
# 1445612                              NaN   34.2651  -118.5820  2017       4
# 1455557                              NaN   34.2824  -118.4063  2017       4
# 1459244                              NaN   34.0428  -118.2461  2017       1
# 1459401                        AVENUE 28   34.0798  -118.2170  2017       2
# 1485854  SAN PEDRO                    ST   34.0442  -118.2439  2017       1
#
#         day month   weekday monthname descent_description hour minute
# 1445612   6    10    Friday   October               White   12     00
# 1455557  24    11    Friday  November            Hispanic   18     05
# 1459244  16     3  Thursday     March               Black   10     49
# 1459401  15     4  Saturday     April            Hispanic   00     01
# 1485854  29     1    Sunday   January            Hispanic   08     50

# %%
homeless_homicides_years = homeless_homicides.groupby\
(['year','division_name', 'premises_description','weapon_description']).agg('size').reset_index(name='total')

# %%
chart_homeless_homicides_years = alt.Chart(homeless_homicides_years).mark_bar().encode(
    y=alt.Y('year:N', axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("sum(total):Q", title="Cases", axis=alt.Axis(format='', tickCount=5))
)

chart_homeless_homicides_years_text = chart_homeless_homicides_years.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='sum(total):Q'
)

(chart_homeless_homicides_years + chart_homeless_homicides_years_text).properties(height=150, width=500, title='Homeless homicide cases per year')

# %%
chart_homeless_divisions = alt.Chart(homeless_homicides_years).mark_bar().encode(
    y=alt.Y('division_name:N',
        sort=alt.EncodingSortField(
            field="total",  # The field to use for the sort
            op="sum",  # The operation to run on the field prior to sorting
            order="descending"  # The order to sort in
        ), axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("sum(total):Q", title="Cases", axis=alt.Axis(format='', tickCount=5))
)

chart_homeless_divisions_text = chart_homeless_divisions.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='sum(total):Q'
)


(chart_homeless_divisions + chart_homeless_divisions_text)\
.properties(height=400, width=700, title='Homeless homicide by police division, 2016-19')

# %%
chart_homeless_weapon = alt.Chart(homeless_homicides_years).mark_bar().encode(
    y=alt.Y('weapon_description:N',
        sort=alt.EncodingSortField(
            field="total",  # The field to use for the sort
            op="sum",  # The operation to run on the field prior to sorting
            order="descending"  # The order to sort in
        ), axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("sum(total):Q", title="Cases", axis=alt.Axis(format='', tickCount=5))
)

chart_homeless_weapon_text = chart_homeless_weapon.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='sum(total):Q'
)

(chart_homeless_weapon + chart_homeless_weapon_text)\
    .properties(height=400, width=700, title='Homeless homicide by weapon type, 2016-19')

# %%
chart_homeless_location = alt.Chart(homeless_homicides_years).mark_bar().encode(
    y=alt.Y('premises_description:N',
        sort=alt.EncodingSortField(
            field="total",  # The field to use for the sort
            op="sum",  # The operation to run on the field prior to sorting
            order="descending"  # The order to sort in
        ), axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("sum(total):Q", title="Cases", axis=alt.Axis(format='', tickCount=5))
)

chart_homeless_location_text = chart_homeless_location.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='sum(total):Q'
)

(chart_homeless_location + chart_homeless_location_text)\
.properties(height=400, width=700, title='Homeless homicide by location type, 2017-19')

# %% [markdown]
# ---

# %% [markdown]
# ## Homeless victims

# %%
homeless_year_victim = homeless_victims.groupby(['year', 'division_name'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)
homeless_year_victim.head()
# Out:
#     year division_name  total
# 43  2019       Central   1600
# 22  2018       Central   1404
# 1   2017       Central    677
# 34  2018       Rampart    338
# 30  2018        Newton    296

# %%
homeless_year_victim = homeless_victims.groupby(['year', 'division_name'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)
homeless_year_victim.head(10)
# Out:
#     year division_name  total
# 43  2019       Central   1600
# 22  2018       Central   1404
# 1   2017       Central    677
# 34  2018       Rampart    338
# 30  2018        Newton    296
# 55  2019       Rampart    281
# 51  2019        Newton    275
# 13  2017       Rampart    262
# 27  2018     Hollywood    253
# 54  2019       Pacific    247

# %% [markdown]
# ### What types of crimes are most common for homeless victims?

# %%
homeless_cases_victim = homeless_victims.groupby(['crime_code_description', 'part_type', 'victim_sex'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %% [markdown]
# ### Homeless victims of serious crimes

# %%
homeless_cases_victim_one = homeless_cases_victim[homeless_cases_victim['part_type'] == '1']
homeless_cases_victim_one.head(100)
# Out:
#                                 crime_code_description part_type victim_sex  \
# 4       Assault with deadly weapon, aggravated assault         1       Male
# 90                                             Robbery         1       Male
# 115                 Theft plain - petty ($950 & under)         1       Male
# 3       Assault with deadly weapon, aggravated assault         1     Female
# 114                 Theft plain - petty ($950 & under)         1     Female
# 57               Intimate partner - aggravated assault         1     Female
# 89                                             Robbery         1     Female
# 86                                      Rape, forcible         1     Female
# 19                                     Brandish weapon         1       Male
# 58               Intimate partner - aggravated assault         1       Male
# 7                                    Attempted robbery         1       Male
# 18                                     Brandish weapon         1     Female
# 118                                      Theft, person         1       Male
# 120  Theft-grand ($950.01 & over)excpt,guns,fowl,li...         1       Male
# 42                                   Criminal homicide         1       Male
# 119  Theft-grand ($950.01 & over)excpt,guns,fowl,li...         1     Female
# 93                 Sexual penetration w/foreign object         1     Female
# 16                                       Bike - stolen         1       Male
# 117                                      Theft, person         1     Female
# 25                                            Burglary         1       Male
# 6                                    Attempted robbery         1     Female
# 103  Sodomy/sexual contact b/w penis of one pers to...         1       Male
# 102  Sodomy/sexual contact b/w penis of one pers to...         1     Female
# 27                               Burglary from vehicle         1       Male
# 71                                     Oral copulation         1     Female
# 84                                     Rape, attempted         1     Female
# 109    Theft from motor vehicle - petty ($950 & under)         1       Male
# 15                                       Bike - stolen         1     Female
# 24                                            Burglary         1     Female
# 94                 Sexual penetration w/foreign object         1       Male
# 80                                          Pickpocket         1       Male
# 1                                                Arson         1       Male
# 108    Theft from motor vehicle - petty ($950 & under)         1     Female
# 26                               Burglary from vehicle         1     Female
# 96            Shoplifting - petty theft ($950 & under)         1       Male
# 72                                     Oral copulation         1       Male
# 0                                                Arson         1     Female
# 41                                   Criminal homicide         1     Female
# 79                                          Pickpocket         1     Female
# 106   Theft from motor vehicle - grand ($400 and over)         1     Female
# 107   Theft from motor vehicle - grand ($400 and over)         1       Male
# 5       Assault with deadly weapon, aggravated assault         1    Unknown
# 95            Shoplifting - petty theft ($950 & under)         1     Female
# 87                                      Rape, forcible         1       Male
# 101   Shots fired at moving vehicle, train or aircraft         1       Male
# 82                                     Purse snatching         1     Female
# 91                                             Robbery         1    Unknown
# 134                           Vehicle - attempt stolen         1       Male
# 85                                     Rape, attempted         1       Male
# 116                 Theft plain - petty ($950 & under)         1    Unknown
# 28                                 Burglary, attempted         1    Unknown
# 121  Theft-grand ($950.01 & over)excpt,guns,fowl,li...         1    Unknown
# 17                                       Boat - stolen         1       Male
# 8                                    Attempted robbery         1    Unknown
# 2         Assault with deadly weapon on police officer         1       Male
# 113                              Theft plain - attempt         1     Female
# 70                             Manslaughter, negligent         1       Male
# 81                                 Pickpocket, attempt         1       Male
# 83                                     Purse snatching         1       Male
# 31         Child abuse (physical) - aggravated assault         1       Male
# 97            Shoplifting - petty theft ($950 & under)         1    Unknown
# 98            Shoplifting-grand theft ($950.01 & over)         1     Female
# 99                   Shots fired at inhabited dwelling         1       Male
# 100   Shots fired at moving vehicle, train or aircraft         1     Female
# 110                        Theft from person - attempt         1     Female
#
#      total
# 4     2220
# 90     938
# 115    734
# 3      625
# 114    514
# 57     390
# 89     350
# 86     311
# 19     232
# 58     148
# 7      138
# 18     124
# 118    124
# 120    112
# 42      91
# 119     76
# 93      74
# 16      71
# 117     68
# 25      38
# 6       37
# 103     33
# 102     32
# 27      29
# 71      28
# 84      24
# 109     19
# 15      17
# 24      17
# 94      16
# 80      12
# 1       12
# 108     12
# 26      12
# 96      11
# 72      11
# 0       10
# 41       9
# 79       7
# 106      7
# 107      6
# 5        4
# 95       4
# 87       4
# 101      3
# 82       3
# 91       2
# 134      2
# 85       2
# 116      2
# 28       1
# 121      1
# 17       1
# 8        1
# 2        1
# 113      1
# 70       1
# 81       1
# 83       1
# 31       1
# 97       1
# 98       1
# 99       1
# 100      1
# 110      1

# %% [markdown]
# ### Where do crimes involving homeless victims occur?

# %%
homeless_victims['division_name'].value_counts('normalize').round(2)*100
# Out:
# Central        31.0
# Rampart         7.0
# Newton          7.0
# N Hollywood     5.0
# Hollywood       5.0
# Pacific         5.0
# Van Nuys        4.0
# Southwest       4.0
# Harbor          3.0
# Olympic         3.0
# 77th Street     3.0
# Southeast       3.0
# Northeast       3.0
# Hollenbeck      3.0
# West LA         3.0
# Foothill        2.0
# Mission         2.0
# West Valley     2.0
# Wilshire        2.0
# Devonshire      2.0
# Topanga         1.0
# Name: division_name, dtype: float64

# %%
alt.Chart(homeless_year_victim).mark_bar().encode(
    y=alt.Y('year:N', title='', axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("mean(total):Q", title="homeless victims", axis=alt.Axis(format='', tickCount=10)),
    facet='division_name:N'
).properties(height=80, width=200, columns=3, title='Homeless victims per year, by division')

# %% [markdown]
# ### Homeless victims in central

# %%
homeless_victims_central = homeless_victims[homeless_victims['division_name'] == 'Central']

# %%
homeless_cases_victim_central = homeless_victims_central.groupby(['crime_code_description'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
homeless_cases_victim_central.head()
# Out:
#                             crime_code_description  total
# 2   Assault with deadly weapon, aggravated assault    767
# 4                         Battery - simple assault    659
# 46              Theft plain - petty ($950 & under)    633
# 35                                         Robbery    402
# 23               Intimate partner - simple assault    223

# %% [markdown]
# ---

# %%
homeless_cases_suspect = homeless_suspects.groupby(['crime_code_description'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
homeless_cases_suspect.head(10)
# Out:
#                                crime_code_description  total
# 4                            Battery - simple assault   3457
# 2      Assault with deadly weapon, aggravated assault   3444
# 93                                        Trespassing   2247
# 73                                            Robbery   2068
# 77           Shoplifting - petty theft ($950 & under)   1866
# 52                  Intimate partner - simple assault   1572
# 95  Vandalism - felony ($400 & over, all church va...   1198
# 11                                    Brandish weapon    905
# 14                                           Burglary    882
# 87                 Theft plain - petty ($950 & under)    868

# %% [markdown]
# ---

# %% [markdown]
# ### What types of crimes do female homeless residents encounter?

# %%
women_pop_share = 30.1
male_pop_share = 67.3

# %%
vic_sex_pivot = pd.pivot_table(cases_grouped, values='total', \
                       index=['crime_code_description'],columns=['victim_sex'], \
                                        aggfunc=np.sum, fill_value=0).reset_index()

# %%
vic_sex_pivot['total_all'] = (vic_sex_pivot['Female'] + \
                vic_sex_pivot['Male'] + \
                vic_sex_pivot['Unknown'])

# %%
vic_sex_pivot['female_share_all'] = ((vic_sex_pivot['Female'] / \
                                           vic_sex_pivot['total_all'])*100).round(2)

# %%
vic_sex_pivot['male_share_all'] = ((vic_sex_pivot['Male'] / \
                                           vic_sex_pivot['total_all'])*100).round(2)

# %%
vic_sex_pivot.sort_values(by='total_all', ascending=False).head(10)
# Out:
# victim_sex                             crime_code_description  Female   Male  \
# 5                                    Battery - simple assault   96977  89384
# 22                                      Burglary from vehicle   70473  87075
# 118                        Theft plain - petty ($950 & under)   64659  76316
# 21                                                   Burglary   57003  81418
# 116                                         Theft of identity   62203  61058
# 75                          Intimate partner - simple assault   89306  22627
# 132         Vandalism - felony ($400 & over, all church va...   41751  59225
# 3              Assault with deadly weapon, aggravated assault   24651  65377
# 133                  Vandalism - misdeameanor ($399 or under)   40471  45131
# 101                                                   Robbery   24203  54463
#
# victim_sex  Unknown  total_all  female_share_all  male_share_all
# 5               253     186614             51.97           47.90
# 22              792     158340             44.51           54.99
# 118            5156     146131             44.25           52.22
# 21             6160     144581             39.43           56.31
# 116             559     123820             50.24           49.31
# 75               43     111976             79.75           20.21
# 132            5722     106698             39.13           55.51
# 3               377      90405             27.27           72.32
# 133            3236      88838             45.56           50.80
# 101            3265      81931             29.54           66.47

# %%
homeless_vic_sex_pivot = pd.pivot_table(homeless_cases_victim, values='total', \
                       index=['crime_code_description'],columns=['victim_sex'], \
                                        aggfunc=np.sum, fill_value=0).reset_index()

# %%
homeless_vic_sex_pivot['total_homeless'] = (homeless_vic_sex_pivot['Female'] + \
                homeless_vic_sex_pivot['Male'] + \
                homeless_vic_sex_pivot['Unknown'])

# %%
homeless_vic_sex_pivot['female_share_homeless'] = ((homeless_vic_sex_pivot['Female'] / \
                                           homeless_vic_sex_pivot['total_homeless'])*100).round(2)

# %%
homeless_vic_sex_pivot['male_share_homeless'] = ((homeless_vic_sex_pivot['Male'] / \
                                           homeless_vic_sex_pivot['total_homeless'])*100).round(2)

# %%
homeless_vic_sex_pivot.sort_values(by='total_homeless', ascending=False).head(20)
# Out:
# victim_sex                             crime_code_description  Female  Male  \
# 2              Assault with deadly weapon, aggravated assault     625  2220
# 4                                    Battery - simple assault     935  1196
# 51                                                    Robbery     350   938
# 35                          Intimate partner - simple assault    1004   268
# 65                         Theft plain - petty ($950 & under)     514   734
# 34                      Intimate partner - aggravated assault     390   148
# 9                                             Brandish weapon     124   232
# 49                                             Rape, forcible     311     4
# 24                     Criminal threats - no weapon displayed     147    84
# 66                                              Theft, person      68   124
# 67          Theft-grand ($950.01 & over)excpt,guns,fowl,li...      76   112
# 3                                           Attempted robbery      37   138
# 23                                          Criminal homicide       9    91
# 73                   Vandalism - misdeameanor ($399 or under)      42    56
# 6                                 Battery with sexual contact      84    12
# 53                        Sexual penetration w/foreign object      74    16
# 7                                               Bike - stolen      17    71
# 58          Sodomy/sexual contact b/w penis of one pers to...      32    33
# 42                                              Other assault      32    28
# 12                                                   Burglary      17    38
#
# victim_sex  Unknown  total_homeless  female_share_homeless  \
# 2                 4            2849                  21.94
# 4                 3            2134                  43.81
# 51                2            1290                  27.13
# 35                1            1273                  78.87
# 65                2            1250                  41.12
# 34                0             538                  72.49
# 9                 0             356                  34.83
# 49                0             315                  98.73
# 24                0             231                  63.64
# 66                0             192                  35.42
# 67                1             189                  40.21
# 3                 1             176                  21.02
# 23                0             100                   9.00
# 73                1              99                  42.42
# 6                 0              96                  87.50
# 53                0              90                  82.22
# 7                 0              88                  19.32
# 58                0              65                  49.23
# 42                0              60                  53.33
# 12                0              55                  30.91
#
# victim_sex  male_share_homeless
# 2                         77.92
# 4                         56.04
# 51                        72.71
# 35                        21.05
# 65                        58.72
# 34                        27.51
# 9                         65.17
# 49                         1.27
# 24                        36.36
# 66                        64.58
# 67                        59.26
# 3                         78.41
# 23                        91.00
# 73                        56.57
# 6                         12.50
# 53                        17.78
# 7                         80.68
# 58                        50.77
# 42                        46.67
# 12                        69.09

# %%
female_share_homeless_all = pd.merge(vic_sex_pivot, homeless_vic_sex_pivot, on='crime_code_description')

# %%
female_share_homeless_all_trimmed = female_share_homeless_all[[ 'crime_code_description',\
                               'total_homeless', 'female_share_all', 'female_share_homeless']]

# %%
female_share_homeless_all_trimmed.sort_values(by='total_homele ss', ascending=False).head(20)
# Out:
# victim_sex                             crime_code_description  total_homeless  \
# 2              Assault with deadly weapon, aggravated assault            2849
# 4                                    Battery - simple assault            2134
# 51                                                    Robbery            1290
# 35                          Intimate partner - simple assault            1273
# 65                         Theft plain - petty ($950 & under)            1250
# 34                      Intimate partner - aggravated assault             538
# 9                                             Brandish weapon             356
# 49                                             Rape, forcible             315
# 24                     Criminal threats - no weapon displayed             231
# 66                                              Theft, person             192
# 67          Theft-grand ($950.01 & over)excpt,guns,fowl,li...             189
# 3                                           Attempted robbery             176
# 23                                          Criminal homicide             100
# 73                   Vandalism - misdeameanor ($399 or under)              99
# 6                                 Battery with sexual contact              96
# 53                        Sexual penetration w/foreign object              90
# 7                                               Bike - stolen              88
# 58          Sodomy/sexual contact b/w penis of one pers to...              65
# 42                                              Other assault              60
# 12                                                   Burglary              55
#
# victim_sex  female_share_all  female_share_homeless
# 2                      27.27                  21.94
# 4                      51.97                  43.81
# 51                     29.54                  27.13
# 35                     79.75                  78.87
# 65                     44.25                  41.12
# 34                     77.39                  72.49
# 9                      34.52                  34.83
# 49                     99.03                  98.73
# 24                     54.66                  63.64
# 66                     63.38                  35.42
# 67                     40.40                  40.21
# 3                      28.15                  21.02
# 23                     13.83                   9.00
# 73                     45.56                  42.42
# 6                      91.48                  87.50
# 53                     89.46                  82.22
# 7                      28.57                  19.32
# 58                     50.11                  49.23
# 42                     50.31                  53.33
# 12                     39.43                  30.91

# %% [markdown]
# ### ---

# %% [markdown]
# ## Basic aggregates on variables for all crimes

# %% [markdown]
# ### Which crimes are most common?

# %%
violations = crimes.groupby(['crime_code_description'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
violations.head(10)
# Out:
#                                 crime_code_description   total
# 5                             Battery - simple assault  186633
# 22                               Burglary from vehicle  158361
# 136                                   Vehicle - stolen  156154
# 118                 Theft plain - petty ($950 & under)  146185
# 21                                            Burglary  144622
# 116                                  Theft of identity  123841
# 75                   Intimate partner - simple assault  111983
# 132  Vandalism - felony ($400 & over, all church va...  106721
# 3       Assault with deadly weapon, aggravated assault   90440
# 133           Vandalism - misdeameanor ($399 or under)   88862

# %% [markdown]
# ### Places where crimes occur?

# %%
places = crimes.groupby(['premises_description'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
places.head(10)
# Out:
#                              premises_description   total
# 278                                        Street  461267
# 267                        Single family dwelling  417827
# 211  Multi-unit dwelling (apartment, duplex, etc)  259470
# 233                                   Parking lot  146340
# 266                                      Sidewalk  103404
# 224                                Other business   94124
# 311                      Vehicle, passenger/truck   77957
# 64                                       Driveway   41660
# 80                                 Garage/carport   36764
# 258                          Restaurant/fast food   28428

# %% [markdown]
# ### Areas of the city?

# %%
divisions = crimes.groupby(['division_name'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
divisions.head(10)
# Out:
#    division_name   total
# 0    77th Street  142045
# 15     Southwest  132261
# 8    N Hollywood  111182
# 12       Pacific  109615
# 14     Southeast  108814
# 7        Mission  101307
# 10     Northeast   97969
# 9         Newton   97494
# 17      Van Nuys   97282
# 6      Hollywood   96352

# %% [markdown]
# ### What kinds of weapons?

# %%
weapons = crimes.groupby(['weapon_description'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
weapons.head(10)
# Out:
#                                 weapon_description   total
# 65  Strong-arm (hands, fist, feet or bodily force)  420047
# 78                                   Verbal threat   57315
# 75                     Unknown weapon/other weapon   55848
# 27                                        Hand gun   33292
# 58                           Semi-automatic pistol   12662
# 32                Knife with blade 6inches or less   12527
# 44                                     Other knife    9521
# 73                                 Unknown firearm    7728
# 77                                         Vehicle    7076
# 50                                        Revolver    5496

# %% [markdown]
# ### Which days of the week?

# %%
weekdays = crimes.groupby(['weekday'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
weekdays.head(7)
# Out:
#      weekday   total
# 0     Friday  317192
# 2   Saturday  296815
# 1     Monday  293949
# 6  Wednesday  291986
# 4   Thursday  290491
# 5    Tuesday  287999
# 3     Sunday  283921

# %% [markdown]
# ---

# %% [markdown]
# ### Cleaning up modus operandi

# %%
# df = crimes[['record_id', 'modus_operandi_code']]

# %%
# df['modus_operandi_code'] = df['modus_operandi_code'].dropna().apply(lambda x: x.split(' '))

# %%
# final = df['modus_operandi_code'].apply(pd.Series)\
# .merge(df, left_index = True, right_index = True)\
# .drop('modus_operandi_code', axis = 1)\
# .melt(id_vars = ['record_id'], value_name = "modus_operandi_code", var_name = 'modoporder')\
# .dropna(subset=['modus_operandi_code'])\
# .sort_values('record_id')

# %%
# mo_counts = final.groupby(['modus_operandi_code']).agg('size')\
# .reset_index(name='count').sort_values(by='count', ascending=False)

# %%
# merged_mo_counts = pd.merge(mo_counts, mocodes, 
#                      left_on = 'modus_operandi_code', 
#                      right_on = 'mo_code', 
#                      how='left')

# %%
# merged_mo_counts.head()

# %% [markdown]
# ---
