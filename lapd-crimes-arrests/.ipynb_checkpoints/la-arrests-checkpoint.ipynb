# %% [markdown]
# # Analyzing 'sit-lie' arrests by LAPD: 2010-19

# %% [markdown]
# ### Load Python tools

# %%
import pandas as pd
import geopandas as gpd
import matplotlib
import geojson
import json
import jenkspy
import numpy as np
from earthpy import clip as cl
from altair import datum
import altair as alt
alt.renderers.enable('notebook')
import altair_latimes as lat
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000

# %% [markdown]
# #### Read in arrests data from city portal

# %%
# https://data.lacity.org/api/views/yru6-6re4/rows.csv?accessType=DOWNLOAD
arrests = pd.read_csv('/Users/mhustiles/data/data/LA/Arrest_Data_from_2010_to_Present.csv')

# %% [markdown]
# #### How many arrest cases are in the database?

# %%
len(arrests)
# Out:
# 1305147

# %% [markdown]
# #### Clean up arrests DataFrame

# %%
arrests.columns = arrests.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
arrests['arrest_date'] = pd.to_datetime(arrests['arrest_date'], format='%m/%d/%Y')
arrests['year'] = arrests['arrest_date'].dt.year
arrests['quarter'] = arrests['arrest_date'].dt.quarter
arrests['day'] = arrests['arrest_date'].dt.day
arrests['month'] = arrests['arrest_date'].dt.month
arrests['monthname'] = arrests['arrest_date'].dt.month_name()
arrests[['report_id', 'time', 'area_id', 'charge_group_code', 'reporting_district', 'year', 'month', 'day']] = \
arrests[['report_id', 'time', 'area_id', 'charge_group_code', 'reporting_district', 'year', 'month','day']].astype(str)
arrests['charge_group_code'] = arrests['charge_group_code'].str.replace('.0', '', regex=False)
arrests['weekday'] = arrests['arrest_date'].dt.weekday_name
arrests['time'] = arrests['time'].str.replace('.0','', regex=False)
arrests['time'] = arrests['time'].str.zfill(4)
arrests['hour'] = arrests['time'].str[:2]
arrests['minute'] = arrests['time'].str[2:]
arrests = arrests[arrests['hour'] != '0n']
arrests = arrests[arrests['hour'] != '24']
arrests.drop('cross_street', axis=1, inplace=True)

# %%
arrests.head()
# Out:
#    report_id arrest_date  time area_id  area_name reporting_district  age  \
# 0    5765501  2019-10-05  0935       5     Harbor                526   49
# 1    5765365  2019-10-05  0259      21    Topanga               2177   29
# 2  191117610  2019-10-05  1300      11  Northeast               1139   51
# 3    5765280  2019-10-05  0020      20    Olympic               2002   29
# 4    5765238  2019-10-05  0001       9   Van Nuys                974   62
#
#   sex_code descent_code charge_group_code        charge_group_description  \
# 0        F            W                24  Miscellaneous Other Violations
# 1        M            B                22         Driving Under Influence
# 2        M            H                16              Narcotic Drug Laws
# 3        M            W                13             Prostitution/Allied
# 4        F            W                22         Driving Under Influence
#
#   arrest_type_code      charge                  charge_description  \
# 0                M    597(B)PC     USE WORK ANIMAL W/CRUELTY/ABUSE
# 1                M  23152(A)VC         DRUNK DRIVING ALCOHOL/DRUGS
# 2                M  11364(A)HS  POSS DEVICE/INSTRUMT/PARAPHERNALIA
# 3                M    647(B)PC                        PROSTITUTION
# 4                M  23152(A)VC         DRUNK DRIVING ALCOHOL/DRUGS
#
#                                   address              location  year  \
# 0  900    ISLAND                       AV  (33.7815, -118.2667)  2019
# 1         DE SOTO                      AV  (34.1689, -118.5882)  2019
# 2                               AVENUE 59  (34.1095, -118.1903)  2019
# 3         WESTERN                      AV  (34.0783, -118.3092)  2019
# 4                                VAN NUYS  (34.1569, -118.4487)  2019
#
#    quarter day month monthname   weekday hour minute
# 0        4   5    10   October  Saturday   09     35
# 1        4   5    10   October  Saturday   02     59
# 2        4   5    10   October  Saturday   13     00
# 3        4   5    10   October  Saturday   00     20
# 4        4   5    10   October  Saturday   00     01

# %% [markdown]
# #### Highlight nighttime hours

# %%
night = ['01', '02', '03', '04', '05', '22', '23', '00']
arrests['night'] = arrests['hour'].isin(night)
night_arrests = arrests[arrests['hour'].isin(night)]

# %% [markdown]
# #### Separate location field into lat/lon

# %%
arrests['location'] = arrests.location.str.replace('(', '').str.replace(')', '')

lat = []
lon = []

for row in arrests['location']:
    try:
        lat.append(row.split(',')[0])
        lon.append(row.split(',')[1])
    except:
        lat.append(np.NaN)
        lon.append(np.NaN)

arrests['latitude'] = lat
arrests['longitude'] = lon
arrests['latitude'] = arrests['latitude'].astype(float)
arrests['longitude'] = arrests['longitude'].astype(float)

# %% [markdown]
# #### Recode descent names into something useful

# %%
descent_recode ={'A':"Asian",'B':"Black",'C':"Asian",'D':"Asian",'F':"Asian",'G':"Asian",'H':"Hispanic",'I':"American Indian/Alaskan Native",'J':"Asian",'K':"Asian",'L':"Asian",'O':"Other",'P':"Asian",'S':"Asian",'U':"Asian",'V':"Asian",'W':"White",'X':"Other",'Z':"Asian"}

# %%
arrests['descent_description'] = arrests['descent_code'].map(descent_recode)

# %%
arrest_type_recode ={'F':"Felony",'I':"Infraction",'M':"Misdemeanor",'O':"Other"}

# %%
arrests['arrest_type_description'] = arrests['arrest_type_code'].map(arrest_type_recode)

# %%
arrests
# Out:
#          report_id arrest_date  time area_id    area_name reporting_district  \
# 0          5765501  2019-10-05  0935       5       Harbor                526
# 1          5765365  2019-10-05  0259      21      Topanga               2177
# 2        191117610  2019-10-05  1300      11    Northeast               1139
# 3          5765280  2019-10-05  0020      20      Olympic               2002
# 4          5765238  2019-10-05  0001       9     Van Nuys                974
# 5          5765400  2019-10-05  0411       1      Central                191
# 6          5765272  2019-10-05  0020      20      Olympic               2004
# 7          5765318  2019-10-05  0200      20      Olympic               2002
# 8          5765337  2019-10-05  0212       1      Central                119
# 9        191117612  2019-10-05  1300      11    Northeast               1139
# 10         5765353  2019-10-05  0240      20      Olympic               2073
# 11         5765370  2019-10-05  0322       9     Van Nuys                966
# 12         5765285  2019-10-05  0020      20      Olympic               2004
# 13         5765331  2019-10-05  0145      20      Olympic               2002
# 14         5765506  2019-10-05  0333      10  West Valley               1079
# 15         5765524  2019-10-05  1200      12  77th Street               1258
# 16         5765475  2019-10-05  0800      14      Pacific               1494
# 17         5765291  2019-10-05  0030      20      Olympic               2002
# 18       191117609  2019-10-05  1300      11    Northeast               1139
# 19         5765339  2019-10-05  0205      20      Olympic               2004
# 20         5765381  2019-10-05  0225      20      Olympic               2063
# 21         5765472  2019-10-05  0935      12  77th Street               1258
# 22         5765306  2019-10-05  0050      20      Olympic               2035
# 23         5765373  2019-10-05  0200      20      Olympic               2063
# 24         5765377  2019-10-05  0250       6    Hollywood                679
# 25         5765368  2019-10-05  0300       6    Hollywood                679
# 26         5765515  2019-10-05  0835       7     Wilshire                782
# 27         5765345  2019-10-05  0145      20      Olympic               2033
# 28         5765248  2019-10-05  0005       1      Central                176
# 29         5765513  2019-10-05  0336      10  West Valley               1079
# 30         5765360  2019-10-05  0300       6    Hollywood                679
# 31         5765528  2019-10-05  1000      14      Pacific               1445
# 32         5765336  2019-10-05  0145      20      Olympic               2002
# 33         5765315  2019-10-05  0130      20      Olympic               2002
# 34         5764582  2019-10-04  1040       9     Van Nuys                935
# 35         5764608  2019-10-04  0515      19      Mission               1961
# 36         5765278  2019-10-04  2358      14      Pacific               1485
# 37         5765011  2019-10-04  2215       1      Central                161
# 38         5764559  2019-10-04  1026       9     Van Nuys                935
# 39         5764858  2019-10-04  1500       1      Central                185
# 40         5764948  2019-10-04  1535       3    Southwest                355
# 41         5764428  2019-10-04  0350       1      Central                156
# 42         5764509  2019-10-04  0926      12  77th Street               1258
# 43         5764497  2019-10-04  0810       2      Rampart                236
# 44         5764485  2019-10-04  0858      12  77th Street               1258
# 45         5764399  2019-10-04  0210       7     Wilshire                714
# 46         5764362  2019-10-04  0110      12  77th Street               1249
# 47         5765302  2019-10-04  2030       5       Harbor                532
# 48         5764350  2019-10-04  0040       3    Southwest                314
# 49         5764620  2019-10-04  1051       9     Van Nuys                926
# 50         5764461  2019-10-04  0450       8      West LA                881
# 51       191224080  2019-10-04  1330      12  77th Street               1249
# 52         5764693  2019-10-04  1110      18    Southeast               1801
# 53       191224074  2019-10-04  1430      12  77th Street               1266
# 54         5765258  2019-10-04  2255       7     Wilshire                785
# 55         5764348  2019-10-04  0120       6    Hollywood                645
# 56         5764934  2019-10-04  2100      12  77th Street               1283
# 57         5764750  2019-10-04  1400       5       Harbor                529
# 58         5764713  2019-10-04  1405      15  N Hollywood               1585
# 59         5764950  2019-10-04  2000       7     Wilshire                779
# 60         5765005  2019-10-04  2249      10  West Valley               1061
# 61         5764994  2019-10-04  2236       4   Hollenbeck                479
# 62         5764443  2019-10-04  0451      15  N Hollywood               1553
# 63         5765012  2019-10-04  2350      20      Olympic               2004
# 64       191224078  2019-10-04  1400      12  77th Street               1266
# 65         5764996  2019-10-04  2125      10  West Valley               1011
# 66         5765243  2019-10-04  2245      10  West Valley               1025
# 67         5764904  2019-10-04  1910      11    Northeast               1195
# 68         5764616  2019-10-04  1205      12  77th Street               1258
# 69         5764382  2019-10-04  0252      16     Foothill               1673
# 70         5764379  2019-10-04  0239       1      Central                131
# 71         5764976  2019-10-04  2030      15  N Hollywood               1513
# 72         5764852  2019-10-04  1745      18    Southeast               1844
# 73         5764628  2019-10-04  0950       1      Central                192
# 74         5764731  2019-10-04  1040      21      Topanga               2143
# 75         5764352  2019-10-04  0055       6    Hollywood                645
# 76       191614869  2019-10-04  1715      16     Foothill               1602
# 77       191224076  2019-10-04  1415      12  77th Street               1266
# 78         5764754  2019-10-04  1335       9     Van Nuys                966
# 79         5764401  2019-10-04  0200      10  West Valley               1021
# 80         5764949  2019-10-04  1945       1      Central                192
# 81         5764431  2019-10-04  0035      11    Northeast               1183
# 82         5764359  2019-10-04  0216      15  N Hollywood               1599
# 83         5764438  2019-10-04  0435       1      Central                162
# 84         5764747  2019-10-04  1430       1      Central                161
# 85         5764807  2019-10-04  1545      15  N Hollywood               1548
# 86         5764947  2019-10-04  2030      19      Mission               1958
# 87         5764683  2019-10-04  1020       8      West LA                835
# 88         5765321  2019-10-04  2110      11    Northeast               1195
# 89         5764760  2019-10-04  1545      19      Mission               1944
# 90         5764658  2019-10-04  1000      10  West Valley               1037
# 91         5764397  2019-10-04  0240      14      Pacific               1489
# 92         5764339  2019-10-04  0055      18    Southeast               1804
# 93         5764560  2019-10-04  0401      19      Mission               1941
# 94       191224079  2019-10-04  1225      12  77th Street               1266
# 95         5764360  2019-10-04  0010       4   Hollenbeck                421
# 96         5764460  2019-10-04  0015       1      Central                171
# 97         5764898  2019-10-04  1900       1      Central                162
# 98         5764363  2019-10-04  0120      14      Pacific               1414
# 99         5764518  2019-10-04  0800       9     Van Nuys                915
# 100        5764860  2019-10-04  1835      18    Southeast               1837
# 101        5764811  2019-10-04  1450       7     Wilshire                711
# 102        5764842  2019-10-04  1630      21      Topanga               2146
# 103      191614866  2019-10-04  1715      16     Foothill               1602
# 104        5764482  2019-10-04  0730       1      Central                119
# 105        5764554  2019-10-04  0915      14      Pacific               1494
# 106      191614867  2019-10-04  1715      16     Foothill               1602
# 107      190620139  2019-10-04  1830       6    Hollywood                622
# 108        5764569  2019-10-04  1030      12  77th Street               1258
# 109        5764998  2019-10-04  2300       9     Van Nuys                964
# 110        5764491  2019-10-04  0730       1      Central                153
# 111      191614868  2019-10-04  1715      16     Foothill               1602
# 112        5765030  2019-10-04  2341      15  N Hollywood               1565
# 113        5764999  2019-10-04  2110      16     Foothill               1623
# 114        5765298  2019-10-04  2350       3    Southwest                329
# 115        5764471  2019-10-04  0500       2      Rampart                261
# 116        5764795  2019-10-04  1550       5       Harbor                521
# 117        5764432  2019-10-04  0315       6    Hollywood                668
# 118      192116706  2019-10-04  2045      21      Topanga               2146
# 119        5765274  2019-10-04  1900      11    Northeast               1138
# 120        5765296  2019-10-04  2330      20      Olympic               2074
# 121        5764661  2019-10-04  1100       5       Harbor                525
# 122        5765261  2019-10-04  2330       6    Hollywood                646
# 123        5764595  2019-10-04  0915       5       Harbor                562
# 124        5764386  2019-10-04  0233       8      West LA                895
# 125        5764801  2019-10-04  1550       3    Southwest                334
# 126        5764773  2019-10-04  1420       3    Southwest                356
# 127        5765237  2019-10-04  2315      14      Pacific               1441
# 128        5763503  2019-10-03  1030       1      Central                127
# 129        5763701  2019-10-03  1155      10  West Valley               1008
# 130        5763449  2019-10-03  0735       2      Rampart                217
# 131        5763594  2019-10-03  0800      21      Topanga               2126
# 132        5764143  2019-10-03  1900       3    Southwest                318
# 133        5763265  2019-10-03  0110      20      Olympic               2063
# 134        5764027  2019-10-03  1610       9     Van Nuys                981
# 135        5764139  2019-10-03  1740      11    Northeast               1195
# 136        5764355  2019-10-03  2255      20      Olympic               2019
# 137        5764181  2019-10-03  1900      18    Southeast               1837
# 138        5764343  2019-10-03  2345       2      Rampart                245
# 139        5764073  2019-10-03  1845      16     Foothill               1689
# 140        5763614  2019-10-03  1115      12  77th Street               1259
# 141        5764049  2019-10-03  1650       3    Southwest                357
# 142        5763410  2019-10-03  0715       1      Central                142
# 143        5764184  2019-10-03  1925      21      Topanga               2189
# 144        5763758  2019-10-03  1425       4   Hollenbeck                491
# 145        5764171  2019-10-03  1905       4   Hollenbeck                429
# 146        5763783  2019-10-03  1455      17   Devonshire               1745
# 147        5764224  2019-10-03  1905       4   Hollenbeck                429
# 148        5763528  2019-10-03  0750       5       Harbor                505
# 149      191015897  2019-10-03  1155      10  West Valley               1008
# 150        5764090  2019-10-03  1630       2      Rampart                295
# 151        5764194  2019-10-03  2110      12  77th Street               1269
# 152        5764252  2019-10-03  2345       6    Hollywood                646
# 153        5763308  2019-10-03  0050      15  N Hollywood               1503
# 154        5763565  2019-10-03  0810       1      Central                153
# 155      191200815  2019-10-03  1240      12  77th Street               1258
# 156        5764043  2019-10-03  1530      13       Newton               1377
# 157        5763680  2019-10-03  1240       6    Hollywood                646
# 158        5763638  2019-10-03  1100      13       Newton               1321
# 159        5763592  2019-10-03  1005       1      Central                153
# 160        5763325  2019-10-03  0235      20      Olympic               2039
# 161        5764147  2019-10-03  1709      11    Northeast               1183
# 162        5763417  2019-10-03  0710      20      Olympic               2005
# 163        5763328  2019-10-03  0325      20      Olympic               2002
# 164        5764235  2019-10-03  2140       6    Hollywood                645
# 165        5764265  2019-10-03  1740       1      Central                157
# 166      191117526  2019-10-03  1710      11    Northeast               1128
# 167        5763309  2019-10-03  0105       5       Harbor                527
# 168        5763570  2019-10-03  1020       1      Central                154
# 169        5764197  2019-10-03  2150       5       Harbor                564
# 170        5764067  2019-10-03  1800      12  77th Street               1249
# 171      190124269  2019-10-03  0900       1      Central                164
# 172        5763713  2019-10-03  1210      13       Newton               1345
# 173        5764370  2019-10-03  2315       8      West LA                831
# 174      191117524  2019-10-03  1635      11    Northeast               1135
# 175        5764163  2019-10-03  2115      15  N Hollywood               1515
# 176        5764175  2019-10-03  1840      18    Southeast               1837
# 177        5763300  2019-10-03  0200       1      Central                176
# 178        5763304  2019-10-03  0107      16     Foothill               1681
# 179        5763350  2019-10-03  0445       6    Hollywood                644
# 180        5764270  2019-10-03  2235      19      Mission               1969
# 181        5763569  2019-10-03  0835       8      West LA                831
# 182        5763546  2019-10-03  0750       5       Harbor                505
# 183      191117525  2019-10-03  1625      11    Northeast               1135
# 184        5763554  2019-10-03  1000       1      Central                119
# 185        5764168  2019-10-03  1900      18    Southeast               1837
# 186        5763644  2019-10-03  1145      12  77th Street               1256
# 187        5763458  2019-10-03  0700       2      Rampart                246
# 188        5764282  2019-10-03  1835      11    Northeast               1162
# 189        5763316  2019-10-03  0220      20      Olympic               2002
# 190        5764047  2019-10-03  1555      13       Newton               1367
# 191        5764132  2019-10-03  1955      18    Southeast               1823
# 192        5763411  2019-10-03  0314      13       Newton               1303
# 193        5764344  2019-10-03  2359      14      Pacific               1472
# 194        5764002  2019-10-03  1450      10  West Valley               1063
# 195        5763310  2019-10-03  0155      20      Olympic               2002
# 196        5763640  2019-10-03  1225       1      Central                127
# 197        5763527  2019-10-03  1000       1      Central                127
# 198        5763315  2019-10-03  0155      13       Newton               1307
# 199        5764095  2019-10-03  1630       2      Rampart                295
# 200        5763685  2019-10-03  1315       5       Harbor                501
# 201        5763761  2019-10-03  1430      16     Foothill               1621
# 202        5763415  2019-10-03  0730      13       Newton               1327
# 203        5764040  2019-10-03  1510       8      West LA                859
# 204        5763744  2019-10-03  1450      12  77th Street               1263
# 205        5763317  2019-10-03  0035       5       Harbor                514
# 206        5764045  2019-10-03  1640      18    Southeast               1846
# 207        5763270  2019-10-03  0100      15  N Hollywood               1513
# 208        5763312  2019-10-03  0231      10  West Valley               1078
# 209        5764263  2019-10-03  2339       1      Central                191
# 210        5764113  2019-10-03  1850      19      Mission               1998
# 211        5763683  2019-10-03  1300       1      Central                138
# 212      191518415  2019-10-03  0745      15  N Hollywood               1511
# 213        5763335  2019-10-03  0327      15  N Hollywood               1599
# 214        5763571  2019-10-03  0750       5       Harbor                505
# 215        5764112  2019-10-03  1850       9     Van Nuys                935
# 216        5764217  2019-10-03  1900      18    Southeast               1837
# 217        5763319  2019-10-03  0315      20      Olympic               2002
# 218      191015896  2019-10-03  1155      10  West Valley               1008
# 219        5763989  2019-10-03  1400       3    Southwest                397
# 220        5764097  2019-10-03  1950      14      Pacific               1469
# 221      191117527  2019-10-03  1730      11    Northeast               1128
# 222        5763679  2019-10-03  1435       9     Van Nuys                935
# 223        5763451  2019-10-03  0555       3    Southwest                335
# 224        5763730  2019-10-03  0935       6    Hollywood                637
# 225        5764149  2019-10-03  1900      18    Southeast               1832
# 226        5763734  2019-10-03  1210       5       Harbor                585
# 227        5763510  2019-10-03  0800      15  N Hollywood               1511
# 228        5764079  2019-10-03  1630       2      Rampart                295
# 229        5763447  2019-10-03  0800      16     Foothill               1653
# 230      190516358  2019-10-03  0720       5       Harbor                503
# 231        5763657  2019-10-03  1100       7     Wilshire                767
# 232        5763509  2019-10-03  0900       1      Central                119
# 233        5764281  2019-10-03  2040       6    Hollywood                645
# 234        5763298  2019-10-03  0035      15  N Hollywood               1531
# 235        5763766  2019-10-03  1445      10  West Valley               1063
# 236        5763252  2019-10-03  0008      10  West Valley               1043
# 237        5763574  2019-10-03  1000      18    Southeast               1824
# 238        5764078  2019-10-03  1300      11    Northeast               1162
# 239        5764211  2019-10-03  2130       7     Wilshire                766
# 240        5764153  2019-10-03  2030      17   Devonshire               1782
# 241      191518394  2019-10-03  1740      15  N Hollywood               1549
# 242        5763461  2019-10-03  0820       2      Rampart                289
# 243        5763658  2019-10-03  1410      14      Pacific               1458
# 244        5763609  2019-10-03  1249       9     Van Nuys                935
# 245        5763521  2019-10-03  0750       5       Harbor                505
# 246        5763670  2019-10-03  1045      11    Northeast               1127
# 247        5764015  2019-10-03  1720      12  77th Street               1239
# 248        5763639  2019-10-03  1240      20      Olympic               2027
# 249        5763777  2019-10-03  1330       3    Southwest                326
# 250        5763425  2019-10-03  0730      16     Foothill               1661
# 251        5763556  2019-10-03  1141       9     Van Nuys                935
# 252        5763620  2019-10-03  1230      12  77th Street               1258
# 253        5763267  2019-10-03  0117      10  West Valley               1049
# 254        5764145  2019-10-03  2030       6    Hollywood                666
# 255        5764157  2019-10-03  1930      18    Southeast               1837
# 256        5763274  2019-10-03  0100       4   Hollenbeck                467
# 257        5763589  2019-10-03  1115       6    Hollywood                666
# 258        5764160  2019-10-03  2020      17   Devonshire               1735
# 259        5763276  2019-10-03  0045      20      Olympic               2002
# 260        5764200  2019-10-03  1840      18    Southeast               1837
# 261        5763612  2019-10-03  1215      14      Pacific               1457
# 262        5763573  2019-10-03  1200       1      Central                127
# 263        5764136  2019-10-03  1915       1      Central                134
# 264        5763437  2019-10-03  0510       5       Harbor                509
# 265        5763445  2019-10-03  0900       1      Central                127
# 266        5763324  2019-10-03  0220      20      Olympic               2002
# 267        5763774  2019-10-03  1600       1      Central                162
# 268      190516357  2019-10-03  0720       5       Harbor                503
# 269        5763669  2019-10-03  1215      12  77th Street               1258
# 270        5764099  2019-10-03  1830      15  N Hollywood               1526
# 271      192116696  2019-10-03  2030      21      Topanga               2136
# 272        5764368  2019-10-03  2110      19      Mission               1902
# 273        5763738  2019-10-03  1445      17   Devonshire               1767
# 274        5763321  2019-10-03  0307       9     Van Nuys                976
# 275      190516328  2019-10-03  0540       5       Harbor                565
# 276        5763397  2019-10-03  0520      18    Southeast               1841
# 277      191518393  2019-10-03  1655      15  N Hollywood               1549
# 278        5763577  2019-10-03  1015       7     Wilshire                785
# 279        5763756  2019-10-03  1400       1      Central                119
# 280        5764275  2019-10-03  2120       6    Hollywood                645
# 281        5764034  2019-10-03  1300       5       Harbor                513
# 282      192101042  2019-10-03  2030      21      Topanga               2136
# 283        5763299  2019-10-03  0200       5       Harbor                587
# 284        5764098  2019-10-03  1630       2      Rampart                295
# 285        5763341  2019-10-03  0230       6    Hollywood                647
# 286        5763399  2019-10-03  0605      12  77th Street               1258
# 287        5764186  2019-10-03  1850      13       Newton               1362
# 288        5764031  2019-10-03  1330       5       Harbor                565
# 289        5764307  2019-10-03  2220       1      Central                192
# 290        5763311  2019-10-03  0210      14      Pacific               1483
# 291        5764259  2019-10-03  2308      14      Pacific               1409
# 292        5762595  2019-10-02  0630       1      Central                119
# 293        5762344  2019-10-02  0138      14      Pacific               1479
# 294        5763148  2019-10-02  1950      18    Southeast               1806
# 295        5763043  2019-10-02  2013      20      Olympic               2063
# 296        5763009  2019-10-02  1845      11    Northeast               1186
# 297        5763166  2019-10-02  1845      19      Mission               1913
# 298        5762501  2019-10-02  0645       9     Van Nuys                926
# 299        5763099  2019-10-02  1545      10  West Valley               1027
# 300      192116550  2019-10-02  1030      21      Topanga               2158
# 301      191614881  2019-10-02  2050      16     Foothill               1612
# 302        5762499  2019-10-02  0740      12  77th Street               1249
# 303        5763020  2019-10-02  1835       2      Rampart                245
# 304        5763081  2019-10-02  2050      10  West Valley               1017
# 305        5762602  2019-10-02  0845       9     Van Nuys                935
# 306      191223896  2019-10-02  1240      12  77th Street               1253
# 307        5762882  2019-10-02  1615       3    Southwest                395
# 308        5762534  2019-10-02  0750       1      Central                119
# 309        5763070  2019-10-02  2005       4   Hollenbeck                426
# 310      190219408  2019-10-02  0115       2      Rampart                246
# 311        5763197  2019-10-02  2130      13       Newton               1371
# 312        5762837  2019-10-02  1345      11    Northeast               1186
# 313        5763119  2019-10-02  2100      11    Northeast               1183
# 314        5762353  2019-10-02  0242      20      Olympic               2053
# 315        5763108  2019-10-02  1840      12  77th Street               1257
# 316        5762705  2019-10-02  1120       3    Southwest                308
# 317        5762679  2019-10-02  1135      17   Devonshire               1735
# 318        5762966  2019-10-02  1710      16     Foothill               1602
# 319        5762301  2019-10-02  0045      19      Mission               1954
# 320      192017830  2019-10-02  1500      20      Olympic               2029
# 321      191614892  2019-10-02  2350      16     Foothill               1612
# 322        5763327  2019-10-02  2230      16     Foothill               1612
# 323        5763094  2019-10-02  2100       3    Southwest                392
# 324        5762928  2019-10-02  1650       1      Central                119
# 325        5763035  2019-10-02  1952      13       Newton               1303
# 326        5762610  2019-10-02  0940      18    Southeast               1842
# 327      191614883  2019-10-02  2300      16     Foothill               1612
# 328        5763262  2019-10-02  2320       6    Hollywood                645
# 329        5762444  2019-10-02  0256      13       Newton               1395
# 330        5762762  2019-10-02  1310      18    Southeast               1846
# 331      191614884  2019-10-02  2300      16     Foothill               1612
# 332      192017768  2019-10-02  1800      20      Olympic               2027
# 333        5762388  2019-10-02  0355       9     Van Nuys                911
# 334        5763086  2019-10-02  1725      15  N Hollywood               1503
# 335        5763085  2019-10-02  1820      12  77th Street               1249
# 336        5763216  2019-10-02  2255       4   Hollenbeck                438
# 337        5763266  2019-10-02  2210       6    Hollywood                667
# 338        5762331  2019-10-02  0205       3    Southwest                376
# 339        5763090  2019-10-02  2100       2      Rampart                246
# 340      192017773  2019-10-02  1800      20      Olympic               2027
# 341        5762427  2019-10-02  0200      12  77th Street               1256
# 342      190219354  2019-10-02  1335       2      Rampart                246
# 343        5763205  2019-10-02  1610      12  77th Street               1263
# 344        5762905  2019-10-02  1620       6    Hollywood                676
# 345        5763102  2019-10-02  1750      15  N Hollywood               1525
# 346      191614889  2019-10-02  2350      16     Foothill               1612
# 347        5763060  2019-10-02  1925      17   Devonshire               1776
# 348        5763171  2019-10-02  2030       9     Van Nuys                998
# 349        5762433  2019-10-02  0409      14      Pacific               1403
# 350        5762816  2019-10-02  1325      12  77th Street               1204
# 351        5762380  2019-10-02  0250      20      Olympic               2049
# 352        5762548  2019-10-02  0730       8      West LA                822
# 353        5763191  2019-10-02  2135      15  N Hollywood               1506
# 354        5762642  2019-10-02  1005       1      Central                127
# 355        5762831  2019-10-02  1030       5       Harbor                507
# 356        5763138  2019-10-02  1930       5       Harbor                531
# 357      191614888  2019-10-02  2250      16     Foothill               1612
# 358        5762430  2019-10-02  0341      11    Northeast               1146
# 359        5762880  2019-10-02  1530       6    Hollywood                642
# 360        5763095  2019-10-02  1620      19      Mission               1995
# 361        5763093  2019-10-02  1805      12  77th Street               1249
# 362        5763091  2019-10-02  2005       7     Wilshire                702
# 363      190516263  2019-10-02  0825       5       Harbor                566
# 364      191716024  2019-10-02  0900      17   Devonshire               1794
# 365        5762739  2019-10-02  1323       9     Van Nuys                935
# 366        5762854  2019-10-02  1345      20      Olympic               2029
# 367        5763194  2019-10-02  2040       4   Hollenbeck                497
# 368        5762769  2019-10-02  1355       9     Van Nuys                935
# 369        5762893  2019-10-02  1143      10  West Valley               1049
# 370        5763211  2019-10-02  2320       4   Hollenbeck                421
# 371      190516264  2019-10-02  0950       5       Harbor                566
# 372      190620120  2019-10-02  1130       6    Hollywood                667
# 373        5762994  2019-10-02  1715       1      Central                152
# 374        5762770  2019-10-02  1220      20      Olympic               2056
# 375      190219409  2019-10-02  0115       2      Rampart                246
# 376        5763240  2019-10-02  2215       9     Van Nuys                971
# 377        5763072  2019-10-02  1800      20      Olympic               2027
# 378        5762355  2019-10-02  0100      18    Southeast               1801
# 379        5762581  2019-10-02  0655      14      Pacific               1494
# 380        5763075  2019-10-02  2015      19      Mission               1944
# 381        5762533  2019-10-02  0930       9     Van Nuys                935
# 382        5762442  2019-10-02  0115      12  77th Street               1265
# 383      191319895  2019-10-02  1800      13       Newton               1362
# 384        5763118  2019-10-02  1950      20      Olympic               2071
# 385        5763207  2019-10-02  2010      19      Mission               1918
# 386      190516265  2019-10-02  0750       5       Harbor                566
# 387        5762641  2019-10-02  1015       9     Van Nuys                931
# 388        5763195  2019-10-02  2050      13       Newton               1383
# 389        5763149  2019-10-02  1930       9     Van Nuys                998
# 390        5762843  2019-10-02  1430      15  N Hollywood               1547
# 391        5762544  2019-10-02  0830       1      Central                119
# 392        5763116  2019-10-02  1725      15  N Hollywood               1503
# 393      192116601  2019-10-02  0900      21      Topanga               2185
# 394        5762872  2019-10-02  1440      10  West Valley               1049
# 395        5763101  2019-10-02  2043      13       Newton               1343
# 396      191421354  2019-10-02  0030      14      Pacific               1472
# 397        5762821  2019-10-02  1140      14      Pacific               1437
# 398        5763004  2019-10-02  1645      18    Southeast               1849
# 399        5763273  2019-10-02  2210       6    Hollywood                627
# 400        5762512  2019-10-02  0735       6    Hollywood                663
# 401        5762500  2019-10-02  0720       1      Central                119
# 402        5763202  2019-10-02  2050      12  77th Street               1283
# 403        5763142  2019-10-02  2030      16     Foothill               1663
# 404        5762684  2019-10-02  1225       1      Central                127
# 405        5762490  2019-10-02  0600       4   Hollenbeck                438
# 406        5763023  2019-10-02  1720      17   Devonshire               1788
# 407        5762897  2019-10-02  1600      20      Olympic               2029
# 408        5762797  2019-10-02  1230       5       Harbor                519
# 409        5763281  2019-10-02  2200      10  West Valley               1005
# 410        5763061  2019-10-02  1700      18    Southeast               1864
# 411        5763215  2019-10-02  1800       5       Harbor                528
# 412        5762708  2019-10-02  1140       6    Hollywood                667
# 413        5762280  2019-10-02  0040       9     Van Nuys                941
# 414      192017772  2019-10-02  1800      20      Olympic               2027
# 415        5763231  2019-10-02  2300       7     Wilshire                706
# 416        5762733  2019-10-02  1150       6    Hollywood                667
# 417        5762956  2019-10-02  1600      21      Topanga               2105
# 418        5763012  2019-10-02  1730      18    Southeast               1842
# 419        5762716  2019-10-02  1120       1      Central                162
# 420        5763157  2019-10-02  2150      13       Newton               1383
# 421        5762366  2019-10-02  0130      19      Mission               1981
# 422        5762614  2019-10-02  0915       1      Central                148
# 423      192116549  2019-10-02  1050      21      Topanga               2158
# 424        5763173  2019-10-02  2145       4   Hollenbeck                438
# 425        5763103  2019-10-02  1725      15  N Hollywood               1515
# 426      192017774  2019-10-02  1800      20      Olympic               2027
# 427        5762491  2019-10-02  0630      12  77th Street               1203
# 428        5762809  2019-10-02  1525      19      Mission               1995
# 429        5763018  2019-10-02  1840      18    Southeast               1824
# 430        5762606  2019-10-02  0815       2      Rampart                201
# 431        5762840  2019-10-02  1255       1      Central                152
# 432        5763109  2019-10-02  1720      15  N Hollywood               1503
# 433        5762361  2019-10-02  0235       7     Wilshire                784
# 434        5763077  2019-10-02  1800      13       Newton               1317
# 435      191614878  2019-10-02  2300      16     Foothill               1612
# 436        5763214  2019-10-02  2320       6    Hollywood                636
# 437        5762777  2019-10-02  1255      12  77th Street               1251
# 438        5762359  2019-10-02  0130      19      Mission               1961
# 439        5762917  2019-10-02  1510       1      Central                119
# 440      191614893  2019-10-02  2050      16     Foothill               1612
# 441        5762815  2019-10-02  1225       5       Harbor                565
# 442      190816401  2019-10-02  1745       8      West LA                882
# 443        5763100  2019-10-02  1600      12  77th Street               1263
# 444        5763151  2019-10-02  2000       3    Southwest                397
# 445        5762685  2019-10-02  0905      17   Devonshire               1723
# 446        5762890  2019-10-02  1300      13       Newton               1341
# 447      190917762  2019-10-02  1740       9     Van Nuys                964
# 448        5762697  2019-10-02  1130       1      Central                127
# 449      191223894  2019-10-02  1240      12  77th Street               1253
# 450        5763188  2019-10-02  1900       9     Van Nuys                998
# 451        5762666  2019-10-02  1020       7     Wilshire                782
# 452        5762640  2019-10-02  1133      12  77th Street               1258
# 453        5762731  2019-10-02  1000      10  West Valley               1008
# 454        5763079  2019-10-02  2000       1      Central                162
# 455        5762958  2019-10-02  1440       7     Wilshire                732
# 456        5762266  2019-10-02  0030      10  West Valley               1031
# 457        5763022  2019-10-02  1730      18    Southeast               1842
# 458      191614880  2019-10-02  2300      16     Foothill               1612
# 459        5763170  2019-10-02  2200       7     Wilshire                749
# 460        5762381  2019-10-02  0130       3    Southwest                362
# 461      191614886  2019-10-02  2300      16     Foothill               1612
# 462        5763007  2019-10-02  1430      10  West Valley               1019
# 463        5763087  2019-10-02  1745      12  77th Street               1249
# 464        5762391  2019-10-02  0130       3    Southwest                362
# 465        5762841  2019-10-02  1430       3    Southwest                399
# 466        5763016  2019-10-02  1825       1      Central                162
# 467        5762633  2019-10-02  1000       1      Central                123
# 468        5763175  2019-10-02  2145       4   Hollenbeck                438
# 469      191614882  2019-10-02  2250      16     Foothill               1612
# 470        5762763  2019-10-02  1300       9     Van Nuys                904
# 471        5763196  2019-10-02  2140      16     Foothill               1602
# 472        5763083  2019-10-02  1755      20      Olympic               2027
# 473        5762434  2019-10-02  0155      14      Pacific               1485
# 474        5763096  2019-10-02  1755       7     Wilshire                755
# 475        5763017  2019-10-02  1858      14      Pacific               1494
# 476        5763192  2019-10-02  2230      20      Olympic               2002
# 477        5762894  2019-10-02  1600       1      Central                164
# 478      192017770  2019-10-02  1800      20      Olympic               2027
# 479        5762860  2019-10-02  1045      16     Foothill               1612
# 480        5762835  2019-10-02  1320      10  West Valley               1065
# 481        5762646  2019-10-02  0915       7     Wilshire                774
# 482        5762318  2019-10-02  0025       1      Central                156
# 483        5763145  2019-10-02  2020       3    Southwest                335
# 484        5762656  2019-10-02  1040      10  West Valley               1008
# 485        5762530  2019-10-02  0710       2      Rampart                251
# 486        5762535  2019-10-02  0845      18    Southeast               1871
# 487        5762719  2019-10-02  1130      20      Olympic               2056
# 488        5763218  2019-10-02  2035      10  West Valley               1018
# 489      192116600  2019-10-02  1050      21      Topanga               2158
# 490      190816446  2019-10-02  1725       8      West LA                882
# 491        5762635  2019-10-02  0830       7     Wilshire                723
# 492      191614891  2019-10-02  2350      16     Foothill               1612
# 493        5762787  2019-10-02  0915       9     Van Nuys                911
# 494        5763184  2019-10-02  2020      20      Olympic               2024
# 495        5762622  2019-10-02  0905      19      Mission               1985
# 496        5762999  2019-10-02  1715      13       Newton               1394
# 497        5763089  2019-10-02  2020       4   Hollenbeck                401
# 498        5762814  2019-10-02  1220       5       Harbor                529
# 499      191614887  2019-10-02  2300      16     Foothill               1612
# ...            ...         ...   ...     ...          ...                ...
# 1304647  100104156  2010-01-02  1745       1      Central                191
# 1304648  101800508  2010-01-02  0445      18    Southeast               1864
# 1304649  100304111  2010-01-02  1500       3    Southwest                316
# 1304650    2180724  2010-01-02  0315       8      West LA                852
# 1304651    2181427  2010-01-02  2220      16     Foothill               1612
# 1304652    2181164  2010-01-02  1815      16     Foothill               1654
# 1304653    2180708  2010-01-02  0238      15  N Hollywood               1511
# 1304654  101404099  2010-01-02  1640      14      Pacific               1444
# 1304655    2181281  2010-01-02  2130       7     Wilshire                749
# 1304656    2181219  2010-01-02  1830      11    Northeast               1181
# 1304657  100904090  2010-01-02  1735       9     Van Nuys                923
# 1304658  100904087  2010-01-02  1805       9     Van Nuys                911
# 1304659  100304127  2010-01-02  1435       3    Southwest                373
# 1304660  102004093  2010-01-02  1535      20      Olympic               2024
# 1304661    2181503  2010-01-02  2045      12  77th Street               1259
# 1304662    2180865  2010-01-02  1030       1      Central                155
# 1304663  100204079  2010-01-02  1550       2      Rampart                265
# 1304664    2180672  2010-01-02  0205      15  N Hollywood               1585
# 1304665    2181217  2010-01-02  1945      16     Foothill               1698
# 1304666  101604186  2010-01-02  2130      16     Foothill               1601
# 1304667  100904044  2010-01-02  1210       9     Van Nuys                915
# 1304668  101804122  2010-01-02  2015      18    Southeast               1863
# 1304669    2180958  2010-01-02  1250       1      Central                157
# 1304670    2181292  2010-01-02  1900       8      West LA                817
# 1304671  100904086  2010-01-02  1650       9     Van Nuys                933
# 1304672    2181102  2010-01-02  1720      11    Northeast               1113
# 1304673  101704122  2010-01-02  1740      17   Devonshire               1764
# 1304674  100804084  2010-01-02  2100       8      West LA                808
# 1304675  101700504  2010-01-02  1220      17   Devonshire               1792
# 1304676  101900509  2010-01-02  1230      19      Mission               1974
# 1304677  100204080  2010-01-02  1930       2      Rampart                246
# 1304678  101704298  2010-01-02  2305      17   Devonshire               1793
# 1304679    2181379  2010-01-02  2245       6    Hollywood                645
# 1304680    2180836  2010-01-02  0945      20      Olympic               2041
# 1304681    2181095  2010-01-02  1640      21      Topanga               2147
# 1304682    2180923  2010-01-02  1030      13       Newton               1327
# 1304683    2180867  2010-01-02  1030       3    Southwest                395
# 1304684    2181125  2010-01-02  1820       9     Van Nuys                919
# 1304685  101704127  2010-01-02  1050      17   Devonshire               1785
# 1304686  100604118  2010-01-02  1250       6    Hollywood                646
# 1304687    2180965  2010-01-02  1320      13       Newton               1307
# 1304688    2181038  2010-01-02  1600       1      Central                148
# 1304689    2181365  2010-01-02  2200      19      Mission               1975
# 1304690  102004567  2010-01-02  2200      20      Olympic               2076
# 1304691    2181285  2010-01-02  1900       8      West LA                817
# 1304692    2181005  2010-01-02  1200      17   Devonshire               1794
# 1304693    2181504  2010-01-02  2140      21      Topanga               2147
# 1304694    2180959  2010-01-02  1215      19      Mission               1974
# 1304695    2181204  2010-01-02  1930      20      Olympic               2024
# 1304696  102105939  2010-01-02  1735      21      Topanga               2157
# 1304697    2181239  2010-01-02  1905      14      Pacific               1446
# 1304698  100104090  2010-01-02  2130       1      Central                128
# 1304699    2181105  2010-01-02  1640      21      Topanga               2147
# 1304700    2181198  2010-01-02  1720      12  77th Street               1258
# 1304701    2180676  2010-01-02  0150       9     Van Nuys                916
# 1304702    2181446  2010-01-02  2310       9     Van Nuys                923
# 1304703  100804886  2010-01-02  0915       8      West LA                851
# 1304704    2180850  2010-01-02  0950      12  77th Street               1252
# 1304705    2180889  2010-01-02  1100       1      Central                158
# 1304706  102104296  2010-01-02  1940      21      Topanga               2185
# 1304707    2181339  2010-01-02  1935      18    Southeast               1822
# 1304708  101904137  2010-01-02  1915      19      Mission               1917
# 1304709  100604229  2010-01-02  1600       6    Hollywood                645
# 1304710    2181224  2010-01-02  1820      10  West Valley               1018
# 1304711  102104092  2010-01-02  1635      21      Topanga               2147
# 1304712    2180944  2010-01-02  1115       1      Central                158
# 1304713    2180656  2010-01-02  0040      19      Mission               1982
# 1304714    2181289  2010-01-02  2100      16     Foothill               1687
# 1304715  100604120  2010-01-02  1415       6    Hollywood                678
# 1304716    2180741  2010-01-02  0410       6    Hollywood                668
# 1304717    2180983  2010-01-02  1330      15  N Hollywood               1557
# 1304718    2180636  2010-01-02  0150       6    Hollywood                645
# 1304719    2181402  2010-01-02  2220      14      Pacific               1474
# 1304720    2180735  2010-01-02  0240      10  West Valley               1018
# 1304721    2181040  2010-01-02  1415      21      Topanga               2156
# 1304722  100604227  2010-01-02  1220       6    Hollywood                638
# 1304723    2181138  2010-01-02  1710       1      Central                147
# 1304724    2180994  2010-01-02  1200      19      Mission               1982
# 1304725  101904133  2010-01-02  1810      19      Mission               1902
# 1304726  100704047  2010-01-02  1745       7     Wilshire                711
# 1304727    2181351  2010-01-02  2115      21      Topanga               2155
# 1304728    2181015  2010-01-02  1300       9     Van Nuys                998
# 1304729    2180756  2010-01-02  0215      11    Northeast               1162
# 1304730    2180697  2010-01-02  0005      16     Foothill               1601
# 1304731    2180617  2010-01-02  0050       6    Hollywood                656
# 1304732    2181025  2010-01-02  1330       8      West LA                833
# 1304733    2181592  2010-01-02  2130      13       Newton               1352
# 1304734  101404749  2010-01-02  1525      14      Pacific               1431
# 1304735    2181027  2010-01-02  1445       5       Harbor                584
# 1304736    2181345  2010-01-02  2050      10  West Valley               1001
# 1304737    2181148  2010-01-02  1745       1      Central                156
# 1304738    2180659  2010-01-02  0045      18    Southeast               1842
# 1304739    2180707  2010-01-02  0315       6    Hollywood                636
# 1304740  101405295  2010-01-02  1610      14      Pacific               1431
# 1304741    2181463  2010-01-02  2315       5       Harbor                563
# 1304742  100604179  2010-01-02  1630       6    Hollywood                636
# 1304743    2181297  2010-01-02  2040      12  77th Street               1248
# 1304744    2180750  2010-01-02  0420      13       Newton               1307
# ...
# 1304902  -118.3703            Hispanic             Misdemeanor
# 1304903  -118.2131               Black                  Felony
# 1304904  -118.2439               Black             Misdemeanor
# 1304905  -118.2871               Black                  Felony
# 1304906  -118.2992            Hispanic                  Felony
# 1304907  -118.2493               Black                  Felony
# 1304908  -118.5535               Black             Misdemeanor
# 1304909  -118.3428               White                  Felony
# 1304910  -118.4633            Hispanic             Misdemeanor
# 1304911  -118.4400               Black             Misdemeanor
# 1304912  -118.3656               Black             Misdemeanor
# 1304913  -118.4441            Hispanic                  Felony
# 1304914  -118.5197               Asian             Misdemeanor
# 1304915  -118.3295               Black             Misdemeanor
# 1304916  -118.2509            Hispanic             Misdemeanor
# 1304917  -118.2421            Hispanic                  Felony
# 1304918  -118.3730            Hispanic                  Felony
# 1304919  -118.3089               Black             Misdemeanor
# 1304920  -118.3703               White             Misdemeanor
# 1304921  -118.3386               Black             Misdemeanor
# 1304922  -118.3309               Black                  Felony
# 1304923  -118.2739            Hispanic                  Felony
# 1304924  -118.2807               White             Misdemeanor
# 1304925  -118.2612               Black             Misdemeanor
# 1304926  -118.3387               Other                  Felony
# 1304927  -118.2818            Hispanic                  Felony
# 1304928  -118.3116            Hispanic                  Felony
# 1304929  -118.2980            Hispanic                  Felony
# 1304930  -118.3090            Hispanic                  Felony
# 1304931  -118.2871               White             Misdemeanor
# 1304932  -118.2503               Black             Misdemeanor
# 1304933  -118.3297            Hispanic             Misdemeanor
# 1304934  -118.5117            Hispanic                  Felony
# 1304935  -118.2624            Hispanic                  Felony
# 1304936  -118.3537               Black                  Felony
# 1304937  -118.2502               Black             Misdemeanor
# 1304938  -118.3785               White                  Felony
# 1304939  -118.2581               White             Misdemeanor
# 1304940  -118.3618            Hispanic                  Felony
# 1304941  -118.5885            Hispanic             Misdemeanor
# 1304942  -118.3108               Black             Misdemeanor
# 1304943  -118.2450               Black                  Felony
# 1304944  -118.2770               Black             Misdemeanor
# 1304945  -118.2916               Black                  Felony
# 1304946  -118.4361            Hispanic             Misdemeanor
# 1304947  -118.4543               White                  Felony
# 1304948  -118.2805               Black                  Felony
# 1304949  -118.3294               Black                  Felony
# 1304950  -118.3351               Black                  Felony
# 1304951  -118.2402               White             Misdemeanor
# 1304952  -118.2089               Black                  Felony
# 1304953  -118.2612               White                  Felony
# 1304954  -118.3122            Hispanic             Misdemeanor
# 1304955  -118.4425            Hispanic             Misdemeanor
# 1304956  -118.4158            Hispanic                  Felony
# 1304957  -118.4736               White                  Felony
# 1304958  -118.4686               Other                  Felony
# 1304959  -118.3136            Hispanic                  Felony
# 1304960  -118.2739            Hispanic             Misdemeanor
# 1304961  -118.3387               White             Misdemeanor
# 1304962  -118.2827               Black                  Felony
# 1304963  -118.3762               White                  Felony
# 1304964  -118.5776            Hispanic                  Felony
# 1304965  -118.2493               Black             Misdemeanor
# 1304966  -118.4583            Hispanic                  Felony
# 1304967  -118.2485               Black             Misdemeanor
# 1304968  -118.5144               White             Misdemeanor
# 1304969  -118.3308               Black             Misdemeanor
# 1304970  -118.2778            Hispanic                  Felony
# 1304971  -118.3109            Hispanic             Misdemeanor
# 1304972  -118.3972            Hispanic             Misdemeanor
# 1304973  -118.3310               White                  Felony
# 1304974  -118.2627               Other                  Felony
# 1304975  -118.4163            Hispanic                  Felony
# 1304976  -118.3004            Hispanic                  Felony
# 1304977  -118.2490            Hispanic                  Felony
# 1304978  -118.4729               White             Misdemeanor
# 1304979  -118.3267               Black             Misdemeanor
# 1304980  -118.3453            Hispanic             Misdemeanor
# 1304981  -118.4051            Hispanic                  Felony
# 1304982  -118.3760               White             Misdemeanor
# 1304983  -118.4797            Hispanic                  Felony
# 1304984  -118.2937               Black                  Felony
# 1304985  -118.5841               Black                  Felony
# 1304986  -118.4221            Hispanic             Misdemeanor
# 1304987  -118.2708               Black                  Felony
# 1304988  -118.1861            Hispanic             Misdemeanor
# 1304989  -118.5448            Hispanic                  Felony
# 1304990  -118.3348               Black             Misdemeanor
# 1304991  -118.4339            Hispanic             Misdemeanor
# 1304992  -118.2588            Hispanic                  Felony
# 1304993  -118.3146               White             Misdemeanor
# 1304994  -118.3122               Other             Misdemeanor
# 1304995  -118.4797               White                  Felony
# 1304996  -118.2827            Hispanic             Misdemeanor
# 1304997  -118.2824            Hispanic             Misdemeanor
# 1304998  -118.4095            Hispanic             Misdemeanor
# 1304999  -118.2739               Black                  Felony
# 1305000  -118.2432               Black                  Felony
# 1305001  -118.4736               White                  Felony
# 1305002  -118.2717            Hispanic                  Felony
# 1305003  -118.4139               Other                  Felony
# 1305004  -118.3091            Hispanic             Misdemeanor
# 1305005  -118.2810            Hispanic                  Felony
# 1305006  -118.4283            Hispanic             Misdemeanor
# 1305007  -118.2461            Hispanic                  Felony
# 1305008  -118.2628               White             Misdemeanor
# 1305009  -118.4741               White             Misdemeanor
# 1305010  -118.2564            Hispanic                  Felony
# 1305011  -118.2696            Hispanic             Misdemeanor
# 1305012  -118.2450            Hispanic             Misdemeanor
# 1305013  -118.2452               Black             Misdemeanor
# 1305014  -118.4531            Hispanic             Misdemeanor
# 1305015  -118.4796            Hispanic             Misdemeanor
# 1305016  -118.3374               White             Misdemeanor
# 1305017  -118.2857               White                  Felony
# 1305018  -118.2902            Hispanic             Misdemeanor
# 1305019  -118.4536            Hispanic             Misdemeanor
# 1305020  -118.4775               White             Misdemeanor
# 1305021  -118.5395               White             Misdemeanor
# 1305022  -118.3760               Other             Misdemeanor
# 1305023  -118.2220            Hispanic                  Felony
# 1305024  -118.6084               Black             Misdemeanor
# 1305025  -118.2987            Hispanic             Misdemeanor
# 1305026  -118.2450               Black                  Felony
# 1305027  -118.3496               Black                  Felony
# 1305028  -118.4313            Hispanic             Misdemeanor
# 1305029  -118.4741               Black             Misdemeanor
# 1305030  -118.2502               Black             Misdemeanor
# 1305031  -118.5339            Hispanic                  Felony
# 1305032  -118.2880            Hispanic                  Felony
# 1305033  -118.2330            Hispanic             Misdemeanor
# 1305034  -118.3090            Hispanic             Misdemeanor
# 1305035  -118.4634            Hispanic             Misdemeanor
# 1305036  -118.3539               Black             Misdemeanor
# 1305037  -118.2104               Other                  Felony
# 1305038  -118.4266            Hispanic             Misdemeanor
# 1305039  -118.4443               White                  Felony
# 1305040  -118.2915               Black             Misdemeanor
# 1305041  -118.3649               Black                  Felony
# 1305042  -118.3539               White             Misdemeanor
# 1305043  -118.2871               Black             Misdemeanor
# 1305044  -118.3766               Black             Misdemeanor
# 1305045  -118.2759            Hispanic                  Felony
# 1305046  -118.4535            Hispanic                  Felony
# 1305047  -118.2673               Black                  Felony
# 1305048  -118.2879            Hispanic             Misdemeanor
# 1305049  -118.2770               White             Misdemeanor
# 1305050  -118.2739               Black             Misdemeanor
# 1305051  -118.4665               White             Misdemeanor
# 1305052  -118.2652            Hispanic                  Felony
# 1305053  -118.2959               Black                  Felony
# 1305054  -118.4775               White             Misdemeanor
# 1305055  -118.3888            Hispanic             Misdemeanor
# 1305056  -118.2407               Black                  Felony
# 1305057  -118.4665               White             Misdemeanor
# 1305058  -118.3092            Hispanic             Misdemeanor
# 1305059  -118.4120            Hispanic             Misdemeanor
# 1305060  -118.2493               Black                  Felony
# 1305061  -118.4095               Black                  Felony
# 1305062  -118.3180            Hispanic             Misdemeanor
# 1305063  -118.3119            Hispanic             Misdemeanor
# 1305064  -118.4312            Hispanic             Misdemeanor
# 1305065  -118.4159               White                  Felony
# 1305066  -118.4499            Hispanic             Misdemeanor
# 1305067  -118.3332            Hispanic             Misdemeanor
# 1305068  -118.3752            Hispanic             Misdemeanor
# 1305069  -118.3374            Hispanic             Misdemeanor
# 1305070  -118.3297               White             Misdemeanor
# 1305071  -118.1826            Hispanic             Misdemeanor
# 1305072  -118.3307            Hispanic             Misdemeanor
# 1305073  -118.3387               White             Misdemeanor
# 1305074  -118.2544               Black             Misdemeanor
# 1305075  -118.3868            Hispanic             Misdemeanor
# 1305076  -118.2718            Hispanic             Misdemeanor
# 1305077  -118.4448               Black             Misdemeanor
# 1305078  -118.3877            Hispanic             Misdemeanor
# 1305079  -118.3015               Black                  Felony
# 1305080  -118.2702            Hispanic             Misdemeanor
# 1305081  -118.3374            Hispanic             Misdemeanor
# 1305082  -118.4200            Hispanic                  Felony
# 1305083  -118.3090            Hispanic                  Felony
# 1305084  -118.3167               Black             Misdemeanor
# 1305085  -118.2941            Hispanic             Misdemeanor
# 1305086  -118.2783            Hispanic                  Felony
# 1305087  -118.2468            Hispanic             Misdemeanor
# 1305088  -118.4090            Hispanic             Misdemeanor
# 1305089  -118.4553               White                  Felony
# 1305090  -118.3774            Hispanic             Misdemeanor
# 1305091  -118.3921            Hispanic                  Felony
# 1305092  -118.2702               Black                  Felony
# 1305093  -118.2926            Hispanic                  Felony
# 1305094  -118.4686               Other                  Felony
# 1305095  -118.2858            Hispanic             Misdemeanor
# 1305096  -118.5928            Hispanic             Misdemeanor
# 1305097  -118.3547               Black                  Felony
# 1305098  -118.3374            Hispanic             Misdemeanor
# 1305099  -118.6233               White                  Felony
# 1305100  -118.3591               Black                  Felony
# 1305101  -118.5973               White                  Felony
# 1305102  -118.4665               White             Misdemeanor
# 1305103  -118.2564            Hispanic                  Felony
# 1305104  -118.2868            Hispanic                  Felony
# 1305105  -118.4765               Other             Misdemeanor
# 1305106  -118.4720               White             Misdemeanor
# 1305107  -118.3311               White             Misdemeanor
# 1305108  -118.5943            Hispanic             Misdemeanor
# 1305109  -118.4387               White                  Felony
# 1305110  -118.3703               White                  Felony
# 1305111  -118.3370               Black             Misdemeanor
# 1305112  -118.3414               Black                  Felony
# 1305113  -118.5929            Hispanic             Misdemeanor
# 1305114  -118.3764               Other             Misdemeanor
# 1305115  -118.3955               White             Misdemeanor
# 1305116  -118.4354            Hispanic                  Felony
# 1305117  -118.4225               White             Misdemeanor
# 1305118  -118.2772               Black                  Felony
# 1305119  -118.5274            Hispanic             Misdemeanor
# 1305120  -118.4729            Hispanic             Misdemeanor
# 1305121  -118.1918            Hispanic             Misdemeanor
# 1305122  -118.1826            Hispanic             Misdemeanor
# 1305123  -118.5710            Hispanic                  Felony
# 1305124  -118.5317            Hispanic                  Felony
# 1305125  -118.2428               Black                  Felony
# 1305126  -118.2842            Hispanic                  Felony
# 1305127  -118.2160            Hispanic             Misdemeanor
# 1305128  -118.4848            Hispanic             Misdemeanor
# 1305129  -118.4662               White             Misdemeanor
# 1305130  -118.2460               White                  Felony
# 1305131  -118.2699            Hispanic             Misdemeanor
# 1305132  -118.4048            Hispanic             Misdemeanor
# 1305133  -118.2924            Hispanic             Misdemeanor
# 1305134  -118.2628               Black             Misdemeanor
# 1305135  -118.3374               Asian             Misdemeanor
# 1305136  -118.3777            Hispanic             Misdemeanor
# 1305137  -118.4736            Hispanic             Misdemeanor
# 1305138  -118.4291               Other             Misdemeanor
# 1305139  -118.4073               White                  Felony
# 1305140  -118.2775            Hispanic             Misdemeanor
# 1305141  -118.3295            Hispanic             Misdemeanor
# 1305142  -118.3656               Other             Misdemeanor
# 1305143  -118.4572               White                  Felony
# 1305144  -118.5955            Hispanic             Misdemeanor
# 1305145  -118.2708               Black                  Felony
# 1305146  -118.4516            Hispanic             Misdemeanor
#
# [1304895 rows x 29 columns]

# %% [markdown]
# #### Count the arrests by charge type

# %%
charges_grouped = arrests.groupby(['charge', 'charge_description']).agg('size').sort_values(ascending=False).reset_index(name='total')

# %% [markdown]
# #### Top 10 arrest charges 2010-2019

# %%
charges_grouped.head(10)
# Out:
#        charge                        charge_description  total
# 0  23152(A)VC               DRUNK DRIVING ALCOHOL/DRUGS  97324
# 1  41.27CLAMC                        DRINKING IN PUBLIC  93527
# 2  273.5(A)PC  CORPORAL INJURY ON SPOUSE/COHABITANT/ETC  46259
# 3  11377(A)HS           POSSESSION CONTROLLED SUBSTANCE  40832
# 4     853.7PC                 FTA AFTER WRITTEN PROMISE  31481
# 5  11350(A)HS  POSSESSION NARCOTIC CONTROLLED SUBSTANCE  29350
# 6    647(B)PC                              PROSTITUTION  26591
# 7     25620BP   OPEN ALCOHOLIC BEV IN PUBLIC PARK/PLACE  25949
# 8  41.18DLAMC          SIT/LIE/SLEEP SIDEWALK OR STREET  25700
# 9        LAMC                LOS ANGELES MUNICIPAL CODE  24574

# %% [markdown]
# #### Isolate all 'sit-lie' cases and just 41.18D

# %%
sit_lie_all = arrests[arrests.charge.str.contains('41.18')]
sit_lie_d = arrests[arrests['charge'] == '41.18DLAMC']
sidewalk_property_cases = arrests[arrests.charge.str.contains('56.11')]

# %%
# How many 'sit-lie' cases total?
len(sit_lie_all)
# Out:
# 36947

# %%
# How many '41.18D' cases total?
len(sit_lie_d)
# Out:
# 28696

# %%
# How many '56.11' cases total?
len(sidewalk_property_cases)
# Out:
# 3909

# %% [markdown]
# ---

# %% [markdown]
# ### Look more closely at the 'sit-lie' cases

# %%
sit_lie_all['sex_code'].value_counts('normalize').round(4)*100
# Out:
# M    74.1
# F    25.9
# Name: sex_code, dtype: float64

# %%
sit_lie_all['descent_description'].value_counts('normalize').round(4)*100
# Out:
# Black                             43.62
# White                             33.19
# Hispanic                          20.26
# Other                              2.37
# Asian                              0.54
# American Indian/Alaskan Native     0.02
# Name: descent_description, dtype: float64

# %%
sit_lie_all['arrest_type_description'].value_counts('normalize').round(4)*100
# Out:
# Misdemeanor    87.01
# Infraction     12.98
# Other           0.01
# Name: arrest_type_description, dtype: float64

# %%
sit_lie_all['night'].value_counts('normalize').round(4)*100
# Out:
# False    95.43
# True      4.57
# Name: night, dtype: float64

# %%
sit_lie_years = sit_lie_all.groupby(['year'])\
.agg('size').sort_values(ascending=False).reset_index(name='total')

sit_lie_years.sort_values(by='year', inplace=True)

# %%
sit_lie_quarters = sit_lie_all.groupby(['quarter', 'year'])\
.agg('size').sort_values(ascending=False).reset_index(name='total')

sit_lie_quarters.sort_values(by='year', inplace=True)

# %%
sit_lie_quarters.head(10)
# Out:
#     quarter  year  total
# 31        3  2010    375
# 32        4  2010    304
# 28        2  2010    467
# 35        1  2010    249
# 34        2  2011    286
# 30        3  2011    389
# 37        1  2011    226
# 27        4  2011    495
# 7         4  2012   1331
# 24        2  2012    817

# %%
sit_lie_quarters.to_csv('output/sit_lie_quarters.csv')

# %% [markdown]
# #### Chart the years

# %%
alt.Chart(sit_lie_years).mark_bar().encode(
    y=alt.Y('year:N', title="Arrests", axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("total:Q", title="Arrests"),
    facet='area_name:N',
).properties(height=200, width=600)

# %% [markdown]
# #### Group all 'sit-lie' cases by charge, location, year — and count arrests

# %%
charges_grouped_sit_lie_all = sit_lie_all.groupby\
(['charge', 'charge_description','area_name','reporting_district', 'year'])\
.agg('size').sort_values(ascending=False).reset_index()

# %%
charges_grouped_sit_lie_all.columns = ['charge', 'charge_description', 'area_name', 'reporting_district', 'year','total']
charges_grouped_sit_lie_all['reporting_district'] = charges_grouped_sit_lie_all['reporting_district'].astype(str)

# %%
charges_grouped_sit_lie_all.head()
# Out:
#        charge                charge_description area_name reporting_district  \
# 0  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                157
# 1  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                111
# 2  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                158
# 3  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                157
# 4  41.18DLAMC  SIT/LIE/SLEEP SIDEWALK OR STREET   Central                157
#
#    year  total
# 0  2016    572
# 1  2017    427
# 2  2013    425
# 3  2014    423
# 4  2013    388

# %%
districts_counts_years_pivot = pd.pivot_table(charges_grouped_sit_lie_all, values='total', \
index=['reporting_district'], columns=['year'], aggfunc=np.sum, fill_value=0).sort_values(by='2019', ascending=False).reset_index()

districts_counts_years_pivot.head()
# Out:
# year reporting_district  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# 0                   156    10    39   223   214   150   134   199   317   153
# 1                   166     5    39   232   282   196   100    79   189   116
# 2                   176     1    14    52    46    22    65   155   132    71
# 3                  1307    11    35    93   147    46    44    18    21    17
# 4                   165     1     3    34    25    30    16    11    81    46
#
# year  2019
# 0       22
# 1       17
# 2       16
# 3       15
# 4       14

# %% [markdown]
# ---

# %% [markdown]
# ## Geography

# %% [markdown]
# #### Import and clean up LAPD reporting districts

# %%
reporting_districts_src = gpd.read_file('/Users/mhustiles/data/github/notebooks/lapd-crimes-arrests/output/lapd_reporting_districts.json')

# %%
reporting_districts_src.plot()

# %%
reporting_districts_src.columns = reporting_districts_src.columns.str.strip().\
str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
reporting_districts_src = reporting_districts_src.rename(columns={"repdist": "reporting_district"})

# %%
reporting_districts_src['reporting_district'] = reporting_districts_src['reporting_district'].astype(str)

# %%
lapd_districts = reporting_districts_src[['reporting_district', 'aprec', 'area', 'geometry']]

# %% [markdown]
# ---

# %% [markdown]
# #### Import and clean up LAPD divisions

# %%
divisions_src = gpd.read_file('/Users/mhustiles/data/github/notebooks/lapd-crimes-arrests/output/lapd_divisions.json')

# %%
divisions_src.plot()

# %%
divisions_src.columns = divisions_src.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
divisions = divisions_src[['aprec', 'prec', 'area', 'geometry']]

# %% [markdown]
# #### Import LA Times neighborhoods

# %%
hoodssrc = gpd.read_file('/Users/mhustiles/data/github/notebooks/lapd-crimes-arrests/input/custom-la-hoods-skid-row.geojson')

# %%
hoodssrc.columns = hoodssrc.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
hoodssrc.plot()

# %% [markdown]
# #### Trim the dataframe

# %%
hoods = hoodssrc[['name', 'geometry']]

# %%
hoods.head()
# Out:
#                      name                                           geometry
# 0         Adams-Normandie  (POLYGON ((-118.3090080000001 34.0374109991240...
# 1                  Arleta  (POLYGON ((-118.4220150000001 34.2241029991218...
# 2       Arlington Heights  (POLYGON ((-118.315909 34.05261099912384, -118...
# 3         Atwater Village  (POLYGON ((-118.2783247308968 34.1530071452962...
# 4  Baldwin Hills/Crenshaw  (POLYGON ((-118.3562610000001 34.0248359991243...

# %% [markdown]
# ---

# %% [markdown]
# ## Merge 'sit-lie' arrests data with geography

# %% [markdown]
# #### Relate all 'sit-lie' arrests to LA Times neighborhoods

# %%
sit_lie_all_gdf = gpd.GeoDataFrame(sit_lie_all, \
geometry=gpd.points_from_xy(sit_lie_all.longitude, sit_lie_all.latitude))

# %%
sit_lie_all_gdf.plot()

# %% [markdown]
# #### Let's remove the stray lat/lon cases

# %%
#Read city of Los Angeles boundary file
la = gpd.read_file('input/la_city_boundary/la_city_boundary_1570551157861.geojson')
la.plot()

# %%
# Remove stray LA arrests with the clip_data module
sit_lie_all_gdf_clipped = cl.clip_shp(sit_lie_all_gdf, la)

# %%
sit_lie_all_gdf_clipped.plot()

# %%
sit_lie_all_gdf_clipped.crs = {'init': "epsg:4326"}
sit_lie_all_gdf.crs = {'init': "epsg:4326"}

# %%
sit_lie_all_gdf_clipped.to_file('output/sit_lie_all_gdf_clipped.geojson', driver='GeoJSON')

# %%
sit_lie_all_gdf_clipped_2019_hollywood = sit_lie_all_gdf_clipped[(sit_lie_all_gdf_clipped['arrest_date'] > '2019/01/01') \
& (sit_lie_all_gdf_clipped['area_name'] == 'Hollywood')]
sit_lie_all_gdf_clipped_2019 = sit_lie_all_gdf_clipped[(sit_lie_all_gdf_clipped['arrest_date'] > '2019/01/01')]

# %%
sit_lie_all_gdf_clipped_2019_hollywood.to_csv('output/sit_lie_all_gdf_clipped_2019_hollywood.csv')
sit_lie_all_gdf_clipped_2019.to_csv('output/sit_lie_all_gdf_clipped_2019.csv')

# %%
sit_lie_all_gdf_clipped.crs = {'init': "epsg:4326"}

# %%
sit_lie_all_hoods = gpd.sjoin(sit_lie_all_gdf, hoods, op='within', how="inner")

# %% [markdown]
# #### 'Busy' neighborhoods: Skid Row, elsewhere Downtown, Venice, Hollywood

# %%
busy_hoods = ['Skid Row', 'Downtown', 'Venice', 'Hollywood']

# %%
sit_lie_all_hoods['busy'] = sit_lie_all_hoods['name'].isin(busy_hoods)

# %%
sit_lie_all_hoods.iloc[10]

# %%
sit_lie_all_hoods_slim = sit_lie_all_hoods[['report_id','arrest_date','time','area_id','area_name','reporting_district','age','sex_code','descent_code','charge_group_code','charge_group_description','arrest_type_code','charge','charge_description','year','month','weekday','name', 'busy']]

# %%
sit_lie_all_hoods_slim.head()
len(sit_lie_all_hoods_slim)

# %% [markdown]
# #### Totals by neighborhood

# %%
hood_counts = sit_lie_all_hoods_slim.groupby(['name']).agg('size').sort_values(ascending=False).reset_index(name='total')

# %%
#Large neighborhoods
hood_counts_busy = hood_counts[hood_counts['total'] > 200 ].sort_values(by='total', ascending=False)

# %%
hood_counts['total'].sum()

# %%
hood_counts['share'] = ((hood_counts['total'] / hood_counts['total'].sum())*100).round()
hood_counts.head()

# %%
bars = alt.Chart(hood_counts_busy).mark_bar().encode(
    x=alt.X('total:Q', title="Arrests", axis=alt.Axis(format='', tickCount=6)), 
    y=alt.Y(
        'name:N',
        sort=alt.EncodingSortField(
            field="total",  # The field to use for the sort
            order="descending"  # The order to sort in
        )
    )
)
text = bars.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='total:Q'
)
(bars + text).properties(height=500, width=400)

# %%
hood_counts_years = sit_lie_all_hoods_slim.groupby(['name', 'year', 'busy']).agg('size').sort_values(ascending=False).reset_index(name='total')

# %%
hood_counts_years.head()

# %% [markdown]
# #### What's the share of the arrests in the 'busy' neighborhoods: Skid row, elsewhere Downtown, Venice, Hollywood?

# %%
hood_counts_years_grouped = sit_lie_all_hoods_slim.groupby(['year', 'busy']).agg('size').sort_values(ascending=False).reset_index(name='total')

# %%
alt.Chart(hood_counts_years_grouped).mark_bar().encode(
    x=alt.X('total', axis=alt.Axis(tickCount=6)),
    y='year',
    color='busy'
)

# %% [markdown]
# #### Pivot on year and neighborhood

# %%
hood_counts_years_pivot = pd.pivot_table(hood_counts_years, values='total', index=['name'], columns=['year'], aggfunc=np.sum, fill_value=0).sort_values(by='2019', ascending=False).reset_index()
hood_counts_years_pivot.head(10)

# %% [markdown]
# #### Filter neighborhoods to the busiest: Skid Row, elsewhere downtown, Hollywood and Venice

# %%
hood_counts_years_busy = hood_counts_years[hood_counts_years['busy'] == True]

# %%
hood_counts_years_busy.head()

# %% [markdown]
# #### Arrests by year in Downtown, Hollywood and Venice

# %%
alt.Chart(hood_counts_years_busy).mark_bar().encode(
    y=alt.Y('total:Q', title="Arrests", axis=alt.Axis(format='', tickCount=6),
        sort=alt.EncodingSortField(
            field="year",  # The field to use for the sort
            order="ascending"  # The order to sort in
        )), 
    x=alt.X(
        'year:N', axis=alt.Axis(format='', title='Year')
    ),
    facet='name:O').properties(
    columns=2,
    width=350,
    height=250
)

# %% [markdown]
# ---

# %% [markdown]
# #### Merge districts with pivoted arrest totals

# %%
districts_counts_years_pivot_geo = lapd_districts.merge(districts_counts_years_pivot, \
    on='reporting_district').sort_values(by='2019', ascending=False)

# %%
districts_counts_years_pivot_geo.head()

# %%
districts_sit_lie_grouped_geo = \
lapd_districts.merge(charges_grouped_sit_lie_all, on='reporting_district').sort_values(by='year', ascending=False)

# %%
districts_sit_lie_grouped_geo.head()

# %% [markdown]
# #### Export to GeoJSON

# %%
districts_counts_years_pivot_geo.to_file('/Users/mhustiles/data/github/notebooks/lapd-crimes-arrests/output/districts_counts_years_pivot_geo.json', driver='GeoJSON')

# %% [markdown]
# ---

# %% [markdown]
# ## Mapping

# %%
breaks = jenkspy.jenks_breaks(list(districts_sit_lie_grouped_geo.total), nb_class=5)
breaks

# %%
def get_group(value):
    for i, b in enumerate(breaks):
        if value <= breaks[i+1]:
            return i

# %%
districts_sit_lie_grouped_geo['arrest_group'] = districts_sit_lie_grouped_geo.total.apply(get_group)

# %%
districts_sit_lie_grouped_geo.to_file('/Users/mhustiles/data/github/notebooks/lapd-crimes-arrests/output/districts_sit_lie_grouped_geo.json', driver='GeoJSON')

# %%
districts_sit_lie_grouped_geo.head()

# %%
sit_lie_geojson = json.loads(districts_sit_lie_grouped_geo.to_json())
sit_lie_features = alt.Data(values=sit_lie_geojson['features'])

# %%
districts_geojson = json.loads(lapd_districts.to_json())
districts_features = alt.Data(values=districts_geojson['features'])

# %%
hoods_geojson = json.loads(hoods.to_json())
hoods_features = alt.Data(values=hoods_geojson['features'])

# %%
districts_geojson_pivot = json.loads(districts_counts_years_pivot_geo.to_json())
districts_geojson_pivot_features = alt.Data(values=districts_geojson_pivot['features'])

# %%
basemap = alt.Chart(districts_features).mark_geoshape(
    fill='lightgray',
    stroke=''
).project('mercator')

groups = alt.Chart(sit_lie_features).mark_geoshape(
    stroke='white'
).encode(
    color='properties.arrest_group:Q'
).transform_filter(
    alt.FieldEqualPredicate(field='properties.year', equal='2016')
)

hoodsmaps = alt.Chart(hoods_features).mark_geoshape(
    fill='',
    stroke='#999999',
    strokeWidth=.2
)

(basemap+groups+hoodsmaps).properties(
    width=600,
    height=600
)

# %%
variable_list = ['properties.2010','properties.2011','properties.2012','properties.2013','properties.2014','properties.2015','properties.2016','properties.2017','properties.2018','properties.2019']

# %%
alt.Chart(districts_features).mark_geoshape().encode(
    alt.Color(alt.repeat('row'), type='quantitative')
).transform_lookup(
    lookup='properties.reporting_district',
    from_=alt.LookupData(districts_geojson_pivot_features, 'properties.reporting_district', variable_list)
).properties(
    width=500,
    height=500
).repeat(
    row=variable_list
).resolve_scale(
    color='shared'
)

# %% [markdown]
# #### Group all 'sit-lie' cases by place and time

# %%
time_sit_lie_hoods = sit_lie_all_hoods.groupby(['name', 'year', 'hour', 'night']).agg('size').sort_values(ascending=False).reset_index()

# %%
time_sit_lie_hoods.columns = ['name', 'year','hour', 'night', 'total']

# %%
time_sit_lie_hoods.head()

# %%
time_sit_lie_hoods_busy = time_sit_lie_hoods[time_sit_lie_hoods['name'].isin(busy_hoods)]

# %%
alt.Chart(time_sit_lie_hoods).mark_bar().encode(
    x='hour:O',
    y="total:Q",
    color=alt.condition(
        alt.datum.night == True,
        alt.value('orange'), 
        alt.value('#82c6df')
    )
).properties(
    title='\'Sit-lie\' arrests in all neighborhoods, by hour',
    columns=2,
    width=320,
    height=300
)

# %%
alt.Chart(time_sit_lie_hoods_busy).mark_bar().encode(
    x='hour:O',
    y="total:Q",
    color=alt.condition(
        alt.datum.hour == '06',
        alt.value('orange'), 
        alt.value('#82c6df')
    ),
    facet='name:O'
).properties(
    title='Arrests by hour and busy neighborhood w/ 6-7a.m. highlighted',
    columns=2,
    width=320,
    height=200
)

# %% [markdown]
# #### How many 'sit-lit' arrests happen between 9-6 a.m.?

# %%
time_sit_lie_hoods_busy['night'].value_counts('normalize').round(2)

# %%
time_sit_lie_hoods_busy_grouped = time_sit_lie_hoods_busy.groupby(['year', 'night']).agg('size').sort_values(ascending=False).reset_index(name='total')

# %%
time_sit_lie_hoods_busy_grouped.head()

# %%
alt.Chart(time_sit_lie_hoods_busy_grouped).mark_bar().encode(
    x=alt.X('total:Q', stack="normalize", axis=alt.Axis(format='%',tickCount=6)),
    y='year:N',
    color='night'
)

# %% [markdown]
# #### What is the average number of arrests per month — and how has that changed over the years?

# %%
sit_lie_all_hoods.columns

# %% [markdown]
# #### Groupby neighborhood and dates — all hoods

# %%
months_grouped = sit_lie_all_hoods.groupby(['name', 'monthname', 'year', 'busy']).agg('size').sort_values(ascending=False).reset_index(name='total')

# %% [markdown]
# #### Groupby neighborhood and dates — busy hoods

# %%
months_grouped_busy = sit_lie_all_hoods[sit_lie_all_hoods['busy'] == True].groupby(['name', 'monthname']).agg('size').sort_values(ascending=False).reset_index(name='total')

# %%
alt.Chart(months_grouped_busy).mark_bar().encode(
    x=alt.X('monthname:O', sort=['January','February','March','April','May','June','July','August','September','October','November','December']),
    y="total:Q",
    color=alt.condition(
        alt.datum.hour == '06',
        alt.value('orange'), 
        alt.value('#82c6df')
    ),
    facet='name:O'
).properties(
    title='A decade of arrests by month and busy neighborhood',
    columns=2,
    width=320,
    height=200
)

# %% [markdown]
# #### What's going on in Skid Row?

# %%
skidrow_months_grouped_busy = sit_lie_all_hoods[sit_lie_all_hoods['name'] == 'Skid Row'].groupby(['name', 'year','monthname']).agg('size').sort_values(ascending=False).reset_index(name='total')

# %%
alt.Chart(skidrow_months_grouped_busy).mark_bar().encode(
    x=alt.X('monthname:O', sort=['January','February','March','April','May','June','July','August','September','October','November','December']),
    y="total:Q",
    color=alt.condition(
        alt.datum.hour == '06',
        alt.value('orange'), 
        alt.value('#82c6df')
    ),
    facet='year:O'
).properties(
    title='Monthly arrests in skid row by year',
    columns=5,
    width=150,
    height=200
)

# %% [markdown]
# #### Arrests by day

# %%
arrest_dates = arrests.groupby(['arrest_date', 'year', 'weekday']).agg('size').reset_index(name='total')

# %%
alt.Chart(arrest_dates).mark_bar().encode(
    x=alt.X('arrest_date:T', axis=alt.Axis(format='%Y', title='', tickCount = 10)),
    y=alt.X('total:Q', axis=alt.Axis(format='', title='', tickCount = 10)),
    # The highlight will be set on the result of a conditional statement
    color=alt.condition(
        alt.datum.arrest_date == '2018-09-04',  # If the year is 1810 this test returns True,
        alt.value('#000000'),     # which sets the bar orange.
        alt.value('skyblue')   # And if it's not true it sets the bar steelblue.
    )
).properties(title='Sit-lie arrests by day', width=800)

# %%
alt.Chart(arrest_dates).mark_bar().encode(
    x=alt.X('weekday:O', axis=alt.Axis(title='', tickCount = 10), 
            sort=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']),
    y=alt.X('total:Q', axis=alt.Axis(title='', tickCount = 10)
),
    facet='year:O'
).properties(
    title='Arrests by day of the week and year',
    columns=2,
    width=300,
    height=200
)

# %% [markdown]
# ---

# %% [markdown]
# ## Homeless population estimates by LA Times neighborhoods

# %%
homelessbyhood = pd.read_csv('input/homeless-unsheltered-by-hood.csv')

# %%
homelessbyhood

# %% [markdown]
# #### Merge with previously pivoted arrests data with hoods spatial data — then merge population counts

# %%
hood_counts_years

# %%
hoods_counts_years_pivot_geo = hoods.merge(hood_counts_years_pivot, on='name').sort_values(by='2019', ascending=False)

# %%
hoods_homeless_counts_years_pivot_geo = hoods_counts_years_pivot_geo.merge(homelessbyhood, on='name').sort_values(by='2019', ascending=False)

# %%
hoods_homeless_counts_years_pivot_geo.head()

# %% [markdown]
# #### Loop and create rate columns for each year

# %%
# hoods_homeless_counts_years_pivot_geo['2017-rate'] = (hoods_homeless_counts_years_pivot_geo['2017']/hoods_homeless_counts_years_pivot_geo['unsheltered'])*100

for n in range(2010, 2020):
    hoods_homeless_counts_years_pivot_geo[f'{n}_rate'] = (hoods_homeless_counts_years_pivot_geo[f'{n}']/hoods_homeless_counts_years_pivot_geo['unsheltered'])*100

# %%
hoods_homeless_counts_years_pivot_geo.head()

# %% [markdown]
# #### Export GeoJSON

# %%
hoods_homeless_counts_years_pivot_geo.to_file('/Users/mhustiles/data/github/notebooks/lapd-crimes-arrests/output/hoods_homeless_counts_years_pivot_geo.json', driver='GeoJSON')

# %%
hoods_homeless_counts_years_pivot_geo.to_csv('/Users/mhustiles/data/github/notebooks/lapd-crimes-arrests/output/hoods_homeless_counts_years_pivot_geo.csv')

# %%
hood_counts_years_pivot = pd.pivot_table(hood_counts_years, \
    values='total', index=['name'], columns=['year'], \
    aggfunc=np.sum, fill_value=0).sort_values(by='2019', ascending=False).reset_index()

# %%
hood_counts_years_pivot.head()
