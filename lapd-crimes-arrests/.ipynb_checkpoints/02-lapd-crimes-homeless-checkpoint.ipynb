# %% [markdown]
# # LAPD 'homeless' crimes: 2010-present

# %% [markdown]
# ### Import data tools

# %%
import pandas as pd
import geopandas as gpd
import pyarrow
import matplotlib
import matplotlib.pyplot as plt
import geojson
import json
import jenkspy
import numpy as np
from earthpy import clip as cl
from altair import datum
import weightedcalcs as wc
import altair as alt
alt.renderers.enable('notebook')
import altair_latimes as lat
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Read crimes CSV downloaded from LA City data portal

# %%
# data exported from '00-lapd-crimes-processing.ipynb'
src = pd.read_feather('/Users/mhustiles/data/data/LA/crimes.feather')

# %%
src
# Out:
#            index  record_id date_reported date_occurred time_occurred  \
# 0              4  100100501    2010-01-03    2010-01-02          2100
# 1              5  100100506    2010-01-05    2010-01-04          1650
# 2              6  100100508    2010-01-08    2010-01-07          2005
# 3              7  100100509    2010-01-09    2010-01-08          2100
# 4              8  100100510    2010-01-09    2010-01-09          0230
# 5              9  100100511    2010-01-09    2010-01-06          2100
# 6             11  100100522    2010-01-15    2010-01-14          2000
# 7             14  100100531    2010-01-16    2010-01-15          2030
# 8             17  100100553    2010-01-23    2010-01-23          1100
# 9             18  100100555    2010-01-23    2010-01-23          2000
# 10            19  100100561    2010-01-26    2010-01-26          1820
# 11            21  100100564    2010-01-30    2010-01-29          1630
# 12            22  100100570    2010-01-31    2010-01-31          0130
# 13            24  100100572    2010-02-01    2010-01-31          1700
# 14            27  100100575    2010-02-01    2010-01-31          1720
# 15            33  100100591    2010-02-10    2010-02-08          1625
# 16            34  100100592    2010-02-08    2010-02-08          1800
# 17            35  100100608    2010-02-11    2010-02-10          1900
# 18            36  100100610    2010-02-11    2010-02-10          1800
# 19            37  100100616    2010-02-11    2010-02-11          1515
# 20            40  100100628    2010-02-15    2010-02-14          1500
# 21            41  100100630    2010-02-15    2010-02-15          0100
# 22            49  100100650    2010-02-25    2010-02-25          0030
# 23            50  100100651    2010-02-26    2010-02-25          2330
# 24            55  100114820    2010-08-01    2010-08-01          0250
# 25            57  100100660    2010-03-01    2010-03-01          0100
# 26            59  100100672    2010-03-06    2010-03-06          0420
# 27            64  100100694    2010-03-12    2010-03-12          0930
# 28            65  100100697    2010-03-12    2010-03-12          1520
# 29            67  100100708    2010-03-14    2010-03-14          0800
# 30            69  100100713    2010-03-14    2010-03-14          2000
# 31            75  100100724    2010-03-18    2010-03-18          0015
# 32            76  100100725    2010-03-18    2010-03-18          0015
# 33            78  100100728    2010-03-19    2010-03-19          1140
# 34            80  100100731    2010-03-21    2010-03-21          0320
# 35            83  100100736    2010-03-22    2010-03-22          1330
# 36            85  100100740    2010-03-25    2010-03-22          1915
# 37            86  100100741    2010-03-24    2010-03-22          2030
# 38            87  100100743    2010-03-25    2010-03-23          0125
# 39            94  100100759    2010-03-28    2010-03-28          0055
# 40            98  100100772    2010-04-03    2010-04-02          2230
# 41           100  100100777    2010-04-06    2010-04-05          1940
# 42           102  100100786    2010-04-08    2010-04-08          0220
# 43           103  100100788    2010-04-08    2010-04-08          0920
# 44           104  100100792    2010-04-10    2010-04-10          1710
# 45           105  100100797    2010-04-14    2010-04-11          0200
# 46           109  100100803    2010-04-14    2010-04-14          0915
# 47           110  100100804    2010-04-15    2010-04-15          0335
# 48           111  100100807    2010-04-15    2010-04-15          1740
# 49           113  100100811    2010-04-16    2010-04-16          0510
# 50           114  100100812    2010-04-16    2010-04-16          0800
# 51           115  100100813    2010-04-16    2010-04-16          1800
# 52           116  100100814    2010-04-16    2010-04-16          1815
# 53           117  100100816    2010-04-16    2010-04-16          1830
# 54           118  100100822    2010-04-16    2010-04-15          1400
# 55           120  100100827    2010-04-17    2010-04-17          1845
# 56           122  100100830    2010-04-17    2010-04-17          2100
# 57           125  100100835    2010-04-17    2010-04-17          2100
# 58           130  100100844    2010-04-24    2010-04-23          0130
# 59           131  100100848    2010-04-25    2010-04-24          2015
# 60           133  100100850    2010-04-24    2010-04-24          2015
# 61           134  100100853    2010-04-25    2010-04-25          1415
# 62           135  100100854    2010-04-26    2010-04-25          1950
# 63           146  100100869    2010-05-03    2010-05-03          0220
# 64           149  100100879    2010-05-05    2010-05-05          1500
# 65           150  100100880    2010-05-05    2010-05-05          2125
# 66           152  100100883    2010-05-06    2010-05-06          0400
# 67           153  100100887    2010-05-07    2010-05-06          1320
# 68           155  100100891    2010-05-06    2010-05-06          1850
# 69           159  100100897    2010-05-10    2010-05-09          2315
# 70           161  100100900    2010-05-10    2010-05-10          1105
# 71           162  100100912    2010-05-12    2010-05-12          0355
# 72           163  100100913    2010-05-12    2010-05-12          0355
# 73           164  100100922    2010-05-14    2010-05-13          0200
# 74           166  100100925    2010-05-14    2010-05-13          0120
# 75           167  100100928    2010-05-13    2010-05-13          1810
# 76           172  100100946    2010-05-20    2010-05-19          1200
# 77           180  100100965    2010-05-24    2010-05-23          1745
# 78           182  100100967    2010-05-24    2010-05-24          0230
# 79           184  100100976    2010-05-30    2010-05-30          0720
# 80           186  100100979    2010-05-30    2010-05-30          0720
# 81           190  100100983    2010-05-31    2010-05-31          1935
# 82           191  100100984    2010-05-31    2010-05-31          2140
# 83           192  100100985    2010-05-31    2010-05-31          1740
# 84           193  100100986    2010-06-01    2010-05-31          2350
# 85           194  100100987    2010-06-01    2010-06-01          0030
# 86           195  100100988    2010-06-01    2010-06-01          0045
# 87           196  100100989    2010-05-31    2010-05-31          1500
# 88           197  100100993    2010-06-02    2010-06-02          1950
# 89           202  100101000    2010-06-05    2010-05-15          1000
# 90           203  100101001    2010-06-05    2010-05-12          2100
# 91           204  100101009    2010-06-07    2010-06-06          0945
# 92           207  100101012    2010-06-07    2010-06-07          1700
# 93           208  100101015    2010-06-08    2010-06-08          1810
# 94           209  100101017    2010-06-08    2010-06-08          2245
# 95           211  100101023    2010-06-10    2010-06-10          1935
# 96           212  100101024    2010-06-10    2010-06-10          2030
# 97           213  100101028    2010-06-11    2010-06-11          1910
# 98           216  100101034    2010-06-12    2010-06-12          1810
# 99           217  100101035    2010-06-13    2010-06-12          2058
# 100          219  100101039    2010-06-14    2010-06-14          1645
# 101          221  100101041    2010-06-14    2010-06-14          0730
# 102          226  100101063    2010-06-17    2010-06-17          1335
# 103          228  100101071    2010-06-18    2010-06-17          1500
# 104          234  100101082    2010-06-19    2010-06-19          0315
# 105          239  100101104    2010-06-23    2010-06-23          1550
# 106          240  100101111    2010-06-24    2010-06-24          0001
# 107          241  100101114    2010-06-24    2010-06-24          1215
# 108          244  100101120    2010-06-26    2010-06-25          2345
# 109          248  100101125    2010-06-28    2010-06-28          0300
# 110          251  100101139    2010-06-29    2010-06-28          1000
# 111          252  100101140    2010-06-29    2010-06-29          1530
# 112          254  100101153    2010-07-02    2010-07-02          0200
# 113          255  100101162    2010-07-03    2010-07-03          1330
# 114          260  100101174    2010-07-05    2010-07-05          0230
# 115          261  100101179    2010-07-06    2010-07-06          1500
# 116          262  100101182    2010-07-07    2010-07-07          1610
# 117          263  100101189    2010-07-08    2010-07-08          2135
# 118          264  100101190    2010-07-08    2010-07-08          1040
# 119          268  100101203    2010-07-11    2010-07-11          1435
# 120          273  100101213    2010-07-13    2010-07-13          2105
# 121          274  100101215    2010-07-14    2010-07-14          1630
# 122          275  100101217    2010-07-15    2010-07-14          2330
# 123          280  100101233    2010-07-15    2010-07-15          2230
# 124          281  100101237    2010-07-15    2010-07-15          1930
# 125          282  100101241    2010-07-16    2010-07-16          1430
# 126          283  100101243    2010-07-16    2010-07-16          1815
# 127          284  100101244    2010-07-16    2010-07-16          2200
# 128          287  100101250    2010-07-18    2010-07-18          0420
# 129          288  100101251    2010-07-18    2010-07-18          1420
# 130          289  100101252    2010-07-18    2010-07-18          1400
# 131          290  100101258    2010-07-21    2010-07-18          2200
# 132          291  100101259    2010-07-19    2010-07-19          1650
# 133          292  100101260    2010-07-19    2010-07-19          2205
# 134          294  100101264    2010-07-22    2010-07-19          0010
# 135          295  100101269    2010-07-22    2010-07-15          2300
# 136          296  100101273    2010-07-22    2010-07-22          1510
# 137          300  100101285    2010-07-29    2010-07-24          0100
# 138          301  100101286    2010-07-30    2010-07-29          2255
# 139          303  100101288    2010-07-30    2010-07-30          1400
# 140          307  100101302    2010-08-01    2010-08-01          2030
# 141          308  100101304    2010-08-02    2010-07-31          1200
# 142          309  100101305    2010-08-01    2010-07-30          1630
# 143          312  100101311    2010-08-06    2010-08-06          1800
# 144          314  100101319    2010-08-07    2010-08-06          1730
# 145          315  100101320    2010-08-07    2010-08-06          1730
# 146          316  100101324    2010-08-07    2010-08-07          1830
# 147          317  100101329    2010-08-11    2010-08-11          1630
# 148          318  100101330    2010-08-12    2010-08-11          2140
# 149          319  100101332    2010-08-12    2010-08-11          2030
# 150          320  100101341    2010-08-14    2010-08-14          2200
# 151          321  100101343    2010-08-15    2010-08-15          0025
# 152          322  100101344    2010-08-15    2010-08-15          0150
# 153          328  100101356    2010-08-18    2010-08-18          1500
# 154          329  100101364    2010-08-20    2010-08-19          2345
# 155          332  100101369    2010-08-20    2010-08-20          2000
# 156          334  100101371    2010-08-21    2010-08-21          1600
# 157          340  100101385    2010-08-24    2010-08-24          2000
# 158          341  100101407    2010-08-28    2010-08-27          2255
# 159          342  100101417    2010-09-04    2010-09-04          1540
# 160          343  100101419    2010-09-04    2010-09-04          1735
# 161          346  100101423    2010-09-04    2010-09-04          1920
# 162          347  100101424    2010-09-05    2010-09-05          0130
# 163          348  100101425    2010-09-06    2010-09-05          1900
# 164          352  100101435    2010-09-09    2010-09-08          1155
# 165          355  100101441    2010-09-13    2010-09-13          0250
# 166          356  100101442    2010-09-13    2010-09-12          2300
# 167          357  100101451    2010-09-18    2010-09-18          0555
# 168          359  100101454    2010-09-18    2010-09-18          0540
# 169          361  100101467    2010-09-23    2010-09-23          2135
# 170          363  100101471    2010-09-25    2010-09-24          1800
# 171          365  100101477    2010-09-25    2010-09-25          1430
# 172          366  100101480    2010-09-29    2010-09-28          2220
# 173          368  100101487    2010-10-05    2010-10-04          1950
# 174          373  100101499    2010-10-13    2010-10-12          2330
# 175          375  100101513    2010-10-15    2010-10-14          1515
# 176          376  100101520    2010-10-18    2010-10-18          0115
# 177          377  100101521    2010-10-18    2010-10-18          0600
# 178          378  100101523    2010-10-21    2010-10-19          1000
# 179          380  100101527    2010-10-20    2010-10-19          2100
# 180          386  100101544    2010-10-24    2010-10-24          0230
# 181          388  100101552    2010-10-26    2010-10-26          0100
# 182          389  100101562    2010-10-29    2010-10-29          1935
# 183          392  100101567    2010-10-31    2010-10-30          2300
# 184          393  100101571    2010-11-03    2010-11-02          2045
# 185          394  100101572    2010-11-03    2010-11-02          1200
# 186          396  100101587    2010-11-07    2010-11-05          2045
# 187          400  100101594    2010-11-11    2010-11-09          1935
# 188          401  100101598    2010-11-11    2010-11-10          2035
# 189          403  100101600    2010-11-11    2010-11-11          0900
# 190          404  100101605    2010-11-15    2010-11-14          1245
# 191          411  100101614    2010-11-17    2010-11-17          1450
# 192          412  100101615    2010-11-16    2010-11-16          2100
# 193          413  100101616    2010-11-18    2010-11-18          0440
# 194          414  100101618    2010-11-18    2010-11-18          1630
# 195          415  100104080    2010-01-02    2010-01-02          1300
# 196          416  100101621    2010-11-19    2010-11-19          1530
# 197          417  100101630    2010-11-21    2010-11-21          1704
# 198          420  100101643    2010-11-26    2010-11-25          2100
# 199          421  100101646    2010-11-27    2010-11-20          0001
# 200          422  100101649    2010-11-27    2010-11-26          1730
# 201          424  100101652    2010-11-27    2010-11-27          0110
# 202          425  100101653    2010-11-27    2010-11-27          0220
# 203          426  100101669    2010-12-03    2010-12-03          0025
# 204          427  100101670    2010-12-03    2010-12-02          1900
# 205          428  100101672    2010-12-04    2010-12-04          1920
# 206          429  100101677    2010-12-08    2010-12-08          0800
# 207          430  100101684    2010-12-10    2010-12-10          1610
# 208          431  100101685    2010-12-11    2010-12-11          1330
# 209          432  100101691    2010-12-12    2010-12-12          0100
# 210          438  100101700    2010-12-15    2010-12-15          1820
# 211          442  100101709    2010-12-17    2010-12-13          1114
# 212          445  100101718    2010-12-24    2010-12-24          1320
# 213          447  100101721    2010-12-25    2010-12-24          1900
# 214          449  100104004    2010-01-01    2010-01-01          0130
# 215          451  100104007    2010-01-01    2010-01-01          0100
# 216          453  100104021    2010-01-01    2010-01-01          1130
# 217          454  100104023    2010-01-01    2010-01-01          1300
# 218          455  100104024    2010-01-01    2010-01-01          1400
# 219          456  100104028    2010-01-01    2010-01-01          1200
# 220          459  100104056    2010-01-01    2010-01-01          0130
# 221          460  100104057    2010-01-01    2010-01-01          0130
# 222          461  100104063    2010-01-02    2010-01-01          2230
# 223          462  100104064    2010-01-02    2010-01-01          1830
# 224          463  100104065    2010-01-02    2010-01-01          2230
# 225          467  100104069    2010-01-02    2010-01-01          1930
# 226          470  100104079    2010-01-02    2010-01-02          1240
# 227          472  100104083    2010-01-02    2010-01-01          1600
# 228          474  100104086    2010-01-02    2010-01-02          1745
# 229          476  100104095    2010-01-03    2010-01-02          2300
# 230          477  100104096    2010-01-03    2010-01-02          1750
# 231          478  100104097    2010-01-03    2010-01-02          2100
# 232          481  100104108    2010-01-03    2010-01-01          2000
# 233          482  100104125    2010-01-03    2010-01-02          1335
# 234          485  100104144    2010-01-03    2010-01-02          1745
# 235          487  100104148    2010-01-04    2010-01-03          1200
# 236          489  100104151    2010-01-04    2010-01-02          1100
# 237          490  100104152    2010-01-04    2010-01-03          0215
# 238          491  100104153    2010-01-04    2010-01-03          0700
# 239          494  100104162    2010-01-04    2010-01-04          0330
# 240          495  100104168    2010-01-04    2010-01-04          0615
# 241          498  100104184    2010-01-05    2010-01-04          1140
# 242          499  100115247    2010-07-31    2010-07-30          2000
# 243          501  100104190    2010-01-05    2010-01-04          1815
# 244          503  100104195    2010-01-05    2010-01-04          2000
# 245          505  100104204    2010-01-04    2010-01-04          0805
# 246          507  100104208    2010-01-04    2010-01-04          0845
# 247          509  100104211    2010-01-05    2010-01-05          0005
# 248          511  100104220    2010-01-05    2010-01-05          0930
# 249          513  100104226    2010-01-05    2010-01-05          0750
# 250          516  100104251    2010-01-06    2010-01-05          2235
# 251          517  100104253    2010-01-05    2010-01-05          2300
# 252          518  100104254    2010-01-06    2010-01-05          2350
# 253          521  100104260    2010-01-06    2010-01-05          1430
# 254          523  100104268    2010-01-06    2010-01-06          0400
# 255          524  100104269    2010-01-05    2010-01-05          1030
# 256          525  100104270    2010-01-06    2010-01-06          1120
# 257          527  100104277    2010-01-06    2010-01-05          2200
# 258          529  100104279    2010-01-06    2010-01-06          1040
# 259          530  100104280    2010-01-06    2010-01-05          2030
# 260          531  100104283    2010-01-06    2010-01-01          1900
# 261          533  100104289    2010-01-06    2010-01-05          1830
# 262          534  100104290    2010-01-06    2010-01-06          1310
# 263          536  100104306    2010-01-07    2010-01-06          1915
# 264          538  100104312    2010-01-07    2010-01-06          0820
# 265          540  100104319    2010-01-07    2010-01-07          0045
# 266          542  100104322    2010-01-07    2010-01-07          0830
# 267          543  100104325    2010-01-07    2010-01-03          1730
# 268          545  100104333    2010-01-07    2010-01-06          1635
# 269          547  100104340    2010-01-07    2010-01-07          1430
# 270          548  100104360    2010-01-07    2010-01-07          1748
# 271          550  100104384    2010-01-08    2010-01-08          0005
# 272          554  100104410    2010-01-08    2010-01-07          1900
# 273          558  100104442    2010-01-08    2010-01-08          1850
# 274          559  100104445    2010-01-09    2010-01-08          0645
# 275          560  100104446    2010-01-09    2010-01-08          2200
# 276          561  100104447    2010-01-09    2010-01-09          2250
# 277          562  100104448    2010-01-09    2010-01-09          2300
# 278          563  100104449    2010-01-09    2010-01-08          2245
# 279          565  100104454    2010-01-09    2010-01-08          2245
# 280          566  100104458    2010-01-09    2010-01-09          0130
# 281          567  100104459    2010-01-08    2010-01-08          1810
# 282          569  100104469    2010-01-09    2010-01-07          2230
# 283          570  100104482    2010-01-09    2010-01-09          1200
# 284          571  100104483    2010-01-09    2010-01-09          1130
# 285          572  100104484    2010-01-09    2010-01-08          2045
# 286          575  100104495    2010-01-10    2010-01-09          1130
# 287          576  100104496    2010-01-10    2010-01-09          2010
# 288          585  100104601    2010-01-12    2010-01-10          1900
# 289          589  100104517    2010-01-10    2010-01-10          1500
# 290          590  100104518    2010-01-10    2010-01-09          1320
# 291          591  100104519    2010-01-10    2010-01-08          1650
# 292          592  100104520    2010-01-10    2010-01-10          0300
# 293          593  100104524    2010-01-10    2010-01-10          1800
# 294          594  100104525    2010-01-10    2010-01-10          1805
# 295          596  100104533    2010-01-11    2010-01-11          0400
# 296          597  100104534    2010-01-11    2010-01-10          1400
# 297          599  100104540    2010-01-11    2010-01-09          0700
# 298          600  100104541    2010-01-11    2010-01-09          2230
# 299          601  100104544    2010-01-11    2010-01-10          1400
# 300          602  100104545    2010-01-11    2010-01-08          1130
# 301          604  100104548    2010-01-11    2010-01-11          0220
# 302          605  100104560    2010-01-11    2010-01-11          1150
# 303          606  100104563    2010-01-11    2010-01-09          1200
# 304          607  100104568    2010-01-11    2010-01-11          1500
# 305          608  100104577    2010-01-11    2010-01-11          1515
# 306          610  100104580    2010-01-11    2010-01-10          1400
# 307          611  100104583    2010-01-11    2010-01-11          0700
# 308          613  100104592    2010-01-12    2010-01-11          1920
# 309          614  100104597    2010-01-12    2010-01-11          0130
# 310          615  100104600    2010-01-12    2010-01-11          1200
# 311          617  100104621    2010-01-12    2010-01-11          1000
# 312          620  100104638    2010-01-12    2010-01-12          1530
# 313          622  100104641    2010-01-08    2010-01-08          1618
# 314          623  100104643    2010-01-12    2010-01-12          1430
# 315          624  100104647    2010-01-12    2010-01-12          1000
# 316          625  100104649    2010-01-12    2010-01-11          2000
# 317          628  100104655    2010-01-12    2010-01-12          1405
# 318          630  100104665    2010-01-12    2010-01-12          1715
# 319          631  100104666    2010-01-13    2010-01-13          0700
# 320          634  100104669    2010-01-07    2010-01-02          0800
# 321          639  100104697    2010-01-11    2010-01-11          1930
# 322          640  100104699    2010-01-13    2010-01-10          1300
# 323          642  100104701    2010-01-13    2010-01-13          1410
# 324          643  100104702    2010-01-12    2010-01-11          0830
# 325          646  100104706    2010-01-12    2010-01-12          1600
# 326          648  100104731    2010-01-13    2010-01-13          1700
# 327          651  100104749    2010-01-13    2010-01-13          1850
# 328          653  100104762    2010-01-14    2010-01-13          2000
# 329          654  100104763    2010-01-14    2010-01-13          1900
# 330          655  100104764    2010-01-14    2010-01-14          0530
# 331          657  100104776    2010-01-14    2010-01-12          0100
# 332          662  100104808    2010-01-14    2010-01-14          2250
# 333          663  100104809    2010-01-14    2010-01-13          1000
# 334          664  100104811    2010-01-15    2010-01-15          0800
# 335          667  100104824    2010-01-15    2010-01-14          1830
# 336          668  100104825    2010-01-15    2010-01-13          0800
# 337          669  100104826    2010-01-15    2010-01-13          1200
# 338          670  100104830    2010-01-15    2010-01-14          2205
# 339          671  100104832    2010-01-15    2010-01-09          1200
# 340          672  100104833    2010-01-15    2010-01-15          0830
# 341          674  100104845    2010-01-16    2010-01-15          1600
# 342          675  100104847    2010-01-16    2010-01-15          1700
# 343          678  100104851    2010-01-16    2010-01-08          1200
# 344          682  100104875    2010-01-15    2010-01-15          1605
# 345          686  100104879    2010-01-16    2010-01-16          0945
# 346          688  100104882    2010-01-16    2010-01-16          0500
# 347          689  100104884    2010-01-16    2010-01-16          1300
# 348          692  100104897    2010-01-16    2010-01-16          1420
# 349          698  100104911    2010-01-17    2010-01-16          1250
# 350          699  100104912    2010-01-17    2010-01-16          2330
# 351          701  100104914    2010-01-17    2010-01-16          1540
# 352          702  100104915    2010-01-17    2010-01-16          0250
# 353          706  100104921    2010-01-17    2010-01-15          2300
# 354          707  100104923    2010-01-17    2010-01-16          2345
# 355          710  100104930    2010-01-17    2010-01-17          1040
# 356          712  100104935    2010-01-17    2010-01-15          2300
# 357          713  100104942    2010-01-18    2010-01-18          0018
# 358          714  100104944    2010-01-17    2010-01-17          1738
# 359          716  100104946    2010-01-17    2010-01-13          2000
# 360          719  100104954    2010-01-18    2010-01-16          1800
# 361          720  100104958    2010-01-18    2010-01-18          0700
# 362          721  100104961    2010-01-18    2010-01-18          0745
# 363          722  100104963    2010-01-18    2010-01-17          1840
# 364          723  100104965    2010-01-18    2010-01-17          1400
# 365          725  100104972    2010-01-18    2010-01-18          0100
# 366          727  100104974    2010-01-18    2010-01-18          1615
# 367          728  100104975    2010-01-18    2010-01-18          1755
# 368          729  100104984    2010-01-18    2010-01-15          0900
# 369          730  100104985    2010-01-18    2010-01-18          2100
# 370          732  100105007    2010-01-19    2010-01-18          1700
# 371          734  100105025    2010-01-19    2010-01-18          2100
# 372          735  100105034    2010-01-19    2010-01-13          1200
# 373          736  100105036    2010-01-19    2010-01-19          1500
# 374          737  100105037    2010-01-19    2010-01-18          1835
# 375          738  100105040    2010-01-19    2010-01-19          1600
# 376          741  100105047    2010-01-20    2010-01-18          1600
# 377          745  100105072    2010-01-20    2010-01-19          1700
# 378          747  100105083    2010-01-20    2010-01-20          1400
# 379          748  100105084    2010-01-20    2010-01-20          0930
# 380          749  100105096    2010-01-19    2010-01-14          1500
# 381          750  100105097    2010-01-19    2010-01-18          1900
# 382          751  100105102    2010-01-20    2010-01-20          0915
# 383          756  100105112    2010-01-21    2010-01-14          1800
# 384          758  100105122    2010-01-21    2010-01-19          1500
# 385          760  100105124    2010-01-20    2010-01-20          0515
# 386          761  100105134    2010-01-21    2010-01-20          1522
# 387          762  100105135    2010-01-21    2010-01-21          0735
# 388          765  100105147    2010-01-21    2010-01-21          1345
# 389          770  100105169    2010-01-21    2010-01-21          1940
# 390          771  100105171    2010-01-21    2010-01-21          1000
# 391          773  100105179    2010-01-22    2010-01-18          2200
# 392          774  100105180    2010-01-22    2010-01-22          0820
# 393          776  100105182    2010-01-22    2010-01-21          2300
# 394          778  100105201    2010-01-22    2010-01-21          1810
# 395          780  100105207    2010-01-23    2010-01-22          1640
# 396          787  100105264    2010-01-24    2010-01-24          0900
# 397          792  100105221    2010-01-23    2010-01-22          2000
# 398          793  100105223    2010-01-23    2010-01-23          1330
# 399          794  100105224    2010-01-23    2010-01-22          1335
# 400          798  100105230    2010-01-23    2010-01-23          0230
# 401          799  100105231    2010-01-23    2010-01-21          1700
# 402          800  100105235    2010-01-23    2010-01-23          1845
# 403          801  100105238    2010-01-24    2010-01-23          0015
# 404          803  100105241    2010-01-24    2010-01-23          1845
# 405          804  100105242    2010-01-24    2010-01-24          0015
# 406          805  100105243    2010-01-24    2010-01-24          0015
# 407          808  100105250    2010-01-23    2010-01-23          1853
# 408          809  100105251    2010-01-24    2010-01-24          0220
# 409          812  100105255    2010-01-24    2010-01-23          2245
# 410          813  100105257    2010-01-24    2010-01-23          2200
# 411          814  100105259    2010-01-24    2010-01-23          2000
# 412          815  100105260    2010-01-24    2010-01-24          0930
# 413          816  100105261    2010-01-24    2010-01-24          1200
# 414          818  100105265    2010-01-24    2010-01-24          0930
# 415          820  100105268    2010-01-24    2010-01-21          2130
# 416          821  100105270    2010-01-24    2010-01-24          1140
# 417          824  100105281    2010-01-24    2010-01-24          1800
# 418          826  100105284    2010-01-25    2010-01-25          0100
# 419          827  100105285    2010-01-25    2010-01-25          0030
# 420          828  100105286    2010-01-25    2010-01-25          0130
# 421          830  100105290    2010-01-25    2010-01-24          1000
# 422          832  100105293    2010-01-24    2010-01-24          1715
# 423          833  100105294    2010-01-25    2010-01-17          2300
# 424          835  100105302    2010-01-25    2010-01-22          1800
# 425          836  100105304    2010-01-25    2010-01-25          0855
# 426          838  100105309    2010-01-25    2010-01-25          0710
# 427          840  100105313    2010-01-25    2010-01-25          1630
# 428          841  100105314    2010-01-25    2010-01-11          1200
# 429          846  100105319    2010-01-25    2010-01-23          1900
# 430          847  100105320    2010-01-25    2010-01-25          1000
# 431          850  100105340    2010-01-26    2010-01-26          0050
# 432          851  100105341    2010-01-26    2010-01-26          0100
# 433          852  100105347    2010-01-26    2010-01-17          1800
# 434          853  100105357    2010-01-20    2010-01-20          0900
# 435          854  100105358    2010-01-26    2010-01-23          0730
# 436          855  100105361    2010-01-26    2010-01-26          1200
# 437          861  100105389    2010-01-27    2010-01-25          1800
# 438          862  100105393    2010-01-26    2010-01-21          1000
# 439          863  100105396    2010-01-27    2010-01-27          1300
# 440          864  100105397    2010-02-02    2010-02-02          2200
# 441          865  100105399    2010-01-27    2010-01-27          0830
# 442          867  100105406    2010-01-27    2010-01-26          1900
# 443          871  100105424    2010-01-27    2010-01-26          1500
# 444          873  100105433    2010-01-27    2010-01-27          1335
# 445          881  100105461    2010-01-27    2010-01-27          1400
# 446          882  100105462    2010-01-27    2010-01-27          1800
# 447          883  100105465    2010-01-14    2010-01-14          1500
# 448          887  100105477    2010-01-28    2010-01-28          0150
# 449          888  100105482    2010-01-28    2010-01-27          1600
# 450          889  100105483    2010-01-28    2010-01-22          2100
# 451          891  100105489    2010-01-28    2010-01-23          1930
# 452          892  100105499    2010-01-28    2010-01-24          2330
# 453          893  100105506    2010-01-29    2010-01-27          1530
# 454          894  100105511    2010-01-29    2010-01-28          2010
# 455          896  100105519    2010-01-29    2010-01-27          2300
# 456          898  100105522    2010-01-29    2010-01-28          0800
# 457          899  100105524    2010-01-29    2010-01-29          0845
# 458          903  100105529    2010-01-29    2010-01-28          2300
# 459          907  100105564    2010-01-30    2010-01-29          2230
# 460          911  100105571    2010-01-30    2010-01-30          0800
# 461          912  100105572    2010-01-30    2010-01-27          2100
# 462          916  100105586    2010-01-30    2010-01-22          1900
# 463          918  100105594    2010-01-30    2010-01-30          0945
# 464          919  100105595    2010-01-30    2010-01-30          0945
# 465          921  100105597    2010-01-30    2010-01-30          1645
# 466          923  100105607    2010-01-30    2010-01-30          1745
# 467          925  100105611    2010-01-31    2010-01-31          0710
# 468          929  100105622    2010-01-31    2010-01-31          1400
# 469          930  100105623    2010-01-31    2010-01-31          1600
# 470          934  100105632    2010-01-31    2010-01-31          2230
# 471          935  100105633    2010-01-31    2010-01-31          1800
# 472          936  100105639    2010-01-31    2010-01-31          2115
# 473          937  100105640    2010-02-01    2010-01-31          1845
# 474          938  100105641    2010-01-31    2010-01-04          2100
# 475          940  100105649    2010-02-01    2010-01-30          1800
# 476          941  100105651    2010-02-01    2010-02-01          1205
# 477          942  100105653    2010-02-01    2010-02-01          1400
# 478          943  100105655    2010-01-27    2010-01-24          2230
# 479          945  100105664    2010-02-02    2010-02-01          1825
# 480          946  100105669    2010-02-02    2010-02-01          1930
# 481          949  100105674    2010-02-02    2010-02-01          2100
# 482          950  100105675    2010-02-02    2010-02-01          2359
# 483          951  100105687    2010-02-02    2010-01-30          1200
# 484          952  100105690    2010-02-02    2010-01-31          1300
# 485          953  100105694    2010-02-02    2010-02-02          1215
# 486          954  100105697    2010-02-02    2010-02-02          0515
# 487          955  100105698    2010-02-02    2010-02-02          0630
# 488          958  100105711    2010-02-02    2010-01-27          2000
# 489          960  100105718    2010-02-03    2010-02-01          1300
# 490          965  100105790    2010-02-03    2010-02-03          2145
# 491          966  100105791    2010-02-03    2010-02-02          1300
# 492          968  100105793    2010-02-03    2010-02-03          1930
# 493          972  100105805    2010-02-03    2010-02-03          2350
# 494          973  100105810    2010-02-04    2010-02-04          0100
# 495          974  100105824    2010-02-04    2010-02-04          1020
# 496          975  100105825    2010-02-04    2010-02-04          0900
# 497          978  100105832    2010-02-04    2010-02-04          1020
# 498          981  100105841    2010-02-04    2010-02-04          1600
# 499          985  100105853    2010-02-04    2010-01-24          2146
# ...          ...        ...           ...           ...           ...
# 1141615  2061517  191817292    2019-08-07    2019-08-06          2020
# 1141616  2061518  191415475    2019-07-05    2019-07-04          1000
# 1141617  2061520  190911950    2019-06-07    2019-06-05          1950
# 1141618  2061523  191913866    2019-07-23    2019-07-22          1230
# 1141619  2061524  190205299    2019-01-26    2019-01-23          2300
# 1141620  2061525  191707749    2019-03-24    2019-03-24          0230
# 1141621  2061526  192017167    2019-09-21    2019-09-20          2230
# 1141622  2061527  190717297    2019-09-29    2019-09-28          1930
# 1141623  2061528  190118779    2019-07-19    2019-07-18          1630
# 1141624  2061534  191213472    2019-05-12    2019-05-12          2055
# 1141625  2061538  192010774    2019-05-16    2019-05-16          1025
# 1141626  2061539  191209830    2019-03-24    2019-03-24          1715
# 1141627  2061540  190916809    2019-09-14    2019-09-12          2300
# 1141628  2061541  192017889    2019-10-05    2019-10-05          0130
# 1141629  2061542  190600895    2019-04-07    2019-04-07          0135
# 1141630  2061543  191607556    2019-04-04    2019-03-30          1100
# 1141631  2061544  192017570    2019-09-29    2019-09-29          0640
# 1141632  2061546  190504045    2019-01-02    2019-01-02          0100
# 1141633  2061547  191820129    2019-09-24    2019-09-23          2330
# 1141634  2061548  191506939    2019-02-25    2019-02-23          1710
# 1141635  2061550  192004979    2019-01-21    2019-01-17          1900
# 1141636  2061551  191604891    2019-01-26    2019-01-25          1900
# 1141637  2061554  191514463    2019-07-18    2019-07-18          1620
# 1141638  2061555  191412427    2019-05-17    2019-05-13          1525
# 1141639  2061556  191413194    2019-05-30    2019-05-29          1910
# 1141640  2061558  190715450    2019-08-20    2019-08-19          1930
# 1141641  2061560  191514662    2019-07-25    2019-07-23          0300
# 1141642  2061561  191111531    2019-06-04    2019-06-02          2000
# 1141643  2061563  191817974    2019-08-17    2019-08-17          1815
# 1141644  2061564  191905964    2019-02-13    2019-02-13          0100
# 1141645  2061566  190918142    2019-10-10    2019-10-09          1315
# 1141646  2061568  191516091    2019-08-22    2019-08-21          1930
# 1141647  2061569  191807803    2019-03-08    2019-03-08          1730
# 1141648  2061570  191418608    2019-08-22    2019-08-22          1830
# 1141649  2061571  191014264    2019-08-30    2019-08-30          1130
# 1141650  2061573  191811645    2019-05-07    2019-05-04          1200
# 1141651  2061574  191010287    2019-05-24    2019-05-23          1400
# 1141652  2061575  191909169    2019-04-19    2019-04-19          1015
# 1141653  2061576  190904779    2019-01-17    2019-01-17          1411
# 1141654  2061577  190410926    2019-06-11    2019-06-11          1240
# 1141655  2061578  190119416    2019-07-28    2019-07-27          1800
# 1141656  2061579  191811040    2019-04-18    2019-04-18          1240
# 1141657  2061581  191113988    2019-07-23    2019-07-19          1100
# 1141658  2061582  191810572    2019-04-19    2019-04-19          2205
# 1141659  2061583  191010746    2019-06-06    2019-04-25          1100
# 1141660  2061584  191613352    2019-08-30    2019-08-30          1645
# 1141661  2061586  191415006    2019-06-28    2019-06-27          1700
# 1141662  2061588  190915711    2019-08-23    2019-08-23          0130
# 1141663  2061590  192015958    2019-08-29    2019-08-28          1930
# 1141664  2061591  192104845    2019-01-20    2019-01-20          1245
# 1141665  2061594  191219096    2019-07-26    2019-07-25          1700
# 1141666  2061595  191913970    2019-07-25    2019-07-18          2330
# 1141667  2061596  190311290    2019-04-21    2019-04-21          2345
# 1141668  2061599  190216805    2019-08-18    2019-08-18          0615
# 1141669  2061600  191609524    2019-05-28    2019-05-28          1830
# 1141670  2061604  191819869    2019-09-17    2019-09-15          1200
# 1141671  2061606  190616989    2019-08-08    2019-08-08          1800
# 1141672  2061607  191709141    2019-04-23    2019-04-23          0730
# 1141673  2061611  190911901    2019-06-06    2019-06-05          2300
# 1141674  2061612  190716567    2019-09-14    2019-09-13          2130
# 1141675  2061613  191223002    2019-09-18    2019-09-12          2300
# 1141676  2061614  191420604    2019-09-20    2019-09-20          1945
# 1141677  2061615  191115393    2019-08-21    2019-08-16          1000
# 1141678  2061616  191809727    2019-04-07    2019-03-30          1000
# 1141679  2061618  190906722    2019-02-24    2019-02-24          0900
# 1141680  2061619  190100735    2019-07-05    2019-07-05          1810
# 1141681  2061621  191116814    2019-09-19    2019-09-18          2102
# 1141682  2061623  191417855    2019-08-05    2019-08-03          0635
# 1141683  2061624  190204597    2019-01-12    2019-01-12          0500
# 1141684  2061626  190309554    2019-03-27    2019-03-27          0330
# 1141685  2061627  190300868    2019-07-23    2019-07-23          0300
# 1141686  2061630  190806927    2019-03-07    2019-03-01          0900
# 1141687  2061633  190414476    2019-09-12    2019-09-11          1730
# 1141688  2061634  190409974    2019-05-18    2019-05-18          0830
# 1141689  2061635  191108310    2019-03-31    2019-03-13          1755
# 1141690  2061638  190914637    2019-08-03    2019-08-02          0500
# 1141691  2061639  190104735    2019-01-11    2019-01-11          1810
# 1141692  2061640  192110241    2019-05-18    2019-04-19          1200
# 1141693  2061642  191814859    2019-06-25    2019-06-23          1148
# 1141694  2061643  190407989    2019-04-02    2019-02-24          0930
# 1141695  2061644  191309857    2019-04-15    2019-04-15          1815
# 1141696  2061645  191008473    2019-04-14    2019-04-14          0800
# 1141697  2061646  190714391    2019-07-29    2019-07-29          1830
# 1141698  2061651  190411747    2019-06-29    2019-06-27          1100
# 1141699  2061653  190123813    2019-09-25    2019-09-25          2130
# 1141700  2061655  190118658    2019-07-17    2019-07-17          1630
# 1141701  2061659  191613232    2019-08-24    2019-08-24          0540
# 1141702  2061660  190514660    2019-08-25    2019-08-24          2300
# 1141703  2061665  192115485    2019-09-09    2019-09-07          1300
# 1141704  2061667  191113106    2019-07-05    2019-07-05          2020
# 1141705  2061668  190307704    2019-02-27    2019-02-26          1540
# 1141706  2061670  191516989    2019-09-08    2019-09-07          1145
# 1141707  2061672  190124102    2019-09-30    2019-09-30          0500
# 1141708  2061673  190511269    2019-06-14    2019-06-13          2000
# 1141709  2061674  191418804    2019-08-21    2019-08-21          0644
# 1141710  2061675  190507935    2019-03-31    2019-03-30          1930
# 1141711  2061679  190619978    2019-10-01    2019-09-27          1140
# 1141712  2061680  190100713    2019-06-15    2019-06-15          0750
# 1141713  2061683  190505173    2019-01-26    2019-01-26          1600
# 1141714  2061685  190711835    2019-06-08    2019-06-08          1526
# 1141715  2061687  190211227    2019-05-12    2019-05-12          0220
# 1141716  2061688  190122796    2019-09-10    2019-09-10          2150
# 1141717  2061689  191312773    2019-06-06    2019-06-06          1630
# 1141718  2061691  191106614    2019-02-22    2019-02-17          1200
# 1141719  2061693  190707341    2019-03-09    2019-03-04          1330
# 1141720  2061695  191914042    2019-07-27    2019-07-26          1700
# 1141721  2061698  191813851    2019-06-08    2019-06-08          2130
# 1141722  2061699  191006803    2019-03-05    2019-03-05          0300
# 1141723  2061700  191420715    2019-09-21    2019-09-16          2350
# 1141724  2061701  192106699    2019-02-26    2019-02-26          1350
# 1141725  2061702  190319884    2019-09-03    2019-09-02          1600
# 1141726  2061703  191219579    2019-08-02    2019-08-01          1800
# 1141727  2061704  190206887    2019-02-23    2019-02-16          0100
# 1141728  2061707  191707617    2019-03-20    2019-03-18          0930
# 1141729  2061708  191805752    2019-02-01    2019-02-01          0700
# 1141730  2061709  190914878    2019-08-08    2019-08-07          1330
# 1141731  2061710  190706104    2019-02-12    2019-02-12          1325
# 1141732  2061711  190504388    2019-01-08    2019-01-08          0715
# 1141733  2061712  190708725    2019-04-05    2019-04-02          1200
# 1141734  2061714  191006604    2019-03-01    2019-02-16          1400
# 1141735  2061717  190115971    2019-06-14    2019-06-14          1220
# 1141736  2061718  190111571    2019-04-18    2019-04-18          0930
# 1141737  2061719  191004384    2019-01-10    2019-01-07          1430
# 1141738  2061720  191910606    2019-05-17    2019-05-14          1500
# 1141739  2061721  191223358    2019-09-24    2019-09-22          0200
# 1141740  2061724  192111875    2019-06-23    2019-06-23          2135
# 1141741  2061725  192107781    2019-03-27    2019-03-26          2200
# 1141742  2061727  190217056    2019-08-22    2019-08-21          2340
# 1141743  2061728  192014345    2019-07-27    2019-07-23          2000
# 1141744  2061733  191500924    2019-06-12    2019-06-11          2315
# 1141745  2061734  191615080    2019-10-09    2019-04-29          0001
# 1141746  2061735  191222359    2019-09-10    2019-09-09          2300
# 1141747  2061738  191406140    2019-01-24    2019-01-16          1100
# 1141748  2061740  191307048    2019-02-26    2019-01-09          1330
# 1141749  2061744  190712475    2019-06-19    2019-06-05          1130
# 1141750  2061745  191410197    2019-04-11    2019-03-29          2200
# 1141751  2061747  192114100    2019-08-10    2019-08-10          0330
# 1141752  2061748  190814279    2019-08-16    2019-08-16          1910
# 1141753  2061752  192011169    2019-05-24    2019-05-24          1730
# 1141754  2061753  191223810    2019-09-30    2019-09-26          1320
# 1141755  2061754  190415070    2019-09-27    2019-09-26          1700
# 1141756  2061755  190909363    2019-04-16    2019-04-16          1300
# 1141757  2061756  190205676    2019-02-03    2019-02-03          0030
# 1141758  2061757  191820864    2019-10-04    2019-10-02          2030
# 1141759  2061759  190213151    2019-06-15    2019-06-15          0145
# 1141760  2061760  191715589    2019-09-20    2019-09-19          2230
# 1141761  2061763  190411584    2019-06-27    2019-06-27          0800
# 1141762  2061764  191700838    2019-09-21    2019-09-21          1811
# 1141763  2061765  192006611    2019-02-23    2019-02-21          2200
# 1141764  2061766  191818924    2019-09-03    2019-08-26          1740
# 1141765  2061767  192106483    2019-02-25    2019-02-25          0930
# 1141766  2061768  191409952    2019-04-08    2019-04-08          0400
# 1141767  2061769  192014248    2019-07-25    2019-07-25          2210
# 1141768  2061770  190601207    2019-10-02    2019-10-02          2040
# 1141769  2061771  191115004    2019-08-13    2019-08-12          1900
# ...
# 1141646     30  pt_one_property
# 1141647     30   pt_one_violent
# 1141648     30  pt_one_property
# 1141649     30   pt_one_violent
# 1141650     00  pt_one_property
# 1141651     00  pt_one_property
# 1141652     15   pt_one_violent
# 1141653     11  pt_one_property
# 1141654     40   pt_one_violent
# 1141655     00  pt_one_property
# 1141656     40  pt_one_property
# 1141657     00  pt_one_property
# 1141658     05   pt_one_violent
# 1141659     00  pt_one_property
# 1141660     45  pt_one_property
# 1141661     00  pt_one_property
# 1141662     30  pt_one_property
# 1141663     30  pt_one_property
# 1141664     45  pt_one_property
# 1141665     00  pt_one_property
# 1141666     30  pt_one_property
# 1141667     45   pt_one_violent
# 1141668     15  pt_one_property
# 1141669     30  pt_one_property
# 1141670     00   pt_one_violent
# 1141671     00   pt_one_violent
# 1141672     30  pt_one_property
# 1141673     00  pt_one_property
# 1141674     30  pt_one_property
# 1141675     00  pt_one_property
# 1141676     45   pt_one_violent
# 1141677     00  pt_one_property
# 1141678     00  pt_one_property
# 1141679     00  pt_one_property
# 1141680     10   pt_one_violent
# 1141681     02  pt_one_property
# 1141682     35  pt_one_property
# 1141683     00  pt_one_property
# 1141684     30   pt_one_violent
# 1141685     00   pt_one_violent
# 1141686     00  pt_one_property
# 1141687     30  pt_one_property
# 1141688     30  pt_one_property
# 1141689     55  pt_one_property
# 1141690     00  pt_one_property
# 1141691     10  pt_one_property
# 1141692     00  pt_one_property
# 1141693     48   pt_one_violent
# 1141694     30  pt_one_property
# 1141695     15   pt_one_violent
# 1141696     00  pt_one_property
# 1141697     30  pt_one_property
# 1141698     00  pt_one_property
# 1141699     30  pt_one_property
# 1141700     30  pt_one_property
# 1141701     40  pt_one_property
# 1141702     00  pt_one_property
# 1141703     00  pt_one_property
# 1141704     20   pt_one_violent
# 1141705     40  pt_one_property
# 1141706     45  pt_one_property
# 1141707     00   pt_one_violent
# 1141708     00  pt_one_property
# 1141709     44  pt_one_property
# 1141710     30  pt_one_property
# 1141711     40  pt_one_property
# 1141712     50   pt_one_violent
# 1141713     00  pt_one_property
# 1141714     26   pt_one_violent
# 1141715     20   pt_one_violent
# 1141716     50   pt_one_violent
# 1141717     30   pt_one_violent
# 1141718     00  pt_one_property
# 1141719     30  pt_one_property
# 1141720     00  pt_one_property
# 1141721     30   pt_one_violent
# 1141722     00  pt_one_property
# 1141723     50  pt_one_property
# 1141724     50  pt_one_property
# 1141725     00  pt_one_property
# 1141726     00  pt_one_property
# 1141727     00  pt_one_property
# 1141728     30  pt_one_property
# 1141729     00   pt_one_violent
# 1141730     30  pt_one_property
# 1141731     25  pt_one_property
# 1141732     15  pt_one_property
# 1141733     00  pt_one_property
# 1141734     00  pt_one_property
# 1141735     20  pt_one_property
# 1141736     30   pt_one_violent
# 1141737     30  pt_one_property
# 1141738     00  pt_one_property
# 1141739     00  pt_one_property
# 1141740     35   pt_one_violent
# 1141741     00  pt_one_property
# 1141742     40  pt_one_property
# 1141743     00  pt_one_property
# 1141744     15   pt_one_violent
# 1141745     01  pt_one_property
# 1141746     00   pt_one_violent
# 1141747     00  pt_one_property
# 1141748     30   pt_one_violent
# 1141749     30  pt_one_property
# 1141750     00  pt_one_property
# 1141751     30  pt_one_property
# 1141752     10  pt_one_property
# 1141753     30   pt_one_violent
# 1141754     20  pt_one_property
# 1141755     00  pt_one_property
# 1141756     00  pt_one_property
# 1141757     30   pt_one_violent
# 1141758     30   pt_one_violent
# 1141759     45   pt_one_violent
# 1141760     30  pt_one_property
# 1141761     00  pt_one_property
# 1141762     11  pt_one_property
# 1141763     00  pt_one_property
# 1141764     40  pt_one_property
# 1141765     30  pt_one_property
# 1141766     00   pt_one_violent
# 1141767     10   pt_one_violent
# 1141768     40   pt_one_violent
# 1141769     00  pt_one_property
# 1141770     00  pt_one_property
# 1141771     00  pt_one_property
# 1141772     20   pt_one_violent
# 1141773     55  pt_one_property
# 1141774     45  pt_one_property
# 1141775     20  pt_one_property
# 1141776     00   pt_one_violent
# 1141777     00  pt_one_property
# 1141778     15  pt_one_property
# 1141779     00  pt_one_property
# 1141780     00  pt_one_property
# 1141781     00  pt_one_property
# 1141782     00   pt_one_violent
# 1141783     45   pt_one_violent
# 1141784     30   pt_one_violent
# 1141785     00  pt_one_property
# 1141786     00  pt_one_property
# 1141787     35   pt_one_violent
# 1141788     00  pt_one_property
# 1141789     01  pt_one_property
# 1141790     00  pt_one_property
# 1141791     30  pt_one_property
# 1141792     50  pt_one_property
# 1141793     30  pt_one_property
# 1141794     20  pt_one_property
# 1141795     56  pt_one_property
# 1141796     30   pt_one_violent
# 1141797     50  pt_one_property
# 1141798     16  pt_one_property
# 1141799     00  pt_one_property
# 1141800     00  pt_one_property
# 1141801     00  pt_one_property
# 1141802     00  pt_one_property
# 1141803     01   pt_one_violent
# 1141804     30   pt_one_violent
# 1141805     15  pt_one_property
# 1141806     30  pt_one_property
# 1141807     30  pt_one_property
# 1141808     30   pt_one_violent
# 1141809     00  pt_one_property
# 1141810     34  pt_one_property
# 1141811     00  pt_one_property
# 1141812     00  pt_one_property
# 1141813     00  pt_one_property
# 1141814     00  pt_one_property
# 1141815     35  pt_one_property
# 1141816     30  pt_one_property
# 1141817     00   pt_one_violent
# 1141818     00  pt_one_property
# 1141819     01  pt_one_property
# 1141820     20  pt_one_property
# 1141821     50  pt_one_property
# 1141822     00  pt_one_property
# 1141823     00  pt_one_property
# 1141824     10  pt_one_property
# 1141825     00  pt_one_property
# 1141826     30   pt_one_violent
# 1141827     57   pt_one_violent
# 1141828     00  pt_one_property
# 1141829     30   pt_one_violent
# 1141830     00  pt_one_property
# 1141831     00  pt_one_property
# 1141832     30  pt_one_property
# 1141833     00  pt_one_property
# 1141834     51  pt_one_property
# 1141835     00  pt_one_property
# 1141836     15   pt_one_violent
# 1141837     00  pt_one_property
# 1141838     15  pt_one_property
# 1141839     00  pt_one_property
# 1141840     45   pt_one_violent
# 1141841     00  pt_one_property
# 1141842     00   pt_one_violent
# 1141843     00  pt_one_property
# 1141844     00  pt_one_property
# 1141845     00  pt_one_property
# 1141846     00  pt_one_property
# 1141847     30  pt_one_property
# 1141848     00  pt_one_property
# 1141849     30  pt_one_property
# 1141850     24   pt_one_violent
# 1141851     00  pt_one_property
# 1141852     00  pt_one_property
# 1141853     15  pt_one_property
# 1141854     00  pt_one_property
# 1141855     00  pt_one_property
# 1141856     00  pt_one_property
# 1141857     00  pt_one_property
# 1141858     00  pt_one_property
# 1141859     30   pt_one_violent
# 1141860     00  pt_one_property
# 1141861     28  pt_one_property
# 1141862     45  pt_one_property
# 1141863     00  pt_one_property
# 1141864     00  pt_one_property
# 1141865     30  pt_one_property
# 1141866     20            other
# 1141867     30  pt_one_property
# 1141868     55   pt_one_violent
# 1141869     40   pt_one_violent
# 1141870     05   pt_one_violent
# 1141871     50  pt_one_property
# 1141872     00  pt_one_property
# 1141873     45   pt_one_violent
# 1141874     30  pt_one_property
# 1141875     00  pt_one_property
# 1141876     30   pt_one_violent
# 1141877     01  pt_one_property
# 1141878     00  pt_one_property
# 1141879     00  pt_one_property
# 1141880     30  pt_one_property
# 1141881     00  pt_one_property
# 1141882     00  pt_one_property
# 1141883     00  pt_one_property
# 1141884     04  pt_one_property
# 1141885     30  pt_one_property
# 1141886     30  pt_one_property
# 1141887     45  pt_one_property
# 1141888     00  pt_one_property
# 1141889     00  pt_one_property
# 1141890     00  pt_one_property
# 1141891     00  pt_one_property
# 1141892     45  pt_one_property
# 1141893     18  pt_one_property
# 1141894     00  pt_one_property
# 1141895     00  pt_one_property
# 1141896     20   pt_one_violent
# 1141897     00   pt_one_violent
# 1141898     45   pt_one_violent
# 1141899     00  pt_one_property
# 1141900     05   pt_one_violent
# 1141901     00  pt_one_property
# 1141902     00  pt_one_property
# 1141903     50  pt_one_property
# 1141904     45  pt_one_property
# 1141905     30   pt_one_violent
# 1141906     00   pt_one_violent
# 1141907     30  pt_one_property
# 1141908     30  pt_one_property
# 1141909     00  pt_one_property
# 1141910     05  pt_one_property
# 1141911     00  pt_one_property
# 1141912     18   pt_one_violent
# 1141913     45  pt_one_property
# 1141914     00  pt_one_property
# 1141915     00   pt_one_violent
# 1141916     15  pt_one_property
# 1141917     43   pt_one_violent
# 1141918     16  pt_one_property
# 1141919     30  pt_one_property
# 1141920     30  pt_one_property
# 1141921     00  pt_one_property
# 1141922     15  pt_one_property
# 1141923     02  pt_one_property
# 1141924     30   pt_one_violent
# 1141925     55  pt_one_property
# 1141926     00   pt_one_violent
# 1141927     00  pt_one_property
# 1141928     15  pt_one_property
# 1141929     00  pt_one_property
# 1141930     20   pt_one_violent
# 1141931     30  pt_one_property
# 1141932     50   pt_one_violent
# 1141933     30  pt_one_property
# 1141934     00  pt_one_property
# 1141935     00  pt_one_property
# 1141936     20  pt_one_property
# 1141937     45  pt_one_property
# 1141938     35   pt_one_violent
# 1141939     00  pt_one_property
# 1141940     30   pt_one_violent
# 1141941     00   pt_one_violent
# 1141942     45  pt_one_property
# 1141943     45  pt_one_property
# 1141944     00  pt_one_property
# 1141945     50  pt_one_property
# 1141946     30  pt_one_property
# 1141947     00  pt_one_property
# 1141948     00  pt_one_property
# 1141949     00  pt_one_property
# 1141950     25  pt_one_property
# 1141951     50  pt_one_property
# 1141952     50   pt_one_violent
# 1141953     30  pt_one_property
# 1141954     15  pt_one_property
# 1141955     00   pt_one_violent
# 1141956     00  pt_one_property
# 1141957     00  pt_one_property
# 1141958     45   pt_one_violent
# 1141959     30  pt_one_property
# 1141960     00   pt_one_violent
# 1141961     15  pt_one_property
# 1141962     40   pt_one_violent
# 1141963     00  pt_one_property
# 1141964     00  pt_one_property
# 1141965     50  pt_one_property
# 1141966     08  pt_one_property
# 1141967     00  pt_one_property
# 1141968     00   pt_one_violent
# 1141969     20  pt_one_property
# 1141970     30  pt_one_property
# 1141971     00  pt_one_property
# 1141972     30  pt_one_property
# 1141973     05  pt_one_property
# 1141974     40  pt_one_property
# 1141975     30  pt_one_property
# 1141976     47  pt_one_property
# 1141977     03   pt_one_violent
# 1141978     00  pt_one_property
# 1141979     00  pt_one_property
# 1141980     50  pt_one_property
# 1141981     00  pt_one_property
# 1141982     00  pt_one_property
# 1141983     00  pt_one_property
# 1141984     00  pt_one_property
# 1141985     14  pt_one_property
# 1141986     30   pt_one_violent
# 1141987     00  pt_one_property
# 1141988     05   pt_one_violent
# 1141989     30  pt_one_property
# 1141990     15  pt_one_property
# 1141991     30  pt_one_property
# 1141992     30  pt_one_property
# 1141993     01  pt_one_property
# 1141994     45   pt_one_violent
# 1141995     40  pt_one_property
# 1141996     00  pt_one_property
# 1141997     00   pt_one_violent
# 1141998     00  pt_one_property
# 1141999     00   pt_one_violent
# 1142000     00  pt_one_property
# 1142001     15  pt_one_property
# 1142002     50  pt_one_property
# 1142003     00  pt_one_property
# 1142004     00  pt_one_property
# 1142005     45  pt_one_property
# 1142006     01  pt_one_property
# 1142007     00  pt_one_property
# 1142008     40   pt_one_violent
# 1142009     46  pt_one_property
# 1142010     45  pt_one_property
# 1142011     30  pt_one_property
# 1142012     05  pt_one_property
# 1142013     15   pt_one_violent
# 1142014     00   pt_one_violent
# 1142015     30  pt_one_property
# 1142016     10   pt_one_violent
# 1142017     00   pt_one_violent
# 1142018     00  pt_one_property
# 1142019     45  pt_one_property
# 1142020     00  pt_one_property
# 1142021     00   pt_one_violent
# 1142022     15   pt_one_violent
# 1142023     25  pt_one_property
# 1142024     30   pt_one_violent
# 1142025     30   pt_one_violent
# 1142026     00  pt_one_property
# 1142027     30  pt_one_property
# 1142028     30  pt_one_property
# 1142029     10   pt_one_violent
# 1142030     20  pt_one_property
# 1142031     15   pt_one_violent
# 1142032     15  pt_one_property
# 1142033     10   pt_one_violent
# 1142034     00  pt_one_property
# 1142035     00   pt_one_violent
# 1142036     26  pt_one_property
# 1142037     00  pt_one_property
# 1142038     00  pt_one_property
# 1142039     45  pt_one_property
# 1142040     40  pt_one_property
# 1142041     40  pt_one_property
# 1142042     00   pt_one_violent
# 1142043     00  pt_one_property
# 1142044     15  pt_one_property
# 1142045     05  pt_one_property
# 1142046     00  pt_one_property
# 1142047     30   pt_one_violent
# 1142048     30  pt_one_property
# 1142049     00  pt_one_property
# 1142050     50  pt_one_property
# 1142051     00  pt_one_property
# 1142052     00  pt_one_property
# 1142053     00   pt_one_violent
# 1142054     00   pt_one_violent
# 1142055     00  pt_one_property
# 1142056     30  pt_one_property
# 1142057     30  pt_one_property
# 1142058     30  pt_one_property
# 1142059     00  pt_one_property
# 1142060     40   pt_one_violent
# 1142061     10   pt_one_violent
# 1142062     30  pt_one_property
# 1142063     05  pt_one_property
# 1142064     45   pt_one_violent
# 1142065     00   pt_one_violent
# 1142066     45  pt_one_property
# 1142067     00  pt_one_property
# 1142068     31  pt_one_property
# 1142069     00  pt_one_property
# 1142070     30   pt_one_violent
# 1142071     35  pt_one_property
# 1142072     00  pt_one_property
# 1142073     30  pt_one_property
# 1142074     00  pt_one_property
# 1142075     00  pt_one_property
# 1142076     30   pt_one_violent
# 1142077     00  pt_one_property
# 1142078     30   pt_one_violent
# 1142079     00  pt_one_property
# 1142080     00  pt_one_property
# 1142081     00  pt_one_property
# 1142082     00  pt_one_property
# 1142083     30  pt_one_property
# 1142084     00   pt_one_violent
# 1142085     30  pt_one_property
# 1142086     00  pt_one_property
# 1142087     30  pt_one_property
# 1142088     00  pt_one_property
# 1142089     15  pt_one_property
# 1142090     00  pt_one_property
# 1142091     10   pt_one_violent
# 1142092     00  pt_one_property
# 1142093     00  pt_one_property
# 1142094     30  pt_one_property
# 1142095     34  pt_one_property
# 1142096     00  pt_one_property
# 1142097     12  pt_one_property
# 1142098     13   pt_one_violent
# 1142099     00  pt_one_property
# 1142100     30  pt_one_property
# 1142101     00  pt_one_property
# 1142102     30  pt_one_property
# 1142103     00  pt_one_property
# 1142104     00   pt_one_violent
# 1142105     00  pt_one_property
# 1142106     30  pt_one_property
# 1142107     20   pt_one_violent
# 1142108     10  pt_one_property
# 1142109     00  pt_one_property
# 1142110     00  pt_one_property
# 1142111     20   pt_one_violent
# 1142112     00            other
# 1142113     10  pt_one_property
# 1142114     15  pt_one_property
#
# [1142115 rows x 39 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Limit dataframe to serious crimes — the type reported to FBI

# %%
crimes = src[src['part_type'] == 1]

# %% [markdown]
# ### Cases involving suspects or victimes defined by LAPD as 'homeless'

# %%
mocrimes = crimes.dropna(subset=['modus_operandi_code'])

# %%
mocodes = pd.read_csv('mo_codes.csv')
mocodes.head()
# Out:
#   mo_code  mo_code_description
# 0    0100  Suspect Impersonate
# 1    0101           Aid victim
# 2    0102                Blind
# 3    0103             Crippled
# 4    0104             Customer

# %%
# Chief Beck orders departmentwide focus on coding in 2016
# MO Code 1218 is to be used when a victim is homeless
# MO Code 2004 is to be used when a suspect is homeless
mocodes_homeless = mocodes[mocodes['mo_code_description'].str.lower().str.contains('homeless')]
mocodes_homeless.head()
# Out:
#     mo_code            mo_code_description
# 361    1218  Victim was Homeless/Transient
# 521    2004  Suspect is homeless/transient

# %% [markdown]
# ### Limit homeless crime data to recent years to account for coding issues

# %%
homeless_dates = ['2016', '2017', '2018', '2019']

# %% [markdown]
# ### Various filters

# %%
#Homeless people codes
homeless_victims = crimes[(crimes['modus_operandi_code'].str.contains('1218', na=False)) & (crimes['year'].isin(homeless_dates))]
homeless_suspects = crimes[(crimes['modus_operandi_code'].str.contains('2004', na=False)) & (crimes['year'].isin(homeless_dates))]
homeless_homicides = homeless_victims[(homeless_victims['crime_code_description']\
                    .str.contains('Criminal homicide', na=False))\
                    & (homeless_victims['year'].isin(homeless_dates))]

# %%
homeless_victims_women = homeless_victims[homeless_victims['victim_sex'] == 'female']

# %% [markdown]
# ### How many cases do we have involving homeless people?

# %%
len(homeless_victims_women)
# Out:
# 0

# %%
len(homeless_victims)
# Out:
# 0

# %%
len(homeless_suspects)
# Out:
# 0

# %%
homeless_victims.columns
# Out:
# Index(['index', 'record_id', 'date_reported', 'date_occurred', 'time_occurred',
#        'division', 'division_name', 'reporting_district', 'part_type',
#        'crime_code', 'crime_code_description', 'modus_operandi_code',
#        'victim_age', 'victim_sex', 'victim_descent', 'premises_code',
#        'premises_description', 'weapon_code', 'weapon_description',
#        'status_code', 'status_code_description', 'crm_cd_1', 'crm_cd_2',
#        'crm_cd_3', 'crm_cd_4', 'address', 'cross_street', 'latitude',
#        'longitude', 'year', 'quarter', 'day', 'month', 'weekday', 'monthname',
#        'descent_description', 'hour', 'minute', 'part_category'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ### Group by cases involving homeless victims

# %%
homeless_victims_years = homeless_victims.groupby\
(['division_name']).agg('size').reset_index(name='total')

# %% [markdown]
# ### Group by cases involving homeless suspects

# %%
homeless_suspects_years = homeless_suspects.groupby\
(['division_name']).agg('size').reset_index(name='total')
homeless_suspects_years.head()
# Out:
# Empty DataFrame
# Columns: [division_name, total]
# Index: []

# %% [markdown]
# ---

# %% [markdown]
# ### Homeless homicides

# %%
homeless_homicides.head()
# Out:
# Empty DataFrame
# Columns: [index, record_id, date_reported, date_occurred, time_occurred, division, division_name, reporting_district, part_type, crime_code, crime_code_description, modus_operandi_code, victim_age, victim_sex, victim_descent, premises_code, premises_description, weapon_code, weapon_description, status_code, status_code_description, crm_cd_1, crm_cd_2, crm_cd_3, crm_cd_4, address, cross_street, latitude, longitude, year, quarter, day, month, weekday, monthname, descent_description, hour, minute, part_category]
# Index: []

# %%
homeless_homicides_years = homeless_homicides.groupby\
(['year','division_name', 'premises_description','weapon_description']).agg('size').reset_index(name='total')

# %%
chart_homeless_homicides_years = alt.Chart(homeless_homicides_years).mark_bar().encode(
    y=alt.Y('year:N', axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("sum(total):Q", title="Cases", axis=alt.Axis(format='', tickCount=5))
)

chart_homeless_homicides_years_text = chart_homeless_homicides_years.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='sum(total):Q'
)

(chart_homeless_homicides_years + chart_homeless_homicides_years_text).properties(height=150, width=500, title='Homeless homicide cases per year')

# %%
chart_homeless_divisions = alt.Chart(homeless_homicides_years).mark_bar().encode(
    y=alt.Y('division_name:N',
        sort=alt.EncodingSortField(
            field="total",  # The field to use for the sort
            op="sum",  # The operation to run on the field prior to sorting
            order="descending"  # The order to sort in
        ), axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("sum(total):Q", title="Cases", axis=alt.Axis(format='', tickCount=5))
)

chart_homeless_divisions_text = chart_homeless_divisions.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='sum(total):Q'
)


(chart_homeless_divisions + chart_homeless_divisions_text)\
.properties(height=400, width=700, title='Homeless homicide by police division, 2016-19')

# %%
chart_homeless_weapon = alt.Chart(homeless_homicides_years).mark_bar().encode(
    y=alt.Y('weapon_description:N',
        sort=alt.EncodingSortField(
            field="total",  # The field to use for the sort
            op="sum",  # The operation to run on the field prior to sorting
            order="descending"  # The order to sort in
        ), axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("sum(total):Q", title="Cases", axis=alt.Axis(format='', tickCount=5))
)

chart_homeless_weapon_text = chart_homeless_weapon.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='sum(total):Q'
)

(chart_homeless_weapon + chart_homeless_weapon_text)\
    .properties(height=400, width=700, title='Homeless homicide by weapon type, 2016-19')

# %%
chart_homeless_location = alt.Chart(homeless_homicides_years).mark_bar().encode(
    y=alt.Y('premises_description:N',
        sort=alt.EncodingSortField(
            field="total",  # The field to use for the sort
            op="sum",  # The operation to run on the field prior to sorting
            order="descending"  # The order to sort in
        ), axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("sum(total):Q", title="Cases", axis=alt.Axis(format='', tickCount=5))
)

chart_homeless_location_text = chart_homeless_location.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='sum(total):Q'
)

(chart_homeless_location + chart_homeless_location_text)\
.properties(height=400, width=700, title='Homeless homicide by location type, 2017-19')

# %% [markdown]
# ---

# %% [markdown]
# ## Homeless victims

# %%
homeless_year_victim = homeless_victims.groupby(['year', 'division_name'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)
homeless_year_victim.head()
# Out:
# Empty DataFrame
# Columns: [year, division_name, total]
# Index: []

# %%
homeless_year_victim = homeless_victims.groupby(['year', 'division_name'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)
homeless_year_victim.head(10)
# Out:
# Empty DataFrame
# Columns: [year, division_name, total]
# Index: []

# %% [markdown]
# ### Where do crimes involving homeless victims occur?

# %%
chart_homeless_victims = alt.Chart(homeless_victims_years).mark_bar().encode(
    y=alt.Y('division_name:N', title='',
        sort=alt.EncodingSortField(
            field="total",  # The field to use for the sort
            op="sum",  # The operation to run on the field prior to sorting
            order="descending"  # The order to sort in
        ), axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("sum(total):Q", title="Cases", axis=alt.Axis(format='', tickCount=5))
)

chart_homeless_victims_text = chart_homeless_victims.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text='sum(total):Q'
)


(chart_homeless_victims + chart_homeless_victims_text)\
.properties(height=400, width=700, title='Cases involving victims who are homeless residents, by police division, 2016-19')

# %%
homeless_victims['division_name'].value_counts('normalize').round(2)*100

# %%
alt.Chart(homeless_year_victim).mark_bar().encode(
    y=alt.Y('year:N', title='', axis=alt.Axis(format='', tickCount=5)),
    x=alt.X("mean(total):Q", title="homeless victims", axis=alt.Axis(format='', tickCount=10)),
    facet='division_name:N'
).properties(height=80, width=200, columns=3, title='Homeless victims per year, by division')

# %% [markdown]
# ### What types of crimes are most common for homeless victims?

# %%
homeless_cases_victim = homeless_victims.groupby(['crime_code_description', 'part_type', 'victim_sex'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %% [markdown]
# ### Homeless victims in central

# %%
homeless_victims_central = homeless_victims[homeless_victims['division_name'] == 'Central']

# %%
homeless_cases_victim_central = homeless_victims_central.groupby(['crime_code_description'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
homeless_cases_victim_central.head()

# %% [markdown]
# ---

# %%
homeless_cases_suspect = homeless_suspects.groupby(['crime_code_description'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
homeless_cases_suspect.head(10)

# %% [markdown]
# ---

# %% [markdown]
# ### What are the population breakdowns for men and women?

# %%
homeless_female_pop_share19 = 30.1
homeless_male_pop_share19 = 67.3
homeless_male_pop19 = 24360
homeless_female_pop19 = 10845

homeless_female_pop_share19 = 31
homeless_male_pop_share19 = 67
homeless_male_pop18 = 20907
homeless_female_pop18 = 9577

city_female_pop_share = 50.5
city_male_pop_share = 45.5
city_female_pop = 2015180
city_male_pop = 1815657

# %% [markdown]
# ### What types of crimes do female homeless residents encounter?

# %%
vic_sex_pivot = pd.pivot_table(homeless_cases_victim, values='total', \
                       index=['crime_code_description'],columns=['victim_sex'], \
                                        aggfunc=np.sum, fill_value=0).reset_index()

# %%
vic_sex_pivot['total_all'] = (vic_sex_pivot['female'] + \
                vic_sex_pivot['male'] + \
                vic_sex_pivot['unknown'])

# %%
vic_sex_pivot['female_share_all'] = ((vic_sex_pivot['female'] / \
                                           vic_sex_pivot['total_all'])*100).round(2)

# %%
vic_sex_pivot['male_share_all'] = ((vic_sex_pivot['male'] / \
                                           vic_sex_pivot['total_all'])*100).round(2)

# %%
vic_sex_pivot.sort_values(by='total_all', ascending=False).head(10)

# %%
homeless_vic_sex_pivot = pd.pivot_table(homeless_cases_victim, values='total', \
                       index=['crime_code_description'],columns=['victim_sex'], \
                                        aggfunc=np.sum, fill_value=0).reset_index()

# %%
homeless_vic_sex_pivot['total_homeless'] = (homeless_vic_sex_pivot['female'] + \
                homeless_vic_sex_pivot['male'] + \
                homeless_vic_sex_pivot['unknown'])

# %%
homeless_vic_sex_pivot['female_share_homeless'] = ((homeless_vic_sex_pivot['female'] / \
                                           homeless_vic_sex_pivot['total_homeless'])*100).round(2)

# %%
homeless_vic_sex_pivot['male_share_homeless'] = ((homeless_vic_sex_pivot['male'] / \
                                           homeless_vic_sex_pivot['total_homeless'])*100).round(2)

# %%
homeless_vic_sex_pivot.sort_values(by='total_homeless', ascending=False).head(20)

# %%
female_share_homeless_all = pd.merge(vic_sex_pivot, homeless_vic_sex_pivot, on='crime_code_description')

# %%
female_share_homeless_all_trimmed = female_share_homeless_all[[ 'crime_code_description',\
                               'total_homeless', 'female_share_all', 'female_share_homeless']]

# %%
female_share_homeless_all_trimmed.sort_values(by='total_homeless', ascending=False).head(20)

# %% [markdown]
# ---

# %% [markdown]
# ### Import homeless population by LA Times neighborhood

# %%
homeless_pop = \
pd.read_csv('/Users/mhustiles/data/github/notebooks/homeless-restrictions-raw/output\
/homeless-apportioned-totals-by-neighborhood.csv')

# %%
homeless_pop = homeless_pop[homeless_pop['totpeople'] > 1]

# %% [markdown]
# ### Relate homeless victim/suspect incident data to LA neighborhoods, not just police geography

# %%
# Read Los Angeles Times neighborhoods
hoods = gpd.read_file('input/custom-la-hoods-skid-row.geojson')
hoods.plot()

# %%
skidrow = hoods[hoods['name'] == 'Skid Row']
skidrow.plot()

# %% [markdown]
# ### Convert homeless victims dataframe to geodataframe, set CRS, join with 'hoods

# %%
homeless_victims_gdf = gpd.GeoDataFrame(homeless_victims, \
    geometry=gpd.points_from_xy(homeless_victims.longitude, homeless_victims.latitude))
homeless_victims_gdf.crs = ({'init':'epsg:4326'})
homeless_victims_hoods = gpd.sjoin(homeless_victims_gdf, hoods, op = 'within')

# %% [markdown]
# ### Convert homeless suspects dataframe to geodataframe, set CRS, join with 'hoods

# %%
homeless_suspects_gdf = gpd.GeoDataFrame(homeless_suspects, \
    geometry=gpd.points_from_xy(homeless_suspects.longitude, homeless_suspects.latitude))
homeless_suspects_gdf.crs = ({'init':'epsg:4326'})
homeless_suspects_hoods = gpd.sjoin(homeless_suspects_gdf, hoods, op = 'within')

# %% [markdown]
# ### Group by hood name

# %%
homeless_victims_hoods_grouped = homeless_victims_hoods.groupby(['name'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
homeless_suspects_hoods_grouped = homeless_suspects_hoods.groupby(['name'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
homeless_suspects_hoods_grouped.head(10)

# %%
homeless_victims_hoods_grouped.head(10)

# %% [markdown]
# ### Calculate crime rate among homeless victims

# %%
homeless_victims_hoods_merged = pd.merge(homeless_victims_hoods_grouped, homeless_pop, on='name')

# %%
homeless_victims_hoods_merged.sort_values(by='totpeople', ascending=False)

# %%
homeless_victims_hoods_merged['rate'] = \
(homeless_victims_hoods_merged['total'] / (homeless_victims_hoods_merged['totpeople']/100)).round(1)

# %%
homeless_victims_hoods_merged.sort_values(by='rate', ascending=False)

# %% [markdown]
# ### Calculate breaks for crime rate

# %%
breaks_rate \
= jenkspy.jenks_breaks(homeless_victims_hoods_merged.rate, nb_class=7)

# %%
breaks_rate

# %%
def get_group_rate(value):
    for i, b in enumerate(breaks_rate):
        if value <= breaks_rate[i+1]:
            return i

# %%
homeless_victims_hoods_merged['rate_score'] = homeless_victims_hoods_merged.rate.apply(get_group_rate)

# %% [markdown]
# ### Calculate breaks for total crimes

# %%
breaks_crimes \
= jenkspy.jenks_breaks(homeless_victims_hoods_merged.total, nb_class=7)

# %%
breaks_crimes

# %%
def get_group_crimes(value):
    for i, b in enumerate(breaks_crimes):
        if value <= breaks_crimes[i+1]:
            return i

# %%
homeless_victims_hoods_merged['crimes_score'] = homeless_victims_hoods_merged.total.apply(get_group_crimes)

# %%
homeless_victims_hoods_merged.sort_values(by='crimes_score', ascending=False).head()

# %% [markdown]
# ### Merge homeless victim rate by 'hoods back to the 'hoods geodataframe

# %%
homeless_victims_maps = hoods.merge(homeless_victims_hoods_merged, on='name', how='left')

# %%
homeless_victims_maps.to_file('output/homeless_victims_maps.geojson', driver='GeoJSON')

# %%
geojson = json.loads(homeless_victims_maps.to_json())

# %%
features = alt.Data(values=geojson['features'])

# %%
base = alt.Chart(features).mark_geoshape(
    stroke='white',
    fill='#e6e6e6',
    strokeWidth=0.1
).encode().properties(
    width=400,
    height=600
)

# %%
geoshape = alt.Chart(features).mark_geoshape(
    fill='#e6e6e6',
    stroke='white'
)

# %%
rate = geoshape.encode(
    color=alt.Color(
        "properties.rate_score:N",
        scale=alt.Scale(
            domain=[0, 1, 2, 3, 4, 5, 6],
            range=lat.palette['schemes']['fire-7']
        ),
        legend=None
    ),
)

crimes = geoshape.encode(
    color=alt.Color(
        "properties.crimes_score:N",
        scale=alt.Scale(
            domain=[0, 1, 2, 3, 4, 5, 6],
            range=lat.palette['schemes']['fire-7']
        ),
        legend=None
    ),
)

# %%
(base + rate).properties(title="Crime victims per/100 homeless residents by L.A. neighborhood").configure_view(
    strokeWidth=0
)

# %%
(base + crimes).properties(title="Total crime victims by L.A. neighborhood").configure_view(
    strokeWidth=0
)

# %% [markdown]
# ## Basic aggregates on variables for all crimes

# %% [markdown]
# ### Which crimes are most common?

# %%
crimes_grouped = crimes.groupby(['crime_code_description', 'victim_sex'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
crimes_grouped.head(10)

# %% [markdown]
# ### Which crimes are most common for homeless victims?

# %%
homeless_crimes_grouped = homeless_victims.groupby(['crime_code_description', 'victim_sex'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
homeless_cases_victim.head(10)

# %% [markdown]
# ### Places where crimes occur?

# %%
places = crimes.groupby(['premises_description'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
places.head(10)

# %% [markdown]
# ### Areas of the city?

# %%
divisions = crimes.groupby(['division_name'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
divisions.head(10)

# %% [markdown]
# ### What kinds of weapons?

# %%
weapons = crimes.groupby(['weapon_description'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
weapons.head(10)

# %% [markdown]
# ### Which days of the week?

# %%
weekdays = crimes.groupby(['weekday'])\
.agg('size').reset_index(name='total').sort_values(by='total', ascending=False)

# %%
weekdays.head(7)

# %% [markdown]
# ---
