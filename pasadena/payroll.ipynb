# %% [markdown]
# # Processing Pasadena (Texas) employee payroll

# %% [markdown]
# ### Import Python tools and Jupyter configuration

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd
import datetime as dt
import matplotlib.pyplot as plt
import altair as alt

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = None

# %% [markdown]
# ### Import wages

# %%
wages = pd.read_csv(
    "data/raw/payroll-gross-wages.csv",
    names=["first_wages", "last_wages", "wages"],
    header=None,
)

# %%
wages["full_name_wages"] = wages["first_wages"] + " " + wages["last_wages"]

# %%
wages[wages["full_name_wages"].fillna("").str.contains("MCCLAIN")]
# Out:
#     first_wages last_wages       wages    full_name_wages
# 670   BRANDON M    MCCLAIN  102,921.02  BRANDON M MCCLAIN

# %%
wages["wages"] = wages["wages"].str.replace(",", "", regex=False).astype(float)

# %%
len(wages)
# Out:
# 1243

# %% [markdown]
# ### Import employee details

# %%
employees = pd.read_csv(
    "data/raw/payroll-employee-list.csv",
    names=[
        "first_employee",
        "last_employee",
        "title",
        "departmentid",
        "department",
        "gender",
        "hiredate",
        "ee_number",
    ],
    parse_dates=["hiredate"],
    dtype={"ee_number": str, "department": str},
)

# %%
employees = employees.drop_duplicates().copy()

# %%
employees["full_name_employee"] = (
    employees["first_employee"] + " " + employees["last_employee"]
)

# %%
employees.head()
# Out:
#   first_employee last_employee                      title departmentid  \
# 0  CHRISTOPHER A         AARON        NPO5 POLICE OFFICER        13421
# 1       DANIEL J         AARON        NPO5 POLICE OFFICER        13421
# 2          JOE A        ABILEZ  N01#*PT POOLED STR & BRDG        14400
# 3       SELENE Z       ACEVEDO    E02 FIN ASST HOUS ADMIN           62
# 4      ALEJANDRA        ACOSTA     N01#PT POOLED AQUATICS        15220
#
#                 department gender   hiredate ee_number   full_name_employee
# 0                   PATROL      M 2013-06-17        25  CHRISTOPHER A AARON
# 1                   PATROL      M 2007-11-26        20       DANIEL J AARON
# 2            STREET/BRIDGE      M 2019-06-04        52         JOE A ABILEZ
# 3  HOUSING ASSIST-VOUCHERS      F 2016-08-22       514     SELENE Z ACEVEDO
# 4                 AQUATICS      F 2020-06-10       183     ALEJANDRA ACOSTA

# %%
len(employees)
# Out:
# 1270

# %%
employees[employees["full_name_employee"].str.contains("ALONSO")]
# Out:
#     first_employee last_employee                     title departmentid  \
# 20   JORGE ANTONIO        ALONSO      N11 MAINT SUPERVISOR        20410
# 21       JULISSA A        ALONSO      N05*PT REC ATTENDANT        15230
# 22         LILIANA        ALONSO   N06 LIBRARY ASSISTANT I        17110
# 367       ALONSO J        GARCIA  N07 WATER BILL ASSIST II        30700
#
#                  department gender   hiredate ee_number    full_name_employee
# 20         BLDG & EQUIPMENT      M 1991-10-23       115  JORGE ANTONIO ALONSO
# 21       RECREATION CENTERS      F 2018-05-21       112      JULISSA A ALONSO
# 22   LIBRARY-ADMIN SERVICES      F 2013-12-23       119        LILIANA ALONSO
# 367           WATER BILLING      M 2020-03-09      2438       ALONSO J GARCIA

# %% [markdown]
# ### Merge employee list with wages

# %%
df = pd.merge(
    employees,
    wages,
    left_on="full_name_employee",
    right_on="full_name_wages",
)

# %%
len(df)
# Out:
# 1182

# %%
df[["title_id", "title_description"]] = df["title"].str.split(" ", 1, expand=True)

# %%
today = pd.to_datetime("today")

# %%
df["time_since"] = (today - df["hiredate"]).dt.days

# %% [markdown]
# ---

# %% [markdown]
# ### How many officers?

# %%
len(df[df["title_description"] == "POLICE OFFICER"])
# Out:
# 236

# %%
patrol_officer = df[
    (df["title_description"] == "POLICE OFFICER") & (df["department"] == "PATROL")
]

# %%
patrol_officer.sort_values("wages", ascending=False).head()
# Out:
#       first_employee last_employee                title departmentid  \
# 300        MARK ALAN      FERGUSON  NPO5 POLICE OFFICER        13421
# 323         STEVEN J        FOWLER  NPO5 POLICE OFFICER        13421
# 870          JERRY C          ROCK  NPO5 POLICE OFFICER        13421
# 332          ALBERTO        GALVAN  NPO5 POLICE OFFICER        13421
# 917  RIGOBERTO RUBEN      SALDIVAR  NPO5 POLICE OFFICER        13421
#
#     department gender   hiredate ee_number        full_name_employee  \
# 300     PATROL      M 1996-03-04      2122        MARK ALAN FERGUSON
# 323     PATROL      M 1991-06-03      2264           STEVEN J FOWLER
# 870     PATROL      M 1995-07-10      5525              JERRY C ROCK
# 332     PATROL      M 1997-04-22      2397            ALBERTO GALVAN
# 917     PATROL      M 1999-04-21      5750  RIGOBERTO RUBEN SALDIVAR
#
#          first_wages last_wages      wages           full_name_wages title_id  \
# 300        MARK ALAN   FERGUSON  137937.51        MARK ALAN FERGUSON     NPO5
# 323         STEVEN J     FOWLER  132889.14           STEVEN J FOWLER     NPO5
# 870          JERRY C       ROCK  132237.54              JERRY C ROCK     NPO5
# 332          ALBERTO     GALVAN  132175.52            ALBERTO GALVAN     NPO5
# 917  RIGOBERTO RUBEN   SALDIVAR  132120.61  RIGOBERTO RUBEN SALDIVAR     NPO5
#
#     title_description  time_since
# 300    POLICE OFFICER        9213
# 323    POLICE OFFICER       10949
# 870    POLICE OFFICER        9451
# 332    POLICE OFFICER        8799
# 917    POLICE OFFICER        8070

# %%
patrol_officer.sort_values("wages", ascending=False).tail()
# Out:
#      first_employee last_employee                title departmentid  \
# 279         SARAH L       ELLIOTT  NPO5 POLICE OFFICER        13421
# 957        SKYLER L      SCHREURS  NPO5 POLICE OFFICER        13421
# 1002         KERI L         SMITH  NPO5 POLICE OFFICER        13421
# 263           IAN G      DOSKOCIL  NPO5 POLICE OFFICER        13421
# 962       MARCELLOS         SEALE  NPO5 POLICE OFFICER        13421
#
#      department gender   hiredate ee_number full_name_employee first_wages  \
# 279      PATROL      F 2020-05-04      1916    SARAH L ELLIOTT     SARAH L
# 957      PATROL      M 2020-05-04      5877  SKYLER L SCHREURS    SKYLER L
# 1002     PATROL      F 2020-05-04      6067       KERI L SMITH      KERI L
# 263      PATROL      M 2020-05-04      1762     IAN G DOSKOCIL       IAN G
# 962      PATROL      M 2017-07-17      5941    MARCELLOS SEALE   MARCELLOS
#
#      last_wages     wages    full_name_wages title_id title_description  \
# 279     ELLIOTT  45140.80    SARAH L ELLIOTT     NPO5    POLICE OFFICER
# 957    SCHREURS  45140.80  SKYLER L SCHREURS     NPO5    POLICE OFFICER
# 1002      SMITH  45140.80       KERI L SMITH     NPO5    POLICE OFFICER
# 263    DOSKOCIL  45140.80     IAN G DOSKOCIL     NPO5    POLICE OFFICER
# 962       SEALE  26777.69    MARCELLOS SEALE     NPO5    POLICE OFFICER
#
#       time_since
# 279          386
# 957          386
# 1002         386
# 263          386
# 962         1408

# %%
patrol_officer[patrol_officer["full_name_wages"].str.contains("CARTER")]
# Out:
#     first_employee last_employee                title departmentid department  \
# 160        JASON M        CARTER  NPO5 POLICE OFFICER        13421     PATROL
#
#     gender   hiredate ee_number full_name_employee first_wages last_wages  \
# 160      M 2017-01-03      1018     JASON M CARTER     JASON M     CARTER
#
#         wages full_name_wages title_id title_description  time_since
# 160  96359.95  JASON M CARTER     NPO5    POLICE OFFICER        1603

# %%
patrol_officer[
    (patrol_officer["time_since"] > 1500) & (patrol_officer["time_since"] < 1800)
].sort_values("wages", ascending=False)
# Out:
#      first_employee last_employee                title departmentid  \
# 372          CODY A       GASSETT  NPO5 POLICE OFFICER        13421
# 77           PAUL M       BENNETT  NPO5 POLICE OFFICER        13421
# 177           ANGEL     CERVANTES  NPO5 POLICE OFFICER        13421
# 779           RAY A         PEREZ  NPO5 POLICE OFFICER        13421
# 160         JASON M        CARTER  NPO5 POLICE OFFICER        13421
# 1156      BRANDON S        WILSON  NPO5 POLICE OFFICER        13421
# 759         JESUS O           PAZ  NPO5 POLICE OFFICER        13421
# 750       MICHAEL P        PALITZ  NPO5 POLICE OFFICER        13421
#
#      department gender   hiredate ee_number full_name_employee first_wages  \
# 372      PATROL      M 2017-01-03      2665     CODY A GASSETT      CODY A
# 77       PATROL      M 2017-01-03       461     PAUL M BENNETT      PAUL M
# 177      PATROL      M 2017-01-03      1050    ANGEL CERVANTES       ANGEL
# 779      PATROL      M 2017-01-03      5166        RAY A PEREZ       RAY A
# 160      PATROL      M 2017-01-03      1018     JASON M CARTER     JASON M
# 1156     PATROL      M 2017-01-03      6960   BRANDON S WILSON   BRANDON S
# 759      PATROL      M 2017-01-03      5159        JESUS O PAZ     JESUS O
# 750      PATROL      M 2017-01-03      5153   MICHAEL P PALITZ   MICHAEL P
#
#      last_wages      wages   full_name_wages title_id title_description  \
# 372     GASSETT  111427.72    CODY A GASSETT     NPO5    POLICE OFFICER
# 77      BENNETT  103488.07    PAUL M BENNETT     NPO5    POLICE OFFICER
# 177   CERVANTES   98923.56   ANGEL CERVANTES     NPO5    POLICE OFFICER
# 779       PEREZ   96914.80       RAY A PEREZ     NPO5    POLICE OFFICER
# 160      CARTER   96359.95    JASON M CARTER     NPO5    POLICE OFFICER
# 1156     WILSON   93740.71  BRANDON S WILSON     NPO5    POLICE OFFICER
# 759         PAZ   92759.28       JESUS O PAZ     NPO5    POLICE OFFICER
# 750      PALITZ   85379.24  MICHAEL P PALITZ     NPO5    POLICE OFFICER
#
#       time_since
# 372         1603
# 77          1603
# 177         1603
# 779         1603
# 160         1603
# 1156        1603
# 759         1603
# 750         1603

# %% [markdown]
# ### Export

# %%
df.to_csv("data/processed/all_employees.csv", index=False)

# %%
patrol_officer.to_csv("data/processed/all_patrol_officers.csv", index=False)

# %%
patrol_officer[
    (patrol_officer["time_since"] > 1500) & (patrol_officer["time_since"] < 1800)
].sort_values("wages", ascending=False).to_csv(
    "data/processed/carter_academy_peers_still_in_patrol.csv", index=False
)
