# %% [markdown]
# # looking for graphics/stories in census of fatal occupational injuries

# %% [markdown]
# #### Import Python tools

# %%
# %load_ext lab_black

# %%
import pandas as pd
import numpy as np
import altair as alt
import requests
import json
from bs4 import BeautifulSoup
import os

os.environ["USE_PYGEOS"] = "0"
import geopandas as gpd

# %%
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000

# %%
from datawrapper import Datawrapper

# %%
dw_token = os.environ.get("dw_api")
dw = Datawrapper(access_token=dw_token)

# %%
month = pd.Timestamp("today").strftime("%Y-%m")

# %%
bls_api = os.environ.get("BLS_Key")

# %% [markdown]
# ---

# %%
import tabula

# %%
df = tabula.read_pdf("data/raw/cfoi.pdf", pages=7)[0]

# %%
years = df.columns[2:].to_list()

# %%
df[years] = (
    df[years].replace(",", "", regex=True).replace(" ", "", regex=True).astype(float)
)

# %%
df["pct_change"] = 100 * (df["2022"] - df["2018"]) / df["2018"]

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0                                              Total1
# 1                                                 NaN
# 2   Violence and other injuries by persons or animals
# 3                        Intentional injury by person
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                            Transportation incidents
# 9                                  Aircraft incidents
# 10                             Rail vehicle incidents
# 11                      Pedestrian vehicular incident
# 12                                                NaN
# 13                             Water vehicle incident
# 14  Roadway incident involving motorized land vehicle
# 15                                                NaN
# ...
