# %% [markdown]
# # getting retail data from BLS (QCEW)
# data [layout](https://www.bls.gov/cew/about-data/downloadable-file-layouts/quarterly/naics-based-quarterly-layout.htm)

# %% [markdown]
# #### Import Python tools

# %%
# %load_ext lab_black

# %%
import pandas as pd
import numpy as np
import altair as alt
import requests
import json
from bs4 import BeautifulSoup
import os

os.environ["USE_PYGEOS"] = "0"
import geopandas as gpd

# %%
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000

# %%
from datawrapper import Datawrapper

# %%
dw_token = os.environ.get("dw_api")
dw = Datawrapper(access_token=dw_token)

# %%
month = pd.Timestamp("today").strftime("%Y-%m")

# %%
bls_api = os.environ.get("BLS_Key")

# %% [markdown]
# ---

# %% [markdown]
# ## Read data

# %% [markdown]
# #### Import table from the bureau's API
# this is how I originally got the data--it's really slow to read in from the api so i saved it to aws and read in from there

# %% [raw]
# years = ["2019", "2020", "2021", "2022"]
# quarters = [1, 2, 3, 4]

# %% [raw]
# urls = []
# for q in quarters:
#     for y in years:
#         urls.append(
#             "https://data.bls.gov/cew/data/api/"
#             + y
#             + "/"
#             + str(q)
#             + "/industry/44_45.csv"
#         )

# %% [raw]
# ## 2023 we only have through q 1
# urls.append("https://data.bls.gov/cew/data/api/2023/1/industry/44_45.csv")

# %% [raw]
# frames = []
# for u in urls:
#     frames.append(pd.read_csv(u))

# %%
df = pd.read_csv("https://ix.cnn.io/data/bls-retail/qcew_retail_trade.csv")

# %%
# fips codes for relevant counties
fips = [
    "06075",  # san francisco
    "06001",  # oakland/alameda county
    "06013",  # pittsburg/contra costa
    "36061",  # new york
    "41051",  # portland/multnomah county
    "53033",  # seattle/king county, wa
    "US000",  # NATIONAL
]

# %%
# narrowing down to the relevant counties and only priately owned retailers
df_slim = df[(df["area_fips"].isin(fips)) & (df["own_code"] == 5)].reset_index(
    drop=True
)

# %%
df_slim["q_year"] = df_slim["year"].astype(str) + "-Q" + df_slim["qtr"].astype(str)

# %%
df_slim["quarter_date"] = pd.PeriodIndex(df_slim["q_year"], freq="Q").to_timestamp()

# %%
# pct_change from q1 2019 will be more interesting
alt.Chart(df_slim[df_slim["area_fips"] != "US000"]).mark_line().encode(
    x=alt.X("quarter_date"), y=alt.Y("qtrly_estabs"), color="area_fips"
)
# Out:
# alt.Chart(...)

# %%
# doesn't seem like we are gonna get quarterly establishments nationwide--too few?
# number of establishments has grown, number of employees has not
df[(df["area_fips"] == "US000") & (df["own_code"] == 5)]
# Out:
#       area_fips  own_code industry_code  agglvl_code  size_code  year  qtr  \
# 4480      US000         5         44-45           14          0  2019    1
# 8965      US000         5         44-45           14          0  2020    1
# 13455     US000         5         44-45           14          0  2021    1
# 17946     US000         5         44-45           14          0  2022    1
# 22427     US000         5         44-45           14          0  2019    2
# 26912     US000         5         44-45           14          0  2020    2
# 31402     US000         5         44-45           14          0  2021    2
# 35893     US000         5         44-45           14          0  2022    2
# 40374     US000         5         44-45           14          0  2019    3
# 44859     US000         5         44-45           14          0  2020    3
# 49349     US000         5         44-45           14          0  2021    3
# 53840     US000         5         44-45           14          0  2022    3
# 58321     US000         5         44-45           14          0  2019    4
# 62806     US000         5         44-45           14          0  2020    4
# 67296     US000         5         44-45           14          0  2021    4
# 71787     US000         5         44-45           14          0  2022    4
# 76278     US000         5         44-45           14          0  2023    1
#
#       disclosure_code  qtrly_estabs  month1_emplvl  month2_emplvl  \
# 4480              NaN       1040988       15630253       15396927
# 8965              NaN       1042124       15464678       15306576
# 13455             NaN       1043216       15132466       15013474
# 17946             NaN       1049355       15293665       15326857
# 22427             NaN       1043323       15425203       15505375
# 26912             NaN       1037726       12807741       13380618
# 31402             NaN       1047229       15062074       15214416
# 35893             NaN       1055217       15377855       15391274
# 40374             NaN       1043974       15556752       15542465
# 44859             NaN       1043148       14650582       14778923
# 49349             NaN       1054234       15349955       15321805
# 53840             NaN       1062572       15495302       15479425
# 58321             NaN       1046756       15588125       16072327
# 62806             NaN       1048849       15153863       15526466
# 67296             NaN       1061429       15526648       15896011
# 71787             NaN       1067544       15510972       15813611
# 76278             NaN       1066986       15447645       15322478
#
#        month3_emplvl  total_qtrly_wages  taxable_qtrly_wages  \
# 4480        15400404       127951801731          92848421903
# 8965        15257954       132159234619          95015758823
# 13455       15065463       136317268042          94509237508
# 17946       15316443       151651896851         101972277168
# 22427       15556564       129699119593          47298847673
# 26912       14306824       123106200520          43825759013
# 31402       15299282       150372221616          50729826902
# 35893       15419466       152143512623          49438393684
# 40374       15409511       129037309072          31633342878
# 44859       14815310       133504267981          32036198671
# 49349       15196048       152552929694          35880221948
# 53840       15369007       160323856686          37879783523
# 58321       16150660       137746213216          26462928506
# 62806       15649781       153732541245          28883694400
# 67296       16027980       170464949086          31865832387
# 71787       15954649       162328535190          29169371730
# 76278       15328574       161135605356         106338701112
#
#        qtrly_contributions  avg_wkly_wage lq_disclosure_code  lq_qtrly_estabs  \
# 4480            1337255565            636                NaN              1.0
# 8965            1339816675            663                NaN              1.0
# 13455           1419401435            696                NaN              1.0
# 17946           1421911749            762                NaN              1.0
# 22427            585004703            644                NaN              1.0
# 26912            463606692            702                NaN              1.0
# 31402            670944756            761                NaN              1.0
# 35893            620922403            760                NaN              1.0
# 40374            385883124            640                NaN              1.0
# 44859            353919950            696                NaN              1.0
# 49349            473383464            768                NaN              1.0
# 53840            476383686            798                NaN              1.0
# 58321            328541177            665                NaN              1.0
# 62806            329835394            766                NaN              1.0
# 67296            433220818            829                NaN              1.0
# 71787            365657052            792                NaN              1.0
# 76278           1389091135            807                NaN              1.0
#
#        lq_month1_emplvl  lq_month2_emplvl  lq_month3_emplvl  \
# 4480                1.0               1.0               1.0
# 8965                1.0               1.0               1.0
# 13455               1.0               1.0               1.0
# 17946               1.0               1.0               1.0
# 22427               1.0               1.0               1.0
# 26912               1.0               1.0               1.0
# 31402               1.0               1.0               1.0
# 35893               1.0               1.0               1.0
# 40374               1.0               1.0               1.0
# 44859               1.0               1.0               1.0
# 49349               1.0               1.0               1.0
# 53840               1.0               1.0               1.0
# 58321               1.0               1.0               1.0
# 62806               1.0               1.0               1.0
# 67296               1.0               1.0               1.0
# 71787               1.0               1.0               1.0
# 76278               1.0               1.0               1.0
#
#        lq_total_qtrly_wages  lq_taxable_qtrly_wages  lq_qtrly_contributions  \
# 4480                    1.0                     1.0                     1.0
# 8965                    1.0                     1.0                     1.0
# 13455                   1.0                     1.0                     1.0
# 17946                   1.0                     1.0                     1.0
# 22427                   1.0                     1.0                     1.0
# 26912                   1.0                     1.0                     1.0
# 31402                   1.0                     1.0                     1.0
# 35893                   1.0                     1.0                     1.0
# 40374                   1.0                     1.0                     1.0
# 44859                   1.0                     1.0                     1.0
# 49349                   1.0                     1.0                     1.0
# 53840                   1.0                     1.0                     1.0
# 58321                   1.0                     1.0                     1.0
# 62806                   1.0                     1.0                     1.0
# 67296                   1.0                     1.0                     1.0
# 71787                   1.0                     1.0                     1.0
# 76278                   1.0                     1.0                     1.0
#
#        lq_avg_wkly_wage oty_disclosure_code  oty_qtrly_estabs_chg  \
# 4480                1.0                 NaN                 -1572
# 8965                1.0                 NaN                  1136
# 13455               1.0                 NaN                  1092
# 17946               1.0                 NaN                  6139
# 22427               1.0                 NaN                   373
# 26912               1.0                 NaN                 -5597
# 31402               1.0                 NaN                  9503
# 35893               1.0                 NaN                  7988
# 40374               1.0                 NaN                  -702
# 44859               1.0                 NaN                  -826
# 49349               1.0                 NaN                 11086
# 53840               1.0                 NaN                  8338
# 58321               1.0                 NaN                 -1089
# 62806               1.0                 NaN                  2093
# 67296               1.0                 NaN                 12580
# 71787               1.0                 NaN                  6115
# 76278               1.0                 NaN                 17631
#
#        oty_qtrly_estabs_pct_chg  oty_month1_emplvl_chg  \
# 4480                       -0.2                -114433
# 8965                        0.1                -165575
# 13455                       0.1                -332212
# 17946                       0.6                 161199
# 22427                       0.0                -186128
# 26912                      -0.5               -2617462
# 31402                       0.9                2254333
# 35893                       0.8                 315781
# 40374                      -0.1                -231863
# 44859                      -0.1                -906170
# 49349                       1.1                 699373
# 53840                       0.8                 145347
# 58321                      -0.1                -142925
# 62806                       0.2                -434262
# 67296                       1.2                 372785
# 71787                       0.6                 -15676
# 76278                       1.7                 153980
#
#        oty_month1_emplvl_pct_chg  oty_month2_emplvl_chg  \
# 4480                        -0.7                -168875
# 8965                        -1.1                 -90351
# 13455                       -2.1                -293102
# 17946                        1.1                 313383
# 22427                       -1.2                -234135
# 26912                      -17.0               -2124757
# 31402                       17.6                1833798
# 35893                        2.1                 176858
# 40374                       -1.5                -238232
# 44859                       -5.8                -763542
# 49349                        4.8                 542882
# 53840                        0.9                 157620
# 58321                       -0.9                -173431
# 62806                       -2.8                -545861
# 67296                        2.5                 369545
# 71787                       -0.1                 -82400
# 76278                        1.0                  -4379
#
#        oty_month2_emplvl_pct_chg  oty_month3_emplvl_chg  \
# 4480                        -1.1                -178209
# 8965                        -0.6                -142450
# 13455                       -1.9                -192491
# 17946                        2.1                 250980
# 22427                       -1.5                -228089
# 26912                      -13.7               -1249740
# 31402                       13.7                 992458
# 35893                        1.2                 120184
# 40374                       -1.5                -228519
# 44859                       -4.9                -594201
# 49349                        3.7                 380738
# 53840                        1.0                 172959
# 58321                       -1.1                -133817
# 62806                       -3.4                -500879
# 67296                        2.4                 378199
# 71787                       -0.5                 -73331
# 76278                        0.0                  12131
#
#        oty_month3_emplvl_pct_chg  oty_total_qtrly_wages_chg  \
# 4480                        -1.1                 2656676476
# 8965                        -0.9                 4207432888
# 13455                       -1.3                 4158033423
# 17946                        1.7                15334628809
# 22427                       -1.4                 3348883624
# 26912                       -8.0                -6592919073
# 31402                        6.9                27266021096
# 35893                        0.8                 1771291007
# 40374                       -1.5                 3255902722
# 44859                       -3.9                 4466958909
# 49349                        2.6                19048661713
# 53840                        1.1                 7770926992
# 58321                       -0.8                 4143497827
# 62806                       -3.1                15986328029
# 67296                        2.4                16732407841
# 71787                       -0.5                -8136413896
# 76278                        0.1                 9483708505
#
#        oty_total_qtrly_wages_pct_chg  oty_taxable_qtrly_wages_chg  \
# 4480                             2.1                   1507523439
# 8965                             3.3                   2167336920
# 13455                            3.1                   -506521315
# 17946                           11.2                   7463039660
# 22427                            2.7                    232166127
# 26912                           -5.1                  -3473088660
# 31402                           22.1                   6904067889
# 35893                            1.2                  -1291433218
# 40374                            2.6                    263559493
# 44859                            3.5                    402855793
# 49349                           14.3                   3844023277
# 53840                            5.1                   1999561575
# 58321                            3.1                    640480031
# 62806                           11.6                   2420765894
# 67296                           10.9                   2982137987
# 71787                           -4.8                  -2696460657
# 76278                            6.3                   4366423944
#
#        oty_taxable_qtrly_wages_pct_chg  oty_qtrly_contributions_chg  \
# 4480                               1.7                    -77655537
# 8965                               2.3                      2561110
# 13455                             -0.5                     79584760
# 17946                              7.9                      2510314
# 22427                              0.5                    -45201796
# 26912                             -7.3                   -121398011
# 31402                             15.8                    207338064
# 35893                             -2.5                    -50022353
# 40374                              0.8                    -24303100
# 44859                              1.3                    -31963174
# 49349                             12.0                    119463514
# 53840                              5.6                      3000222
# 58321                              2.5                    -15311278
# 62806                              9.1                      1294217
# 67296                             10.3                    103385424
# 71787                             -8.5                    -67563766
# 76278                              4.3                    -32820614
#
#        oty_qtrly_contributions_pct_chg  oty_avg_wkly_wage_chg  \
# 4480                              -5.5                     19
# 8965                               0.2                     27
# 13455                              5.9                     33
# 17946                              0.2                     66
# 22427                             -7.2                     25
# 26912                            -20.8                     58
# 31402                             44.7                     59
# 35893                             -7.5                     -1
# 40374                             -5.9                     25
# 44859                             -8.3                     56
# 49349                             33.8                     72
# 53840                              0.6                     30
# 58321                             -4.5                     26
# 62806                              0.4                    101
# 67296                             31.3                     63
# 71787                            -15.6                    -37
# 76278                             -2.3                     45
#
#        oty_avg_wkly_wage_pct_chg
# 4480                         3.1
# 8965                         4.2
# 13455                        5.0
# 17946                        9.5
# 22427                        4.0
# 26912                        9.0
# 31402                        8.4
# 35893                       -0.1
# 40374                        4.1
# 44859                        8.8
# 49349                       10.3
# 53840                        3.9
# 58321                        4.1
# 62806                       15.2
# 67296                        8.2
# 71787                       -4.5
# 76278                        5.9

# %%
df_slim["avg_monthly_employees"] = (
    df_slim["month1_emplvl"] + df_slim["month2_emplvl"] + df_slim["month3_emplvl"]
) / 3

# %%
df_slim["employees_per_estab"] = (
    df_slim["avg_monthly_employees"] / df_slim["qtrly_estabs"]
)

# %%
alt.Chart(df_slim[df_slim["area_fips"] == "US000"]).mark_line().encode(
    x=alt.X("quarter_date"), y=alt.Y("employees_per_estab")
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Need to process the data so i have a month in each cell to look at employees

# %%
q1 = df_slim[df_slim["qtr"] == 1]
q2 = df_slim[df_slim["qtr"] == 2]
q3 = df_slim[df_slim["qtr"] == 3]
q4 = df_slim[df_slim["qtr"] == 4]

# %%
q1_emp = q1[
    [
        "area_fips",
        "year",
        "qtr",
        "quarter_date",
        "month1_emplvl",
        "month2_emplvl",
        "month3_emplvl",
    ]
].rename(
    columns={
        "month1_emplvl": "January",
        "month2_emplvl": "February",
        "month3_emplvl": "March",
    }
)

q2_emp = q2[
    [
        "area_fips",
        "year",
        "qtr",
        "quarter_date",
        "month1_emplvl",
        "month2_emplvl",
        "month3_emplvl",
    ]
].rename(
    columns={
        "month1_emplvl": "April",
        "month2_emplvl": "May",
        "month3_emplvl": "June",
    }
)

q3_emp = q3[
    [
        "area_fips",
        "year",
        "qtr",
        "quarter_date",
        "month1_emplvl",
        "month2_emplvl",
        "month3_emplvl",
    ]
].rename(
    columns={
        "month1_emplvl": "July",
        "month2_emplvl": "August",
        "month3_emplvl": "September",
    }
)

q4_emp = q4[
    [
        "area_fips",
        "year",
        "qtr",
        "quarter_date",
        "month1_emplvl",
        "month2_emplvl",
        "month3_emplvl",
    ]
].rename(
    columns={
        "month1_emplvl": "October",
        "month2_emplvl": "November",
        "month3_emplvl": "December",
    }
)

# %%
q1_emp_long = q1_emp.melt(
    id_vars=["area_fips", "year", "qtr", "quarter_date"],
    value_vars=["January", "February", "March"],
)

q2_emp_long = q2_emp.melt(
    id_vars=["area_fips", "year", "qtr", "quarter_date"],
    value_vars=["April", "May", "June"],
)
q3_emp_long = q3_emp.melt(
    id_vars=["area_fips", "year", "qtr", "quarter_date"],
    value_vars=["July", "August", "September"],
)
q4_emp_long = q4_emp.melt(
    id_vars=["area_fips", "year", "qtr", "quarter_date"],
    value_vars=["October", "November", "December"],
)

# %%
monthly_employees = pd.concat(
    [q1_emp_long, q2_emp_long, q3_emp_long, q4_emp_long]
).reset_index(drop=True)

# %%
monthly_employees["date"] = pd.to_datetime(
    monthly_employees["variable"] + " " + monthly_employees["year"].astype(str)
)

# %%
alt.Chart(
    monthly_employees[monthly_employees["area_fips"] != "US000"]
).mark_line().encode(x=alt.X("date"), y=alt.Y("value"), color=alt.Color("area_fips"))
# Out:
# alt.Chart(...)

# %%
dw_employees = (
    monthly_employees[monthly_employees["area_fips"] != "US000"]
    .pivot(columns="area_fips", index="date", values="value")
    .reset_index()
)

# %%
dw.add_data(data=dw_employees, chart_id="EJRs4")
# Out:
# <Response [204]>

# %% [markdown]
# ### doing some comparisons of q1 2019 vs. 2023 for dot plots

# %%
comparison_2019_23 = df_slim[
    (df_slim["quarter_date"] == "2019-01-01")
    | (df_slim["quarter_date"] == "2023-01-01")
][
    [
        "area_fips",
        "q_year",
        "quarter_date",
        "qtrly_estabs",
        "avg_monthly_employees",
        "employees_per_estab",
    ]
]

# %%
employee_chg = comparison_2019_23.pivot(
    columns="q_year", values="avg_monthly_employees", index="area_fips"
).reset_index()

# %%
dw.add_data(
    data=comparison_2019_23.pivot(
        columns="q_year", values="employees_per_estab", index="area_fips"
    ).reset_index(),
    chart_id="EMpPm",
)
# Out:
# <Response [201]>

# %%
estab_chg = comparison_2019_23.pivot(
    columns="q_year", values="qtrly_estabs", index="area_fips"
).reset_index()

# %%
estab_chg["pct_change"] = (estab_chg["2023-Q1"] - estab_chg["2019-Q1"]) / estab_chg[
    "2019-Q1"
]

# %%
dw.add_data(data=estab_chg, chart_id="YK4ES")
# Out:
# <Response [201]>

# %%
monthly_employees[monthly_employees["area_fips"] == "53033"].sort_values("date")
# Out:
#     area_fips  year  qtr quarter_date   variable   value       date
# 5       53033  2019    1   2019-01-01    January  157978 2019-01-01
# 40      53033  2019    1   2019-01-01   February  154992 2019-02-01
# 75      53033  2019    1   2019-01-01      March  155586 2019-03-01
# 110     53033  2019    2   2019-04-01      April  155419 2019-04-01
# 138     53033  2019    2   2019-04-01        May  157884 2019-05-01
# 166     53033  2019    2   2019-04-01       June  160157 2019-06-01
# 194     53033  2019    3   2019-07-01       July  163184 2019-07-01
# 222     53033  2019    3   2019-07-01     August  163790 2019-08-01
# 250     53033  2019    3   2019-07-01  September  162188 2019-09-01
# 278     53033  2019    4   2019-10-01    October  162492 2019-10-01
# 306     53033  2019    4   2019-10-01   November  165971 2019-11-01
# 334     53033  2019    4   2019-10-01   December  170568 2019-12-01
# 12      53033  2020    1   2020-01-01    January  165207 2020-01-01
# 47      53033  2020    1   2020-01-01   February  163730 2020-02-01
# 82      53033  2020    1   2020-01-01      March  163667 2020-03-01
# 117     53033  2020    2   2020-04-01      April  147214 2020-04-01
# 145     53033  2020    2   2020-04-01        May  148712 2020-05-01
# 173     53033  2020    2   2020-04-01       June  157868 2020-06-01
# 201     53033  2020    3   2020-07-01       July  164358 2020-07-01
# 229     53033  2020    3   2020-07-01     August  167290 2020-08-01
# 257     53033  2020    3   2020-07-01  September  168799 2020-09-01
# 285     53033  2020    4   2020-10-01    October  170081 2020-10-01
# 313     53033  2020    4   2020-10-01   November  173972 2020-11-01
# 341     53033  2020    4   2020-10-01   December  176099 2020-12-01
# 19      53033  2021    1   2021-01-01    January  170653 2021-01-01
# 54      53033  2021    1   2021-01-01   February  168284 2021-02-01
# 89      53033  2021    1   2021-01-01      March  166910 2021-03-01
# 124     53033  2021    2   2021-04-01      April  165629 2021-04-01
# 152     53033  2021    2   2021-04-01        May  166658 2021-05-01
# 180     53033  2021    2   2021-04-01       June  169800 2021-06-01
# 208     53033  2021    3   2021-07-01       July  172365 2021-07-01
# 236     53033  2021    3   2021-07-01     August  173781 2021-08-01
# 264     53033  2021    3   2021-07-01  September  174423 2021-09-01
# 292     53033  2021    4   2021-10-01    October  175062 2021-10-01
# 320     53033  2021    4   2021-10-01   November  177003 2021-11-01
# 348     53033  2021    4   2021-10-01   December  178818 2021-12-01
# 26      53033  2022    1   2022-01-01    January  103849 2022-01-01
# 61      53033  2022    1   2022-01-01   February  104297 2022-02-01
# 96      53033  2022    1   2022-01-01      March  104394 2022-03-01
# 131     53033  2022    2   2022-04-01      April  103741 2022-04-01
# 159     53033  2022    2   2022-04-01        May  104055 2022-05-01
# 187     53033  2022    2   2022-04-01       June  104344 2022-06-01
# 215     53033  2022    3   2022-07-01       July  106082 2022-07-01
# 243     53033  2022    3   2022-07-01     August  105819 2022-08-01
# 271     53033  2022    3   2022-07-01  September  104526 2022-09-01
# 299     53033  2022    4   2022-10-01    October  104102 2022-10-01
# 327     53033  2022    4   2022-10-01   November  106083 2022-11-01
# 355     53033  2022    4   2022-10-01   December  107029 2022-12-01
# 33      53033  2023    1   2023-01-01    January  104602 2023-01-01
# 68      53033  2023    1   2023-01-01   February  103975 2023-02-01
# 103     53033  2023    1   2023-01-01      March  104107 2023-03-01
