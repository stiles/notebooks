# %% [markdown]
# # Charting firefighter payroll in California: 2011-2018

# %% [markdown]
# This notebook processess government payroll [data](https://publicpay.ca.gov/Reports/RawExport.aspx) compiled and released annually by the California state controller's office. The data include anonymized salary information for all employees at cities, counties, special districts and state government.

# %% [markdown]
# ---

# %% [markdown]
# ### Load python tools

# %%
import pandas as pd
import geopandas as gpd
import cpi
from urllib.request import urlopen 
import pyarrow
import jenkspy
import matplotlib.pyplot as plt
# %matplotlib inline
import json
import numpy as np
from altair import datum
import altair as alt
alt.renderers.enable('notebook')
import altair_latimes as lat
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
pd.options.display.float_format = '{:,.0f}'.format
cpi.update()

# %% [markdown]
# ### Read the fire payroll data

# %%
payroll_fire = pd.read_csv('/Users/mhustiles/data/data/controller/output/payroll_fire.csv')

# %%
agency_overtime = pd.read_csv('/Users/mhustiles/data/data/controller/output/agency_overtime.csv')

# %%
len(payroll_fire)
# Out:
# 307402

# %% [markdown]
# ---

# %% [markdown]
# ### What about agencies in our area?

# %%
area_counties = ['LOS ANGELES', 'ORANGE', 'KERN', 'VENTURA', 'RIVERSIDE', 'SAN BERNARDINO']

# %%
la_agency_overtime = agency_overtime[(agency_overtime['employercounty'] == 'LOS ANGELES') &\
                                         (agency_overtime['type'] != 'SPECIAL DISTRICT')]

la_area_agency_overtime = agency_overtime[(agency_overtime['employercounty'].isin(area_counties)) &\
                                         (agency_overtime['type'] != 'SPECIAL DISTRICT')]

# %%
la_agency_grouped = agency_overtime[agency_overtime['employercounty'].isin(area_counties)]\
    .groupby(['year']).agg({'ot_share_wages':'mean'}).reset_index()

# %%
la_agency_grouped
# Out:
#    year  ot_share_wages
# 0  2011              18
# 1  2012              20
# 2  2013              22
# 3  2014              22
# 4  2015              24
# 5  2016              25
# 6  2017              26
# 7  2018              25

# %% [markdown]
# ### Just cities

# %%
cities_overtime = agency_overtime[(agency_overtime.type == 'CITY')]
cities_overtime.head()
# Out:
#    Unnamed: 0  employerfull  type employercounty  year  adjusted_overtime  \
# 0           0  ALAMEDA_CITY  CITY        ALAMEDA  2011            788,909
# 1           1  ALAMEDA_CITY  CITY        ALAMEDA  2012            547,408
# 2           2  ALAMEDA_CITY  CITY        ALAMEDA  2013            626,923
# 3           3  ALAMEDA_CITY  CITY        ALAMEDA  2014          1,236,750
# 4           4  ALAMEDA_CITY  CITY        ALAMEDA  2015          2,300,568
#
#    adjusted_wages  adjusted_basewages  overtime      wages  ot_share_wages
# 0      13,773,499          12,984,590   706,696 12,338,155               6
# 1      12,792,108          12,244,700   500,510 11,696,174               4
# 2      13,579,294          12,952,371   581,609 12,597,783               5
# 3      14,282,029          13,045,279 1,165,970 13,464,660               9
# 4      15,568,764          13,268,196 2,171,480 14,695,177              15

# %% [markdown]
# ### Statewide

# %%
state = payroll_fire.groupby(['year']).agg({'adjusted_overtime':'sum', \
                                            'adjusted_basewages':'sum', \
                                            'wages':'sum', \
                                            'overtime':'sum',\
                                           }).reset_index()

# %%
state.rename(columns={'adjusted_basewages':'BaseWages',
                      'adjusted_overtime': 'Overtime',\
                      'wages': 'naWages',\
                       'overtime': 'naOvertime',\
                     'year': 'Year'}, inplace=True)

# %% [markdown]
# ### What was the share of overtime to wages each year?

# %%
state['OT_Share_Wages'] = ( state['naOvertime']  / state['naWages'] )*100

# %%
state.head(10)
# Out:
#    Year      Overtime     BaseWages       naWages    naOvertime  \
# 0  2011   823,947,631 3,284,339,057 3,680,159,849   738,083,590
# 1  2012   934,994,755 3,244,335,888 3,821,276,346   854,891,284
# 2  2013 1,003,171,054 3,185,910,145 3,886,294,642   930,661,906
# 3  2014 1,075,066,122 3,117,678,130 3,952,791,054 1,013,539,461
# 4  2015 1,199,673,471 3,337,353,600 4,282,447,504 1,132,357,948
# 5  2016 1,247,353,780 3,438,516,460 4,478,734,797 1,192,215,425
# 6  2017 1,330,159,012 3,488,223,138 4,703,500,232 1,298,444,794
# 7  2018 1,364,028,799 3,536,243,646 4,900,272,445 1,364,028,799
#
#    OT_Share_Wages
# 0              20
# 1              22
# 2              24
# 3              26
# 4              26
# 5              27
# 6              28
# 7              28

# %%
statemelt = pd.melt(state,id_vars=['Year'], value_vars=['Overtime', 'BaseWages'],\
        var_name='Compensation', value_name='Total')

# %%
state.to_csv('output/state.csv')

# %%
statemelt.to_csv('output/statemelt.csv')

# %%
alt.Chart(statemelt).mark_area().encode(
    x=alt.X("Year:N", title=' '),
    y=alt.Y("Total:Q", title=' ', axis=alt.Axis(tickCount=6, format='$~s')),
    color="Compensation:N",
    order=alt.Order(
      # Sort the segments of the bars by this field
      'Compensation',
      sort='ascending'
    )
).properties(width=500, title='Firefighter compensation in California')

# %% [markdown]
# ---

# %% [markdown]
# ### Los Angeles-area fire agencies: Share of wages in overtime

# %%
la_area = pd.DataFrame(la_agency_overtime[la_agency_overtime['employerfull'] \
                                          != 'LA_HABRA_HEIGHTS_CITY'][['employerfull', 'year', 'ot_share_wages']])

# %%
la_agency_grouped['ot_share_wages'] = la_agency_grouped['ot_share_wages']/100

# %%
alt.Chart(la_agency_grouped).mark_area().encode(
    x=alt.X('year:N', title='', axis=alt.Axis(format='')),
    y=alt.Y("ot_share_wages:Q",
        scale=alt.Scale(domain=(0, .25)), title="", axis=alt.Axis(format='%', tickCount=6)),
).properties(height=500, width=500, columns=6, title='L.A. region: Overtime\'s share of firefighter wages')

# %%
la_area['ot_share_wages'] = la_area['ot_share_wages']/100

# %%
alt.Chart(cities_overtime).mark_area().encode(
    x=alt.X('year:N', title='', axis=alt.Axis(format='', tickCount=2, values=(2011,2018))),
    y=alt.Y("ot_share_wages:Q", title="", axis=alt.Axis(format='%', tickCount=3)),
    facet=alt.Facet('employerfull:N')
).properties(height=100, width=100, columns=5, \
             title='L.A.-area agencies: Overtime\'s share of firefighter wages')

# %% [markdown]
# ### What's the rate of increase for OT, wages and benefits for each place?

# %%
agency_overtime = pd.read_csv('output/agency_overtime.csv')
agency_overtime.drop(columns=['Unnamed: 0', 'type','wages', 'overtime'], inplace=True)
agency_overtime['employerfull'] = agency_overtime['employerfull'].str.replace('_SPECIAL_DISTRICT','')
agency_overtime['employercounty'] = agency_overtime['employercounty'].str.replace('NAN','')

# %%
agency_overtime_2018 = agency_overtime[(agency_overtime['year'] == 2018)]

# %%
agency_overtime_2018.sort_values(by='ot_share_wages', ascending=False).head()
# Out:
#                                      employerfull employercounty  year  \
# 2307  MONTEZUMA_FIRE_PROTECTION_DISTRICT_(SOLANO)         SOLANO  2018
# 3084              SALIDA_FIRE_PROTECTION_DISTRICT     STANISLAUS  2018
# 613               CHESTER_PUBLIC_UTILITY_DISTRICT         PLUMAS  2018
# 3489   SOUTH_LAKE_COUNTY_FIRE_PROTECTION_DISTRICT           LAKE  2018
# 2259                              MONTEBELLO_CITY    LOS ANGELES  2018
#
#       adjusted_overtime  adjusted_wages  adjusted_basewages  ot_share_wages
# 2307            256,367         313,472              57,105              82
# 3084             19,417          26,969               7,552              72
# 613           2,209,066       3,446,468           1,237,402              64
# 3489             66,920         138,091              71,171              48
# 2259          2,947,963       6,384,622           3,436,659              46

# %%
agency_overtime_slope = agency_overtime[(agency_overtime['year'] == 2011) | (agency_overtime['year'] == 2018)]

# %%
agency_overtime.sort_values(by='adjusted_overtime', ascending=False).head(20)
# Out:
#             employerfull employercounty  year  adjusted_overtime  \
# 1986  LOS_ANGELES_COUNTY    LOS ANGELES  2017        202,569,406
# 1987  LOS_ANGELES_COUNTY    LOS ANGELES  2018        200,371,155
# 1978    LOS_ANGELES_CITY    LOS ANGELES  2017        200,297,491
# 1985  LOS_ANGELES_COUNTY    LOS ANGELES  2016        197,369,374
# 1976    LOS_ANGELES_CITY    LOS ANGELES  2015        194,577,723
# 1979    LOS_ANGELES_CITY    LOS ANGELES  2018        194,037,539
# 1977    LOS_ANGELES_CITY    LOS ANGELES  2016        193,805,688
# 451        CALFIRE_STATE                 2018        182,236,906
# 1984  LOS_ANGELES_COUNTY    LOS ANGELES  2015        175,704,520
# 1975    LOS_ANGELES_CITY    LOS ANGELES  2014        170,170,047
# 1983  LOS_ANGELES_COUNTY    LOS ANGELES  2014        163,014,544
# 1982  LOS_ANGELES_COUNTY    LOS ANGELES  2013        159,648,826
# 450        CALFIRE_STATE                 2017        157,599,967
# 1974    LOS_ANGELES_CITY    LOS ANGELES  2013        150,689,736
# 1981  LOS_ANGELES_COUNTY    LOS ANGELES  2012        145,007,457
# 448        CALFIRE_STATE                 2015        143,542,078
# 1980  LOS_ANGELES_COUNTY    LOS ANGELES  2011        140,594,166
# 447        CALFIRE_STATE                 2014        134,101,142
# 449        CALFIRE_STATE                 2016        134,016,297
# 1973    LOS_ANGELES_CITY    LOS ANGELES  2012        122,766,643
#
#       adjusted_wages  adjusted_basewages  ot_share_wages
# 1986     537,839,137         335,269,731              38
# 1987     540,509,188         340,138,033              37
# 1978     598,913,979         398,616,488              33
# 1985     523,570,488         326,201,114              38
# 1976     570,247,170         375,669,446              34
# 1979     593,514,555         399,477,016              33
# 1977     571,517,808         377,712,120              34
# 451      674,482,853         492,245,948              27
# 1984     492,788,615         317,084,095              36
# 1975     503,552,469         333,382,422              34
# 1983     474,753,826         311,739,282              34
# 1982     470,916,794         311,267,967              34
# 450      622,532,256         464,932,289              25
# 1974     523,278,745         372,589,009              29
# 1981     467,626,001         322,618,544              31
# 448      567,356,645         423,814,567              25
# 1980     469,986,489         329,392,322              30
# 447      523,719,850         389,618,707              26
# 449      566,532,437         432,516,140              24
# 1973     500,561,545         377,794,902              25

# %%
agency_overtime_largest = payroll_fire.groupby('employerfull').agg({'adjusted_overtime':'sum'}).reset_index()
agency_overtime_largest.head()
# Out:
#                                         employerfull  adjusted_overtime
# 0                                       ALAMEDA_CITY         10,260,678
# 1                                     ALAMEDA_COUNTY         50,144,091
# 2                                        ALBANY_CITY          4,953,897
# 3  ALBION-LITTLE_RIVER_FIRE_PROTECTION_SPECIAL_DI...                  0
# 4                                      ALHAMBRA_CITY         22,182,421

# %%
largest = agency_overtime_largest[(agency_overtime_largest['adjusted_overtime'] > 10000000) &\
                                 (agency_overtime_largest['adjusted_overtime'] < 100000000)]\
    .sort_values(by='adjusted_overtime', ascending=False).head(30)

# %%
large_list = largest.employerfull.to_list()

# %%
agency_overtime_melt = pd.melt(agency_overtime,id_vars=['year', 'employerfull'], \
                               value_vars=['adjusted_overtime','adjusted_basewages'],\
                                var_name='Compensation', value_name='Amount')

# %%
agency_overtime_melt_else = pd.DataFrame(agency_overtime_melt[agency_overtime_melt['employerfull'].isin(large_list)])

# %%
agency_overtime_melt_else['employerfull'] = agency_overtime_melt_else['employerfull'].str.replace('_',' ')

# %%
agency_overtime_melt_else
# Out:
#       year           employerfull        Compensation     Amount
# 8     2011         ALAMEDA COUNTY   adjusted_overtime          0
# 9     2012         ALAMEDA COUNTY   adjusted_overtime          0
# 10    2015         ALAMEDA COUNTY   adjusted_overtime 13,956,109
# 11    2016         ALAMEDA COUNTY   adjusted_overtime 15,865,394
# 12    2017         ALAMEDA COUNTY   adjusted_overtime  3,441,105
# 13    2018         ALAMEDA COUNTY   adjusted_overtime 16,881,483
# 57    2011           ANAHEIM CITY   adjusted_overtime  6,339,837
# 58    2012           ANAHEIM CITY   adjusted_overtime  7,515,434
# 59    2013           ANAHEIM CITY   adjusted_overtime 10,052,613
# 60    2014           ANAHEIM CITY   adjusted_overtime 10,130,655
# 61    2015           ANAHEIM CITY   adjusted_overtime 10,926,466
# 62    2016           ANAHEIM CITY   adjusted_overtime 11,693,886
# 63    2017           ANAHEIM CITY   adjusted_overtime 12,459,292
# 64    2018           ANAHEIM CITY   adjusted_overtime 11,227,272
# 239   2011     BEVERLY HILLS CITY   adjusted_overtime  4,249,201
# 240   2012     BEVERLY HILLS CITY   adjusted_overtime  4,368,751
# 241   2013     BEVERLY HILLS CITY   adjusted_overtime  3,780,112
# 242   2014     BEVERLY HILLS CITY   adjusted_overtime  4,811,984
# 243   2015     BEVERLY HILLS CITY   adjusted_overtime  5,208,970
# 244   2016     BEVERLY HILLS CITY   adjusted_overtime  4,044,118
# 245   2017     BEVERLY HILLS CITY   adjusted_overtime  4,008,327
# 246   2018     BEVERLY HILLS CITY   adjusted_overtime  4,279,560
# 400   2011           BURBANK CITY   adjusted_overtime  4,201,035
# 401   2012           BURBANK CITY   adjusted_overtime  4,724,705
# 402   2013           BURBANK CITY   adjusted_overtime  4,525,638
# 403   2014           BURBANK CITY   adjusted_overtime  4,765,831
# 404   2015           BURBANK CITY   adjusted_overtime  4,559,716
# 405   2016           BURBANK CITY   adjusted_overtime  5,278,995
# 406   2017           BURBANK CITY   adjusted_overtime  5,719,123
# 407   2018           BURBANK CITY   adjusted_overtime  4,969,948
# ...    ...                    ...                 ...        ...
# 7255  2011    SAN BERNARDINO CITY  adjusted_basewages 18,285,274
# 7256  2012    SAN BERNARDINO CITY  adjusted_basewages 17,660,110
# 7257  2013    SAN BERNARDINO CITY  adjusted_basewages 14,147,995
# 7258  2014    SAN BERNARDINO CITY  adjusted_basewages 13,790,943
# 7259  2015    SAN BERNARDINO CITY  adjusted_basewages 12,982,871
# 7260  2016    SAN BERNARDINO CITY  adjusted_basewages  6,875,167
# 7261  2011  SAN BERNARDINO COUNTY  adjusted_basewages 16,750,872
# 7262  2012  SAN BERNARDINO COUNTY  adjusted_basewages 12,054,902
# 7263  2013  SAN BERNARDINO COUNTY  adjusted_basewages 12,681,895
# 7264  2014  SAN BERNARDINO COUNTY  adjusted_basewages 13,921,917
# 7265  2015  SAN BERNARDINO COUNTY  adjusted_basewages  9,092,746
# 7266  2016  SAN BERNARDINO COUNTY  adjusted_basewages  9,675,681
# 7267  2017  SAN BERNARDINO COUNTY  adjusted_basewages 11,165,649
# 7268  2018  SAN BERNARDINO COUNTY  adjusted_basewages 12,354,171
# 7318  2011          SAN JOSE CITY  adjusted_basewages 86,826,994
# 7319  2012          SAN JOSE CITY  adjusted_basewages 77,723,974
# 7320  2013          SAN JOSE CITY  adjusted_basewages 79,629,459
# 7321  2014          SAN JOSE CITY  adjusted_basewages 78,811,711
# 7322  2015          SAN JOSE CITY  adjusted_basewages 86,623,517
# 7323  2016          SAN JOSE CITY  adjusted_basewages 85,085,511
# 7324  2017          SAN JOSE CITY  adjusted_basewages 85,160,384
# 7325  2018          SAN JOSE CITY  adjusted_basewages 87,596,010
# 7685  2011          TORRANCE CITY  adjusted_basewages 20,252,035
# 7686  2012          TORRANCE CITY  adjusted_basewages 19,036,914
# 7687  2013          TORRANCE CITY  adjusted_basewages 18,747,550
# 7688  2014          TORRANCE CITY  adjusted_basewages 16,928,818
# 7689  2015          TORRANCE CITY  adjusted_basewages 18,137,428
# 7690  2016          TORRANCE CITY  adjusted_basewages 18,470,203
# 7691  2017          TORRANCE CITY  adjusted_basewages 18,689,253
# 7692  2018          TORRANCE CITY  adjusted_basewages 16,686,562
#
# [420 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### How much did overtime, wages increase by agency?

# %%
agency_overtime.head()
# Out:
#    employerfull employercounty  year  adjusted_overtime  adjusted_wages  \
# 0  ALAMEDA_CITY        ALAMEDA  2011            788,909      13,773,499
# 1  ALAMEDA_CITY        ALAMEDA  2012            547,408      12,792,108
# 2  ALAMEDA_CITY        ALAMEDA  2013            626,923      13,579,294
# 3  ALAMEDA_CITY        ALAMEDA  2014          1,236,750      14,282,029
# 4  ALAMEDA_CITY        ALAMEDA  2015          2,300,568      15,568,764
#
#    adjusted_basewages  ot_share_wages
# 0          12,984,590               6
# 1          12,244,700               4
# 2          12,952,371               5
# 3          13,045,279               9
# 4          13,268,196              15

# %%
agency_ot = pd.pivot_table(agency_overtime, \
                values='adjusted_overtime',\
                index='employerfull', columns=['year']).reset_index()

# %%
agency_ot.columns = agency_ot.columns.map(str)

# %%
agency_ot_slim = pd.DataFrame(agency_ot[['employerfull','2011','2018']])

# %%
agency_ot_slim['ot_change'] = ((agency_ot_slim['2018'] -\
                                agency_ot_slim['2011'])/agency_ot_slim['2011'])*100

# %%
agency_basewages = pd.pivot_table(agency_overtime, \
                values='adjusted_basewages',\
                index='employerfull', columns=['year']).reset_index()

# %%
agency_basewages.columns = agency_basewages.columns.map(str)

# %%
agency_basewages_slim = pd.DataFrame(agency_basewages[['employerfull','2011','2018']])

# %%
agency_basewages_slim['ot_change'] = (((agency_basewages_slim['2018'] - \
                                       agency_basewages_slim['2011'])/agency_basewages_slim['2011'])*100).fillna(0)

# %%
agency_ot_slim.rename(columns={'2011':'overtime2011',
                      '2018': 'overtime2018',\
                      'ot_change': 'ot_change'}, inplace=True)

# %%
agency_basewages_slim.rename(columns={'2011':'wages2011',
                      '2018': 'wages2018',\
                      'ot_change': 'wages_change'}, inplace=True)

# %%
agencies = pd.merge(agency_ot_slim, agency_basewages_slim, on='employerfull')

# %%
agencies['employer'] = agencies['employerfull'].str.replace('_',' ')

# %%
agencies_slim = pd.DataFrame(agencies[['employer','wages_change','ot_change']]).dropna()

# %% [markdown]
# ### Remove outliers

# %%
agencies_slim = agencies_slim[(agencies_slim['wages_change'] < 1000) &\
                             (agencies_slim['ot_change'] < 1000) ]

# %%
agencies_slim.sort_values(by='ot_change', ascending=False).head(10)
# Out:
# year                                    employer  wages_change  ot_change
# 245                                    IONE CITY           196        903
# 559        VETERANS AFFAIRS, DEPARTMENT OF STATE            -8        874
# 366                           NEWPORT BEACH CITY           204        862
# 386          OPHIR HILL FIRE PROTECTION DISTRICT             7        851
# 497                                   SELMA CITY            -0        825
# 157                               EL CENTRO CITY            74        727
# 283                                 LINCOLN CITY            -7        721
# 73                                CALISTOGA CITY            42        685
# 102          CLOVERDALE FIRE PROTECTION DISTRICT            18        662
# 346   MORONGO VALLEY COMMUNITY SERVICES DISTRICT             8        658
