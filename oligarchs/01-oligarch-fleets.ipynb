# %% [markdown]
# # Oligarch boats

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd
import simplejson as json

# %%
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000
pd.set_option("display.max_columns", None)

# %% [markdown]
# ---

# %%
jsons = {
    "fleets": [
        {
            "id": 2142981,
            "name": "Russian Oligarchs",
            "colorIndex": 8,
            "is_vessel_plus": False,
            "isOwnedByUser": True,
            "ships": [
                {"id": 371455, "name": "A", "shipType": 9},
                {"id": 3515668, "name": "ANDROMEDA", "shipType": 9},
                {"id": 5615797, "name": "ANNA", "shipType": 9},
                {"id": 4890250, "name": "AURORA", "shipType": 9},
                {"id": 385196, "name": "CLIO", "shipType": 9},
                {"id": 371584, "name": "ECLIPSE", "shipType": 9},
                {"id": 4032552, "name": "GALACTICA SUPER NOVA", "shipType": 9},
                {"id": 470288, "name": "GRACEFUL", "shipType": 9},
                {"id": 4240019, "name": "HERE COMES THE SUN", "shipType": 9},
                {"id": 385752, "name": "ICE", "shipType": 9},
                {"id": 6318635, "name": "LA DATCHA", "shipType": 9},
                {"id": 468988, "name": "LADY ANASTASIA", "shipType": 9},
                {"id": 371059, "name": "LE GRAND BLEU", "shipType": 9},
                {"id": 470229, "name": "LENA", "shipType": 9},
                {"id": 201758, "name": "LUNA", "shipType": 9},
                {"id": 1148803, "name": "MADAME GU", "shipType": 9},
                {"id": 6570613, "name": "MY SOLARIS", "shipType": 9},
                {"id": 385359, "name": "NIRVANA", "shipType": 9},
                {"id": 6326693, "name": "NORD", "shipType": 9},
                {"id": 384919, "name": "OCEAN VICTORY", "shipType": 9},
                {"id": 384299, "name": "PACIFIC", "shipType": 9},
                {"id": 384596, "name": "PALLADIUM", "shipType": 9},
                {"id": 143368, "name": "QUANTUM BLUE", "shipType": 9},
                {"id": 254151, "name": "RAGNAR", "shipType": 9},
                {"id": 3177005, "name": "ROYAL ROMANCE", "shipType": 9},
                {"id": 3598603, "name": "SAILING YACHT A", "shipType": 6},
                {"id": 384459, "name": "SEA RHAPSODY", "shipType": 9},
                {"id": 6665254, "name": "SKORPIOS", "shipType": 9},
                {"id": 384563, "name": "TANGO", "shipType": 9},
                {"id": 371598, "name": "TITAN", "shipType": 9},
                {"id": 466857, "name": "VALERIE", "shipType": 9},
            ],
        }
    ]
}

# %%
fleets = []

for o in jsons["fleets"]:
    fleets.append(pd.DataFrame(o["ships"]))

# %%
fleet_names = pd.concat(fleets)

# %%
fleet_names["url"] = "https://www.marinetraffic.com/en/ais/details/ships/shipid:" + str(
    fleet_names["id"]
)

# %%
fleet_names
# Out:
#          id                  name  shipType  \
# 0    371455                     A         9
# 1   3515668             ANDROMEDA         9
# 2   5615797                  ANNA         9
# 3   4890250                AURORA         9
# 4    385196                  CLIO         9
# 5    371584               ECLIPSE         9
# 6   4032552  GALACTICA SUPER NOVA         9
# 7    470288              GRACEFUL         9
# 8   4240019    HERE COMES THE SUN         9
# 9    385752                   ICE         9
# 10  6318635             LA DATCHA         9
# 11   468988        LADY ANASTASIA         9
# 12   371059         LE GRAND BLEU         9
# 13   470229                  LENA         9
# 14   201758                  LUNA         9
# 15  1148803             MADAME GU         9
# 16  6570613            MY SOLARIS         9
# 17   385359               NIRVANA         9
# 18  6326693                  NORD         9
# 19   384919         OCEAN VICTORY         9
# 20   384299               PACIFIC         9
# 21   384596             PALLADIUM         9
# 22   143368          QUANTUM BLUE         9
# 23   254151                RAGNAR         9
# 24  3177005         ROYAL ROMANCE         9
# 25  3598603       SAILING YACHT A         6
# 26   384459          SEA RHAPSODY         9
# 27  6665254              SKORPIOS         9
# 28   384563                 TANGO         9
# 29   371598                 TITAN         9
# 30   466857               VALERIE         9
#
#                                                   url
# 0   https://www.marinetraffic.com/en/ais/details/s...
# 1   https://www.marinetraffic.com/en/ais/details/s...
# 2   https://www.marinetraffic.com/en/ais/details/s...
# 3   https://www.marinetraffic.com/en/ais/details/s...
# 4   https://www.marinetraffic.com/en/ais/details/s...
# 5   https://www.marinetraffic.com/en/ais/details/s...
# 6   https://www.marinetraffic.com/en/ais/details/s...
# 7   https://www.marinetraffic.com/en/ais/details/s...
# 8   https://www.marinetraffic.com/en/ais/details/s...
# 9   https://www.marinetraffic.com/en/ais/details/s...
# 10  https://www.marinetraffic.com/en/ais/details/s...
# 11  https://www.marinetraffic.com/en/ais/details/s...
# 12  https://www.marinetraffic.com/en/ais/details/s...
# 13  https://www.marinetraffic.com/en/ais/details/s...
# 14  https://www.marinetraffic.com/en/ais/details/s...
# 15  https://www.marinetraffic.com/en/ais/details/s...
# 16  https://www.marinetraffic.com/en/ais/details/s...
# 17  https://www.marinetraffic.com/en/ais/details/s...
# 18  https://www.marinetraffic.com/en/ais/details/s...
# 19  https://www.marinetraffic.com/en/ais/details/s...
# 20  https://www.marinetraffic.com/en/ais/details/s...
# 21  https://www.marinetraffic.com/en/ais/details/s...
# 22  https://www.marinetraffic.com/en/ais/details/s...
# 23  https://www.marinetraffic.com/en/ais/details/s...
# 24  https://www.marinetraffic.com/en/ais/details/s...
# 25  https://www.marinetraffic.com/en/ais/details/s...
# 26  https://www.marinetraffic.com/en/ais/details/s...
# 27  https://www.marinetraffic.com/en/ais/details/s...
# 28  https://www.marinetraffic.com/en/ais/details/s...
# 29  https://www.marinetraffic.com/en/ais/details/s...
# 30  https://www.marinetraffic.com/en/ais/details/s...

# %%
fleet_names.to_csv("data/processed/yacts.csv", index=False)
