# %% [markdown]
# # LA County probation juvenile statistics 2020

# %%
# %load_ext lab_black

# %%
import pandas as pd
import altair as alt
import altair_latimes as lat

# %%
alt.themes.register("latimes", lat.theme)
alt.themes.enable("latimes")
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ### Get the 2020 institutions report

# %%
# PDF too messy to parse. Used Tabula to export csvs for violence, population, race, gender, etc., in 2020 by month

# %%
url = "http://file.lacounty.gov/SDSInter/probation/1104983_LAPROB.INSTITUTIONS.STATISTICS.2020_MASTER.pdf"

# %% [markdown]
# ---

# %% [markdown]
# ## Population

# %% [markdown]
# ### Read the data and clean up

# %%
pop = pd.read_csv("input/population_2020.csv")

# %%
pop["population"] = pop["population"].str.replace(" ", "_", regex=False).str.lower()

# %%
pop.columns = pop.columns.str.lower()

# %%
pop.rename(columns={"population": "category"}, inplace=True)

# %%
pop
# Out:
#                    category  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  \
# 0  average_daily_population  545  540  507  382  362  305  304  304  311  327
# 1                     black  197  205  193  134  118   90   96   99  110  103
# 2                 caucasian   30   25   20   13   10   11   19   19   12    8
# 3                  hispanic  310  302  288  228  228  200  186  182  188  213
# 4                     other    8    8    6    7    5    4    3    4    1    3
#
#    nov  dec
# 0  330  314
# 1  116  123
# 2    7    5
# 3  207  185
# 4    0    1

# %% [markdown]
# ---

# %% [markdown]
# ## Violence

# %% [markdown]
# ### Read the data and clean up

# %%
violence = pd.read_csv("input/violence_2020.csv")

# %%
violence.columns = violence.columns.str.lower()

# %%
violence["category"] = (
    violence["category"].str.replace(" ", "_", regex=False).str.lower()
)

# %%
violence
# Out:
#                        category  jan  feb  mar  apr  may  jun  jul  aug  sep  \
# 0       youth_on_youth_violence  104  103   97   48   52   43   41   40   41
# 1       youth_on_staff_assaults   39   24   44   21   18   16   14   12   14
# 2      direct_assaults_on_staff   34   22   38   19   16   16   14   10   11
# 3  incidental_assaults_on_staff    5    2    6    2    2    0    0    2    3
#
#    oct  nov  dec
# 0   49   49   55
# 1   18   26   14
# 2   16   25   13
# 3    2    1    1

# %% [markdown]
# ---

# %%
pop_vio = pd.concat([violence, pop]).reset_index(drop=True)

# %%
pop_vio
# Out:
#                        category  jan  feb  mar  apr  may  jun  jul  aug  sep  \
# 0       youth_on_youth_violence  104  103   97   48   52   43   41   40   41
# 1       youth_on_staff_assaults   39   24   44   21   18   16   14   12   14
# 2      direct_assaults_on_staff   34   22   38   19   16   16   14   10   11
# 3  incidental_assaults_on_staff    5    2    6    2    2    0    0    2    3
# 4      average_daily_population  545  540  507  382  362  305  304  304  311
# 5                         black  197  205  193  134  118   90   96   99  110
# 6                     caucasian   30   25   20   13   10   11   19   19   12
# 7                      hispanic  310  302  288  228  228  200  186  182  188
# 8                         other    8    8    6    7    5    4    3    4    1
#
#    oct  nov  dec
# 0   49   49   55
# 1   18   26   14
# 2   16   25   13
# 3    2    1    1
# 4  327  330  314
# 5  103  116  123
# 6    8    7    5
# 7  213  207  185
# 8    3    0    1

# %%
pop_vio_df = pop_vio.iloc[[0, 1, 4]].T

# %%
pop_vio_df.reset_index(level=0, inplace=True)

# %%
pop_vio_df.columns = [
    "month",
    "youth_on_youth_violence",
    "youth_on_staff_assaults",
    "average_daily_population",
]

# %%
pop_vio_df = pop_vio_df[pop_vio_df["month"] != "category"].copy()

# %%
pop_vio_df[
    [
        "youth_on_youth_violence",
        "youth_on_staff_assaults",
        "average_daily_population",
    ]
] = pop_vio_df[
    [
        "youth_on_youth_violence",
        "youth_on_staff_assaults",
        "average_daily_population",
    ]
].astype(
    int
)

# %%
pop_vio_df["youth_assault_rate_per_100"] = (
    (pop_vio_df["youth_on_youth_violence"] / pop_vio_df["average_daily_population"])
    * 100
).round(1)

# %%
pop_vio_df["staff_assault_rate_per_100"] = (
    (pop_vio_df["youth_on_staff_assaults"] / pop_vio_df["average_daily_population"])
    * 100
).round(1)

# %%
pop_vio_df
# Out:
#    month  youth_on_youth_violence  youth_on_staff_assaults  \
# 1    jan                      104                       39
# 2    feb                      103                       24
# 3    mar                       97                       44
# 4    apr                       48                       21
# 5    may                       52                       18
# 6    jun                       43                       16
# 7    jul                       41                       14
# 8    aug                       40                       12
# 9    sep                       41                       14
# 10   oct                       49                       18
# 11   nov                       49                       26
# 12   dec                       55                       14
#
#     average_daily_population  youth_assault_rate_per_100  \
# 1                        545                        19.1
# 2                        540                        19.1
# 3                        507                        19.1
# 4                        382                        12.6
# 5                        362                        14.4
# 6                        305                        14.1
# 7                        304                        13.5
# 8                        304                        13.2
# 9                        311                        13.2
# 10                       327                        15.0
# 11                       330                        14.8
# 12                       314                        17.5
#
#     staff_assault_rate_per_100
# 1                          7.2
# 2                          4.4
# 3                          8.7
# 4                          5.5
# 5                          5.0
# 6                          5.2
# 7                          4.6
# 8                          3.9
# 9                          4.5
# 10                         5.5
# 11                         7.9
# 12                         4.5

# %%
area = (
    alt.Chart(pop_vio_df)
    .mark_area(opacity=0.2)
    .encode(
        x=alt.X(
            "month:O",
            sort=[
                "jan",
                "feb",
                "mar",
                "apr",
                "may",
                "jun",
                "jul",
                "aug",
                "sep",
                "oct",
                "nov",
                "dec",
            ],
            title="Month in 2020",
        ),
        y=alt.Y("staff_assault_rate_per_100", title="Youth on staff assualt rate"),
    )
)

line = (
    alt.Chart(pop_vio_df)
    .mark_line()
    .encode(
        x=alt.X(
            "month:O",
            sort=[
                "jan",
                "feb",
                "mar",
                "apr",
                "may",
                "jun",
                "jul",
                "aug",
                "sep",
                "oct",
                "nov",
                "dec",
            ],
            title="Month in 2020",
        ),
        y=alt.Y("staff_assault_rate_per_100", title=""),
    )
)

# %%
(line + area)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ---

# %%
race_df = pop_vio.iloc[5:9].T

# %%
race_df
# Out:
#        index      5          6         7      8
# 0   category  black  caucasian  hispanic  other
# 1        jan    197         30       310      8
# 2        feb    205         25       302      8
# 3        mar    193         20       288      6
# 4        apr    134         13       228      7
# 5        may    118         10       228      5
# 6        jun     90         11       200      4
# 7        jul     96         19       186      3
# 8        aug     99         19       182      4
# 9        sep    110         12       188      1
# 10       oct    103          8       213      3
# 11       nov    116          7       207      0
# 12       dec    123          5       185      1

# %%
race_df.reset_index(level=0, inplace=True)

# %%
race_df.columns = ["month", "black", "white", "latino", "other"]

# %%
race_df = race_df[race_df["month"] != "category"].copy()

# %%
race_df[["black", "white", "latino", "other"]] = race_df[
    ["black", "white", "latino", "other"]
].astype(int)

# %%
cols = ["black", "white", "latino", "other"]

# %%
race_df["total"] = race_df.sum(axis=1)

# %%
race_melt_df = pd.melt(
    race_df, id_vars="month", value_vars=["black", "white", "latino", "other"]
)

# %%
alt.Chart(race_melt_df).mark_area().encode(
    x=alt.X(
        "month:O",
        sort=[
            "jan",
            "feb",
            "mar",
            "apr",
            "may",
            "jun",
            "jul",
            "aug",
            "sep",
            "oct",
            "nov",
            "dec",
        ],
        title="Month in 2020",
    ),
    y=alt.Y(
        "value:Q",
        title="Youths in L.A. County juvenile halls, 2020",
        axis=alt.Axis(tickCount=5),
    ),
    color=alt.Color("variable:N", title="Race/ethnicity"),
)
# Out:
# alt.Chart(...)

# %%
months = ["jan", "dec"]

# %%
jan_dec_race = race_melt_df[race_melt_df["month"].isin(months)]

# %%
alt.Chart(race_melt_df).mark_line().encode(
    x=alt.X(
        "month:O",
        sort=[
            "jan",
            "feb",
            "mar",
            "apr",
            "may",
            "jun",
            "jul",
            "aug",
            "sep",
            "oct",
            "nov",
            "dec",
        ],
    ),
    y="value",
    color="variable",
    facet="variable",
).properties(width=100, height=100)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Pct change by race

# %%
race_melt_df.head()
# Out:
#   month variable  value  pct_ch
# 0   jan    black    197     NaN
# 1   feb    black    205     NaN
# 2   mar    black    193     NaN
# 3   apr    black    134     NaN
# 4   may    black    118     NaN

# %%
race_melt_df["pct_ch"] = race_melt_df.groupby("variable")["value"].pct_change(11)

# %%
race_melt_df[race_melt_df["month"].isin(months)]
# Out:
#    month variable  value    pct_ch
# 0    jan    black    197       NaN
# 11   dec    black    123 -0.375635
# 12   jan    white     30       NaN
# 23   dec    white      5 -0.833333
# 24   jan   latino    310       NaN
# 35   dec   latino    185 -0.403226
# 36   jan    other      8       NaN
# 47   dec    other      1 -0.875000
