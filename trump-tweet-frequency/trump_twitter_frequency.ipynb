# %% [markdown]
# ## How often does President Trump tweet each day?

# %%
import altair as alt
import pandas as pd
import psycopg2 as pg
import matplotlib as mpl
import numpy as np
import json
import altair_latimes as lat
alt.renderers.enable('notebook')
alt.themes.register('latimes', lat.theme)
alt.themes.enable('latimes')
# Out:
# ThemeRegistry.enable('latimes')

# %% [markdown]
# ### Local url for @realDonaldTrump scraped data: 2012 - Aug. 2019

# %%
url = '/Users/mhustiles/Desktop/github/notebooks/trump-tweet-frequency/trump_archive.json'

# %% [markdown]
# ### Local url for @realDonaldTrump data — updated 9/29/19

# %% [markdown]
# ### *Download latest tweets using Twint*
# `twint -u realdonaldtrump --since 2019-08-13 -o trump_update.json --json`

# %%
urladd = '/Users/mhustiles/Desktop/github/notebooks/trump-tweet-frequency/trump_update.json'

# %%
src = pd.read_json('/Users/mhustiles/Desktop/github/notebooks/trump-tweet-frequency/all.json')

# %%
src.sort_values(by='created_at', ascending=False)
# Out:
#                created_at  favorite_count               id_str  is_retweet  \
# 0     2019-09-29 18:16:31               0  1178373003014488064        True
# 1     2019-09-29 18:15:22           26372  1178372711439093760       False
# 2     2019-09-29 18:12:38           26317  1178372025901109248       False
# 3     2019-09-29 17:47:35           33753  1178365721249759232       False
# 4     2019-09-29 15:18:44           44361  1178328262537285632       False
# 5     2019-09-29 14:25:34               0  1178314883672215552        True
# 6     2019-09-29 14:25:22               0  1178314832786968576        True
# 7     2019-09-29 14:23:21               0  1178314324575735808        True
# 8     2019-09-29 14:20:12           30650  1178313529700622336       False
# 9     2019-09-29 14:16:43               0  1178312653732814848        True
# 10    2019-09-29 14:16:38               0  1178312631691726848        True
# 11    2019-09-29 14:16:10               0  1178312517774389248        True
# 12    2019-09-29 14:16:07               0  1178312503887093760        True
# 13    2019-09-29 14:15:15               0  1178312286127169536        True
# 14    2019-09-29 14:14:41               0  1178312142703005696        True
# 15    2019-09-29 14:13:21               0  1178311808945414144        True
# 16    2019-09-29 14:13:17               0  1178311788565336064        True
# 17    2019-09-29 14:13:02               0  1178311726883905536        True
# 18    2019-09-29 14:12:37               0  1178311620994457600        True
# 19    2019-09-29 14:11:31               0  1178311345944612864        True
# 20    2019-09-29 14:11:14               0  1178311276084318208        True
# 21    2019-09-29 14:11:11               0  1178311261949485056        True
# 22    2019-09-29 14:10:49               0  1178311168324227072        True
# 23    2019-09-29 14:10:31           28098  1178311095360073728       False
# 24    2019-09-29 14:02:57               0  1178309191049650176        True
# 25    2019-09-29 14:02:45               0  1178309140986376192        True
# 26    2019-09-29 14:02:38               0  1178309108899991552        True
# 27    2019-09-29 14:02:35               0  1178309095885017088        True
# 28    2019-09-29 13:18:48           44890  1178298078031437824       False
# 29    2019-09-29 12:29:36           55064  1178285698111168512       False
# ...                   ...             ...                  ...         ...
# 16072 2009-06-24 22:09:19               0           2317112756       False
# 16073 2009-06-23 13:40:38               9           2294519255       False
# 16082  Read an excerpt from Think Like A Champion by ...
# 16083  "Your higher self is in direct opposition to y...
# 16084  Did you know Donald Trump is on Facebook? http...
# 16085  Don't forget to enter the "Think Like A Champi...
# 16086  "Keep it fast, short and direct - whatever it ...
# 16087  Read a great interview with Donald Trump that ...
# 16088  "Always know you could be on the precipice of ...
# 16089  "...these days...we could all use a little of ...
# 16090  "We win in our lives by having a champion's vi...
# 16091  "Don’t be afraid of being unique - it's like b...
# 16092  "When the achiever achieves, it's not a platea...
# 16093  Enter the "Think Like A Champion" signed book ...
# 16094  "Strive for wholeness and keep your sense of w...
# 16095  Listen to an interview with Donald Trump discu...
# 16096  Miss USA Tara Conner will not be fired - "I've...
# 16097  "My persona will never be that of a wallflower...
# 16098  New Blog Post: Celebrity Apprentice Finale and...
# 16099  Donald Trump reads Top Ten Financial Tips on L...
# 16100  Donald Trump will be appearing on The View tom...
# 16101  Be sure to tune in and watch Donald Trump on L...
#
# [16102 rows x 7 columns]

# %% [markdown]
# ### Read data, concatenate, remove duplicate tweets from update

# %%
# trumptweets = pd.read_json(url, orient='columns', lines=True)
# trumptweetsnu = pd.read_json(urladd, orient='columns', lines=True)
# trumpall = pd.concat([trumptweets, trumptweetsnu]).drop_duplicates('id').sort_values(['created_at'], ascending=False)

# %% [markdown]
# ### Clean up data types in scraped data

# %%
trumpall['retweet'] = trumpall['retweet'].astype(str)
trumpall['video'] = trumpall['video'].astype(str)
trumpall['user_id'] = trumpall['user_id'].astype(str)
trumpall['user_id'] = trumpall['user_id'].astype(str)
trumpall['id'] = trumpall['id'].astype(str)
trumpall['conversation_id'] = trumpall['conversation_id'].astype(str)

# %% [markdown]
# ### Add columns parsing dates to dataframe

# %%
trumpall['year'] = trumpall['date'].dt.year
trumpall['month'] = trumpall['date'].dt.month
trumpall['day'] = trumpall['date'].dt.day

# %% [markdown]
# ### Get GMT time

# %%
trumpall['hour_gmt'] = trumpall['created_at'].dt.hour

# %% [markdown]
# ### Clean them up

# %%
trumpall['year'] = trumpall['year'].astype(str)
trumpall['month'] = trumpall['month'].astype(str)
trumpall['day'] = trumpall['day'].astype(str)
trumpall['hour_gmt'] = trumpall['hour_gmt'].astype(str)

# %% [markdown]
# ### What did he average each day in retweets, likes and replies

# %%
trump_engagements_day = trumpall.groupby(['date']).mean().round(0).reset_index()

# %%
trump_engagements_day
# Out:
#            date  likes_count  replies_count  retweets_count
# 0    2009-05-04        566.0          104.0           266.0
# 1    2009-05-08         22.0            8.0            12.0
# 2    2009-05-12       1016.0           54.0           724.0
# 3    2009-05-13         15.0            9.0            14.0
# 4    2009-05-14         23.0            6.0            17.0
# 5    2009-05-15          7.0            6.0            14.0
# 6    2009-05-16         48.0            9.0            20.0
# 7    2009-05-17         59.0            6.0            32.0
# 8    2009-05-18        101.0           10.0            66.0
# 9    2009-05-19         16.0            2.0            17.0
# 10   2009-05-20         30.0            8.0            18.0
# 11   2009-05-21         41.0           11.0            31.0
# 12   2009-05-22          4.0            5.0            12.0
# 13   2009-05-23         80.0            7.0            53.0
# 14   2009-05-26         62.0            2.0            33.0
# 15   2009-05-27         13.0            5.0             4.0
# 16   2009-05-28         59.0           87.0            60.0
# 17   2009-06-03         21.0            5.0            14.0
# 18   2009-06-05         32.0            2.0            11.0
# 19   2009-06-08          3.0            4.0            10.0
# 20   2009-06-14         16.0           13.0            17.0
# 21   2009-06-15         36.0           15.0            37.0
# 22   2009-06-18         17.0            4.0            20.0
# 23   2009-06-21        134.0            9.0            69.0
# 24   2009-06-23         12.0            4.0            15.0
# 25   2009-06-24         14.0            2.0            27.0
# 26   2009-06-26        229.0           14.0            90.0
# 27   2009-06-30          7.0            4.0             5.0
# 28   2009-07-04         30.0            8.0            25.0
# 29   2009-07-13         30.0            3.0            15.0
# ...         ...          ...            ...             ...
# 2972 2019-07-15     145656.0        26276.0         31690.0
# 2973 2019-07-16     135027.0        25205.0         29637.0
# 2974 2019-07-17     122529.0        17588.0         26612.0
# 2975 2019-07-18      82584.0         8519.0         18983.0
# 2976 2019-07-19     113103.0        11274.0         27387.0
# 2977 2019-07-20      93887.0        13192.0         19513.0
# 2978 2019-07-21     108036.0        16793.0         23099.0
# 2979 2019-07-22      90215.0        14867.0         19704.0
# 2980 2019-07-23      89188.0        11785.0         18268.0
# 2981 2019-07-24      77042.0        13210.0         18919.0
# 2982 2019-07-25     116974.0        12646.0         25717.0
# 2983 2019-07-26     101298.0        14593.0         23603.0
# 2984 2019-07-27      92658.0        16383.0         23235.0
# 2985 2019-07-28     114979.0        18112.0         26045.0
# 2986 2019-07-29      89785.0        10552.0         20256.0
# 2987 2019-07-30      82224.0         7650.0         19589.0
# 2988 2019-07-31      97592.0        13549.0         21585.0
# 2989 2019-08-01      66022.0         6314.0         15152.0
# 2990 2019-08-02     192610.0        25320.0         47862.0
# 2991 2019-08-03      91079.0        17422.0         17852.0
# 2992 2019-08-04     131378.0        25126.0         21914.0
# 2993 2019-08-05      88678.0        20119.0         21115.0
# 2994 2019-08-06      87862.0        21322.0         20519.0
# 2995 2019-08-07      88489.0        14614.0         19336.0
# 2996 2019-08-08      79491.0         8119.0         15865.0
# 2997 2019-08-09     128762.0        25237.0         26514.0
# 2998 2019-08-10     123133.0        23784.0         25698.0
# 2999 2019-08-11      81313.0        14898.0         17584.0
# 3000 2019-08-12      48622.0         8214.0         11973.0
# 3001 2019-08-13      36876.0         6826.0          9879.0
#
# [3002 rows x 4 columns]

# %% [markdown]
# ### Limit data to when Trump took office

# %%
trumpall_prez = trumpall[trumpall.date >= '2017-01-20']

# %% [markdown]
# ### Limit data to month Trump announced candidacy

# %%
trumpall_running = trumpall[trumpall.date >= '2015-06-01']

# %% [markdown]
# ### Count daily tweets since candidacy, create dataframe with results

# %%
trump_tweets_day_candidacy = trumpall_running.groupby(['date']).size()
trump_tweets_day_candidacy_df = pd.DataFrame({'date': trump_tweets_day_candidacy.index, 'count': trump_tweets_day_candidacy.values})

# %% [markdown]
# ### Count daily tweets since inaguration, create dataframe with results

# %%
trump_tweets_day_prez = trumpall_prez.groupby(['date']).size()
trump_tweets_day_prez_df = pd.DataFrame({'date': trump_tweets_day_prez.index, 'count': trump_tweets_day_prez.values})

# %% [markdown]
# ### Sort table to see top days since candidacy

# %%
trump_freq_candidacy = trump_tweets_day_candidacy_df.sort_values(['count'], ascending=False)

# %%
trump_freq_candidacy.head(10)
# Out:
#           date  count
# 132 2015-10-13     95
# 503 2016-10-19     78
# 137 2015-10-18     70
# 110 2015-09-21     67
# 31  2015-07-02     60
# 49  2015-07-20     55
# 348 2016-05-17     54
# 493 2016-10-09     47
# 54  2015-07-25     46
# 148 2015-10-29     46

# %% [markdown]
# ### Sort table to see top days since inauguration

# %%
trump_freq_inauguration = trump_tweets_day_prez_df.sort_values(['count'], ascending=False)

# %%
trump_freq_inauguration.head(10)
# Out:
#           date  count
# 889 2019-07-11     35
# 902 2019-07-24     33
# 890 2019-07-12     28
# 882 2019-07-04     28
# 874 2019-06-26     28
# 916 2019-08-07     25
# 825 2019-05-08     24
# 905 2019-07-27     23
# 922 2019-08-13     23
# 887 2019-07-09     23

# %% [markdown]
# ### Read all from today

# %%
trump_tweets_today = trumpall[trumpall.date == '2019-08-13']

# %% [markdown]
# ### Chart it!

# %%
#bars

lines = alt.Chart(trump_tweets_day_candidacy_df, title = '@realDonaldTrump tweet frequency since candidacy announcement').mark_bar().encode(
    x = alt.X('date:T', axis = alt.Axis(title = '', format = ("%b %y"))),
    y = alt.Y('count:Q',
        scale=alt.Scale(domain=(0, 100)), axis = alt.Axis(tickCount=6, title = 'Daily tweet counts and mean')),
)

#rule showing mean

rule = alt.Chart(trump_tweets_day_candidacy_df).mark_rule(color='red').encode(
    y='mean(count):Q'
)

#rule label -- would like to add "Average: " annotation
text = rule.mark_text(
    align='center',
    baseline='middle',
    dx=200,
    dy=10,
    fontWeight='bold',
).encode(
    text=alt.Text('mean(count):Q', format=".2"))

#go
( lines + rule + text ).properties(height=600,width=800)

# %%
#bars

lines = alt.Chart(trump_freq_inauguration, title = '@realDonaldTrump tweet frequency since inauguration').mark_bar().encode(
    x = alt.X('date:T', axis = alt.Axis(title = '', format = ("%b %y"))),
    y = alt.Y('count:Q',
        scale=alt.Scale(domain=(0, 40)), axis = alt.Axis(tickCount=6, title = 'Daily tweet counts and mean')),
)

#rule showing mean

rule = alt.Chart(trump_freq_inauguration).mark_rule(color='red').encode(
    y='mean(count):Q'
)

#rule label -- would like to add "Average: " annotation
text = rule.mark_text(
    align='center',
    baseline='middle',
    dx=200,
    dy=10,
    fontWeight='bold',
).encode(
    text=alt.Text('mean(count):Q', format=".2"))

#go
( lines + rule + text ).properties(height=600,width=800)
