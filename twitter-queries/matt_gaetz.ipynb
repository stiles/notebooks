# %% [markdown]
# ## Processing tweets

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd
import jenkspy
import matplotlib.pyplot as plt

# %matplotlib inline
import json
import numpy as np
import altair as alt
import altair_latimes as lat

alt.themes.register("latimes", lat.theme)
alt.themes.enable("latimes")
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ### Get the archive

# %%
src = pd.read_json(
    "../../twint/mattgaetz.json",
    convert_dates=["created_at", "date", "time"],
    dtype={"timezone": str},
    date_unit="s",
    lines=True,
)

# %%
src.sort_values("date", ascending=False).head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1377030479136882688  1377030477257773056  2021-03-30 15:50:24 PDT
# 3  1376986940394848261  1376986940394848256  2021-03-30 12:57:24 PDT
# 1  1377030478167937024  1377030477257773056  2021-03-30 15:50:24 PDT
# 2  1377030477257773065  1377030477257773056  2021-03-30 15:50:24 PDT
# 4  1376314658932527115  1376314658932527104  2021-03-28 16:26:00 PDT
#
#          date      time timezone   user_id   username        name place  \
# 0  2021-03-30  15:50:24    -0700  58579942  mattgaetz  Matt Gaetz
# 3  2021-03-30  12:57:24    -0700  58579942  mattgaetz  Matt Gaetz
# 1  2021-03-30  15:50:24    -0700  58579942  mattgaetz  Matt Gaetz
# 2  2021-03-30  15:50:24    -0700  58579942  mattgaetz  Matt Gaetz
# 4  2021-03-28  16:26:00    -0700  58579942  mattgaetz  Matt Gaetz
#
#                                                tweet language mentions  \
# 0  ...of the ongoing extortion investigation.   I...       en       []
# 3  This article identifies me as a “South Florida...       en       []
# 1  ...and my father has even been wearing a wire ...       en       []
# 2  Over the past several weeks my family and I ha...       en       []
# 4  They are executing a wokeification of the mili...       en       []
#
#                                                 urls photos  replies_count  \
# 0                                                 []     []           6243
# 3                                                 []     []           2282
# 1                                                 []     []           4451
# 2                                                 []     []          21417
# 4  [https://www.foxnews.com/politics/matt-gaetz-b...     []            498
#
#    retweets_count  likes_count          hashtags cashtags  \
# 0            4201        19279                []       []
# 3             501         2258  [freemarccaputo]       []
# 1            2985        14148                []       []
# 2            7332        26666                []       []
# 4             959         3707                []       []
#
#                                                 link  retweet  \
# 0  https://twitter.com/mattgaetz/status/137703047...    False
# 3  https://twitter.com/mattgaetz/status/137698694...    False
# 1  https://twitter.com/mattgaetz/status/137703047...    False
# 2  https://twitter.com/mattgaetz/status/137703047...    False
# 4  https://twitter.com/mattgaetz/status/137631465...    False
#
#                                            quote_url  video thumbnail near  \
# 0                                                         0
# 3  https://twitter.com/politico/status/1376972588...      0
# 1                                                         0
# 2                                                         0
# 4                                                         0
#
#   geo source user_rt_id user_rt retweet_id reply_to retweet_date translate  \
# 0                                                []
# 3                                                []
# 1                                                []
# 2                                                []
# 4                                                []
#
#   trans_src trans_dest
# 0
# 3
# 1
# 2
# 4

# %%
len(src)
# Out:
# 7879

# %% [markdown]
# ### Clean up dates ...

# %%
src["date"] = pd.to_datetime(src["date"])
src["year"] = src["date"].dt.year
src["month"] = src["date"].dt.month
src["day"] = src["date"].dt.day

# %% [markdown]
# ### ... and times

# %%
src["time"] = pd.to_datetime(src["time"])
src["hour"] = src["time"].dt.hour
src["minute"] = src["time"].dt.minute
src["time"] = src["time"].dt.time

# %%
src["id"] = src["id"].astype(str)
src["year"] = src["year"].astype(str)
src["month"] = src["month"].astype(str)
src["day"] = src["day"].astype(str)
src["hour"] = src["hour"].astype(str)

# %% [markdown]
# ### Mentions of 'trafficking'

# %%
src[src["tweet"].str.contains("trafficking")][["id", "date", "username", "tweet"]].head(
    20
)
# Out:
#                        id       date   username  \
# 2771  1084912598863228931 2019-01-14  mattgaetz
# 5584   342677915324006400 2013-06-06  mattgaetz
# 5935   287218514660585473 2013-01-04  mattgaetz
# 6605   178135899886989312 2012-03-09  mattgaetz
# 6792   144783751086477312 2011-12-08  mattgaetz
#
#                                                   tweet
# 2771  Dear @GovRonDeSantis - I know you are a stickl...
# 5584  Bondi, FDLE launch new human trafficking train...
# 5935  Crim Justice 2 work on this next week "@fladjj...
# 6605  Great article from @nwfdailynews on our effort...
# 6792  Great to have @PamBondi in the Judiciary Commi...

# %% [markdown]
# ### Mentions of 'Mueller'

# %%
src[src["tweet"].str.contains("Mueller")][["id", "date", "username", "tweet"]].head(20)
# Out:
#                        id       date   username  \
# 325   1340826367370403840 2020-12-20  mattgaetz
# 539   1322246816050675712 2020-10-30  mattgaetz
# 646   1309527927801995264 2020-09-25  mattgaetz
# 692   1305530080001753094 2020-09-14  mattgaetz
# 974   1281624871718588417 2020-07-10  mattgaetz
# 1867  1208987349725650946 2019-12-22  mattgaetz
# 1967  1194701059425476608 2019-11-13  mattgaetz
# 2231  1156377055182884866 2019-07-30  mattgaetz
# 2239  1155965052861632515 2019-07-29  mattgaetz
# 2242  1155246040246829063 2019-07-27  mattgaetz
# 2245  1154623584658219009 2019-07-25  mattgaetz
# 2249  1154127742524432385 2019-07-24  mattgaetz
# 2251  1154115532452483072 2019-07-24  mattgaetz
# 2252  1154111791498170368 2019-07-24  mattgaetz
# 2254  1154094019280084993 2019-07-24  mattgaetz
# 2256  1154058264205770753 2019-07-24  mattgaetz
# 2334  1141739771716427776 2019-06-20  mattgaetz
# 2337  1141530916101210112 2019-06-19  mattgaetz
# 2369  1137007599642038279 2019-06-07  mattgaetz
# 2386  1135623567960399874 2019-06-03  mattgaetz
#
#                                                   tweet
# 325   @MuellerSheWrote I haven’t been vaccined and h...
# 539   Veronica’s Closet had 35 million initial viewe...
# 646   When I said Mueller was out to get Trump in 20...
# 692   The Mueller team obstructed way more justice t...
# 974   I hope John Durham is contact tracing the Muel...
# 1867  Dems: “Trump is a Russian asset” - then Muelle...
# 1967  House Democrats are having such a bad day they...
# 2231  Tonight’s Democratic candidates are making Rob...
# 2239  The dossier itself cites multiple Russian gov’...
# 2242                                  #BringBackMueller
# 2245  @neiman_rockford Certainly more times than Mue...
# 2249  Mueller on Wednesday claimed he was “not famil...
# 2251  The post-Mueller left wing blame game begins b...
# 2252              #MuellerDay   https://t.co/jroafkhaUN
# 2254  “Gaetz was right. Mueller’s entire investigati...
# 2256  .@JerryNadler - Thx for bringing Mueller in to...
# 2334  Basically sums up where we stand #NoCollusion ...
# 2337  How @RepAndyBiggsAZ, @replouiegohmert, @RepDou...
# 2369  Identifying someone as a Russian spy who was a...
# 2386  Couldn’t get Barr.  Couldn’t get McGann.   Cou...

# %%
src.reset_index().to_csv("output/mattgaetz.csv", index=False)
