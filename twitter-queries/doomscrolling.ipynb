# %% [markdown]
# # Processing 'doomscrolling' tweets

# %% [markdown]
# ### Import Python tools and Jupyter configuration

# %%
# %load_ext lab_black

# %%
import pandas as pd
import altair as alt
import altair_latimes as lat
import matplotlib.pyplot as plt
import matplotlib as mpl
from datetime import datetime

# %%
alt.themes.register("latimes", lat.theme)
alt.themes.enable("stiles")
# Out:
# ThemeRegistry.enable('latimes')

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
alt.data_transformers.disable_max_rows()
pd.options.display.max_colwidth = None

# %% [markdown]
# ### Get the archive

# %%
src = pd.read_json(
    "../../twint/doomscrolling.json",
    convert_dates=["created_at", "date", "time"],
    dtype={"timezone": str},
    date_unit="s",
    lines=True,
)

# %%
src.sort_values("date", ascending=False).head()
# Out:
#                      id      conversation_id               created_at  \
# 0   1393179723518316544  1393179723518316544  2021-05-14 05:21:44 PDT
# 25  1393112955345162241  1393112955345162240  2021-05-14 00:56:25 PDT
# 19  1393133948528517125  1393133948528517120  2021-05-14 02:19:51 PDT
# 20  1393130842138972162  1393124244490395648  2021-05-14 02:07:30 PDT
# 21  1393129313885696000  1393129313885696000  2021-05-14 02:01:26 PDT
#
#           date      time timezone              user_id        username  \
# 0   2021-05-14  05:21:44    -0700  1296517517544960001  stopdoomscroll
# 25  2021-05-14  00:56:25    -0700            870603950    defiantsquid
# 19  2021-05-14  02:19:51    -0700  1150726007910891520       gyukaakuu
# 20  2021-05-14  02:07:30    -0700             14539144    witherthorne
# 21  2021-05-14  02:01:26    -0700              5980812  thecultureofme
#
#                                     name place  \
# 0                      stopdoomscrolling
# 25  defiantsquid | Ben Haley fan account
# 19                    doomscrolling lady
# 20                                Dils 🐣
# 21                      MF Doomscrolling
#
#                                                                                                                                                                                                                     tweet  \
# 0                                                                                              Is now really the time dinosaur! Your session of doomscrolling has expired! Maybe you should delete your facebook account!
# 25  Overdid it a bit yesterday with all the zoom meetings, events, VR games and bedtime doomscrolling, so I'm taking things easy with screens today. Might even read a book 🤷‍♂️  Be nice to each other while I'm away! X
# 19                                                                                                                                          Can be too open but also too tertutup at the same time. False communication..
# 20                                                                                                                                                             @AsrolWenger Baring penat lepas masak sambil doomscrolling
# 21                                                                                                                                                                       https://t.co/QHo3niaHBA  https://t.co/tXCNdqoLnB
#
#    language mentions                          urls  \
# 0        en       []                            []
# 25       en       []                            []
# 19       en       []                            []
# 20       in       []                            []
# 21      und       []  [https://go.tcom.co/2QgnpRY]
#
#                                                photos  replies_count  \
# 0                                                  []              0
# 25                                                 []              2
# 19                                                 []              0
# 20                                                 []              0
# 21  [https://pbs.twimg.com/media/E1VjupmXsAIPe6r.jpg]              0
#
#     retweets_count  likes_count hashtags cashtags  \
# 0                0            0       []       []
# 25               0            9       []       []
# 19               0            0       []       []
# 20               0            0       []       []
# 21               0            0       []       []
#
#                                                              link  retweet  \
# 0   https://twitter.com/stopdoomscroll/status/1393179723518316544    False
# 25    https://twitter.com/DefiantSquid/status/1393112955345162241    False
# 19       https://twitter.com/gyukaakuu/status/1393133948528517125    False
# 20    https://twitter.com/witherthorne/status/1393130842138972162    False
# 21  https://twitter.com/thecultureofme/status/1393129313885696000    False
#
#                                                       quote_url  video  \
# 0                                                                    0
# 25                                                                   0
# 19  https://twitter.com/sadiementary/status/1393065081689174018      0
# 20                                                                   0
# 21                                                                   1
#
#                                           thumbnail near geo source  \
# 0
# 25
# 19
# 20
# 21  https://pbs.twimg.com/media/E1VjupmXsAIPe6r.jpg
#
#    user_rt_id user_rt retweet_id  \
# 0
# 25
# 19
# 20
# 21
#
#                                                                 reply_to  \
# 0                                                                     []
# 25                                                                    []
# 19                                                                    []
# 20  [{'screen_name': 'AsrolWenger', 'name': 'Asrol', 'id': '242330827'}]
# 21                                                                    []
#
#    retweet_date translate trans_src trans_dest
# 0
# 25
# 19
# 20
# 21

# %%
len(src)
# Out:
# 108401

# %% [markdown]
# ### Clean up dates ...

# %%
src["date"] = pd.to_datetime(src["date"])
src["year"] = src["date"].dt.year
src["month"] = src["date"].dt.month
src["day"] = src["date"].dt.day

# %% [markdown]
# ### ... and times

# %%
src["time"] = pd.to_datetime(src["time"])
src["hour"] = src["time"].dt.hour
src["minute"] = src["time"].dt.minute
src["time"] = src["time"].dt.time

# %%
src["id"] = src["id"].astype(str)
src["year"] = src["year"].astype(str)
src["month"] = src["month"].astype(str)
src["day"] = src["day"].astype(str)
src["hour"] = src["hour"].astype(str)

# %%
src = src.drop_duplicates(subset="id")

# %%
src.sort_values("retweets_count", ascending=False)[
    ["id", "date", "username", "retweets_count", "tweet"]
].head(10)
# Out:
#                         id       date        username  retweets_count  \
# 82106  1312936187057893377 2020-10-04  matthewamiller           50284
# 38630  1346904164824178690 2021-01-06        q_kingwv           40563
# 34986  1347011666123366402 2021-01-06          faayza           29758
# 30610  1347434641540538368 2021-01-07  ethanjacobslaw           29111
# 34035  1347059063864119301 2021-01-06   kurtkohlstedt           24230
# 37461  1346939675429232640 2021-01-06  nathanallebach           22409
# 98900  1286348333951389696 2020-07-23      catvalente           11890
# 35537  1346991070186532865 2021-01-06       jpbrammer           11620
# 98787  1286496613955862530 2020-07-23   marysuewriter            9495
# 83550  1312003511622815744 2020-10-02          ncroal            5809
#
#                                                                                                                                                                                                                                                                                           tweet
# 82106                                                                                                                                                                                         Elect Joe Biden so you can read books at night again rather than endlessly doomscrolling twitter.
# 38630                                                                                                                                                                                                                               Sorry boss I can't work I am doomscrolling the coup attempt
# 34986                                                                                                                                                             doomscrolling break:  this person trying to do an audition tape while their cat just wants attention  https://t.co/SC282aotCk
# 30610                                                                                                                                                                                                              OK doomscrolling is bad but have you SEEN the quality of the doom this week?
# 34035                                                                                                                                            We interrupt your regularly scheduled doomscrolling to bring you a joyful deer prancing across a beach at sunrise 🦌 🌅  https://t.co/Lnk96yx1f6
# 37461                                                                                                                                                                           🛑 STOP 🛑  you've reached the doomscrolling checkpoint. this is your reminder to take a break from doomscrolling
# 98900                                                                            Every millennial I know is locked in their house doomscrolling &amp; baking bread while their parents think masks are poisonous gay 5g tools of the new world order and getting haircuts at Applebees but sure
# 35537                                                                                                                                                                                                                                               I'm not "doomscrolling" I just live in hell
# 98787  what’s dangerous about doomscrolling is that repeated emphasis on the importance of staying informed can easily trick you into thinking that endlessly consuming bad news on autopilot is a progressive moral duty, when in actuality it’s the digital equivalent of emotional self-harm
# 83550                                                                                                                                                                                                                                       TIL the opposite of doomscrolling is schadensurfing

# %% [markdown]
# ### Users who've mentioned it the most?

# %%
count = src.groupby("username")["id"].size().reset_index(name="tweets")

# %%
count.sort_values("tweets", ascending=False).head(20)
# Out:
#               username  tweets
# 54240     nodoomscroll    1157
# 69797   stopdoomscroll     912
# 38779         karenkho     608
# 72670   thecultureofme     317
# 10859      brian_pelts     121
# 8360         bee_k_bee     104
# 59789       rachaelp95     104
# 79646     writerly_dee      97
# 49822  mindfulness_for      81
# 41375     kristaldixon      54
# 29000        gyukaakuu      51
# 76096     tweetledee2b      47
# 40540      kindnesssee      46
# 238      2bappreciator      45
# 22655     ellemagazine      42
# 12799   casualmonolith      39
# 41476   kropotkinpetyr      38
# 4267   americanstudier      36
# 46515         mapscats      31
# 28291        grade_bot      31

# %% [markdown]
# ### How many times has the question been posed?

# %%
len(src[src["tweet"].str.contains("are you doomscrolling?")])
# Out:
# 307

# %% [markdown]
# ### Featuring @karenkho

# %%
src[src["username"] == "karenkho"][["id", "date", "username", "tweet"]].head(20)
# Out:
#                        id       date  username  \
# 56    1393040397602017281 2021-05-13  karenkho
# 307   1392705739618242563 2021-05-12  karenkho
# 544   1392342134863368192 2021-05-11  karenkho
# 800   1391974300077416448 2021-05-10  karenkho
# 1084  1391594903214477313 2021-05-09  karenkho
# 1099  1391575191067693058 2021-05-09  karenkho
# 1287  1391233213855584257 2021-05-08  karenkho
# 1499  1390881349049925633 2021-05-07  karenkho
# 1673  1390672887892353029 2021-05-07  karenkho
# 1745  1390528281208934405 2021-05-06  karenkho
# 1970  1390153840591245315 2021-05-05  karenkho
# 2106  1389816559561056256 2021-05-04  karenkho
# 2118  1389794671149428737 2021-05-04  karenkho
# 2263  1389414114867429377 2021-05-03  karenkho
# 2363  1389085803918266373 2021-05-02  karenkho
# 2377  1389055959843184642 2021-05-02  karenkho
# 2475  1388722865030246402 2021-05-01  karenkho
# 2487  1388700351499542528 2021-05-01  karenkho
# 2532  1388562190165217294 2021-05-01  karenkho
# 2592  1388357732084879362 2021-04-30  karenkho
#
#                                                                                                                                                                                                                                                                             tweet
# 56                                                                                       what if instead of a doomscrolling reminder, I just told all of you it's important to write a to-list, moisturize regularly, go to sleep early, and charge your phone away from your bed
# 307                                                                                                                                                                                                                                              Hi, are you still doomscrolling?
# 544                                                                                                                                                                                                                                              Hi, are you still doomscrolling?
# 800                                                                                                                                                                                                                                                    Hi, are you doomscrolling?
# 1084                                                                                                                                                                                                                                                   Hi, are you doomscrolling?
# 1099                                                                                                                                           instead of a doomscrolling reminder, I'm just going to encourage you to go to sleep early tonight. You deserve extra time to rest.
# 1287                                                                                                                                                                                                                                                   Hi, are you doomscrolling?
# 1499                                                                                                                                                                                                                                                   Hi, are you doomscrolling?
# 1673                                                                                                 I lost count of this phenomenon last year due to all the doomscrolling tweets but I also gained 28k followers (to which my sister asked, "do you make any money from that?")
# 1745                                                                                                                                                                                                                                             hi, are you still doomscrolling?
# 1970                                                                                                                                                                                                                                                   hi, are you doomscrolling?
# 2106                                                                                                                                                              creams are expensive but you only have one face so keep moisturizing daily and stop doomscrolling for the night
# 2118                         Hi, are you doomscrolling? It's "grab your favorite book and start winding down" or "settle into bed" time. This website continues to be full of bad opinions and will still be here tomorrow. Give your eyes a break for the night. You deserve it.
# 2263  hi, are you doomscrolling?  A lot of heated debates and arguments on this website today. How about taking a hot shower and going to bed early tonight? Taking care of yourself always makes you feel better and helps give you more energy to tackle tomorrow's challenges.
# 2363                                                                                                                                                                                                                                             Hi, are you still doomscrolling?
# 2377                                                      hi, are you doomscrolling?  This website doesn't need more of your attention tonight. Apply a sheet mask, take a hot shower, read a fun book, and try to go to sleep early. You still deserve time to reflect and rest.
# 2475                                                                                                                                                                                                                                             Hi, are you still doomscrolling?
# 2487     I don't know if I should keep writing the doomscrolling reminders the same way, but try to take care of yourself tonight. Do something that helps rest your eyes and mind, like a hot bath, a great book, or a few stretches before bed. You still deserve time to rest.
# 2532                                                              hi! Are you doomscrolling? Lack of structure on weekends can be unmooring. Why not take a walk outside if you can, or do another activity that gives you joy? Don't forget to drink a big glass of water today.
# 2592                                                                                                                                                                        If you're still doomscrolling, I get it. Try not to stay up too late. You still deserve time to rest.

# %% [markdown]
# ---

# %% [markdown]
# ### Export

# %%
src.reset_index().to_csv("output/doomscrolling.csv", index=False)

# %%
src[src["username"] == "karenkho"].reset_index().to_csv(
    "output/karenkho.csv", index=False
)
