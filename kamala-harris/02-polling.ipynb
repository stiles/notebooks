# %% [markdown]
# # Kamala Harris polls

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd
import altair as alt
import altair_latimes as lat
import glob
import os
import numpy as np

# %%
alt.themes.register("latimes", lat.theme)
alt.themes.enable("latimes")
pd.options.display.max_columns = 50
pd.options.display.max_rows = 1000
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ### Grab the latest polls from RealClearPolitics

# %%
url = "https://www.realclearpolitics.com/epolls/other/kamala_harris_favorableunfavorable-6690.html#polls"

# %%
wayback = 'http://web.archive.org/cdx/search/cdx?url=https://www.realclearpolitics.com/epolls/other/kamala_harris_favorableunfavorable-6690.html&output=json'

# %%
src = pd.read_html(url)

# %%
latest_polls = src[0]

# %%
all_polls = src[1]

# %%
all_polls
# Out:
#                                     Poll           Date    Sample  Favorable  \
# 0                            RCP Average     4/18 - 5/4        --       48.3
# 1                 Economist/YouGovYouGov      5/1 - 5/4   1187 RV       44.0
# 2       Politico/Morning ConsultPolitico     4/30 - 5/3   1991 RV       50.0
# 3                   Harvard-HarrisHarris    4/27 - 4/29   1872 RV       50.0
# 4                 Economist/YouGovYouGov    4/25 - 4/27   1219 RV       47.0
# 5       Politico/Morning ConsultPolitico    4/24 - 4/26   1991 RV       52.0
# 6                       FOX NewsFOX News    4/18 - 4/21   1002 RV       49.0
# 7                 Economist/YouGovYouGov    4/17 - 4/20   1225 RV       47.0
# 8                 Economist/YouGovYouGov    4/10 - 4/13   1263 RV       47.0
# 9       Politico/Morning ConsultPolitico     4/9 - 4/12   1992 RV       51.0
# 10                Economist/YouGovYouGov      4/3 - 4/6   1243 RV       48.0
# ...
